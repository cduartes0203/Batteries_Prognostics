# %% [markdown]
# RNN - Erro dos pesos computados e usado somente durante a iteração

# %%
import numpy as np
from numpy import linalg as LA
import pandas as pd
import operator as op
import ipynbname
import math
import matplotlib.cm as cm
import optuna
from optuna.samplers import RandomSampler
from optuna.samplers import TPESampler
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_pareto_front
from optuna.importance import get_param_importances
from optuna.exceptions import TrialPruned
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import matplotlib as mpl
#from Testing.RTLO import *
from Functions.RLS import *
from Functions.Utils_RTLO import *
from Functions.Graphs import *
from sklearn.metrics import root_mean_squared_error as RMSE
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.metrics import mean_squared_error as MSE

FileName = ipynbname.name()

params = [14, 12, 2, 0.01, 1e-08, 0.0001, 2]
df = pd.read_csv(r'Dataset\Bearing1_1.csv')
sig = df['PC1'].values

def PlotPredError(rtlo,w=9,h=3):
    s = len(rtlo.yWAPE)
    t = rtlo.t
    fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(w, h))
    axes = axes.flatten()
    ax1,ax2,ax3,ax4 = axes[0], axes[1], axes[2], axes[3]

    ax1.plot(t, rtlo.yR, color='black',label='Y-Real', linestyle='-')
    ax1.plot(t, rtlo.yP, color='blue',label='Y-Pred', linestyle='-')
    ax1.plot(t, rtlo.yL, color='blue', linestyle='--')
    ax1.plot(t, rtlo.yU, color='blue', linestyle='--')
    
    ax1.set_title('Y - Real x Prediction')
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y', color='black')
    ax1.legend()

    ax2.plot(t, rtlo.eR, color='black',label='e-Real', linestyle='-')
    ax2.plot(t, rtlo.eP, color='blue',label='e-Pred', linestyle='-')
    ax2.set_title('Error - Real x Prediction')
    ax2.set_xlabel('X')
    ax2.set_ylabel('Prediction Error', color='black') 
    ax2.legend()
    
    ax3.plot(t[-s:], rtlo.yWAPE, color='blue',label='WAPE', linestyle='-')
    ax3.set_title('Prediction WAPE')
    ax3.set_xlabel('X')
    ax3.set_ylabel('WAPE', color='black') 

    '''ax4.plot(t[-s:], rtlo.rWAPE, color='blue',label='WAPE', linestyle='-')
    ax4.set_title('RUL Prediction WAPE')
    ax4.set_xlabel('X')
    ax4.set_ylabel('WAPE', color='black') '''

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()

def PlotPredErrorPLY(rtlo, w=800, h=300):
    # s: tamanho do vetor WAPE (caso comece depois do início)
    t = rtlo.t
    
    # Criando o layout de 1 linha e 4 colunas
    fig = make_subplots(
        rows=1, cols=3, 
        shared_xaxes=True,
        subplot_titles=('Y - Real x Prediction', 'RUL - Real x Pred', 'Error - Real x Pred', 'Prediction WAPE', 'RUL Prediction WAPE')
    )

    # --- Subplot 1: Y Real x Pred (com Intervalos) ---
    fig.add_trace(go.Scatter(x=t, y=rtlo.yR, name='Y-Real', line=dict(color='black')), row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=rtlo.yP, name='Y-Pred', line=dict(color='blue')), row=1, col=1)
    # Intervalos (Dashed)
    fig.add_trace(go.Scatter(x=t, y=rtlo.yL, name='y-Lower', line=dict(color='blue', dash='dash'), showlegend=False), row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=rtlo.yU, name='y-Upper', line=dict(color='blue', dash='dash'), showlegend=False), row=1, col=1)

    fig.add_trace(go.Scatter(x=t, y=rtlo.rulR, name='rul R', line=dict(color='black'), showlegend=True), row=1, col=2)
    fig.add_trace(go.Scatter(x=t, y=rtlo.rulP, name='rul P', line=dict(color='blue'), showlegend=True), row=1, col=2)
    fig.add_trace(go.Scatter(x=t, y=rtlo.rulL, name='rul L', line=dict(color='red'), showlegend=True), row=1, col=2)
    fig.add_trace(go.Scatter(x=t, y=rtlo.rulU, name='rul U', line=dict(color='green'), showlegend=True), row=1, col=2)

    #fig.add_trace(go.Scatter(x=t, y=rtlo.εM_hist, name='rul R', line=dict(color='black'), showlegend=False), row=1, col=3)
    fig.add_trace(go.Scatter(x=t, y=rtlo.eR, name='erro R', line=dict(color='black')), row=1, col=3)
    fig.add_trace(go.Scatter(x=t, y=rtlo.eP, name='erro P', line=dict(color='blue')), row=1, col=3)

    # Atualizando Layout e Eixos
    fig.update_layout(
        width=w, height=h,
        title_text=f"RTLO Model Performance Analysis",
        template='plotly_white',
        showlegend=True,
        margin=dict(l=40, r=40, t=80, b=40)
    )

    # Labels dos eixos (opcional, já que os títulos ajudam)
    fig.update_xaxes(title_text="Time / Index")
    fig.update_yaxes(title_text="Amplitude", col=1)
    fig.update_yaxes(title_text="Error", col=2)

    fig.show()
    
def SelSampler(mode='auto'):
    '''mode: auto, random,  tpe'''
    if mode == 'auto':
        sampler = None
    elif mode == 'tpe':
        sampler = optuna.samplers.TPESampler(multivariate=True, constant_linker=True,group=True,n_startup_trials=2000)
    elif mode == 'random':
        sampler=RandomSampler()
    return sampler

# %%
class RTLO:
    def __init__(self, nI,nR,nO,ηS=[0.1,0.1,0.1], τ=10,lr=1e-5):
        np.random.seed(42)
        self.k = 1
        self.j = nI-1
        self.t = np.array([])
        self.ref = None
        self.act = 'relu'
        self.nI, self.nR, self.nO = nI, nR, nO

        self.ηS = np.array(ηS)
        self.τ = τ
        self.ρ = 0.001

        self.xPi = np.zeros(nI)
        self.hP, self.hU, self.hL = [np.zeros(nR) for i in range(3)]

        self.pS = np.zeros((self.nR, self.nR))
        self.qS = np.zeros((self.nR, self.nI))

        self.ΔOS = np.zeros((nO, nR))
        self.ΔRS = np.zeros((nR, nR))
        self.ΔIS = np.zeros((nR, nI))
        
        self.wI = XavierUniform([nR, nI],sd=42)
        self.wR = XavierUniform([nR, nR],sd=41)
        self.wO = XavierUniform([nO, nR],sd=40)
        self.BS = XavierUniform([nR, nO],sd=39)

        self.rls = RLS_LogarithmicRegressor(0.95,1e7)
        
        self.yP, self.yR, self.yL, self.yU = [np.array([]) for i in range(4)]
        self.yP_hist = np.zeros(self.nI)
        self.eS = np.zeros(nI)
        self.eS2 = np.zeros(nI)
        self.eP = np.array([])
        self.eR = np.array([])

        self.εY, self.εM, self.εE, self.εR, self.ΣW = [0 for i in range(5)]
        self.εM_hist = np.array([])
        self.εR_hist = np.array([])

        self.μrWAPE = 0
        self.MPsum = 0

        self.rR = 1e-9
        self.rP = 1e-10
        self.rL = 1e-11
        self.rU = 1e-12
        self.rRsum = 0

        self.rulR, self.rulP, self.rulL, self.rulU = [np.array([]) for i in range(4)]


    def PredSingle(self,x):

        u = np.dot(self.wR, self.hS) + np.dot(self.wI, x)
        h = self.hS + (-self.hS + Activation(u,self.act))/self.τ
        y = np.dot(self.wO, h)

        return y

    def fit(self,xP,yR,store=False,show=False):

        exp=2
        W = self.j**exp
        η1,η2,η3 = self.ηS        
        #print('fit self.hP:',self.hP[-5:])
        uS = self.wR @ self.hP + self.wI @ xP
        #hP = self.hP + (-self.hP + Activation(uS,self.act))/self.τ
        hP = self.hP*(1-1/self.τ) +Activation(uS,self.act)/self.τ
        yP = self.wO @ hP
        eS = yR-yP

        if show: 
            #print('yR:',yR)
            #print('xP:',xP)
            print('fit  yP:',yP[0])
            #print('fit  hP:',self.hP)
            #print('fit  hP2:',hP)
            #print('fit xP:',xP)
            #print('fit uP:',uS)
            #print('fit  wR:\n',self.wR)
            #print('fit  wI\n:',self.wI)
            #print('fit  wO\n:',self.wO)

        self.pS = np.outer(dActivation(uS,self.act),self.hP)/self.τ + (1-1/self.τ)*self.pS
        self.qS = np.outer(dActivation(uS,self.act),self.xPi)/self.τ + (1-1/self.τ)*self.qS

        δOS = η1*np.outer(eS,hP)
        δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
        δIS = η3*np.outer(np.dot(self.BS, eS),np.ones(self.nI))*self.qS

        self.ΔIS = (self.ΔIS*(self.k-1) + δIS)/self.k
        self.ΔRS = (self.ΔRS*(self.k-1) + δRS)/self.k
        self.ΔOS = (self.ΔOS*(self.k-1) + δOS)/self.k

        self.wI = self.wI + δIS
        self.wR = self.wR + δRS
        self.wO = self.wO + δOS

        self.hP = hP
        self.xPi = xP

        #self.UpdateRLS(yP,yR)

        ΣW = self.ΣW + W
        ΔY = np.abs((yR-yP)/yR)
        ΔM = np.linalg.norm(ΔY,ord=2)
        ΔR = np.abs((self.rR-self.rP)/(self.rR+1e-9))
        #ΔE = np.abs((self.eR[-1]-self.eP[-1])/self.eR[-1])

        self.εY = ((self.εY*self.ΣW) + (W*ΔY[0]))/ΣW
        self.εM = ((self.εM*self.ΣW) + (W*ΔM))/ΣW
        self.εR = ((self.εR*self.ΣW) + (W*ΔR))/ΣW
        #self.εE = ((self.εE*self.ΣW) + (W*ΔE))/ΣW
        self.ΣW = ΣW

        if store:
            self.yR = np.append(self.yR,yR[0])
            self.εM_hist = np.append(self.εM_hist,self.εM)
            self.εR_hist = np.append(self.εR_hist,self.εR)

        self.k = self.k+1
        self.j = self.j+1
        self.t = np.append(self.t,self.k + self.nI)
        self.yP_hist = np.delete(np.append(self.yP_hist,yP[0]),0)
        #self.ηS = self.ηS/(1 + self.decay*self.k)


    def PredRulIntr(self, x,lim=0.2,maxRul=110,store=False,show=False):
        #print('yH:',self.yP_hist)
        #print('eS: ',self.eS)

        for i,y in enumerate(self.yP_hist):
            if y != 0:
                self.eS2[i] = self.rls.predict(np.abs(y))
        #print('eS2:',self.eS2)

        xP,xL,xU =x.copy(), (x-(self.ρ*self.eS2)).copy(),(x+(self.ρ*self.eS2)).copy()    

        #xP,xL,xU =x.copy(), x.copy()*0.999, x.copy()*1.00

        predict = True
        PredRuls = [True for i in range(3)]
        PredVals, Ruls = [0 for i in range(3)], [0 for i in range(3)]
        wR,wI,wO = self.wR,self.wI,self.wO

        wRp, wRn = np.maximum(0, self.wR), np.abs(np.minimum(0, self.wR))
        wIp, wIn = np.maximum(0, self.wI), np.abs(np.minimum(0, self.wI))
        wOp, wOn = np.maximum(0, self.wO), np.abs(np.minimum(0, self.wO))
        #hU,hL = np.maximum(0, self.hS), np.minimum(0, self.hS)
        hL,hP,hU = [self.hP.copy() for i in range(3)]

        while predict:
            uP = wR@hP + wI@xP
            uL = (wRp @ hL - wRn @ hU) + (wIp @ xL - wIn @ xU)
            uU = (wRp @ hU - wRn @ hL) + (wIp @ xU - wIn @ xL)

            hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
            hL = hL*(1-1/self.τ) + Activation(uL,self.act)/self.τ
            hU = hU*(1-1/self.τ) + Activation(uU,self.act)/self.τ
    
            yP = (wO@hP)
            yL = (wOp @ hL - wOn @ hU)
            yU = (wOp @ hU - wOn @ hL)

            #if show: print(yP)
            yP = yP[0]
            yL = yL[0]
            yU = yU[0]

            xP = np.delete(np.append(xP,yP),0)
            xL = np.delete(np.append(xL,yL),0)
            xU = np.delete(np.append(xU,yU),0)
            PredVals = [yL,yP,yU]

            if Ruls[0] == 0:
                self.yL = np.append(self.yL,yL)
                self.yP = np.append(self.yP,yP)
                self.yU = np.append(self.yU,yU)
            
            CheckPred,CheckLim=0,0
            for i in range(3):
                if PredRuls[i]: 
                    Ruls[i] = Ruls[i]+1
                    if Ruls[i] >= maxRul:
                        CheckLim = CheckLim + 1
                        Ruls[i] = maxRul
                        PredRuls[i] = False
                if PredVals[i] < lim: PredRuls[i] = False
                if not PredRuls[i]: CheckPred = CheckPred + 1
            if CheckPred == 3:break
            if CheckLim == 3:break
        
        self.rR=self.ref-self.k
        self.rL,self.rP,self.rU = Ruls

        if store:
            self.rulR = np.append(self.rulR,self.rR)
            self.rulL = np.append(self.rulL,self.rL)
            self.rulP = np.append(self.rulP,self.rP)
            self.rulU = np.append(self.rulU,self.rU)
    
    def PredRulIntr2(self, x,lim=0.2,maxRul=110,store=False,show=False):
        #print('yH:',self.yP_hist)
        #print('eS: ',self.eS)

        for i,y in enumerate(self.yP_hist):
            if y != 0:
                self.eS2[i] = self.rls.predict(np.abs(y))
        #print('eS2:',self.eS2)

        xP,xL,xU =x.copy(), (x-(self.ρ*self.eS2)).copy(),(x+(self.ρ*self.eS2)).copy()    

        #xP,xL,xU =x.copy(), x.copy()*0.999, x.copy()*1.00

        predict = True
        PredRuls = [True for i in range(3)]
        PredVals, Ruls = [0 for i in range(3)], [0 for i in range(3)]
        wR,wI,wO = self.wR,self.wI,self.wO
        ep = 0.125
        wRp, wRn = np.maximum((1+ep)*wR, (1-ep)*wR), np.minimum((1+ep)*wR, (1-ep)*wR)

        print('wRn',wRn[0][:5])
        print('wR ',wR[0][:5])
        print('wRp',wRp[0][:5])
        print('---')

        wIp, wIn = np.maximum((1+ep)*wI, (1-ep)*wI), np.minimum((1+ep)*wI, (1-ep)*wI)
        wOp, wOn = np.maximum((1+ep)*wO, (1-ep)*wO), np.minimum((1+ep)*wO, (1-ep)*wO)

        #hU,hL = np.maximum(0, self.hS), np.minimum(0, self.hS)
        #hL,hP,hU = (1-ep)*self.hP.copy(),self.hP.copy(),(1+ep)*self.hP.copy()  
        hP = self.hP.copy()  
        hU, hL = np.maximum((1+ep)*hP, (1-ep)*hP), np.minimum((1+ep)*hP, (1-ep)*hP)

        while predict:
            uP = wR@hP + wI@xP
            uL = (wRn @ hL) + (wIn @ xL)
            uU = (wRp @ hU) + (wIp @ xU)

            hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
            hL = hL*(1-1/self.τ) + Activation(uL,self.act)/self.τ
            hU = hU*(1-1/self.τ) + Activation(uU,self.act)/self.τ
    
            yP = (wO@hP)[0]
            yL = (wOn @ hL)[0]
            yU = (wOp @ hU)[0]

            PredVals = sorted([yL,yP,yU])

            yL,yP,yU = PredVals

            xP = np.delete(np.append(xP,yP),0)
            xL = np.delete(np.append(xL,yL),0)
            xU = np.delete(np.append(xU,yU),0)

            if Ruls[0] == 0:
                self.yL = np.append(self.yL,yL)
                self.yP = np.append(self.yP,yP)
                self.yU = np.append(self.yU,yU)
            
            CheckPred,CheckLim=0,0
            for i in range(3):
                if PredRuls[i]: 
                    Ruls[i] = Ruls[i]+1
                    if Ruls[i] >= maxRul:
                        CheckLim = CheckLim + 1
                        Ruls[i] = maxRul
                        PredRuls[i] = False
                if PredVals[i] < lim: PredRuls[i] = False
                if not PredRuls[i]: CheckPred = CheckPred + 1
            if CheckPred == 3:break
            if CheckLim == 3:break
        
        self.rR=self.ref-self.k
        self.rL,self.rP,self.rU = Ruls

        if store:
            self.rulR = np.append(self.rulR,self.rR)
            self.rulL = np.append(self.rulL,self.rL)
            self.rulP = np.append(self.rulP,self.rP)
            self.rulU = np.append(self.rulU,self.rU)
    
    def PredRul(self, x,maxRul=100,lim=0.2,store=False):
        xP = x.copy()
        rulP=0
        predict = True
        hP = self.hP.copy()
        while predict:
            uP = (self.wR @ hP) + (self.wI @ xP)
            hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
            yP = (self.wO @ hP)[0]
            xP = np.delete(np.append(xP,yP),0)
            if store:
                if rulP==0:
                    self.yP = np.append(self.yP,yP)

            if predict: rulP = rulP+1
            if yP < lim: predict = False
            if rulP >= maxRul:
                break

        self.rR=self.ref-self.k
        self.rP = rulP

        if store:
            self.rulR = np.append(self.rulR,self.rR)
            self.rulP = np.append(self.rulP,self.rP)
            
    
    def UpdateRLS(self,yP,yR):
        eP = np.abs(self.rls.predict(np.abs(yP[0])))
        eR = np.abs(yP-yR)[0]
        self.rls.update(np.abs(yP[0]), eR)
        self.eR = np.append(self.eR,eR)
        self.eP = np.append(self.eP,eP)
        self.eS = np.append(self.eS,eP)
        self.eS = np.delete(self.eS,0)

# %% [markdown]
# #Optimize parameters for minimize error of degradation prediction

# %%
rates = [1/(10**i) for i in range(1,7)][::-1]
def objective(trial):

    nI = trial.suggest_int('nI', 10, 22) 
    nR = trial.suggest_int('nR', 27, 45) 
    nO = trial.suggest_int('nO', 1, 1) 
    N1 = trial.suggest_categorical('N1', rates[2:]) 
    N2 = trial.suggest_categorical('N2', rates[:-1]) 
    N3 = trial.suggest_categorical('N3', rates[:-1]) 
    τ = trial.suggest_int('τ', 1, 20)        
    X,Y = PrepareDataAhead(sig,n=nI,m=nO)
    X,Y = X[:-1],Y[:-1]
    rnn = RTLO(nI,nR,nO,[N1,N2,N3],τ)
    rnn.ref = len(sig)-nI
    cont = 0
    for i,_ in enumerate(X):
        rnn.PredRul(X[i],maxRul=len(sig)-nI,store=True)
        rnn.fit(X[i],Y[i],store=True)

        if i == 50:
            if np.mean(rnn.εM_hist)>1:
                raise TrialPruned()
            if np.mean(rnn.rulP)>np.mean(rnn.rulR)*1.1:
                raise TrialPruned()
            if np.mean(rnn.rulP)<np.mean(rnn.rulR)*0.3:
                raise TrialPruned()
        if i>=40:
            if rnn.rulP[i]==rnn.rulP[i-1]:
                cont = cont+1
            if cont> 20:
                raise TrialPruned()

        '''if i % 20 == 0:  # Report every 10 time steps
            trial.report(rnn.εM, step=i)
            if trial.should_prune():
                raise optuna.TrialPruned()'''
            
    return rnn.εM*rnn.εR

#pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
pruner=optuna.pruners.HyperbandPruner()
study = optuna.create_study(
    direction="minimize",
    sampler=SelSampler(mode='auto'),
    pruner=pruner,
    #storage="sqlite:///" + f'Optuna/{FileName}_Prdct.db', study_name=f'P{4}',
    load_if_exists=True)
study.optimize(objective, n_trials=4000)
params = list(study.best_params.values())
print('Erro:', study.best_value, 'parameters: ', params)
# Out:
# [I 2026-04-23 14:44:26,242] A new study created in memory with name: no-name-54cc1ad1-565b-4a11-ac6e-634e21d0bae4
# [I 2026-04-23 14:44:26,248] Trial 0 pruned.
# [I 2026-04-23 14:44:26,299] Trial 1 pruned.
# [I 2026-04-23 14:44:26,311] Trial 2 pruned.
# [I 2026-04-23 14:44:26,367] Trial 3 pruned.
# [I 2026-04-23 14:44:26,436] Trial 4 finished with value: 1.0378059385314566 and parameters: {'nI': 12, 'nR': 31, 'nO': 1, 'N1': 0.0001, 'N2': 1e-06, 'N3': 1e-05, 'τ': 13}. Best is trial 4 with value: 1.0378059385314566.
# [I 2026-04-23 14:44:26,490] Trial 5 pruned.
# [I 2026-04-23 14:44:26,540] Trial 6 pruned.
# [I 2026-04-23 14:44:26,590] Trial 7 pruned.
# [I 2026-04-23 14:44:26,644] Trial 8 pruned.
# [I 2026-04-23 14:44:26,695] Trial 9 pruned.
# [I 2026-04-23 14:44:26,747] Trial 10 pruned.
# [I 2026-04-23 14:44:26,755] Trial 11 pruned.
# [I 2026-04-23 14:44:26,764] Trial 12 pruned.
# [I 2026-04-23 14:44:26,822] Trial 13 pruned.
# [I 2026-04-23 14:44:26,873] Trial 14 pruned.
# [I 2026-04-23 14:44:26,884] Trial 15 pruned.
# [I 2026-04-23 14:44:26,890] Trial 16 pruned.
# [I 2026-04-23 14:44:26,942] Trial 17 pruned.
# [I 2026-04-23 14:44:26,948] Trial 18 pruned.
# [I 2026-04-23 14:44:26,959] Trial 19 pruned.
# [I 2026-04-23 14:44:27,014] Trial 20 pruned.
# [I 2026-04-23 14:44:27,078] Trial 21 pruned.
# [I 2026-04-23 14:44:27,136] Trial 22 pruned.
# [I 2026-04-23 14:44:27,191] Trial 23 pruned.
# [I 2026-04-23 14:44:27,252] Trial 24 pruned.
# [I 2026-04-23 14:44:27,306] Trial 25 pruned.
# [I 2026-04-23 14:44:27,365] Trial 26 pruned.
# [I 2026-04-23 14:44:27,378] Trial 27 pruned.
# [I 2026-04-23 14:44:27,425] Trial 28 pruned.
# [I 2026-04-23 14:44:27,481] Trial 29 pruned.
# [I 2026-04-23 14:44:27,544] Trial 30 pruned.
# [I 2026-04-23 14:44:27,555] Trial 31 pruned.
# [I 2026-04-23 14:44:27,611] Trial 32 pruned.
# [I 2026-04-23 14:44:27,664] Trial 33 pruned.
# [I 2026-04-23 14:44:27,723] Trial 34 pruned.
# [I 2026-04-23 14:44:27,756] Trial 35 pruned.
# [I 2026-04-23 14:44:27,814] Trial 36 pruned.
# [I 2026-04-23 14:44:27,887] Trial 37 finished with value: 1.0295592371258222 and parameters: {'nI': 10, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-05, 'τ': 12}. Best is trial 37 with value: 1.0295592371258222.
# [I 2026-04-23 14:44:27,952] Trial 38 pruned.
# [I 2026-04-23 14:44:28,011] Trial 39 pruned.
# [I 2026-04-23 14:44:28,075] Trial 40 pruned.
# [I 2026-04-23 14:44:28,085] Trial 41 pruned.
# [I 2026-04-23 14:44:28,139] Trial 42 pruned.
# [I 2026-04-23 14:44:28,147] Trial 43 pruned.
# [I 2026-04-23 14:44:28,196] Trial 44 pruned.
# [I 2026-04-23 14:44:28,251] Trial 45 pruned.
# [I 2026-04-23 14:44:28,260] Trial 46 pruned.
# [I 2026-04-23 14:44:28,267] Trial 47 pruned.
# [I 2026-04-23 14:44:28,331] Trial 48 pruned.
# [I 2026-04-23 14:44:28,344] Trial 49 pruned.
# [I 2026-04-23 14:44:28,354] Trial 50 pruned.
# [I 2026-04-23 14:44:28,407] Trial 51 pruned.
# [I 2026-04-23 14:44:28,463] Trial 52 pruned.
# [I 2026-04-23 14:44:28,522] Trial 53 pruned.
# [I 2026-04-23 14:44:28,577] Trial 54 pruned.
# [I 2026-04-23 14:44:28,637] Trial 55 pruned.
# [I 2026-04-23 14:44:28,694] Trial 56 pruned.
# [I 2026-04-23 14:44:28,754] Trial 57 pruned.
# [I 2026-04-23 14:44:28,764] Trial 58 pruned.
# [I 2026-04-23 14:44:28,823] Trial 59 pruned.
# [I 2026-04-23 14:44:28,881] Trial 60 pruned.
# [I 2026-04-23 14:44:28,938] Trial 61 pruned.
# [I 2026-04-23 14:44:28,992] Trial 62 pruned.
# [I 2026-04-23 14:44:29,044] Trial 63 pruned.
# [I 2026-04-23 14:44:29,098] Trial 64 pruned.
# [I 2026-04-23 14:44:29,152] Trial 65 pruned.
# [I 2026-04-23 14:44:29,219] Trial 66 pruned.
# [I 2026-04-23 14:44:29,273] Trial 67 pruned.
# [I 2026-04-23 14:44:29,326] Trial 68 pruned.
# [I 2026-04-23 14:44:29,381] Trial 69 pruned.
# [I 2026-04-23 14:44:29,390] Trial 70 pruned.
# [I 2026-04-23 14:44:29,447] Trial 71 pruned.
# [I 2026-04-23 14:44:29,502] Trial 72 pruned.
# [I 2026-04-23 14:44:29,561] Trial 73 pruned.
# [I 2026-04-23 14:44:29,615] Trial 74 pruned.
# [I 2026-04-23 14:44:29,631] Trial 75 pruned.
# [I 2026-04-23 14:44:29,686] Trial 76 pruned.
# [I 2026-04-23 14:44:29,697] Trial 77 pruned.
# [I 2026-04-23 14:44:29,753] Trial 78 pruned.
# [I 2026-04-23 14:44:29,815] Trial 79 pruned.
# [I 2026-04-23 14:44:29,824] Trial 80 pruned.
# [I 2026-04-23 14:44:29,881] Trial 81 pruned.
# [I 2026-04-23 14:44:29,934] Trial 82 pruned.
# [I 2026-04-23 14:44:29,943] Trial 83 pruned.
# [I 2026-04-23 14:44:29,981] Trial 84 pruned.
# [I 2026-04-23 14:44:30,042] Trial 85 pruned.
# [I 2026-04-23 14:44:30,052] Trial 86 pruned.
# [I 2026-04-23 14:44:30,109] Trial 87 pruned.
# [I 2026-04-23 14:44:30,166] Trial 88 pruned.
# [I 2026-04-23 14:44:30,204] Trial 89 pruned.
# [I 2026-04-23 14:44:30,266] Trial 90 pruned.
# [I 2026-04-23 14:44:30,285] Trial 91 pruned.
# [I 2026-04-23 14:44:30,328] Trial 92 pruned.
# [I 2026-04-23 14:44:30,342] Trial 93 pruned.
# [I 2026-04-23 14:44:30,395] Trial 94 pruned.
# [I 2026-04-23 14:44:30,472] Trial 95 finished with value: 1.6042925019522551 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 37 with value: 1.0295592371258222.
# [I 2026-04-23 14:44:30,519] Trial 96 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,569] Trial 97 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,617] Trial 98 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,668] Trial 99 pruned.
# [I 2026-04-23 14:44:30,722] Trial 100 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,769] Trial 101 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,816] Trial 102 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,864] Trial 103 finished with value: 0.7439220354636773 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 15}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,917] Trial 104 finished with value: 0.7439220354636773 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 15}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:30,964] Trial 105 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,012] Trial 106 finished with value: 0.7439220354636773 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 15}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,061] Trial 107 finished with value: 0.7439220354636773 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 15}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,114] Trial 108 pruned.
# [I 2026-04-23 14:44:31,162] Trial 109 finished with value: 0.7483632542809546 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 16}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,215] Trial 110 pruned.
# [I 2026-04-23 14:44:31,265] Trial 111 finished with value: 0.7483632542809546 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 16}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,313] Trial 112 finished with value: 0.7483632542809546 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 16}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,368] Trial 113 pruned.
# [I 2026-04-23 14:44:31,422] Trial 114 pruned.
# [I 2026-04-23 14:44:31,468] Trial 115 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,525] Trial 116 pruned.
# [I 2026-04-23 14:44:31,577] Trial 117 pruned.
# [I 2026-04-23 14:44:31,626] Trial 118 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,678] Trial 119 pruned.
# [I 2026-04-23 14:44:31,729] Trial 120 pruned.
# [I 2026-04-23 14:44:31,778] Trial 121 finished with value: 0.7439220354636773 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 15}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,827] Trial 122 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,874] Trial 123 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:31,928] Trial 124 pruned.
# [I 2026-04-23 14:44:31,978] Trial 125 pruned.
# [I 2026-04-23 14:44:32,024] Trial 126 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,078] Trial 127 pruned.
# [I 2026-04-23 14:44:32,132] Trial 128 pruned.
# [I 2026-04-23 14:44:32,184] Trial 129 pruned.
# [I 2026-04-23 14:44:32,240] Trial 130 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,288] Trial 131 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,335] Trial 132 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,389] Trial 133 pruned.
# [I 2026-04-23 14:44:32,450] Trial 134 pruned.
# [I 2026-04-23 14:44:32,504] Trial 135 pruned.
# [I 2026-04-23 14:44:32,553] Trial 136 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,566] Trial 137 pruned.
# [I 2026-04-23 14:44:32,621] Trial 138 pruned.
# [I 2026-04-23 14:44:32,635] Trial 139 pruned.
# [I 2026-04-23 14:44:32,690] Trial 140 pruned.
# [I 2026-04-23 14:44:32,741] Trial 141 pruned.
# [I 2026-04-23 14:44:32,791] Trial 142 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,837] Trial 143 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,892] Trial 144 pruned.
# [I 2026-04-23 14:44:32,941] Trial 145 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:32,994] Trial 146 pruned.
# [I 2026-04-23 14:44:33,047] Trial 147 pruned.
# [I 2026-04-23 14:44:33,061] Trial 148 pruned.
# [I 2026-04-23 14:44:33,120] Trial 149 pruned.
# [I 2026-04-23 14:44:33,182] Trial 150 pruned.
# [I 2026-04-23 14:44:33,229] Trial 151 finished with value: 0.7286839096312137 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 14}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,277] Trial 152 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,326] Trial 153 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,374] Trial 154 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,438] Trial 155 pruned.
# [I 2026-04-23 14:44:33,488] Trial 156 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,542] Trial 157 pruned.
# [I 2026-04-23 14:44:33,597] Trial 158 pruned.
# [I 2026-04-23 14:44:33,643] Trial 159 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,697] Trial 160 pruned.
# [I 2026-04-23 14:44:33,747] Trial 161 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,797] Trial 162 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,848] Trial 163 finished with value: 0.7070586996013911 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 13}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,904] Trial 164 pruned.
# [I 2026-04-23 14:44:33,960] Trial 165 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:33,974] Trial 166 pruned.
# [I 2026-04-23 14:44:34,026] Trial 167 pruned.
# [I 2026-04-23 14:44:34,072] Trial 168 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:34,126] Trial 169 pruned.
# [I 2026-04-23 14:44:34,176] Trial 170 pruned.
# [I 2026-04-23 14:44:34,226] Trial 171 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:34,276] Trial 172 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:34,326] Trial 173 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:34,379] Trial 174 pruned.
# [I 2026-04-23 14:44:34,439] Trial 175 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:34,493] Trial 176 pruned.
# [I 2026-04-23 14:44:34,508] Trial 177 pruned.
# [I 2026-04-23 14:44:34,564] Trial 178 pruned.
# [I 2026-04-23 14:44:34,618] Trial 179 pruned.
# [I 2026-04-23 14:44:34,633] Trial 180 pruned.
# [I 2026-04-23 14:44:34,676] Trial 181 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:34,726] Trial 182 finished with value: 0.6708865369149823 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 96 with value: 0.6708865369149823.
# [I 2026-04-23 14:44:34,780] Trial 183 pruned.
# [I 2026-04-23 14:44:34,828] Trial 184 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 184 with value: 0.6364565584485271.
# [I 2026-04-23 14:44:34,887] Trial 185 pruned.
# [I 2026-04-23 14:44:34,935] Trial 186 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 184 with value: 0.6364565584485271.
# [I 2026-04-23 14:44:34,990] Trial 187 pruned.
# [I 2026-04-23 14:44:35,039] Trial 188 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 184 with value: 0.6364565584485271.
# [I 2026-04-23 14:44:35,097] Trial 189 pruned.
# [I 2026-04-23 14:44:35,151] Trial 190 pruned.
# [I 2026-04-23 14:44:35,200] Trial 191 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 184 with value: 0.6364565584485271.
# [I 2026-04-23 14:44:35,247] Trial 192 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 184 with value: 0.6364565584485271.
# [I 2026-04-23 14:44:35,298] Trial 193 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 184 with value: 0.6364565584485271.
# [I 2026-04-23 14:44:35,344] Trial 194 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,401] Trial 195 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,447] Trial 196 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,501] Trial 197 pruned.
# [I 2026-04-23 14:44:35,557] Trial 198 pruned.
# [I 2026-04-23 14:44:35,605] Trial 199 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,653] Trial 200 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,697] Trial 201 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,754] Trial 202 pruned.
# [I 2026-04-23 14:44:35,792] Trial 203 pruned.
# [I 2026-04-23 14:44:35,840] Trial 204 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,901] Trial 205 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:35,954] Trial 206 pruned.
# [I 2026-04-23 14:44:36,001] Trial 207 pruned.
# [I 2026-04-23 14:44:36,061] Trial 208 pruned.
# [I 2026-04-23 14:44:36,075] Trial 209 pruned.
# [I 2026-04-23 14:44:36,124] Trial 210 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,171] Trial 211 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,218] Trial 212 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,265] Trial 213 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,330] Trial 214 pruned.
# [I 2026-04-23 14:44:36,364] Trial 215 pruned.
# [I 2026-04-23 14:44:36,418] Trial 216 pruned.
# [I 2026-04-23 14:44:36,463] Trial 217 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,519] Trial 218 pruned.
# [I 2026-04-23 14:44:36,559] Trial 219 pruned.
# [I 2026-04-23 14:44:36,610] Trial 220 pruned.
# [I 2026-04-23 14:44:36,662] Trial 221 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,711] Trial 222 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,765] Trial 223 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,813] Trial 224 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,861] Trial 225 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,911] Trial 226 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:36,965] Trial 227 pruned.
# [I 2026-04-23 14:44:37,015] Trial 228 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:37,071] Trial 229 pruned.
# [I 2026-04-23 14:44:37,121] Trial 230 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:37,172] Trial 231 finished with value: 0.6364565584485271 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:37,220] Trial 232 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:37,266] Trial 233 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:37,316] Trial 234 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:37,372] Trial 235 pruned.
# [I 2026-04-23 14:44:37,409] Trial 236 pruned.
# [I 2026-04-23 14:44:37,476] Trial 237 pruned.
# [I 2026-04-23 14:44:37,530] Trial 238 finished with value: 0.5876277476916308 and parameters: {'nI': 22, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 10}. Best is trial 194 with value: 0.5876277476916308.
# [I 2026-04-23 14:44:37,596] Trial 239 finished with value: 0.10781121740739082 and parameters: {'nI': 21, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 9}. Best is trial 239 with value: 0.10781121740739082.
# [I 2026-04-23 14:44:37,662] Trial 240 finished with value: 0.10781121740739082 and parameters: {'nI': 21, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 9}. Best is trial 239 with value: 0.10781121740739082.
# [I 2026-04-23 14:44:37,738] Trial 241 finished with value: 1.183335528436977 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 9}. Best is trial 239 with value: 0.10781121740739082.
# [I 2026-04-23 14:44:37,748] Trial 242 pruned.
# [I 2026-04-23 14:44:37,800] Trial 243 pruned.
# [I 2026-04-23 14:44:37,814] Trial 244 pruned.
# [I 2026-04-23 14:44:37,850] Trial 245 pruned.
# [I 2026-04-23 14:44:37,880] Trial 246 pruned.
# [I 2026-04-23 14:44:37,946] Trial 247 finished with value: 0.10099300218175913 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,012] Trial 248 pruned.
# [I 2026-04-23 14:44:38,068] Trial 249 pruned.
# [I 2026-04-23 14:44:38,113] Trial 250 finished with value: 0.13307624345331798 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,160] Trial 251 finished with value: 0.13307624345331798 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,217] Trial 252 pruned.
# [I 2026-04-23 14:44:38,261] Trial 253 finished with value: 0.3829021144863696 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,317] Trial 254 pruned.
# [I 2026-04-23 14:44:38,367] Trial 255 pruned.
# [I 2026-04-23 14:44:38,409] Trial 256 finished with value: 0.3829021144863696 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,471] Trial 257 pruned.
# [I 2026-04-23 14:44:38,524] Trial 258 pruned.
# [I 2026-04-23 14:44:38,581] Trial 259 pruned.
# [I 2026-04-23 14:44:38,629] Trial 260 finished with value: 0.13307624345331798 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,676] Trial 261 finished with value: 0.13307624345331798 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,729] Trial 262 pruned.
# [I 2026-04-23 14:44:38,774] Trial 263 finished with value: 0.13307624345331798 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,826] Trial 264 pruned.
# [I 2026-04-23 14:44:38,880] Trial 265 finished with value: 0.13307624345331798 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:38,920] Trial 266 pruned.
# [I 2026-04-23 14:44:38,975] Trial 267 pruned.
# [I 2026-04-23 14:44:39,022] Trial 268 finished with value: 0.13307624345331798 and parameters: {'nI': 22, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 10}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:39,080] Trial 269 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:39,101] Trial 270 pruned.
# [I 2026-04-23 14:44:39,164] Trial 271 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:39,226] Trial 272 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:39,281] Trial 273 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:39,322] Trial 274 pruned.
# [I 2026-04-23 14:44:39,333] Trial 275 pruned.
# [I 2026-04-23 14:44:39,392] Trial 276 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 247 with value: 0.10099300218175913.
# [I 2026-04-23 14:44:39,442] Trial 277 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:39,497] Trial 278 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:39,547] Trial 279 pruned.
# [I 2026-04-23 14:44:39,601] Trial 280 pruned.
# [I 2026-04-23 14:44:39,661] Trial 281 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:39,721] Trial 282 pruned.
# [I 2026-04-23 14:44:39,780] Trial 283 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:39,830] Trial 284 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:39,871] Trial 285 pruned.
# [I 2026-04-23 14:44:39,930] Trial 286 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:39,980] Trial 287 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,030] Trial 288 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,088] Trial 289 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,136] Trial 290 finished with value: 0.09422187988525592 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 6}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,186] Trial 291 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,226] Trial 292 pruned.
# [I 2026-04-23 14:44:40,276] Trial 293 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,313] Trial 294 pruned.
# [I 2026-04-23 14:44:40,360] Trial 295 finished with value: 0.09422187988525592 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 6}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,376] Trial 296 pruned.
# [I 2026-04-23 14:44:40,427] Trial 297 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,465] Trial 298 pruned.
# [I 2026-04-23 14:44:40,480] Trial 299 pruned.
# [I 2026-04-23 14:44:40,530] Trial 300 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,568] Trial 301 pruned.
# [I 2026-04-23 14:44:40,617] Trial 302 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,669] Trial 303 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,719] Trial 304 pruned.
# [I 2026-04-23 14:44:40,776] Trial 305 pruned.
# [I 2026-04-23 14:44:40,825] Trial 306 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,875] Trial 307 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,926] Trial 308 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:40,977] Trial 309 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,030] Trial 310 pruned.
# [I 2026-04-23 14:44:41,076] Trial 311 pruned.
# [I 2026-04-23 14:44:41,121] Trial 312 finished with value: 0.09422187988525592 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 6}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,171] Trial 313 pruned.
# [I 2026-04-23 14:44:41,221] Trial 314 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,267] Trial 315 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,326] Trial 316 pruned.
# [I 2026-04-23 14:44:41,363] Trial 317 pruned.
# [I 2026-04-23 14:44:41,413] Trial 318 finished with value: 0.09422187988525592 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 6}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,458] Trial 319 finished with value: 0.09422187988525592 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 6}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,505] Trial 320 finished with value: 0.09422187988525592 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 6}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,551] Trial 321 finished with value: 0.09422187988525592 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 6}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,590] Trial 322 pruned.
# [I 2026-04-23 14:44:41,642] Trial 323 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,693] Trial 324 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,734] Trial 325 pruned.
# [I 2026-04-23 14:44:41,762] Trial 326 pruned.
# [I 2026-04-23 14:44:41,802] Trial 327 pruned.
# [I 2026-04-23 14:44:41,817] Trial 328 pruned.
# [I 2026-04-23 14:44:41,867] Trial 329 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,917] Trial 330 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:41,955] Trial 331 pruned.
# [I 2026-04-23 14:44:41,975] Trial 332 pruned.
# [I 2026-04-23 14:44:42,034] Trial 333 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,084] Trial 334 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,123] Trial 335 pruned.
# [I 2026-04-23 14:44:42,180] Trial 336 pruned.
# [I 2026-04-23 14:44:42,217] Trial 337 pruned.
# [I 2026-04-23 14:44:42,271] Trial 338 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,284] Trial 339 pruned.
# [I 2026-04-23 14:44:42,333] Trial 340 finished with value: 0.050404562180027736 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 7}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,380] Trial 341 pruned.
# [I 2026-04-23 14:44:42,437] Trial 342 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,488] Trial 343 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,525] Trial 344 pruned.
# [I 2026-04-23 14:44:42,538] Trial 345 pruned.
# [I 2026-04-23 14:44:42,588] Trial 346 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,634] Trial 347 pruned.
# [I 2026-04-23 14:44:42,700] Trial 348 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,711] Trial 349 pruned.
# [I 2026-04-23 14:44:42,738] Trial 350 pruned.
# [I 2026-04-23 14:44:42,796] Trial 351 pruned.
# [I 2026-04-23 14:44:42,816] Trial 352 pruned.
# [I 2026-04-23 14:44:42,873] Trial 353 pruned.
# [I 2026-04-23 14:44:42,883] Trial 354 pruned.
# [I 2026-04-23 14:44:42,939] Trial 355 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:42,988] Trial 356 pruned.
# [I 2026-04-23 14:44:43,046] Trial 357 pruned.
# [I 2026-04-23 14:44:43,100] Trial 358 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,154] Trial 359 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,213] Trial 360 pruned.
# [I 2026-04-23 14:44:43,227] Trial 361 pruned.
# [I 2026-04-23 14:44:43,279] Trial 362 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,300] Trial 363 pruned.
# [I 2026-04-23 14:44:43,355] Trial 364 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,408] Trial 365 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,463] Trial 366 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,484] Trial 367 pruned.
# [I 2026-04-23 14:44:43,521] Trial 368 pruned.
# [I 2026-04-23 14:44:43,576] Trial 369 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,638] Trial 370 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,695] Trial 371 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,735] Trial 372 pruned.
# [I 2026-04-23 14:44:43,746] Trial 373 pruned.
# [I 2026-04-23 14:44:43,800] Trial 374 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,821] Trial 375 pruned.
# [I 2026-04-23 14:44:43,875] Trial 376 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:43,888] Trial 377 pruned.
# [I 2026-04-23 14:44:43,925] Trial 378 pruned.
# [I 2026-04-23 14:44:43,980] Trial 379 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:44,038] Trial 380 pruned.
# [I 2026-04-23 14:44:44,092] Trial 381 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:44,104] Trial 382 pruned.
# [I 2026-04-23 14:44:44,161] Trial 383 pruned.
# [I 2026-04-23 14:44:44,228] Trial 384 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:44,285] Trial 385 pruned.
# [I 2026-04-23 14:44:44,343] Trial 386 pruned.
# [I 2026-04-23 14:44:44,364] Trial 387 pruned.
# [I 2026-04-23 14:44:44,421] Trial 388 pruned.
# [I 2026-04-23 14:44:44,475] Trial 389 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:44,487] Trial 390 pruned.
# [I 2026-04-23 14:44:44,546] Trial 391 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:44,601] Trial 392 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:44,642] Trial 393 pruned.
# [I 2026-04-23 14:44:44,707] Trial 394 pruned.
# [I 2026-04-23 14:44:44,758] Trial 395 pruned.
# [I 2026-04-23 14:44:44,770] Trial 396 pruned.
# [I 2026-04-23 14:44:44,808] Trial 397 pruned.
# [I 2026-04-23 14:44:44,868] Trial 398 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:44,906] Trial 399 pruned.
# [I 2026-04-23 14:44:44,958] Trial 400 pruned.
# [I 2026-04-23 14:44:45,003] Trial 401 finished with value: 0.027334335233397265 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.0001, 'N2': 0.01, 'N3': 1e-06, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:45,060] Trial 402 pruned.
# [I 2026-04-23 14:44:45,106] Trial 403 pruned.
# [I 2026-04-23 14:44:45,164] Trial 404 pruned.
# [I 2026-04-23 14:44:45,224] Trial 405 pruned.
# [I 2026-04-23 14:44:45,285] Trial 406 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:45,342] Trial 407 pruned.
# [I 2026-04-23 14:44:45,387] Trial 408 pruned.
# [I 2026-04-23 14:44:45,448] Trial 409 pruned.
# [I 2026-04-23 14:44:45,501] Trial 410 finished with value: 0.01931710575708278 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 8}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:45,568] Trial 411 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 277 with value: 0.01931710575708278.
# [I 2026-04-23 14:44:45,621] Trial 412 pruned.
# [I 2026-04-23 14:44:45,666] Trial 413 pruned.
# [I 2026-04-23 14:44:45,722] Trial 414 pruned.
# [I 2026-04-23 14:44:45,740] Trial 415 pruned.
# [I 2026-04-23 14:44:45,751] Trial 416 pruned.
# [I 2026-04-23 14:44:45,810] Trial 417 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 277 with value: 0.01931710575708278.
# ...
# [I 2026-04-23 14:48:20,469] Trial 3854 pruned.
# [I 2026-04-23 14:48:20,549] Trial 3855 pruned.
# [I 2026-04-23 14:48:20,629] Trial 3856 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:20,713] Trial 3857 finished with value: 0.15784097823414045 and parameters: {'nI': 17, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:20,780] Trial 3858 pruned.
# [I 2026-04-23 14:48:20,859] Trial 3859 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:20,943] Trial 3860 pruned.
# [I 2026-04-23 14:48:21,022] Trial 3861 finished with value: 0.16461007439160263 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.0001, 'N2': 0.01, 'N3': 1e-06, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:21,094] Trial 3862 pruned.
# [I 2026-04-23 14:48:21,160] Trial 3863 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:21,226] Trial 3864 pruned.
# [I 2026-04-23 14:48:21,287] Trial 3865 pruned.
# [I 2026-04-23 14:48:21,374] Trial 3866 finished with value: 0.04428111332458229 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:21,463] Trial 3867 pruned.
# [I 2026-04-23 14:48:21,520] Trial 3868 pruned.
# [I 2026-04-23 14:48:21,605] Trial 3869 pruned.
# [I 2026-04-23 14:48:21,682] Trial 3870 finished with value: 0.04428111332458229 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:21,769] Trial 3871 pruned.
# [I 2026-04-23 14:48:21,852] Trial 3872 pruned.
# [I 2026-04-23 14:48:21,948] Trial 3873 pruned.
# [I 2026-04-23 14:48:22,032] Trial 3874 pruned.
# [I 2026-04-23 14:48:22,133] Trial 3875 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:22,197] Trial 3876 finished with value: 0.026731565277095776 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:22,289] Trial 3877 pruned.
# [I 2026-04-23 14:48:22,359] Trial 3878 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:22,452] Trial 3879 pruned.
# [I 2026-04-23 14:48:22,494] Trial 3880 pruned.
# [I 2026-04-23 14:48:22,578] Trial 3881 pruned.
# [I 2026-04-23 14:48:22,666] Trial 3882 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:22,741] Trial 3883 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:22,836] Trial 3884 pruned.
# [I 2026-04-23 14:48:22,919] Trial 3885 finished with value: 0.13325631254993084 and parameters: {'nI': 19, 'nR': 41, 'nO': 1, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:22,967] Trial 3886 pruned.
# [I 2026-04-23 14:48:23,059] Trial 3887 pruned.
# [I 2026-04-23 14:48:23,135] Trial 3888 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:23,225] Trial 3889 finished with value: 0.010033044472607219 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:23,315] Trial 3890 pruned.
# [I 2026-04-23 14:48:23,394] Trial 3891 pruned.
# [I 2026-04-23 14:48:23,476] Trial 3892 pruned.
# [I 2026-04-23 14:48:23,573] Trial 3893 pruned.
# [I 2026-04-23 14:48:23,639] Trial 3894 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:23,725] Trial 3895 pruned.
# [I 2026-04-23 14:48:23,814] Trial 3896 pruned.
# [I 2026-04-23 14:48:23,882] Trial 3897 pruned.
# [I 2026-04-23 14:48:23,985] Trial 3898 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:24,071] Trial 3899 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:24,150] Trial 3900 pruned.
# [I 2026-04-23 14:48:24,231] Trial 3901 finished with value: 0.17642360837091267 and parameters: {'nI': 18, 'nR': 41, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:24,301] Trial 3902 pruned.
# [I 2026-04-23 14:48:24,381] Trial 3903 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:24,468] Trial 3904 finished with value: 0.010033044472607219 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:24,542] Trial 3905 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:24,628] Trial 3906 pruned.
# [I 2026-04-23 14:48:24,715] Trial 3907 pruned.
# [I 2026-04-23 14:48:24,803] Trial 3908 pruned.
# [I 2026-04-23 14:48:24,847] Trial 3909 pruned.
# [I 2026-04-23 14:48:24,908] Trial 3910 pruned.
# [I 2026-04-23 14:48:25,003] Trial 3911 finished with value: 0.5575376280391702 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-06, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:25,102] Trial 3912 pruned.
# [I 2026-04-23 14:48:25,173] Trial 3913 pruned.
# [I 2026-04-23 14:48:25,256] Trial 3914 pruned.
# [I 2026-04-23 14:48:25,347] Trial 3915 pruned.
# [I 2026-04-23 14:48:25,444] Trial 3916 pruned.
# [I 2026-04-23 14:48:25,513] Trial 3917 pruned.
# [I 2026-04-23 14:48:25,607] Trial 3918 pruned.
# [I 2026-04-23 14:48:25,686] Trial 3919 pruned.
# [I 2026-04-23 14:48:25,789] Trial 3920 pruned.
# [I 2026-04-23 14:48:25,872] Trial 3921 pruned.
# [I 2026-04-23 14:48:25,948] Trial 3922 pruned.
# [I 2026-04-23 14:48:25,994] Trial 3923 pruned.
# [I 2026-04-23 14:48:26,084] Trial 3924 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:26,160] Trial 3925 pruned.
# [I 2026-04-23 14:48:26,246] Trial 3926 pruned.
# [I 2026-04-23 14:48:26,325] Trial 3927 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:26,400] Trial 3928 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:26,490] Trial 3929 finished with value: 0.010033044472607219 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:26,577] Trial 3930 pruned.
# [I 2026-04-23 14:48:26,652] Trial 3931 pruned.
# [I 2026-04-23 14:48:26,745] Trial 3932 pruned.
# [I 2026-04-23 14:48:26,817] Trial 3933 finished with value: 0.22046638302854432 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.001, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:26,895] Trial 3934 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:26,978] Trial 3935 pruned.
# [I 2026-04-23 14:48:27,067] Trial 3936 pruned.
# [I 2026-04-23 14:48:27,157] Trial 3937 pruned.
# [I 2026-04-23 14:48:27,258] Trial 3938 finished with value: 0.8646831877240242 and parameters: {'nI': 15, 'nR': 41, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:27,344] Trial 3939 finished with value: 0.5574670025482649 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-05, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:27,426] Trial 3940 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:27,515] Trial 3941 pruned.
# [I 2026-04-23 14:48:27,600] Trial 3942 finished with value: 0.010033044472607219 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:27,677] Trial 3943 pruned.
# [I 2026-04-23 14:48:27,770] Trial 3944 pruned.
# [I 2026-04-23 14:48:27,839] Trial 3945 finished with value: 0.03269946740577216 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 5}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:27,919] Trial 3946 pruned.
# [I 2026-04-23 14:48:28,001] Trial 3947 finished with value: 0.010033044472607219 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:28,089] Trial 3948 pruned.
# [I 2026-04-23 14:48:28,136] Trial 3949 pruned.
# [I 2026-04-23 14:48:28,213] Trial 3950 pruned.
# [I 2026-04-23 14:48:28,298] Trial 3951 pruned.
# [I 2026-04-23 14:48:28,387] Trial 3952 pruned.
# [I 2026-04-23 14:48:28,456] Trial 3953 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:28,554] Trial 3954 pruned.
# [I 2026-04-23 14:48:28,598] Trial 3955 pruned.
# [I 2026-04-23 14:48:28,669] Trial 3956 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:28,749] Trial 3957 pruned.
# [I 2026-04-23 14:48:28,820] Trial 3958 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:28,868] Trial 3959 pruned.
# [I 2026-04-23 14:48:28,963] Trial 3960 pruned.
# [I 2026-04-23 14:48:29,037] Trial 3961 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:29,131] Trial 3962 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:29,197] Trial 3963 pruned.
# [I 2026-04-23 14:48:29,292] Trial 3964 pruned.
# [I 2026-04-23 14:48:29,373] Trial 3965 pruned.
# [I 2026-04-23 14:48:29,441] Trial 3966 pruned.
# [I 2026-04-23 14:48:29,512] Trial 3967 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:29,609] Trial 3968 pruned.
# [I 2026-04-23 14:48:29,680] Trial 3969 pruned.
# [I 2026-04-23 14:48:29,774] Trial 3970 pruned.
# [I 2026-04-23 14:48:29,847] Trial 3971 finished with value: 0.23334536519052698 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 9}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:29,931] Trial 3972 pruned.
# [I 2026-04-23 14:48:30,014] Trial 3973 pruned.
# [I 2026-04-23 14:48:30,108] Trial 3974 pruned.
# [I 2026-04-23 14:48:30,198] Trial 3975 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:30,296] Trial 3976 pruned.
# [I 2026-04-23 14:48:30,385] Trial 3977 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:30,438] Trial 3978 pruned.
# [I 2026-04-23 14:48:30,546] Trial 3979 pruned.
# [I 2026-04-23 14:48:30,634] Trial 3980 pruned.
# [I 2026-04-23 14:48:30,722] Trial 3981 pruned.
# [I 2026-04-23 14:48:30,804] Trial 3982 pruned.
# [I 2026-04-23 14:48:30,898] Trial 3983 pruned.
# [I 2026-04-23 14:48:30,964] Trial 3984 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:31,043] Trial 3985 pruned.
# [I 2026-04-23 14:48:31,144] Trial 3986 pruned.
# [I 2026-04-23 14:48:31,262] Trial 3987 pruned.
# [I 2026-04-23 14:48:31,351] Trial 3988 pruned.
# [I 2026-04-23 14:48:31,440] Trial 3989 finished with value: 0.012993692863220732 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 2}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:31,501] Trial 3990 pruned.
# [I 2026-04-23 14:48:31,601] Trial 3991 pruned.
# [I 2026-04-23 14:48:31,693] Trial 3992 pruned.
# [I 2026-04-23 14:48:31,799] Trial 3993 pruned.
# [I 2026-04-23 14:48:31,891] Trial 3994 finished with value: 0.0028502519868755676 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:31,950] Trial 3995 pruned.
# [I 2026-04-23 14:48:32,059] Trial 3996 finished with value: 0.5039753448934116 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:32,118] Trial 3997 pruned.
# [I 2026-04-23 14:48:32,216] Trial 3998 finished with value: 0.010033044472607219 and parameters: {'nI': 20, 'nR': 42, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 4}. Best is trial 595 with value: 0.0028502519868755676.
# [I 2026-04-23 14:48:32,281] Trial 3999 finished with value: 0.01913024346778408 and parameters: {'nI': 20, 'nR': 43, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 3}. Best is trial 595 with value: 0.0028502519868755676.
# Erro: 0.0028502519868755676 parameters:  [20, 42, 1, 0.001, 0.01, 0.01, 3]

# %% [markdown]
# Erro: 0.0023427213218621956 parameters:  [23, 36, 1, 0.1, 0.0001, 1e-06, 16]\
# Erro: 0.0014063554855017542 parameters:  [15, 37, 1, 0.1, 1e-06, 1e-06, 13]\
# Erro: 0.0012346218859173332 parameters:  [19, 42, 1, 0.1, 0.1, 0.01, 11]\
# Erro: 0.0012692318048607616 parameters:  [19, 42, 1, 0.1, 0.001, 0.01, 12]\
# Erro: 0.0012926757089637237 parameters:  [15, 37, 1, 0.1, 1e-06, 0.01, 13]\
# Erro: 0.0012927806734242414 parameters:  [15, 37, 1, 0.1, 0.01, 0.01, 13]

# %%
rates = [1/(10**i) for i in range(1,7)][::-1]
def objective(trial):

    nI = trial.suggest_int('nI', 2, 25) 
    nR = trial.suggest_int('nR', 1, 50) 
    nO = trial.suggest_int('nO', 1, 25) 
    N1 = trial.suggest_categorical('N1', rates[:]) 
    N2 = trial.suggest_categorical('N2', rates[:]) 
    N3 = trial.suggest_categorical('N3', rates) 
    τ = trial.suggest_int('τ', 1, 50)        
    X,Y = PrepareDataAhead(sig,n=nI,m=nO)
    X,Y=X[:-1],Y[:-1]
    rnn = RTLO(nI,nR,nO,[N1,N2,N3],τ)
    rnn.ref = len(sig)-nI
    cont = 0
    for i,_ in enumerate(X):
        rnn.PredRul(X[i],store=True)
        rnn.fit(X[i],Y[i],store=True)
        
        if i == 50:
            if np.mean(rnn.εM_hist)>1:
                raise TrialPruned()
            if np.mean(rnn.rulP)>np.mean(rnn.rulR)*1.1:
                raise TrialPruned()
            if np.mean(rnn.rulP)<np.mean(rnn.rulR)*0.3:
                raise TrialPruned()
        if i>=40:
            if rnn.rulP[i]==rnn.rulP[i-1]:
                cont = cont+1
            if cont> 20:
                raise TrialPruned()

        '''if i == 50:
            if np.mean(rnn.εM_hist)>1:
                raise TrialPruned()

        if i % 20 == 0:  # Report every 10 time steps
            trial.report(rnn.εM, step=i)
            if trial.should_prune():
                raise optuna.TrialPruned()'''  
    return rnn.εM, rnn.εR

#pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
pruner=optuna.pruners.HyperbandPruner()
study = optuna.create_study(
    directions=["minimize", "minimize"],
    sampler=SelSampler(mode='auto'),
    pruner=pruner,
    #storage="sqlite:///" + f'Optuna/{FileName}_Prdct.db', study_name=f'P{4}',
    load_if_exists=True)
study.optimize(objective, n_trials=1000)
best_trials = study.best_trials
print(f"Encontrados {len(best_trials)} modelos na Fronteira de Pareto:")

for i, trial in enumerate(best_trials):
    print(f"\n--- Modelo Elite {i+1} ---")
    print(f"Valores: Erro_M = {trial.values[0]:.6f}, Erro_R = {trial.values[1]:.6f}")
    print(f"Parâmetros: {trial.params}")

# Se você quiser apenas os parâmetros do PRIMEIRO modelo da fronteira para testar:
first_best_params = best_trials[0].params

# %% [markdown]
# Valores: Erro_M = 0.023125, Erro_R = 0.408742
# Parâmetros: {'nI': 15, 'nR': 41, 'nO': 2, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.001, 'τ': 1}

# %%
params = {'nI': 6, 'nR': 43, 'nO': 1, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.1, 'τ': 18}
params = trial.params
params={'nI': 25, 'nR': 37, 'nO': 1, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.1, 'τ': 11}
params = list(params.values())
#params = [8, 41, 1, 0.1, 0.01, 0.001, 2]

# %%
nI,nR,nO,N1,N2,N3,τ= params
X,Y = PrepareDataAhead(sig,n=nI,m=nO)
X,Y = X[:-1],Y[:-1]
rnn = RTLO(nI,nR,nO,[N1,N2,N3],τ)
rnn.ref = len(sig)-nI
for i in range(len(X[:])):
    rnn.PredRul(x=X[i],store=True)
    #rnn.PredRulIntr2(x=X[i],maxRul=len(sig)-nI,store=True,show=False)
    rnn.fit(X[i],Y[i],store=True,show=False)
#print(.wR[0])
print(rnn.εM,rnn.εR)  
PlotPredErrorPLY(rnn)
# Out:
# 0.01314294438031333 0.1782493522053804

# %%
i=50
r_m = np.mean(rnn.rulR[:i])
r_mL = np.mean(rnn.rulR[:i])*0.3
r_mU = np.mean(rnn.rulR[:i])*1.05
p_m = (np.mean(rnn.rulP[:i]))

print('lower:',r_mL,'mid:',r_m,'upper:',r_mU)
print('pred:',p_m)
# Out:
# lower: 28.65 mid: 95.5 upper: 100.275
# pred: 86.14

# %%
#params =  [14, 8, 14, 0.001, 0.01, 1e-06, 1e-07, 29]
nI,nR,nO,N1,N2,N3,τ= params
ηS = [N1,N2,N3]
X,Y = PrepareDataAhead(sig,n=nI,m=nO)
rnn = RTLO(nI,nR,nO,ηS,τ)
rnn.ref = len(sig)-nI

i=0

# %%
#rnn.PredRul(x=X[i],store=True)
print('iteration:',i)
print('xP:',X[i])
print('yR:',Y[i])
rnn.PredRulIntr2(x=X[i],store=True,show=True)
rnn.fit(X[i],Y[i],store=True,show=False)
i=i+1
# Out:
# iteration: 1
# xP: [0.91429178 0.91121962 0.90817817 0.90519636 0.90227154 0.89941598]
# yR: [0.89663373 0.8939275  0.89128272 0.88870303 0.88617045 0.88366572]
# [np.float64(-0.03730620483456837), np.float64(-0.04602629367076666), np.float64(-0.05561926571854693)]

# %%
v = [np.float64(-0.03730620483456837), np.float64(-0.04602629367076666), np.float64(-0.05561926571854693)]
v = sorted(v)
print(v)
# Out:
# [np.float64(-0.05561926571854693), np.float64(-0.04602629367076666), np.float64(-0.03730620483456837)]
