# %% [markdown]
# RNN - Erro dos pesos computados e usado somente durante a iteração

# %%
import numpy as np
from numpy import linalg as LA
import pandas as pd
import operator as op
import ipynbname
import math
import matplotlib.cm as cm
import optuna
from optuna.samplers import RandomSampler
from optuna.samplers import TPESampler
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_pareto_front
from optuna.importance import get_param_importances
from optuna.exceptions import TrialPruned
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import matplotlib as mpl
#from Testing.RTLO import *
from Functions.RLS import *
from Functions.Utils_RTLO import *
from Functions.Graphs import *
from sklearn.metrics import root_mean_squared_error as RMSE
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.metrics import mean_squared_error as MSE

FileName = ipynbname.name()

df = pd.read_csv(r'Dataset\Dataset_1_NCA_battery_SoH\CY25-05_1-#01.csv')
sig = df['soh'].values

def PlotPredError(rtlo,w=9,h=3):
    s = len(rtlo.yWAPE)
    t = rtlo.t
    fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(w, h))
    axes = axes.flatten()
    ax1,ax2,ax3,ax4 = axes[0], axes[1], axes[2], axes[3]

    ax1.plot(t, rtlo.yR, color='black',label='Y-Real', linestyle='-')
    ax1.plot(t, rtlo.yP, color='blue',label='Y-Pred', linestyle='-')
    ax1.plot(t, rtlo.yL, color='blue', linestyle='--')
    ax1.plot(t, rtlo.yU, color='blue', linestyle='--')
    
    ax1.set_title('Y - Real x Prediction')
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y', color='black')
    ax1.legend()

    ax2.plot(t, rtlo.eR, color='black',label='e-Real', linestyle='-')
    ax2.plot(t, rtlo.eP, color='blue',label='e-Pred', linestyle='-')
    ax2.set_title('Error - Real x Prediction')
    ax2.set_xlabel('X')
    ax2.set_ylabel('Prediction Error', color='black') 
    ax2.legend()
    
    ax3.plot(t[-s:], rtlo.yWAPE, color='blue',label='WAPE', linestyle='-')
    ax3.set_title('Prediction WAPE')
    ax3.set_xlabel('X')
    ax3.set_ylabel('WAPE', color='black') 

    '''ax4.plot(t[-s:], rtlo.rWAPE, color='blue',label='WAPE', linestyle='-')
    ax4.set_title('RUL Prediction WAPE')
    ax4.set_xlabel('X')
    ax4.set_ylabel('WAPE', color='black') '''

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()

def PlotPredErrorPLY(rtlo, w=800, h=300):
    # s: tamanho do vetor WAPE (caso comece depois do início)
    t = rtlo.t
    
    # Criando o layout de 1 linha e 4 colunas
    fig = make_subplots(
        rows=1, cols=3, 
        shared_xaxes=True,
        subplot_titles=('Y - Real x Prediction', 'RUL - Real x Pred', 'Error - Real x Pred', 'Prediction WAPE', 'RUL Prediction WAPE')
    )

    # --- Subplot 1: Y Real x Pred (com Intervalos) ---
    fig.add_trace(go.Scatter(x=t, y=rtlo.yR, name='Y-Real', line=dict(color='black')), row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=rtlo.yP, name='Y-Pred', line=dict(color='blue')), row=1, col=1)
    # Intervalos (Dashed)
    fig.add_trace(go.Scatter(x=t, y=rtlo.yL, name='y-Lower', line=dict(color='blue', dash='dash'), showlegend=False), row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=rtlo.yU, name='y-Upper', line=dict(color='blue', dash='dash'), showlegend=False), row=1, col=1)

    fig.add_trace(go.Scatter(x=t, y=rtlo.rulR, name='rul R', line=dict(color='black'), showlegend=True), row=1, col=2)
    fig.add_trace(go.Scatter(x=t, y=rtlo.rulP, name='rul P', line=dict(color='blue'), showlegend=True), row=1, col=2)
    fig.add_trace(go.Scatter(x=t, y=rtlo.rulL, name='rul L', line=dict(color='red'), showlegend=True), row=1, col=2)
    fig.add_trace(go.Scatter(x=t, y=rtlo.rulU, name='rul U', line=dict(color='green'), showlegend=True), row=1, col=2)

    #fig.add_trace(go.Scatter(x=t, y=rtlo.εM_hist, name='rul R', line=dict(color='black'), showlegend=False), row=1, col=3)
    fig.add_trace(go.Scatter(x=t, y=rtlo.eR, name='erro R', line=dict(color='black')), row=1, col=3)
    fig.add_trace(go.Scatter(x=t, y=rtlo.eP, name='erro P', line=dict(color='blue')), row=1, col=3)

    # Atualizando Layout e Eixos
    fig.update_layout(
        width=w, height=h,
        title_text=f"RTLO Model Performance Analysis",
        template='plotly_white',
        showlegend=True,
        margin=dict(l=40, r=40, t=80, b=40)
    )

    # Labels dos eixos (opcional, já que os títulos ajudam)
    fig.update_xaxes(title_text="Time / Index")
    fig.update_yaxes(title_text="Amplitude", col=1)
    fig.update_yaxes(title_text="Error", col=2)

    fig.show()
    
def SelSampler(mode='auto'):
    '''mode: auto, random,  tpe'''
    if mode == 'auto':
        sampler = None
    elif mode == 'tpe':
        sampler = optuna.samplers.TPESampler(multivariate=True, constant_linker=True,group=True,n_startup_trials=2000)
    elif mode == 'random':
        sampler=RandomSampler()
    return sampler

# %%
class RTLO:
    def __init__(self, nI,nR,nO,ηS=[0.1,0.1,0.1], τ=10,lr=1e-5):
        np.random.seed(42)
        self.k = 1
        self.j = nI-1
        self.t = np.array([])
        self.ref = None
        self.act = 'relu'
        self.nI, self.nR, self.nO = nI, nR, nO

        self.ηS = np.array(ηS)
        self.τ = τ
        self.ρ = 0.001

        self.xPi = np.zeros(nI)
        self.hP, self.hU, self.hL = [np.zeros(nR) for i in range(3)]

        self.pS = np.zeros((self.nR, self.nR))
        self.qS = np.zeros((self.nR, self.nI))

        self.ΔOS = np.zeros((nO, nR))
        self.ΔRS = np.zeros((nR, nR))
        self.ΔIS = np.zeros((nR, nI))
        
        self.wI = XavierUniform([nR, nI],sd=42)
        self.wR = XavierUniform([nR, nR],sd=41)
        self.wO = XavierUniform([nO, nR],sd=40)
        self.BS = XavierUniform([nR, nO],sd=39)

        self.rls = RLS_LogarithmicRegressor(0.95,1e7)
        
        self.yP, self.yR, self.yL, self.yU = [np.array([]) for i in range(4)]
        self.yP_hist = np.zeros(self.nI)
        self.eS = np.zeros(nI)
        self.eS2 = np.zeros(nI)
        self.eP = np.array([])
        self.eR = np.array([])

        self.εY, self.εM, self.εE, self.εR, self.ΣW = [0 for i in range(5)]
        self.εM_hist = np.array([])
        self.εR_hist = np.array([])

        self.μrWAPE = 0
        self.MPsum = 0

        self.rR = 1e-9
        self.rP = 1e-10
        self.rL = 1e-11
        self.rU = 1e-12
        self.rRsum = 0

        self.rulR, self.rulP, self.rulL, self.rulU = [np.array([]) for i in range(4)]


    def PredSingle(self,x):

        u = np.dot(self.wR, self.hS) + np.dot(self.wI, x)
        h = self.hS + (-self.hS + Activation(u,self.act))/self.τ
        y = np.dot(self.wO, h)

        return y

    def fit(self,xP,yR,store=False,show=False):

        exp=2
        W = self.j**exp
        η1,η2,η3 = self.ηS        
        #print('fit self.hP:',self.hP[-5:])
        uS = self.wR @ self.hP + self.wI @ xP
        #hP = self.hP + (-self.hP + Activation(uS,self.act))/self.τ
        hP = self.hP*(1-1/self.τ) +Activation(uS,self.act)/self.τ
        yP = self.wO @ hP
        eS = yR-yP

        if show: 
            #print('yR:',yR)
            #print('xP:',xP)
            print('fit  yP:',yP[0])
            #print('fit  hP:',self.hP)
            #print('fit  hP2:',hP)
            #print('fit xP:',xP)
            #print('fit uP:',uS)
            #print('fit  wR:\n',self.wR)
            #print('fit  wI\n:',self.wI)
            #print('fit  wO\n:',self.wO)

        self.pS = np.outer(dActivation(uS,self.act),self.hP)/self.τ + (1-1/self.τ)*self.pS
        self.qS = np.outer(dActivation(uS,self.act),self.xPi)/self.τ + (1-1/self.τ)*self.qS

        δOS = η1*np.outer(eS,hP)
        δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
        δIS = η3*np.outer(np.dot(self.BS, eS),np.ones(self.nI))*self.qS

        self.ΔIS = (self.ΔIS*(self.k-1) + δIS)/self.k
        self.ΔRS = (self.ΔRS*(self.k-1) + δRS)/self.k
        self.ΔOS = (self.ΔOS*(self.k-1) + δOS)/self.k

        self.wI = self.wI + δIS
        self.wR = self.wR + δRS
        self.wO = self.wO + δOS

        self.hP = hP
        self.xPi = xP

        #self.UpdateRLS(yP,yR)

        ΣW = self.ΣW + W
        ΔY = np.abs((yR-yP)/yR)
        ΔM = np.linalg.norm(ΔY,ord=2)
        ΔR = np.abs((self.rR-self.rP)/(self.rR+1e-9))
        #ΔE = np.abs((self.eR[-1]-self.eP[-1])/self.eR[-1])

        self.εY = ((self.εY*self.ΣW) + (W*ΔY[0]))/ΣW
        self.εM = ((self.εM*self.ΣW) + (W*ΔM))/ΣW
        self.εR = ((self.εR*self.ΣW) + (W*ΔR))/ΣW
        #self.εE = ((self.εE*self.ΣW) + (W*ΔE))/ΣW
        self.ΣW = ΣW

        if store:
            self.yR = np.append(self.yR,yR[0])
            self.εM_hist = np.append(self.εM_hist,self.εM)
            self.εR_hist = np.append(self.εR_hist,self.εR)

        self.k = self.k+1
        self.j = self.j+1
        self.t = np.append(self.t,self.k + self.nI)
        self.yP_hist = np.delete(np.append(self.yP_hist,yP[0]),0)
        #self.ηS = self.ηS/(1 + self.decay*self.k)


    def PredRulIntr(self, x,lim=0.2,maxRul=110,store=False,show=False):
        #print('yH:',self.yP_hist)
        #print('eS: ',self.eS)

        for i,y in enumerate(self.yP_hist):
            if y != 0:
                self.eS2[i] = self.rls.predict(np.abs(y))
        #print('eS2:',self.eS2)

        xP,xL,xU =x.copy(), (x-(self.ρ*self.eS2)).copy(),(x+(self.ρ*self.eS2)).copy()    

        #xP,xL,xU =x.copy(), x.copy()*0.999, x.copy()*1.00

        predict = True
        PredRuls = [True for i in range(3)]
        PredVals, Ruls = [0 for i in range(3)], [0 for i in range(3)]
        wR,wI,wO = self.wR,self.wI,self.wO

        wRp, wRn = np.maximum(0, self.wR), np.abs(np.minimum(0, self.wR))
        wIp, wIn = np.maximum(0, self.wI), np.abs(np.minimum(0, self.wI))
        wOp, wOn = np.maximum(0, self.wO), np.abs(np.minimum(0, self.wO))
        #hU,hL = np.maximum(0, self.hS), np.minimum(0, self.hS)
        hL,hP,hU = [self.hP.copy() for i in range(3)]

        while predict:
            uP = wR@hP + wI@xP
            uL = (wRp @ hL - wRn @ hU) + (wIp @ xL - wIn @ xU)
            uU = (wRp @ hU - wRn @ hL) + (wIp @ xU - wIn @ xL)

            hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
            hL = hL*(1-1/self.τ) + Activation(uL,self.act)/self.τ
            hU = hU*(1-1/self.τ) + Activation(uU,self.act)/self.τ
    
            yP = (wO@hP)
            yL = (wOp @ hL - wOn @ hU)
            yU = (wOp @ hU - wOn @ hL)

            #if show: print(yP)
            yP = yP[0]
            yL = yL[0]
            yU = yU[0]

            xP = np.delete(np.append(xP,yP),0)
            xL = np.delete(np.append(xL,yL),0)
            xU = np.delete(np.append(xU,yU),0)
            PredVals = [yL,yP,yU]

            if Ruls[0] == 0:
                self.yL = np.append(self.yL,yL)
                self.yP = np.append(self.yP,yP)
                self.yU = np.append(self.yU,yU)
            
            CheckPred,CheckLim=0,0
            for i in range(3):
                if PredRuls[i]: 
                    Ruls[i] = Ruls[i]+1
                    if Ruls[i] >= maxRul:
                        CheckLim = CheckLim + 1
                        Ruls[i] = maxRul
                        PredRuls[i] = False
                if PredVals[i] < lim: PredRuls[i] = False
                if not PredRuls[i]: CheckPred = CheckPred + 1
            if CheckPred == 3:break
            if CheckLim == 3:break
        
        self.rR=self.ref-self.k
        self.rL,self.rP,self.rU = Ruls

        if store:
            self.rulR = np.append(self.rulR,self.rR)
            self.rulL = np.append(self.rulL,self.rL)
            self.rulP = np.append(self.rulP,self.rP)
            self.rulU = np.append(self.rulU,self.rU)
    
    def PredRulIntr2(self, x,lim=0.2,maxRul=110,store=False,show=False):
        #print('yH:',self.yP_hist)
        #print('eS: ',self.eS)

        for i,y in enumerate(self.yP_hist):
            if y != 0:
                self.eS2[i] = self.rls.predict(np.abs(y))
        #print('eS2:',self.eS2)

        xP,xL,xU =x.copy(), (x-(self.ρ*self.eS2)).copy(),(x+(self.ρ*self.eS2)).copy()    

        #xP,xL,xU =x.copy(), x.copy()*0.999, x.copy()*1.00

        predict = True
        PredRuls = [True for i in range(3)]
        PredVals, Ruls = [0 for i in range(3)], [0 for i in range(3)]
        wR,wI,wO = self.wR,self.wI,self.wO
        ep = 0.125
        wRp, wRn = np.maximum((1+ep)*wR, (1-ep)*wR), np.minimum((1+ep)*wR, (1-ep)*wR)

        print('wRn',wRn[0][:5])
        print('wR ',wR[0][:5])
        print('wRp',wRp[0][:5])
        print('---')

        wIp, wIn = np.maximum((1+ep)*wI, (1-ep)*wI), np.minimum((1+ep)*wI, (1-ep)*wI)
        wOp, wOn = np.maximum((1+ep)*wO, (1-ep)*wO), np.minimum((1+ep)*wO, (1-ep)*wO)

        #hU,hL = np.maximum(0, self.hS), np.minimum(0, self.hS)
        #hL,hP,hU = (1-ep)*self.hP.copy(),self.hP.copy(),(1+ep)*self.hP.copy()  
        hP = self.hP.copy()  
        hU, hL = np.maximum((1+ep)*hP, (1-ep)*hP), np.minimum((1+ep)*hP, (1-ep)*hP)

        while predict:
            uP = wR@hP + wI@xP
            uL = (wRn @ hL) + (wIn @ xL)
            uU = (wRp @ hU) + (wIp @ xU)

            hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
            hL = hL*(1-1/self.τ) + Activation(uL,self.act)/self.τ
            hU = hU*(1-1/self.τ) + Activation(uU,self.act)/self.τ
    
            yP = (wO@hP)[0]
            yL = (wOn @ hL)[0]
            yU = (wOp @ hU)[0]

            PredVals = sorted([yL,yP,yU])

            yL,yP,yU = PredVals

            xP = np.delete(np.append(xP,yP),0)
            xL = np.delete(np.append(xL,yL),0)
            xU = np.delete(np.append(xU,yU),0)

            if Ruls[0] == 0:
                self.yL = np.append(self.yL,yL)
                self.yP = np.append(self.yP,yP)
                self.yU = np.append(self.yU,yU)
            
            CheckPred,CheckLim=0,0
            for i in range(3):
                if PredRuls[i]: 
                    Ruls[i] = Ruls[i]+1
                    if Ruls[i] >= maxRul:
                        CheckLim = CheckLim + 1
                        Ruls[i] = maxRul
                        PredRuls[i] = False
                if PredVals[i] < lim: PredRuls[i] = False
                if not PredRuls[i]: CheckPred = CheckPred + 1
            if CheckPred == 3:break
            if CheckLim == 3:break
        
        self.rR=self.ref-self.k
        self.rL,self.rP,self.rU = Ruls

        if store:
            self.rulR = np.append(self.rulR,self.rR)
            self.rulL = np.append(self.rulL,self.rL)
            self.rulP = np.append(self.rulP,self.rP)
            self.rulU = np.append(self.rulU,self.rU)
    
    def PredRul(self, x,maxRul=100,lim=0.2,store=False):
        xP = x.copy()
        rulP=0
        predict = True
        hP = self.hP.copy()
        while predict:
            uP = (self.wR @ hP) + (self.wI @ xP)
            hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
            yP = (self.wO @ hP)[0]
            xP = np.delete(np.append(xP,yP),0)
            if store:
                if rulP==0:
                    self.yP = np.append(self.yP,yP)

            if predict: rulP = rulP+1
            if yP < lim: predict = False
            if rulP >= maxRul:
                break

        self.rR=self.ref-self.k
        self.rP = rulP

        if store:
            self.rulR = np.append(self.rulR,self.rR)
            self.rulP = np.append(self.rulP,self.rP)
            
    
    def UpdateRLS(self,yP,yR):
        eP = np.abs(self.rls.predict(np.abs(yP[0])))
        eR = np.abs(yP-yR)[0]
        self.rls.update(np.abs(yP[0]), eR)
        self.eR = np.append(self.eR,eR)
        self.eP = np.append(self.eP,eP)
        self.eS = np.append(self.eS,eP)
        self.eS = np.delete(self.eS,0)

# %% [markdown]
# #Optimize parameters for minimize error of degradation prediction

# %%
rates = [1/(10**i) for i in range(1,7)][::-1]
def objective(trial):

    nI = trial.suggest_int('nI', 2, 30) 
    nR = trial.suggest_int('nR', 1, 50) 
    nO = trial.suggest_int('nO', 1, 10) 
    N1 = trial.suggest_categorical('N1', rates[:]) 
    N2 = trial.suggest_categorical('N2', rates[:]) 
    N3 = trial.suggest_categorical('N3', rates[:]) 
    τ = trial.suggest_int('τ', 1, 30)        
    X,Y = PrepareDataAhead(sig,n=nI,m=nO)
    X,Y = X[:-1],Y[:-1]
    rnn = RTLO(nI,nR,nO,[N1,N2,N3],τ)
    rnn.ref = len(sig)-nI
    cont = 0
    for i,_ in enumerate(X):
        rnn.PredRul(X[i],maxRul=len(sig)-nI,lim=0.75,store=True)
        rnn.fit(X[i],Y[i],store=True)

        '''if i == 50:
            if np.mean(rnn.εM_hist)>1:
                raise TrialPruned()
            if np.mean(rnn.rulP)>np.mean(rnn.rulR)*1.1:
                raise TrialPruned()
            if np.mean(rnn.rulP)<np.mean(rnn.rulR)*0.3:
                raise TrialPruned()
        if i>=40:
            if rnn.rulP[i]==rnn.rulP[i-1]:
                cont = cont+1
            if cont> 20:
                raise TrialPruned()'''
            
    return rnn.εM+rnn.εR

#pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
pruner=optuna.pruners.HyperbandPruner()

study = optuna.create_study(
    direction="minimize",
    sampler=SelSampler(mode='random'),
    pruner=pruner,
    #storage="sqlite:///" + f'Optuna/{FileName}_Prdct.db', study_name=f'P{4}',
    load_if_exists=True)
study.optimize(objective, n_trials=10000)
params = list(study.best_params.values())
print('Erro:', study.best_value, 'parameters: ', params)
# Out:
# [I 2026-04-23 14:58:14,755] A new study created in memory with name: no-name-6a378f39-8532-44e5-8e13-d7f850518553
# [I 2026-04-23 14:58:14,765] Trial 0 finished with value: 2.573423008397281 and parameters: {'nI': 12, 'nR': 12, 'nO': 6, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.001, 'τ': 26}. Best is trial 0 with value: 2.573423008397281.
# [I 2026-04-23 14:58:14,777] Trial 1 finished with value: 2.025864405863426 and parameters: {'nI': 6, 'nR': 37, 'nO': 4, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.0001, 'τ': 12}. Best is trial 1 with value: 2.025864405863426.
# [I 2026-04-23 14:58:14,784] Trial 2 finished with value: 2.1629819034945994 and parameters: {'nI': 5, 'nR': 44, 'nO': 4, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.001, 'τ': 22}. Best is trial 1 with value: 2.025864405863426.
# [I 2026-04-23 14:58:14,797] Trial 3 finished with value: 0.9428254261433733 and parameters: {'nI': 8, 'nR': 5, 'nO': 1, 'N1': 0.0001, 'N2': 0.01, 'N3': 1e-06, 'τ': 29}. Best is trial 3 with value: 0.9428254261433733.
# [I 2026-04-23 14:58:14,807] Trial 4 finished with value: 0.7568591861525014 and parameters: {'nI': 18, 'nR': 7, 'nO': 1, 'N1': 0.0001, 'N2': 0.1, 'N3': 1e-05, 'τ': 19}. Best is trial 4 with value: 0.7568591861525014.
# [I 2026-04-23 14:58:14,856] Trial 5 finished with value: 8.473910076162754 and parameters: {'nI': 18, 'nR': 24, 'nO': 8, 'N1': 0.001, 'N2': 0.001, 'N3': 0.001, 'τ': 6}. Best is trial 4 with value: 0.7568591861525014.
# [I 2026-04-23 14:58:14,976] Trial 6 finished with value: 0.004380361514483936 and parameters: {'nI': 7, 'nR': 8, 'nO': 10, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.01, 'τ': 7}. Best is trial 6 with value: 0.004380361514483936.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:292: RuntimeWarning: overflow encountered in matmul
#   uP = (self.wR @ hP) + (self.wI @ xP)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:294: RuntimeWarning: overflow encountered in matmul
#   yP = (self.wO @ hP)[0]
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:292: RuntimeWarning: invalid value encountered in matmul
#   uP = (self.wR @ hP) + (self.wI @ xP)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:292: RuntimeWarning: invalid value encountered in add
#   uP = (self.wR @ hP) + (self.wI @ xP)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:72: RuntimeWarning: overflow encountered in matmul
#   yP = self.wO @ hP
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:91: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# [W 2026-04-23 14:58:15,076] Trial 7 failed with parameters: {'nI': 14, 'nR': 12, 'nO': 10, 'N1': 0.01, 'N2': 0.001, 'N3': 0.1, 'τ': 23} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:15,076] Trial 7 failed with value nan.
# c:\Users\Claudio\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\numeric.py:925: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:91: RuntimeWarning: overflow encountered in multiply
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:69: RuntimeWarning: overflow encountered in matmul
#   uS = self.wR @ self.hP + self.wI @ xP
# c:\Users\Claudio\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\numeric.py:925: RuntimeWarning: invalid value encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:91: RuntimeWarning: invalid value encountered in multiply
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:95: RuntimeWarning: invalid value encountered in add
#   self.ΔRS = (self.ΔRS*(self.k-1) + δRS)/self.k
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:96: RuntimeWarning: invalid value encountered in add
#   self.ΔOS = (self.ΔOS*(self.k-1) + δOS)/self.k
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:99: RuntimeWarning: invalid value encountered in add
#   self.wR = self.wR + δRS
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:100: RuntimeWarning: invalid value encountered in add
#   self.wO = self.wO + δOS
# [W 2026-04-23 14:58:15,196] Trial 8 failed with parameters: {'nI': 16, 'nR': 18, 'nO': 7, 'N1': 0.001, 'N2': 0.1, 'N3': 0.01, 'τ': 21} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:15,201] Trial 8 failed with value nan.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:294: RuntimeWarning: invalid value encountered in matmul
#   yP = (self.wO @ hP)[0]
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:92: RuntimeWarning: invalid value encountered in multiply
#   δIS = η3*np.outer(np.dot(self.BS, eS),np.ones(self.nI))*self.qS
# [W 2026-04-23 14:58:15,301] Trial 9 failed with parameters: {'nI': 20, 'nR': 30, 'nO': 4, 'N1': 0.1, 'N2': 0.01, 'N3': 0.0001, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:15,301] Trial 9 failed with value nan.
# [I 2026-04-23 14:58:15,313] Trial 10 finished with value: 1.6301713176112311 and parameters: {'nI': 2, 'nR': 31, 'nO': 3, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.0001, 'τ': 26}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:15,376] Trial 11 finished with value: 0.26186436512083083 and parameters: {'nI': 28, 'nR': 6, 'nO': 10, 'N1': 0.01, 'N2': 0.1, 'N3': 0.01, 'τ': 22}. Best is trial 6 with value: 0.004380361514483936.
# [W 2026-04-23 14:58:15,501] Trial 12 failed with parameters: {'nI': 20, 'nR': 37, 'nO': 9, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.1, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:15,501] Trial 12 failed with value nan.
# [W 2026-04-23 14:58:15,571] Trial 13 failed with parameters: {'nI': 13, 'nR': 38, 'nO': 9, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-06, 'τ': 10} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:15,571] Trial 13 failed with value nan.
# [I 2026-04-23 14:58:15,584] Trial 14 finished with value: 3.292950524479872e+27 and parameters: {'nI': 27, 'nR': 18, 'nO': 9, 'N1': 1e-06, 'N2': 0.01, 'N3': 1e-05, 'τ': 25}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:15,596] Trial 15 finished with value: 2.202995495347687 and parameters: {'nI': 27, 'nR': 7, 'nO': 6, 'N1': 1e-05, 'N2': 0.0001, 'N3': 1e-05, 'τ': 5}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:15,675] Trial 16 finished with value: 3.0592324697587037 and parameters: {'nI': 28, 'nR': 39, 'nO': 6, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 12}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:15,686] Trial 17 finished with value: 1.7296094061268208 and parameters: {'nI': 8, 'nR': 11, 'nO': 4, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.1, 'τ': 21}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:15,809] Trial 18 finished with value: 0.07405552970971695 and parameters: {'nI': 3, 'nR': 24, 'nO': 1, 'N1': 0.001, 'N2': 0.001, 'N3': 0.1, 'τ': 7}. Best is trial 6 with value: 0.004380361514483936.
# [W 2026-04-23 14:58:15,929] Trial 19 failed with parameters: {'nI': 11, 'nR': 35, 'nO': 9, 'N1': 0.01, 'N2': 0.1, 'N3': 0.01, 'τ': 12} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:15,929] Trial 19 failed with value nan.
# [I 2026-04-23 14:58:15,945] Trial 20 finished with value: 0.6255350557413295 and parameters: {'nI': 21, 'nR': 43, 'nO': 1, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-06, 'τ': 16}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:15,959] Trial 21 finished with value: 2.1022301896028273 and parameters: {'nI': 24, 'nR': 25, 'nO': 8, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.001, 'τ': 7}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:16,120] Trial 22 finished with value: 0.04158902958411953 and parameters: {'nI': 5, 'nR': 45, 'nO': 6, 'N1': 0.1, 'N2': 0.1, 'N3': 0.1, 'τ': 18}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:16,248] Trial 23 finished with value: 9.366879299752526 and parameters: {'nI': 20, 'nR': 17, 'nO': 3, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.001, 'τ': 23}. Best is trial 6 with value: 0.004380361514483936.
# [W 2026-04-23 14:58:16,325] Trial 24 failed with parameters: {'nI': 28, 'nR': 47, 'nO': 6, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.01, 'τ': 6} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:16,325] Trial 24 failed with value nan.
# [I 2026-04-23 14:58:16,426] Trial 25 finished with value: 0.036077244653724555 and parameters: {'nI': 28, 'nR': 23, 'nO': 8, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.0001, 'τ': 12}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:16,546] Trial 26 finished with value: 0.24642303977635868 and parameters: {'nI': 15, 'nR': 50, 'nO': 10, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.0001, 'τ': 12}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:16,562] Trial 27 finished with value: 2.792132188601522 and parameters: {'nI': 24, 'nR': 7, 'nO': 4, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.001, 'τ': 21}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:16,666] Trial 28 finished with value: 0.014111948517872747 and parameters: {'nI': 10, 'nR': 13, 'nO': 4, 'N1': 0.1, 'N2': 0.01, 'N3': 1e-05, 'τ': 11}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:16,740] Trial 29 finished with value: 0.11478234608096348 and parameters: {'nI': 8, 'nR': 12, 'nO': 9, 'N1': 0.01, 'N2': 0.001, 'N3': 1e-06, 'τ': 8}. Best is trial 6 with value: 0.004380361514483936.
# [W 2026-04-23 14:58:16,884] Trial 30 failed with parameters: {'nI': 8, 'nR': 20, 'nO': 6, 'N1': 1e-05, 'N2': 0.001, 'N3': 0.1, 'τ': 2} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:16,884] Trial 30 failed with value nan.
# [I 2026-04-23 14:58:16,942] Trial 31 finished with value: 8.643831181174646 and parameters: {'nI': 12, 'nR': 39, 'nO': 5, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-06, 'τ': 19}. Best is trial 6 with value: 0.004380361514483936.
# [I 2026-04-23 14:58:16,955] Trial 32 finished with value: 3.2822383169217346 and parameters: {'nI': 27, 'nR': 35, 'nO': 6, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.0001, 'τ': 9}. Best is trial 6 with value: 0.004380361514483936.
# [W 2026-04-23 14:58:17,043] Trial 33 failed with parameters: {'nI': 24, 'nR': 28, 'nO': 9, 'N1': 0.001, 'N2': 0.1, 'N3': 0.001, 'τ': 29} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:17,043] Trial 33 failed with value nan.
# [I 2026-04-23 14:58:17,149] Trial 34 finished with value: 77.39045709434666 and parameters: {'nI': 5, 'nR': 25, 'nO': 3, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.1, 'τ': 16}. Best is trial 6 with value: 0.004380361514483936.
# [W 2026-04-23 14:58:17,278] Trial 35 failed with parameters: {'nI': 13, 'nR': 33, 'nO': 5, 'N1': 0.01, 'N2': 0.1, 'N3': 0.1, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:17,278] Trial 35 failed with value nan.
# [I 2026-04-23 14:58:17,325] Trial 36 finished with value: 0.0033185742073780725 and parameters: {'nI': 19, 'nR': 42, 'nO': 3, 'N1': 0.1, 'N2': 0.1, 'N3': 0.01, 'τ': 10}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:17,396] Trial 37 finished with value: 21.22242382952757 and parameters: {'nI': 17, 'nR': 22, 'nO': 3, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.01, 'τ': 23}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:17,449] Trial 38 failed with parameters: {'nI': 19, 'nR': 32, 'nO': 6, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-05, 'τ': 18} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:17,449] Trial 38 failed with value nan.
# [I 2026-04-23 14:58:17,550] Trial 39 finished with value: 0.1559359757719183 and parameters: {'nI': 15, 'nR': 20, 'nO': 5, 'N1': 0.01, 'N2': 0.01, 'N3': 1e-05, 'τ': 9}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:17,632] Trial 40 finished with value: 0.025763248052418246 and parameters: {'nI': 17, 'nR': 18, 'nO': 9, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 1}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:17,650] Trial 41 finished with value: 1.0424630023775607 and parameters: {'nI': 5, 'nR': 48, 'nO': 2, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.001, 'τ': 2}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:17,731] Trial 42 failed with parameters: {'nI': 27, 'nR': 41, 'nO': 2, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.1, 'τ': 19} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:17,731] Trial 42 failed with value nan.
# [I 2026-04-23 14:58:17,842] Trial 43 finished with value: 0.0045025610835782 and parameters: {'nI': 19, 'nR': 46, 'nO': 1, 'N1': 0.01, 'N2': 0.0001, 'N3': 0.01, 'τ': 4}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:17,940] Trial 44 failed with parameters: {'nI': 4, 'nR': 49, 'nO': 10, 'N1': 0.001, 'N2': 0.1, 'N3': 1e-06, 'τ': 21} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:17,940] Trial 44 failed with value nan.
# [I 2026-04-23 14:58:17,955] Trial 45 finished with value: 1.5237665606492832 and parameters: {'nI': 29, 'nR': 40, 'nO': 2, 'N1': 1e-05, 'N2': 0.0001, 'N3': 1e-05, 'τ': 19}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:18,073] Trial 46 failed with parameters: {'nI': 10, 'nR': 43, 'nO': 3, 'N1': 0.001, 'N2': 0.1, 'N3': 0.1, 'τ': 28} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:18,073] Trial 46 failed with value nan.
# [I 2026-04-23 14:58:18,079] Trial 47 finished with value: 0.7931183983470085 and parameters: {'nI': 19, 'nR': 9, 'nO': 2, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-06, 'τ': 1}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:18,171] Trial 48 failed with parameters: {'nI': 19, 'nR': 49, 'nO': 7, 'N1': 0.001, 'N2': 0.1, 'N3': 0.01, 'τ': 22} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:18,171] Trial 48 failed with value nan.
# [I 2026-04-23 14:58:18,244] Trial 49 finished with value: 0.15674657735583408 and parameters: {'nI': 18, 'nR': 14, 'nO': 7, 'N1': 0.001, 'N2': 0.001, 'N3': 0.1, 'τ': 18}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:18,244] Trial 50 finished with value: 0.5257114638618592 and parameters: {'nI': 18, 'nR': 8, 'nO': 3, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.001, 'τ': 6}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:18,380] Trial 51 failed with parameters: {'nI': 4, 'nR': 4, 'nO': 2, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.01, 'τ': 8} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:18,380] Trial 51 failed with value nan.
# [I 2026-04-23 14:58:18,395] Trial 52 finished with value: 1.2513146883193063 and parameters: {'nI': 24, 'nR': 10, 'nO': 2, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-05, 'τ': 6}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:18,534] Trial 53 failed with parameters: {'nI': 18, 'nR': 12, 'nO': 4, 'N1': 1e-06, 'N2': 0.1, 'N3': 0.01, 'τ': 15} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:18,534] Trial 53 failed with value nan.
# [I 2026-04-23 14:58:18,612] Trial 54 finished with value: 64.51345340985046 and parameters: {'nI': 24, 'nR': 23, 'nO': 3, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.01, 'τ': 11}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:18,635] Trial 55 finished with value: 0.0941647317372735 and parameters: {'nI': 17, 'nR': 36, 'nO': 3, 'N1': 0.01, 'N2': 1e-05, 'N3': 1e-05, 'τ': 24}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:18,760] Trial 56 finished with value: 7.312952208605968 and parameters: {'nI': 20, 'nR': 39, 'nO': 3, 'N1': 1e-05, 'N2': 0.001, 'N3': 1e-05, 'τ': 14}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:18,896] Trial 57 finished with value: 24.173567589536894 and parameters: {'nI': 20, 'nR': 18, 'nO': 10, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-05, 'τ': 6}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:18,996] Trial 58 failed with parameters: {'nI': 25, 'nR': 24, 'nO': 2, 'N1': 1e-06, 'N2': 0.1, 'N3': 0.001, 'τ': 11} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:18,996] Trial 58 failed with value nan.
# [I 2026-04-23 14:58:19,084] Trial 59 finished with value: 0.5684282580162621 and parameters: {'nI': 8, 'nR': 16, 'nO': 5, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.001, 'τ': 24}. Best is trial 36 with value: 0.0033185742073780725.
# [W 2026-04-23 14:58:19,189] Trial 60 failed with parameters: {'nI': 30, 'nR': 38, 'nO': 9, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.01, 'τ': 18} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:19,189] Trial 60 failed with value nan.
# [I 2026-04-23 14:58:19,189] Trial 61 finished with value: 2.3912236751183635 and parameters: {'nI': 6, 'nR': 44, 'nO': 8, 'N1': 0.001, 'N2': 0.001, 'N3': 0.0001, 'τ': 27}. Best is trial 36 with value: 0.0033185742073780725.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:113: RuntimeWarning: overflow encountered in scalar multiply
#   self.εY = ((self.εY*self.ΣW) + (W*ΔY[0]))/ΣW
# [W 2026-04-23 14:58:19,317] Trial 62 failed with parameters: {'nI': 6, 'nR': 31, 'nO': 5, 'N1': 0.001, 'N2': 0.1, 'N3': 0.01, 'τ': 30} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:19,317] Trial 62 failed with value nan.
# [I 2026-04-23 14:58:19,325] Trial 63 finished with value: 1.5660120589429603 and parameters: {'nI': 12, 'nR': 46, 'nO': 5, 'N1': 0.001, 'N2': 0.001, 'N3': 0.0001, 'τ': 16}. Best is trial 36 with value: 0.0033185742073780725.
# [I 2026-04-23 14:58:19,421] Trial 64 finished with value: 0.0020109938357879614 and parameters: {'nI': 7, 'nR': 43, 'nO': 3, 'N1': 0.1, 'N2': 0.001, 'N3': 0.1, 'τ': 11}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,552] Trial 65 finished with value: 0.05902433729736219 and parameters: {'nI': 6, 'nR': 33, 'nO': 4, 'N1': 0.1, 'N2': 0.0001, 'N3': 1e-05, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,568] Trial 66 finished with value: 3.1630472131305276 and parameters: {'nI': 19, 'nR': 25, 'nO': 9, 'N1': 1e-05, 'N2': 0.001, 'N3': 1e-05, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,580] Trial 67 finished with value: 2.89099899232247 and parameters: {'nI': 27, 'nR': 1, 'nO': 9, 'N1': 0.001, 'N2': 0.1, 'N3': 1e-05, 'τ': 3}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,588] Trial 68 finished with value: 2.281099207035224 and parameters: {'nI': 2, 'nR': 33, 'nO': 3, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.001, 'τ': 6}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,671] Trial 69 finished with value: 0.005971836945808044 and parameters: {'nI': 12, 'nR': 34, 'nO': 9, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.0001, 'τ': 15}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,788] Trial 70 finished with value: 2.7387269429789525 and parameters: {'nI': 20, 'nR': 33, 'nO': 1, 'N1': 0.0001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 27}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:19,879] Trial 71 failed with parameters: {'nI': 26, 'nR': 9, 'nO': 3, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.1, 'τ': 26} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:19,879] Trial 71 failed with value nan.
# [I 2026-04-23 14:58:19,885] Trial 72 finished with value: 0.9146442506035588 and parameters: {'nI': 9, 'nR': 2, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.0001, 'τ': 19}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,900] Trial 73 finished with value: 1.6973522014679798 and parameters: {'nI': 25, 'nR': 32, 'nO': 4, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-05, 'τ': 27}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:19,908] Trial 74 finished with value: 2.6409670491052397 and parameters: {'nI': 6, 'nR': 13, 'nO': 6, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.001, 'τ': 26}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:20,005] Trial 75 failed with parameters: {'nI': 19, 'nR': 29, 'nO': 5, 'N1': 1e-05, 'N2': 1e-06, 'N3': 0.1, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:20,005] Trial 75 failed with value nan.
# [I 2026-04-23 14:58:20,079] Trial 76 finished with value: 0.4846429980936342 and parameters: {'nI': 2, 'nR': 16, 'nO': 3, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.1, 'τ': 13}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:20,094] Trial 77 finished with value: 1.9996108547002478 and parameters: {'nI': 17, 'nR': 8, 'nO': 4, 'N1': 1e-05, 'N2': 1e-06, 'N3': 0.001, 'τ': 18}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:20,198] Trial 78 finished with value: 0.13156285593069664 and parameters: {'nI': 24, 'nR': 21, 'nO': 4, 'N1': 0.1, 'N2': 1e-06, 'N3': 1e-06, 'τ': 30}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:20,214] Trial 79 finished with value: 1.5175184121647782 and parameters: {'nI': 6, 'nR': 36, 'nO': 3, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 23}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:20,337] Trial 80 failed with parameters: {'nI': 20, 'nR': 34, 'nO': 10, 'N1': 0.001, 'N2': 0.1, 'N3': 0.0001, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:20,337] Trial 80 failed with value nan.
# [I 2026-04-23 14:58:20,353] Trial 81 finished with value: 14.995591130751357 and parameters: {'nI': 7, 'nR': 37, 'nO': 10, 'N1': 1e-06, 'N2': 1e-06, 'N3': 0.01, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:20,483] Trial 82 failed with parameters: {'nI': 11, 'nR': 28, 'nO': 10, 'N1': 0.1, 'N2': 0.01, 'N3': 0.1, 'τ': 21} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:20,483] Trial 82 failed with value nan.
# [I 2026-04-23 14:58:20,554] Trial 83 finished with value: 0.12627529859540926 and parameters: {'nI': 21, 'nR': 11, 'nO': 1, 'N1': 1e-06, 'N2': 1e-06, 'N3': 0.01, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:20,646] Trial 84 failed with parameters: {'nI': 27, 'nR': 6, 'nO': 6, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.1, 'τ': 21} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:20,646] Trial 84 failed with value nan.
# [I 2026-04-23 14:58:20,742] Trial 85 finished with value: 0.8618544847837384 and parameters: {'nI': 30, 'nR': 34, 'nO': 3, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 30}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:20,758] Trial 86 finished with value: 0.9823843249182409 and parameters: {'nI': 29, 'nR': 38, 'nO': 1, 'N1': 1e-05, 'N2': 1e-05, 'N3': 1e-05, 'τ': 8}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:20,771] Trial 87 finished with value: 3.943560183007106 and parameters: {'nI': 29, 'nR': 24, 'nO': 6, 'N1': 1e-05, 'N2': 0.001, 'N3': 1e-06, 'τ': 28}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:20,775] Trial 88 finished with value: 2.3316525605202827 and parameters: {'nI': 26, 'nR': 6, 'nO': 6, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.01, 'τ': 29}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:20,888] Trial 89 failed with parameters: {'nI': 27, 'nR': 22, 'nO': 4, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.1, 'τ': 3} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:20,888] Trial 89 failed with value nan.
# [W 2026-04-23 14:58:20,946] Trial 90 failed with parameters: {'nI': 13, 'nR': 40, 'nO': 8, 'N1': 1e-06, 'N2': 0.01, 'N3': 0.001, 'τ': 20} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:20,946] Trial 90 failed with value nan.
# [I 2026-04-23 14:58:20,962] Trial 91 finished with value: 1.4388346848451288 and parameters: {'nI': 10, 'nR': 6, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.001, 'τ': 8}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,046] Trial 92 finished with value: 0.5267569375047096 and parameters: {'nI': 30, 'nR': 40, 'nO': 7, 'N1': 0.01, 'N2': 0.01, 'N3': 1e-06, 'τ': 15}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,062] Trial 93 finished with value: 2.1527067881025865 and parameters: {'nI': 15, 'nR': 11, 'nO': 4, 'N1': 0.0001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 23}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,077] Trial 94 finished with value: 3.9344108847789596 and parameters: {'nI': 3, 'nR': 40, 'nO': 10, 'N1': 0.0001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 19}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:21,173] Trial 95 failed with parameters: {'nI': 7, 'nR': 31, 'nO': 10, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-06, 'τ': 13} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:21,173] Trial 95 failed with value nan.
# [I 2026-04-23 14:58:21,173] Trial 96 finished with value: 0.07729850445936995 and parameters: {'nI': 23, 'nR': 12, 'nO': 1, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.001, 'τ': 5}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:21,317] Trial 97 failed with parameters: {'nI': 4, 'nR': 28, 'nO': 8, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.1, 'τ': 28} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:21,317] Trial 97 failed with value nan.
# [I 2026-04-23 14:58:21,322] Trial 98 finished with value: 1.6793407074980151 and parameters: {'nI': 27, 'nR': 18, 'nO': 4, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 15}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,400] Trial 99 finished with value: 0.04583657275212691 and parameters: {'nI': 23, 'nR': 45, 'nO': 4, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 4}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,508] Trial 100 finished with value: 0.031467167477104194 and parameters: {'nI': 16, 'nR': 21, 'nO': 2, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 6}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,508] Trial 101 finished with value: 0.7284635489761251 and parameters: {'nI': 13, 'nR': 14, 'nO': 1, 'N1': 1e-06, 'N2': 1e-06, 'N3': 0.0001, 'τ': 9}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:21,647] Trial 102 failed with parameters: {'nI': 19, 'nR': 18, 'nO': 3, 'N1': 1e-06, 'N2': 1e-06, 'N3': 0.1, 'τ': 2} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:21,647] Trial 102 failed with value nan.
# [I 2026-04-23 14:58:21,650] Trial 103 finished with value: 4.607630096917842 and parameters: {'nI': 20, 'nR': 46, 'nO': 8, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-06, 'τ': 23}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,675] Trial 104 finished with value: 0.1771680425383363 and parameters: {'nI': 2, 'nR': 35, 'nO': 8, 'N1': 0.01, 'N2': 0.01, 'N3': 0.0001, 'τ': 17}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:21,814] Trial 105 finished with value: 15.56827610779368 and parameters: {'nI': 22, 'nR': 32, 'nO': 3, 'N1': 0.0001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 1}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:21,966] Trial 106 failed with parameters: {'nI': 2, 'nR': 37, 'nO': 9, 'N1': 0.01, 'N2': 0.1, 'N3': 1e-06, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:21,966] Trial 106 failed with value nan.
# [I 2026-04-23 14:58:22,043] Trial 107 finished with value: 0.010283132910786455 and parameters: {'nI': 29, 'nR': 17, 'nO': 1, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.1, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:22,135] Trial 108 failed with parameters: {'nI': 5, 'nR': 44, 'nO': 10, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.01, 'τ': 15} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:22,135] Trial 108 failed with value nan.
# [I 2026-04-23 14:58:22,227] Trial 109 finished with value: 0.004759668780624559 and parameters: {'nI': 19, 'nR': 19, 'nO': 6, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.0001, 'τ': 3}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:22,333] Trial 110 failed with parameters: {'nI': 26, 'nR': 37, 'nO': 5, 'N1': 0.01, 'N2': 0.01, 'N3': 0.1, 'τ': 3} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:22,333] Trial 110 failed with value nan.
# [I 2026-04-23 14:58:22,352] Trial 111 finished with value: 2.4604513451514762 and parameters: {'nI': 6, 'nR': 31, 'nO': 10, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.0001, 'τ': 17}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:22,453] Trial 112 finished with value: 0.34505253833738386 and parameters: {'nI': 20, 'nR': 13, 'nO': 4, 'N1': 0.01, 'N2': 0.0001, 'N3': 1e-06, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:22,456] Trial 113 finished with value: 3.559771517408645 and parameters: {'nI': 26, 'nR': 45, 'nO': 7, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 30}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:22,549] Trial 114 failed with parameters: {'nI': 29, 'nR': 9, 'nO': 10, 'N1': 0.0001, 'N2': 0.1, 'N3': 1e-05, 'τ': 10} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:22,549] Trial 114 failed with value nan.
# [I 2026-04-23 14:58:22,558] Trial 115 finished with value: 0.03749998118874337 and parameters: {'nI': 5, 'nR': 47, 'nO': 2, 'N1': 0.01, 'N2': 0.01, 'N3': 1e-05, 'τ': 5}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:22,692] Trial 116 failed with parameters: {'nI': 10, 'nR': 44, 'nO': 4, 'N1': 1e-05, 'N2': 0.1, 'N3': 1e-06, 'τ': 15} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:22,692] Trial 116 failed with value nan.
# [W 2026-04-23 14:58:22,729] Trial 117 failed with parameters: {'nI': 23, 'nR': 25, 'nO': 6, 'N1': 0.001, 'N2': 0.001, 'N3': 0.1, 'τ': 29} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:22,729] Trial 117 failed with value nan.
# [W 2026-04-23 14:58:22,841] Trial 118 failed with parameters: {'nI': 21, 'nR': 11, 'nO': 9, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.01, 'τ': 10} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:22,841] Trial 118 failed with value nan.
# [I 2026-04-23 14:58:22,857] Trial 119 finished with value: 3.3081441373923957 and parameters: {'nI': 8, 'nR': 18, 'nO': 9, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 21}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:22,976] Trial 120 finished with value: 0.8749692500732167 and parameters: {'nI': 21, 'nR': 45, 'nO': 10, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.001, 'τ': 22}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,080] Trial 121 finished with value: 2.670352573402326 and parameters: {'nI': 3, 'nR': 17, 'nO': 5, 'N1': 0.01, 'N2': 0.1, 'N3': 1e-06, 'τ': 29}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,197] Trial 122 finished with value: 4.279418801892046 and parameters: {'nI': 20, 'nR': 39, 'nO': 5, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 16}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,210] Trial 123 finished with value: 0.1170581277201916 and parameters: {'nI': 16, 'nR': 9, 'nO': 3, 'N1': 0.01, 'N2': 1e-06, 'N3': 1e-06, 'τ': 9}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,317] Trial 124 finished with value: 0.0021098636382566936 and parameters: {'nI': 21, 'nR': 18, 'nO': 1, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-06, 'τ': 3}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,327] Trial 125 finished with value: 0.6819414378998324 and parameters: {'nI': 14, 'nR': 16, 'nO': 1, 'N1': 0.0001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 26}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:23,423] Trial 126 failed with parameters: {'nI': 19, 'nR': 30, 'nO': 5, 'N1': 0.01, 'N2': 0.1, 'N3': 0.001, 'τ': 21} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:23,425] Trial 126 failed with value nan.
# [I 2026-04-23 14:58:23,436] Trial 127 finished with value: 1.0871334922481208 and parameters: {'nI': 22, 'nR': 7, 'nO': 2, 'N1': 0.01, 'N2': 1e-05, 'N3': 1e-05, 'τ': 29}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,480] Trial 128 finished with value: inf and parameters: {'nI': 27, 'nR': 40, 'nO': 5, 'N1': 1e-05, 'N2': 0.001, 'N3': 0.01, 'τ': 25}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,492] Trial 129 finished with value: 1.2519396893496788 and parameters: {'nI': 26, 'nR': 7, 'nO': 4, 'N1': 1e-06, 'N2': 1e-05, 'N3': 0.001, 'τ': 1}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,605] Trial 130 finished with value: 22.618518823426065 and parameters: {'nI': 18, 'nR': 27, 'nO': 7, 'N1': 1e-05, 'N2': 0.001, 'N3': 1e-06, 'τ': 30}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,714] Trial 131 finished with value: 5.544835444869186 and parameters: {'nI': 25, 'nR': 20, 'nO': 6, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 29}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,725] Trial 132 finished with value: 4.446284636450692 and parameters: {'nI': 24, 'nR': 21, 'nO': 10, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-05, 'τ': 14}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,736] Trial 133 finished with value: 1.420333091373908 and parameters: {'nI': 2, 'nR': 19, 'nO': 7, 'N1': 0.01, 'N2': 0.0001, 'N3': 1e-05, 'τ': 12}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:23,835] Trial 134 failed with parameters: {'nI': 18, 'nR': 19, 'nO': 6, 'N1': 0.001, 'N2': 0.1, 'N3': 0.001, 'τ': 22} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:23,836] Trial 134 failed with value nan.
# [W 2026-04-23 14:58:23,962] Trial 135 failed with parameters: {'nI': 26, 'nR': 40, 'nO': 2, 'N1': 0.001, 'N2': 0.01, 'N3': 0.1, 'τ': 3} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:23,962] Trial 135 failed with value nan.
# [I 2026-04-23 14:58:23,977] Trial 136 finished with value: 309.29758175441106 and parameters: {'nI': 26, 'nR': 41, 'nO': 2, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.1, 'τ': 28}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:23,988] Trial 137 finished with value: 3.695217084167859 and parameters: {'nI': 7, 'nR': 17, 'nO': 7, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-05, 'τ': 29}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:24,134] Trial 138 failed with parameters: {'nI': 14, 'nR': 47, 'nO': 5, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.001, 'τ': 3} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:24,135] Trial 138 failed with value nan.
# [I 2026-04-23 14:58:24,222] Trial 139 finished with value: 0.04644174745212834 and parameters: {'nI': 30, 'nR': 25, 'nO': 3, 'N1': 0.01, 'N2': 1e-05, 'N3': 1e-05, 'τ': 7}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:24,231] Trial 140 finished with value: 1.8983307524008344 and parameters: {'nI': 20, 'nR': 2, 'nO': 4, 'N1': 0.01, 'N2': 0.1, 'N3': 0.001, 'τ': 28}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:24,279] Trial 141 finished with value: 0.8807526708779402 and parameters: {'nI': 5, 'nR': 10, 'nO': 3, 'N1': 0.1, 'N2': 0.1, 'N3': 1e-06, 'τ': 25}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:24,313] Trial 142 finished with value: inf and parameters: {'nI': 15, 'nR': 29, 'nO': 6, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-06, 'τ': 17}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:24,322] Trial 143 finished with value: 7.476492870994714 and parameters: {'nI': 20, 'nR': 21, 'nO': 9, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-05, 'τ': 4}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:24,339] Trial 144 finished with value: 0.2099538730868814 and parameters: {'nI': 3, 'nR': 10, 'nO': 8, 'N1': 0.1, 'N2': 0.001, 'N3': 1e-06, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:24,453] Trial 145 failed with parameters: {'nI': 11, 'nR': 35, 'nO': 9, 'N1': 0.01, 'N2': 0.1, 'N3': 0.01, 'τ': 8} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:24,453] Trial 145 failed with value nan.
# [W 2026-04-23 14:58:24,586] Trial 146 failed with parameters: {'nI': 23, 'nR': 28, 'nO': 7, 'N1': 0.01, 'N2': 0.001, 'N3': 0.1, 'τ': 3} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:24,586] Trial 146 failed with value nan.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:293: RuntimeWarning: invalid value encountered in multiply
#   hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
# [W 2026-04-23 14:58:24,771] Trial 147 failed with parameters: {'nI': 4, 'nR': 34, 'nO': 4, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-06, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:24,771] Trial 147 failed with value nan.
# [I 2026-04-23 14:58:24,781] Trial 148 finished with value: 0.49193350540576586 and parameters: {'nI': 21, 'nR': 49, 'nO': 1, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-05, 'τ': 26}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:24,894] Trial 149 finished with value: 1.0279954615965017 and parameters: {'nI': 24, 'nR': 26, 'nO': 4, 'N1': 0.01, 'N2': 0.001, 'N3': 0.01, 'τ': 21}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:24,936] Trial 150 finished with value: 6.125505732225655 and parameters: {'nI': 28, 'nR': 26, 'nO': 8, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.001, 'τ': 23}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:25,003] Trial 151 finished with value: 1.1499597022270684 and parameters: {'nI': 25, 'nR': 26, 'nO': 8, 'N1': 0.001, 'N2': 0.001, 'N3': 0.01, 'τ': 30}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:25,101] Trial 152 failed with parameters: {'nI': 5, 'nR': 11, 'nO': 8, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-06, 'τ': 26} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:25,101] Trial 152 failed with value nan.
# [I 2026-04-23 14:58:25,112] Trial 153 finished with value: 1.8978112809579004 and parameters: {'nI': 30, 'nR': 1, 'nO': 4, 'N1': 1e-05, 'N2': 0.001, 'N3': 0.1, 'τ': 27}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:25,156] Trial 154 finished with value: 33.42573449487225 and parameters: {'nI': 10, 'nR': 14, 'nO': 9, 'N1': 1e-06, 'N2': 1e-06, 'N3': 0.1, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:25,283] Trial 155 failed with parameters: {'nI': 16, 'nR': 12, 'nO': 2, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-06, 'τ': 12} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:25,284] Trial 155 failed with value nan.
# [W 2026-04-23 14:58:25,367] Trial 156 failed with parameters: {'nI': 15, 'nR': 44, 'nO': 10, 'N1': 1e-05, 'N2': 0.001, 'N3': 0.01, 'τ': 5} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:25,367] Trial 156 failed with value nan.
# [I 2026-04-23 14:58:25,422] Trial 157 finished with value: 5.379368022693254 and parameters: {'nI': 30, 'nR': 50, 'nO': 1, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-05, 'τ': 1}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:25,541] Trial 158 finished with value: 0.12724975280149703 and parameters: {'nI': 18, 'nR': 33, 'nO': 10, 'N1': 0.01, 'N2': 0.0001, 'N3': 0.0001, 'τ': 9}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:25,551] Trial 159 finished with value: 5.321647071846546 and parameters: {'nI': 28, 'nR': 40, 'nO': 9, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-05, 'τ': 21}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:25,617] Trial 160 failed with parameters: {'nI': 8, 'nR': 43, 'nO': 8, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-05, 'τ': 12} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:25,618] Trial 160 failed with value nan.
# [I 2026-04-23 14:58:25,629] Trial 161 finished with value: 2.786524049208483 and parameters: {'nI': 3, 'nR': 8, 'nO': 9, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 16}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:25,640] Trial 162 finished with value: 2.313008819066235 and parameters: {'nI': 13, 'nR': 34, 'nO': 5, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 10}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:25,726] Trial 163 finished with value: 24.501313914311336 and parameters: {'nI': 29, 'nR': 23, 'nO': 9, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-05, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:25,857] Trial 164 failed with parameters: {'nI': 18, 'nR': 32, 'nO': 7, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.001, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:25,857] Trial 164 failed with value nan.
# [I 2026-04-23 14:58:25,865] Trial 165 finished with value: 2.9790463065499098 and parameters: {'nI': 5, 'nR': 15, 'nO': 7, 'N1': 1e-05, 'N2': 1e-05, 'N3': 1e-05, 'τ': 27}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:25,965] Trial 166 failed with parameters: {'nI': 10, 'nR': 40, 'nO': 2, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-06, 'τ': 16} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:25,970] Trial 166 failed with value nan.
# [I 2026-04-23 14:58:25,978] Trial 167 finished with value: 3.9521452476594154 and parameters: {'nI': 15, 'nR': 40, 'nO': 10, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 25}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:26,057] Trial 168 failed with parameters: {'nI': 21, 'nR': 47, 'nO': 4, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-06, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:26,057] Trial 168 failed with value nan.
# [I 2026-04-23 14:58:26,228] Trial 169 finished with value: 3.9294426725217733 and parameters: {'nI': 10, 'nR': 30, 'nO': 1, 'N1': 0.0001, 'N2': 0.0001, 'N3': 0.01, 'τ': 4}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:26,246] Trial 170 finished with value: 0.15554027413599614 and parameters: {'nI': 10, 'nR': 21, 'nO': 4, 'N1': 0.01, 'N2': 0.001, 'N3': 0.001, 'τ': 22}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:26,357] Trial 171 finished with value: 0.021639356616786024 and parameters: {'nI': 13, 'nR': 12, 'nO': 5, 'N1': 0.1, 'N2': 0.1, 'N3': 0.1, 'τ': 15}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:26,422] Trial 172 failed with parameters: {'nI': 29, 'nR': 29, 'nO': 5, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.1, 'τ': 22} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:26,422] Trial 172 failed with value nan.
# [I 2026-04-23 14:58:26,491] Trial 173 finished with value: 4.456813774000051 and parameters: {'nI': 25, 'nR': 31, 'nO': 10, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.0001, 'τ': 24}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:26,642] Trial 174 failed with parameters: {'nI': 5, 'nR': 38, 'nO': 10, 'N1': 0.0001, 'N2': 0.1, 'N3': 1e-06, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:26,642] Trial 174 failed with value nan.
# [W 2026-04-23 14:58:26,762] Trial 175 failed with parameters: {'nI': 12, 'nR': 45, 'nO': 9, 'N1': 0.01, 'N2': 0.01, 'N3': 0.1, 'τ': 8} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:26,762] Trial 175 failed with value nan.
# [I 2026-04-23 14:58:26,775] Trial 176 finished with value: 0.9143939051272398 and parameters: {'nI': 23, 'nR': 2, 'nO': 1, 'N1': 0.1, 'N2': 0.001, 'N3': 0.01, 'τ': 3}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:26,820] Trial 177 finished with value: 0.09041956256334205 and parameters: {'nI': 12, 'nR': 44, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.1, 'τ': 21}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:26,961] Trial 178 finished with value: 19.39622821214688 and parameters: {'nI': 18, 'nR': 43, 'nO': 5, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.001, 'τ': 9}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:27,007] Trial 179 failed with parameters: {'nI': 28, 'nR': 16, 'nO': 1, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.1, 'τ': 11} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:27,007] Trial 179 failed with value nan.
# [I 2026-04-23 14:58:27,016] Trial 180 finished with value: 2.132032653476725 and parameters: {'nI': 21, 'nR': 1, 'nO': 5, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.1, 'τ': 27}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:27,028] Trial 181 finished with value: 4.946912934342554 and parameters: {'nI': 10, 'nR': 41, 'nO': 10, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-05, 'τ': 5}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:27,090] Trial 182 finished with value: 0.6003652224823702 and parameters: {'nI': 16, 'nR': 31, 'nO': 6, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.01, 'τ': 1}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:27,090] Trial 183 finished with value: 2.343387178123189 and parameters: {'nI': 28, 'nR': 1, 'nO': 6, 'N1': 0.01, 'N2': 0.0001, 'N3': 0.01, 'τ': 16}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:27,111] Trial 184 finished with value: 1.6331766544814377 and parameters: {'nI': 30, 'nR': 2, 'nO': 3, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.0001, 'τ': 21}. Best is trial 64 with value: 0.0020109938357879614.
# [I 2026-04-23 14:58:27,119] Trial 185 finished with value: 2.702297547371888 and parameters: {'nI': 15, 'nR': 15, 'nO': 9, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 17}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:27,218] Trial 186 failed with parameters: {'nI': 11, 'nR': 46, 'nO': 5, 'N1': 1e-06, 'N2': 0.01, 'N3': 0.01, 'τ': 12} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:27,218] Trial 186 failed with value nan.
# [W 2026-04-23 14:58:27,326] Trial 187 failed with parameters: {'nI': 24, 'nR': 26, 'nO': 6, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.0001, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:27,326] Trial 187 failed with value nan.
# [I 2026-04-23 14:58:27,439] Trial 188 finished with value: 0.025603206055710495 and parameters: {'nI': 14, 'nR': 19, 'nO': 6, 'N1': 0.1, 'N2': 0.1, 'N3': 0.01, 'τ': 26}. Best is trial 64 with value: 0.0020109938357879614.
# [W 2026-04-23 14:58:27,548] Trial 189 failed with parameters: {'nI': 11, 'nR': 27, 'nO': 2, 'N1': 0.001, 'N2': 0.01, 'N3': 0.1, 'τ': 30} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 14:58:27,548] Trial 189 failed with value nan.
# ...
# [I 2026-04-23 15:28:58,549] Trial 24933 finished with value: 2.131856092935045 and parameters: {'nI': 25, 'nR': 2, 'nO': 5, 'N1': 0.0001, 'N2': 0.001, 'N3': 1e-05, 'τ': 27}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:58,625] Trial 24934 finished with value: 0.08989270219155401 and parameters: {'nI': 21, 'nR': 41, 'nO': 4, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.01, 'τ': 20}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:58,708] Trial 24935 finished with value: 13.179570165843513 and parameters: {'nI': 22, 'nR': 29, 'nO': 6, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.01, 'τ': 19}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:58,824] Trial 24936 finished with value: 11.220676449696224 and parameters: {'nI': 21, 'nR': 18, 'nO': 8, 'N1': 1e-05, 'N2': 1e-06, 'N3': 1e-05, 'τ': 19}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:58,833] Trial 24937 finished with value: 2.239822794068757 and parameters: {'nI': 21, 'nR': 4, 'nO': 7, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-06, 'τ': 21}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,003] Trial 24938 finished with value: 0.01741492503032282 and parameters: {'nI': 11, 'nR': 29, 'nO': 2, 'N1': 0.1, 'N2': 0.1, 'N3': 0.01, 'τ': 17}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,012] Trial 24939 finished with value: 1.6342158906372843 and parameters: {'nI': 29, 'nR': 3, 'nO': 3, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.0001, 'τ': 10}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,022] Trial 24940 finished with value: 2.1547303908695965 and parameters: {'nI': 7, 'nR': 7, 'nO': 5, 'N1': 0.0001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 23}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,174] Trial 24941 finished with value: 0.004887028249019562 and parameters: {'nI': 5, 'nR': 20, 'nO': 8, 'N1': 0.1, 'N2': 0.0001, 'N3': 1e-05, 'τ': 7}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,195] Trial 24942 finished with value: 2.44578272037726 and parameters: {'nI': 2, 'nR': 18, 'nO': 6, 'N1': 0.001, 'N2': 0.001, 'N3': 0.001, 'τ': 28}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,291] Trial 24943 finished with value: 0.00601832240434078 and parameters: {'nI': 3, 'nR': 12, 'nO': 6, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.01, 'τ': 21}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,347] Trial 24944 finished with value: 0.07100091487627322 and parameters: {'nI': 9, 'nR': 38, 'nO': 8, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.1, 'τ': 25}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,358] Trial 24945 finished with value: 1.8837078690331173 and parameters: {'nI': 4, 'nR': 16, 'nO': 3, 'N1': 1e-05, 'N2': 1e-06, 'N3': 0.01, 'τ': 28}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,371] Trial 24946 finished with value: 1.226700135740075 and parameters: {'nI': 14, 'nR': 37, 'nO': 8, 'N1': 0.001, 'N2': 1e-06, 'N3': 1e-06, 'τ': 12}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,512] Trial 24947 finished with value: 43.60495998892204 and parameters: {'nI': 22, 'nR': 17, 'nO': 2, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.01, 'τ': 11}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:28:59,616] Trial 24948 failed with parameters: {'nI': 26, 'nR': 48, 'nO': 10, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.001, 'τ': 15} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:28:59,616] Trial 24948 failed with value nan.
# [I 2026-04-23 15:28:59,679] Trial 24949 finished with value: 0.14098239502987917 and parameters: {'nI': 19, 'nR': 9, 'nO': 4, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.1, 'τ': 16}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,726] Trial 24950 finished with value: 0.3551056624699063 and parameters: {'nI': 15, 'nR': 4, 'nO': 3, 'N1': 0.1, 'N2': 0.1, 'N3': 0.0001, 'τ': 24}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,839] Trial 24951 finished with value: 0.014325803971419892 and parameters: {'nI': 19, 'nR': 42, 'nO': 2, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.1, 'τ': 25}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,849] Trial 24952 finished with value: 1.2331760122231683 and parameters: {'nI': 13, 'nR': 8, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-05, 'τ': 6}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:28:59,951] Trial 24953 finished with value: 118.74947200214471 and parameters: {'nI': 8, 'nR': 39, 'nO': 8, 'N1': 1e-06, 'N2': 1e-06, 'N3': 0.01, 'τ': 12}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:00,074] Trial 24954 failed with parameters: {'nI': 27, 'nR': 20, 'nO': 4, 'N1': 0.1, 'N2': 0.001, 'N3': 0.01, 'τ': 13} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:00,074] Trial 24954 failed with value nan.
# [I 2026-04-23 15:29:00,082] Trial 24955 finished with value: 12.423338122239311 and parameters: {'nI': 30, 'nR': 46, 'nO': 10, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.01, 'τ': 24}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:00,099] Trial 24956 finished with value: 62534230527950.7 and parameters: {'nI': 5, 'nR': 32, 'nO': 7, 'N1': 1e-06, 'N2': 0.01, 'N3': 0.0001, 'τ': 15}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:00,212] Trial 24957 finished with value: 0.04047205048807267 and parameters: {'nI': 27, 'nR': 19, 'nO': 3, 'N1': 0.01, 'N2': 0.001, 'N3': 1e-06, 'τ': 6}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:00,224] Trial 24958 finished with value: 3.5813713992433462 and parameters: {'nI': 8, 'nR': 43, 'nO': 9, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-06, 'τ': 6}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:00,371] Trial 24959 failed with parameters: {'nI': 5, 'nR': 36, 'nO': 10, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.0001, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:00,374] Trial 24959 failed with value nan.
# [W 2026-04-23 15:29:00,487] Trial 24960 failed with parameters: {'nI': 27, 'nR': 22, 'nO': 5, 'N1': 0.1, 'N2': 1e-06, 'N3': 1e-05, 'τ': 16} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:00,487] Trial 24960 failed with value nan.
# [I 2026-04-23 15:29:00,575] Trial 24961 finished with value: 2.2715169905898667 and parameters: {'nI': 17, 'nR': 33, 'nO': 4, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.1, 'τ': 2}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:00,711] Trial 24962 failed with parameters: {'nI': 21, 'nR': 31, 'nO': 9, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.1, 'τ': 12} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:00,711] Trial 24962 failed with value nan.
# [W 2026-04-23 15:29:00,824] Trial 24963 failed with parameters: {'nI': 16, 'nR': 9, 'nO': 4, 'N1': 1e-06, 'N2': 0.1, 'N3': 0.001, 'τ': 19} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:00,824] Trial 24963 failed with value nan.
# [I 2026-04-23 15:29:00,832] Trial 24964 finished with value: 3.5322942885719413 and parameters: {'nI': 13, 'nR': 25, 'nO': 10, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-06, 'τ': 22}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:00,970] Trial 24965 finished with value: 261348.00540801362 and parameters: {'nI': 25, 'nR': 29, 'nO': 9, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.001, 'τ': 21}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:00,978] Trial 24966 finished with value: 2.280248398050362 and parameters: {'nI': 7, 'nR': 34, 'nO': 4, 'N1': 1e-05, 'N2': 1e-06, 'N3': 1e-06, 'τ': 4}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:01,099] Trial 24967 failed with parameters: {'nI': 27, 'nR': 26, 'nO': 5, 'N1': 0.01, 'N2': 0.1, 'N3': 1e-05, 'τ': 5} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:01,099] Trial 24967 failed with value nan.
# [I 2026-04-23 15:29:01,112] Trial 24968 finished with value: 2.0844293763656916 and parameters: {'nI': 3, 'nR': 50, 'nO': 6, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 26}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:01,124] Trial 24969 finished with value: 2.458514800164073 and parameters: {'nI': 24, 'nR': 48, 'nO': 3, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.01, 'τ': 28}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:01,138] Trial 24970 finished with value: 1.7163014131874523 and parameters: {'nI': 10, 'nR': 10, 'nO': 6, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 11}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:01,288] Trial 24971 finished with value: 10.516885356902664 and parameters: {'nI': 22, 'nR': 25, 'nO': 5, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-05, 'τ': 6}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:01,299] Trial 24972 finished with value: 4203.609064786102 and parameters: {'nI': 9, 'nR': 12, 'nO': 6, 'N1': 1e-06, 'N2': 0.01, 'N3': 0.001, 'τ': 21}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:01,307] Trial 24973 finished with value: 2.34887791081236 and parameters: {'nI': 24, 'nR': 10, 'nO': 7, 'N1': 0.001, 'N2': 0.001, 'N3': 0.001, 'τ': 5}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:01,424] Trial 24974 failed with parameters: {'nI': 24, 'nR': 36, 'nO': 6, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.0001, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:01,424] Trial 24974 failed with value nan.
# [I 2026-04-23 15:29:01,558] Trial 24975 finished with value: 0.129143927201933 and parameters: {'nI': 16, 'nR': 34, 'nO': 3, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.001, 'τ': 15}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:01,741] Trial 24976 failed with parameters: {'nI': 3, 'nR': 32, 'nO': 1, 'N1': 1e-06, 'N2': 0.1, 'N3': 0.0001, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:01,741] Trial 24976 failed with value nan.
# [I 2026-04-23 15:29:01,822] Trial 24977 finished with value: 0.9871228560117326 and parameters: {'nI': 30, 'nR': 37, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 23}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:01,941] Trial 24978 finished with value: 0.018380720053769235 and parameters: {'nI': 3, 'nR': 23, 'nO': 5, 'N1': 0.1, 'N2': 0.01, 'N3': 1e-05, 'τ': 17}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:02,061] Trial 24979 finished with value: 1.8810935659457502 and parameters: {'nI': 9, 'nR': 27, 'nO': 8, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.001, 'τ': 12}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:02,141] Trial 24980 failed with parameters: {'nI': 2, 'nR': 19, 'nO': 4, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.1, 'τ': 14} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:02,141] Trial 24980 failed with value nan.
# [I 2026-04-23 15:29:02,221] Trial 24981 finished with value: 6.560899933342754 and parameters: {'nI': 14, 'nR': 35, 'nO': 10, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 26}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:02,304] Trial 24982 failed with parameters: {'nI': 24, 'nR': 31, 'nO': 6, 'N1': 0.001, 'N2': 0.01, 'N3': 1e-05, 'τ': 6} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:02,304] Trial 24982 failed with value nan.
# [I 2026-04-23 15:29:02,399] Trial 24983 finished with value: 15.414730325659246 and parameters: {'nI': 17, 'nR': 27, 'nO': 8, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-05, 'τ': 24}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:02,444] Trial 24984 finished with value: 0.04562045698963846 and parameters: {'nI': 17, 'nR': 41, 'nO': 7, 'N1': 0.01, 'N2': 0.001, 'N3': 0.001, 'τ': 19}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:02,612] Trial 24985 failed with parameters: {'nI': 8, 'nR': 41, 'nO': 2, 'N1': 1e-06, 'N2': 0.1, 'N3': 0.0001, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:02,612] Trial 24985 failed with value nan.
# [I 2026-04-23 15:29:02,778] Trial 24986 finished with value: 2.0352194571146573 and parameters: {'nI': 21, 'nR': 44, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.0001, 'τ': 3}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:02,790] Trial 24987 finished with value: 1.84128438277213 and parameters: {'nI': 10, 'nR': 41, 'nO': 2, 'N1': 0.0001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 29}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:02,799] Trial 24988 finished with value: 2.5191790834173515 and parameters: {'nI': 14, 'nR': 35, 'nO': 7, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.0001, 'τ': 16}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:02,945] Trial 24989 finished with value: 0.08688130276715236 and parameters: {'nI': 5, 'nR': 14, 'nO': 9, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.1, 'τ': 22}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:03,086] Trial 24990 finished with value: 0.7176500961521383 and parameters: {'nI': 11, 'nR': 47, 'nO': 6, 'N1': 0.01, 'N2': 0.001, 'N3': 1e-05, 'τ': 24}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:03,228] Trial 24991 failed with parameters: {'nI': 6, 'nR': 46, 'nO': 10, 'N1': 1e-06, 'N2': 0.1, 'N3': 0.001, 'τ': 11} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:03,232] Trial 24991 failed with value nan.
# [I 2026-04-23 15:29:03,240] Trial 24992 finished with value: 3.072464659831132 and parameters: {'nI': 3, 'nR': 21, 'nO': 9, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.0001, 'τ': 27}. Best is trial 13305 with value: 0.00028172699674651534.
# [W 2026-04-23 15:29:03,380] Trial 24993 failed with parameters: {'nI': 21, 'nR': 20, 'nO': 9, 'N1': 0.0001, 'N2': 0.1, 'N3': 1e-05, 'τ': 16} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:29:03,380] Trial 24993 failed with value nan.
# [I 2026-04-23 15:29:03,499] Trial 24994 finished with value: 0.0043326389187737695 and parameters: {'nI': 16, 'nR': 12, 'nO': 5, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.001, 'τ': 1}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:03,615] Trial 24995 finished with value: 0.007847961011405077 and parameters: {'nI': 4, 'nR': 25, 'nO': 8, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.001, 'τ': 13}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:03,629] Trial 24996 finished with value: 4.606213127792067 and parameters: {'nI': 29, 'nR': 42, 'nO': 9, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.0001, 'τ': 25}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:03,640] Trial 24997 finished with value: 0.2375932736774678 and parameters: {'nI': 2, 'nR': 38, 'nO': 2, 'N1': 0.01, 'N2': 0.01, 'N3': 0.001, 'τ': 6}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:03,651] Trial 24998 finished with value: 2.166889759937851 and parameters: {'nI': 22, 'nR': 6, 'nO': 7, 'N1': 0.01, 'N2': 0.001, 'N3': 0.0001, 'τ': 16}. Best is trial 13305 with value: 0.00028172699674651534.
# [I 2026-04-23 15:29:03,782] Trial 24999 finished with value: 3.326094782607821 and parameters: {'nI': 9, 'nR': 46, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.1, 'τ': 30}. Best is trial 13305 with value: 0.00028172699674651534.
# Erro: 0.00028172699674651534 parameters:  [3, 13, 2, 0.1, 0.001, 1e-05, 1]

# %% [markdown]
# Erro: 0.00048766868214013016 parameters:  [5, 48, 1, 0.1, 1e-06, 0.1, 9]\
# Erro: 0.0004731207146124864 parameters:  [9, 12, 1, 1e-06, 0.01, 0.1, 1]\
# Erro: 0.0003514928586813473 parameters:  [10, 38, 1, 0.1, 1e-06, 1e-05, 5]\
# Erro: 0.0002067700572095104 parameters:  [3, 38, 1, 0.1, 0.001, 1e-06, 1]\
# Erro: 0.00014817900818612473 parameters:  [3, 13, 1, 0.1, 0.1, 0.01, 1]\
# \

# %%
rates = [1/(10**i) for i in range(1,8)][::-1]
def objective(trial):

    nI = trial.suggest_int('nI', 2, 30) 
    nR = trial.suggest_int('nR', 1, 50) 
    nO = trial.suggest_int('nO', 1, 30) 
    N1 = trial.suggest_categorical('N1', rates[:]) 
    N2 = trial.suggest_categorical('N2', rates[:]) 
    N3 = trial.suggest_categorical('N3', rates[:]) 
    τ = trial.suggest_int('τ', 1, 30)           
    X,Y = PrepareDataAhead(sig,n=nI,m=nO)
    X,Y = X[:-1], Y[:-1]
    rnn = RTLO(nI,nR,nO,[N1,N2,N3],τ)
    rnn.ref = len(sig)-nI

    for i,_ in enumerate(X):
        rnn.PredRul(X[i],maxRul=len(sig)-nI,lim=0.75,store=True)
        rnn.fit(X[i],Y[i],store=True)

        '''if i % 20==0 and i >=40:
            if np.mean(rnn.rulP)<np.mean(rnn.rulR)*0.3 or np.mean(rnn.rulP)>np.mean(rnn.rulR)*1.12:
                raise TrialPruned()

        if i == 50:
            if np.mean(rnn.εM_hist)>1:
                raise TrialPruned()
        if i % 20 == 0:  # Report every 10 time steps
            trial.report(rnn.εM, step=i)
            if trial.should_prune():
                raise optuna.TrialPruned()'''
            
    return rnn.εM, rnn.εR

#pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
pruner=optuna.pruners.HyperbandPruner()

study = optuna.create_study(
    directions=["minimize", "minimize"],
    sampler=SelSampler(mode='random'),
    #pruner=pruner,
    #storage="sqlite:///" + f'Optuna/{FileName}_Prdct.db', study_name=f'P{4}',
    load_if_exists=True)
study.optimize(objective, n_trials=10000)

best_trials = study.best_trials

print(f"Encontrados {len(best_trials)} modelos na Fronteira de Pareto:")

for i, trial in enumerate(best_trials):
    print(f"Erro_M = {trial.values[0]:.6f}, Erro_R = {trial.values[1]:.6f}",
          f"Parâmetros: {trial.params}")
# Se você quiser apenas os parâmetros do PRIMEIRO modelo da fronteira para testar:
first_best_params = best_trials[0].params
params = list(trial.params.values())
# Out:
# [I 2026-04-23 15:39:38,093] A new study created in memory with name: no-name-d72d377e-0b60-4f9a-84da-ab45bb608480
# [I 2026-04-23 15:39:38,110] Trial 0 finished with values: [3.316699602702806, 0.9655364987181043] and parameters: {'nI': 8, 'nR': 11, 'nO': 10, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.001, 'τ': 27}.
# [I 2026-04-23 15:39:38,121] Trial 1 finished with values: [1.8447656154022758, 0.9140461872832186] and parameters: {'nI': 30, 'nR': 41, 'nO': 1, 'N1': 1e-06, 'N2': 1e-07, 'N3': 0.0001, 'τ': 22}.
# [I 2026-04-23 15:39:38,132] Trial 2 finished with values: [95.27106639224584, 0.9535445888335153] and parameters: {'nI': 15, 'nR': 4, 'nO': 5, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.01, 'τ': 25}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:294: RuntimeWarning: overflow encountered in matmul
#   yP = (self.wO @ hP)[0]
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:292: RuntimeWarning: overflow encountered in matmul
#   uP = (self.wR @ hP) + (self.wI @ xP)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:292: RuntimeWarning: invalid value encountered in matmul
#   uP = (self.wR @ hP) + (self.wI @ xP)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:294: RuntimeWarning: invalid value encountered in matmul
#   yP = (self.wO @ hP)[0]
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:72: RuntimeWarning: overflow encountered in matmul
#   yP = self.wO @ hP
# c:\Users\Claudio\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\numeric.py:925: RuntimeWarning: invalid value encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:91: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# [W 2026-04-23 15:39:38,164] Trial 3 failed with parameters: {'nI': 23, 'nR': 44, 'nO': 10, 'N1': 0.0001, 'N2': 0.01, 'N3': 1e-05, 'τ': 18} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:38,164] Trial 3 failed with value (nan, 2.9099041947367135).
# [I 2026-04-23 15:39:38,204] Trial 4 finished with values: [15.321432817224695, 3.3959511607430684] and parameters: {'nI': 23, 'nR': 43, 'nO': 9, 'N1': 1e-05, 'N2': 1e-07, 'N3': 0.01, 'τ': 21}.
# [I 2026-04-23 15:39:38,212] Trial 5 finished with values: [2.645751311064591, 0.9596448622877677] and parameters: {'nI': 7, 'nR': 1, 'nO': 7, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.01, 'τ': 28}.
# [I 2026-04-23 15:39:38,226] Trial 6 finished with values: [1.9620007912444855, 0.9337855399926914] and parameters: {'nI': 25, 'nR': 44, 'nO': 2, 'N1': 1e-07, 'N2': 1e-06, 'N3': 0.001, 'τ': 29}.
# [I 2026-04-23 15:39:38,300] Trial 7 finished with values: [0.01594862925736195, 0.44542943224078035] and parameters: {'nI': 14, 'nR': 19, 'nO': 10, 'N1': 0.1, 'N2': 0.01, 'N3': 1e-06, 'τ': 8}.
# [I 2026-04-23 15:39:38,312] Trial 8 finished with values: [2.2981385890908066, 0.9566239498123226] and parameters: {'nI': 30, 'nR': 36, 'nO': 6, 'N1': 1e-07, 'N2': 1e-06, 'N3': 1e-07, 'τ': 7}.
# [I 2026-04-23 15:39:38,321] Trial 9 finished with values: [2.0, 0.9492595131394952] and parameters: {'nI': 8, 'nR': 2, 'nO': 4, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.001, 'τ': 11}.
# [I 2026-04-23 15:39:38,329] Trial 10 finished with values: [2.8879358177193484, 0.9618980403755636] and parameters: {'nI': 13, 'nR': 7, 'nO': 8, 'N1': 1e-07, 'N2': 0.0001, 'N3': 0.0001, 'τ': 11}.
# [I 2026-04-23 15:39:38,343] Trial 11 finished with values: [1.0557352553817931, 0.9339716928215432] and parameters: {'nI': 17, 'nR': 42, 'nO': 2, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.001, 'τ': 9}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:91: RuntimeWarning: invalid value encountered in multiply
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# [W 2026-04-23 15:39:38,463] Trial 12 failed with parameters: {'nI': 4, 'nR': 28, 'nO': 7, 'N1': 1e-06, 'N2': 0.01, 'N3': 0.0001, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:38,463] Trial 12 failed with value (nan, 4.6557361296099655).
# [I 2026-04-23 15:39:38,480] Trial 13 finished with values: [0.1921512578036002, 0.8516895401742062] and parameters: {'nI': 16, 'nR': 6, 'nO': 2, 'N1': 0.1, 'N2': 0.001, 'N3': 1e-05, 'τ': 30}.
# [I 2026-04-23 15:39:38,492] Trial 14 finished with values: [5.721718201990266, 0.9492333303291619] and parameters: {'nI': 14, 'nR': 24, 'nO': 4, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-07, 'τ': 20}.
# [I 2026-04-23 15:39:38,503] Trial 15 finished with values: [1.5821865367140409, 0.9340468626581447] and parameters: {'nI': 2, 'nR': 31, 'nO': 2, 'N1': 0.0001, 'N2': 1e-06, 'N3': 1e-05, 'τ': 5}.
# [W 2026-04-23 15:39:38,583] Trial 16 failed with parameters: {'nI': 30, 'nR': 23, 'nO': 6, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-06, 'τ': 28} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:38,585] Trial 16 failed with value (nan, 4.09107191130042).
# [I 2026-04-23 15:39:38,592] Trial 17 finished with values: [3.7717210976824216, 0.9568808235993096] and parameters: {'nI': 17, 'nR': 22, 'nO': 6, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-05, 'τ': 29}.
# [I 2026-04-23 15:39:38,603] Trial 18 finished with values: [3.815826357765909, 0.9636663307741566] and parameters: {'nI': 27, 'nR': 11, 'nO': 9, 'N1': 0.0001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 8}.
# [I 2026-04-23 15:39:38,612] Trial 19 finished with values: [2.6408442092272666, 0.9593871053745601] and parameters: {'nI': 29, 'nR': 2, 'nO': 7, 'N1': 0.01, 'N2': 0.01, 'N3': 0.0001, 'τ': 7}.
# [I 2026-04-23 15:39:38,642] Trial 20 finished with values: [0.1365797338396637, 0.4259401693927196] and parameters: {'nI': 6, 'nR': 36, 'nO': 3, 'N1': 0.01, 'N2': 0.0001, 'N3': 0.001, 'τ': 7}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:292: RuntimeWarning: invalid value encountered in add
#   uP = (self.wR @ hP) + (self.wI @ xP)
# c:\Users\Claudio\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\numeric.py:925: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:91: RuntimeWarning: overflow encountered in multiply
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:69: RuntimeWarning: overflow encountered in matmul
#   uS = self.wR @ self.hP + self.wI @ xP
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:96: RuntimeWarning: invalid value encountered in add
#   self.ΔOS = (self.ΔOS*(self.k-1) + δOS)/self.k
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:100: RuntimeWarning: invalid value encountered in add
#   self.wO = self.wO + δOS
# [W 2026-04-23 15:39:38,742] Trial 21 failed with parameters: {'nI': 30, 'nR': 7, 'nO': 10, 'N1': 0.1, 'N2': 0.001, 'N3': 0.1, 'τ': 20} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:38,742] Trial 21 failed with value (nan, 3.0527966074393755).
# [I 2026-04-23 15:39:38,753] Trial 22 finished with values: [1.507317607472793, 0.9340468626581447] and parameters: {'nI': 2, 'nR': 12, 'nO': 2, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-07, 'τ': 19}.
# [I 2026-04-23 15:39:38,884] Trial 23 finished with values: [0.030585478079203813, 3.35432593782342] and parameters: {'nI': 23, 'nR': 13, 'nO': 2, 'N1': 0.1, 'N2': 0.01, 'N3': 0.1, 'τ': 30}.
# [I 2026-04-23 15:39:39,012] Trial 24 finished with values: [0.022718764825242675, 0.6058240506342157] and parameters: {'nI': 8, 'nR': 48, 'nO': 7, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.001, 'τ': 22}.
# [I 2026-04-23 15:39:39,024] Trial 25 finished with values: [2.2360679774997894, 0.9535785690213188] and parameters: {'nI': 6, 'nR': 1, 'nO': 5, 'N1': 0.1, 'N2': 0.0001, 'N3': 1e-07, 'τ': 2}.
# [I 2026-04-23 15:39:39,148] Trial 26 finished with values: [1.6699541678575103, 3.745665181559304] and parameters: {'nI': 22, 'nR': 31, 'nO': 8, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 21}.
# [W 2026-04-23 15:39:39,262] Trial 27 failed with parameters: {'nI': 22, 'nR': 15, 'nO': 10, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-06, 'τ': 24} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:39,263] Trial 27 failed with value (nan, 3.3141890257058164).
# [I 2026-04-23 15:39:39,273] Trial 28 finished with values: [1.066619578228438, 0.9145142920477788] and parameters: {'nI': 19, 'nR': 25, 'nO': 1, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.001, 'τ': 24}.
# [I 2026-04-23 15:39:39,284] Trial 29 finished with values: [0.7870014965410169, 0.9431654588440763] and parameters: {'nI': 22, 'nR': 38, 'nO': 3, 'N1': 1e-06, 'N2': 1e-06, 'N3': 0.001, 'τ': 14}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:293: RuntimeWarning: invalid value encountered in multiply
#   hP = hP*(1-1/self.τ) + Activation(uP,self.act)/self.τ
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:69: RuntimeWarning: invalid value encountered in matmul
#   uS = self.wR @ self.hP + self.wI @ xP
# [W 2026-04-23 15:39:39,501] Trial 30 failed with parameters: {'nI': 6, 'nR': 50, 'nO': 3, 'N1': 0.01, 'N2': 0.1, 'N3': 0.0001, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:39,502] Trial 30 failed with value (nan, 6.937453241582368).
# [I 2026-04-23 15:39:39,677] Trial 31 finished with values: [5.387244305254309, 4.370008049579366] and parameters: {'nI': 5, 'nR': 11, 'nO': 8, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-07, 'τ': 5}.
# [I 2026-04-23 15:39:39,689] Trial 32 finished with values: [17.347078289788097, 0.9340344476426111] and parameters: {'nI': 10, 'nR': 37, 'nO': 2, 'N1': 1e-07, 'N2': 1e-05, 'N3': 0.1, 'τ': 17}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:92: RuntimeWarning: invalid value encountered in multiply
#   δIS = η3*np.outer(np.dot(self.BS, eS),np.ones(self.nI))*self.qS
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:95: RuntimeWarning: invalid value encountered in add
#   self.ΔRS = (self.ΔRS*(self.k-1) + δRS)/self.k
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:99: RuntimeWarning: invalid value encountered in add
#   self.wR = self.wR + δRS
# [W 2026-04-23 15:39:39,793] Trial 33 failed with parameters: {'nI': 10, 'nR': 43, 'nO': 4, 'N1': 1e-07, 'N2': 0.1, 'N3': 1e-05, 'τ': 24} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:39,795] Trial 33 failed with value (nan, 5.957761251038122).
# [W 2026-04-23 15:39:39,895] Trial 34 failed with parameters: {'nI': 6, 'nR': 42, 'nO': 1, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-06, 'τ': 20} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:39,895] Trial 34 failed with value (nan, 10.959857361034434).
# [W 2026-04-23 15:39:40,029] Trial 35 failed with parameters: {'nI': 24, 'nR': 31, 'nO': 5, 'N1': 1e-07, 'N2': 0.01, 'N3': 0.0001, 'τ': 10} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:40,033] Trial 35 failed with value (nan, 4.555307066315409).
# [I 2026-04-23 15:39:40,041] Trial 36 finished with values: [1.6741908796422427, 0.9567791466490472] and parameters: {'nI': 24, 'nR': 10, 'nO': 6, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-06, 'τ': 2}.
# [I 2026-04-23 15:39:40,204] Trial 37 finished with values: [0.45817310192505045, 4.1813026108540186] and parameters: {'nI': 10, 'nR': 39, 'nO': 8, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.001, 'τ': 4}.
# [W 2026-04-23 15:39:40,316] Trial 38 failed with parameters: {'nI': 30, 'nR': 30, 'nO': 6, 'N1': 0.001, 'N2': 1e-07, 'N3': 0.1, 'τ': 5} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:40,316] Trial 38 failed with value (nan, 4.05919394959406).
# [I 2026-04-23 15:39:40,329] Trial 39 finished with values: [3.8961934923589454, 0.9638266282036358] and parameters: {'nI': 15, 'nR': 47, 'nO': 9, 'N1': 1e-07, 'N2': 0.0001, 'N3': 1e-07, 'τ': 25}.
# [I 2026-04-23 15:39:40,339] Trial 40 finished with values: [2.876094233695969, 0.963837417026306] and parameters: {'nI': 13, 'nR': 30, 'nO': 9, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.001, 'τ': 27}.
# [I 2026-04-23 15:39:40,474] Trial 41 finished with values: [0.17144686879893858, 4.737506509611485] and parameters: {'nI': 29, 'nR': 19, 'nO': 1, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 16}.
# [I 2026-04-23 15:39:40,516] Trial 42 finished with values: [0.2404743208463702, 0.6812092716843635] and parameters: {'nI': 3, 'nR': 35, 'nO': 5, 'N1': 0.01, 'N2': 0.01, 'N3': 0.01, 'τ': 7}.
# [I 2026-04-23 15:39:40,527] Trial 43 finished with values: [0.7293865881941526, 0.933750798107538] and parameters: {'nI': 26, 'nR': 8, 'nO': 2, 'N1': 1e-07, 'N2': 0.001, 'N3': 0.0001, 'τ': 8}.
# [I 2026-04-23 15:39:40,539] Trial 44 finished with values: [2.4238073786394425, 0.9492058075775657] and parameters: {'nI': 17, 'nR': 17, 'nO': 4, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-07, 'τ': 21}.
# [I 2026-04-23 15:39:40,595] Trial 45 finished with values: [0.015452075588247868, 0.5838071152573993] and parameters: {'nI': 17, 'nR': 37, 'nO': 1, 'N1': 0.01, 'N2': 0.001, 'N3': 1e-05, 'τ': 6}.
# [I 2026-04-23 15:39:40,633] Trial 46 finished with values: [0.14033608540684883, 0.8660373055443982] and parameters: {'nI': 19, 'nR': 42, 'nO': 5, 'N1': 0.01, 'N2': 0.01, 'N3': 0.001, 'τ': 12}.
# [I 2026-04-23 15:39:40,641] Trial 47 finished with values: [2.82842712474619, 0.9618521476061689] and parameters: {'nI': 19, 'nR': 2, 'nO': 8, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.001, 'τ': 13}.
# [I 2026-04-23 15:39:40,728] Trial 48 finished with values: [0.09408479822210919, 0.7552342374360367] and parameters: {'nI': 5, 'nR': 11, 'nO': 1, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.0001, 'τ': 23}.
# [I 2026-04-23 15:39:40,735] Trial 49 finished with values: [2.5820128185997366, 0.9533439696406985] and parameters: {'nI': 27, 'nR': 26, 'nO': 5, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-06, 'τ': 15}.
# [I 2026-04-23 15:39:40,745] Trial 50 finished with values: [3.1622776601683795, 0.9654983638770377] and parameters: {'nI': 17, 'nR': 2, 'nO': 10, 'N1': 1e-05, 'N2': 1e-05, 'N3': 1e-07, 'τ': 13}.
# [I 2026-04-23 15:39:40,756] Trial 51 finished with values: [1.802658734163905, 0.9141657834845289] and parameters: {'nI': 28, 'nR': 41, 'nO': 1, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-07, 'τ': 21}.
# [I 2026-04-23 15:39:40,766] Trial 52 finished with values: [2.6600880067124213, 0.9618521476061689] and parameters: {'nI': 19, 'nR': 9, 'nO': 8, 'N1': 0.001, 'N2': 1e-06, 'N3': 1e-06, 'τ': 4}.
# [I 2026-04-23 15:39:40,818] Trial 53 finished with values: [1.1942795294009636, 0.7264772059452028] and parameters: {'nI': 18, 'nR': 3, 'nO': 9, 'N1': 0.001, 'N2': 0.01, 'N3': 0.001, 'τ': 4}.
# [I 2026-04-23 15:39:40,841] Trial 54 finished with values: [3.905607136949488, 4.821879683687687] and parameters: {'nI': 9, 'nR': 18, 'nO': 3, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.01, 'τ': 14}.
# [I 2026-04-23 15:39:40,908] Trial 55 finished with values: [0.8740980442578029, 7.4449941254766365] and parameters: {'nI': 19, 'nR': 36, 'nO': 2, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.01, 'τ': 22}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:292: RuntimeWarning: overflow encountered in add
#   uP = (self.wR @ hP) + (self.wI @ xP)
# [W 2026-04-23 15:39:41,015] Trial 56 failed with parameters: {'nI': 10, 'nR': 40, 'nO': 7, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.0001, 'τ': 19} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:41,015] Trial 56 failed with value (nan, 4.417993081638606).
# [W 2026-04-23 15:39:41,112] Trial 57 failed with parameters: {'nI': 15, 'nR': 47, 'nO': 9, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.0001, 'τ': 27} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:41,113] Trial 57 failed with value (nan, 3.801929045975936).
# [I 2026-04-23 15:39:41,120] Trial 58 finished with values: [3.4632267623989157, 0.9432048717455431] and parameters: {'nI': 20, 'nR': 41, 'nO': 3, 'N1': 0.0001, 'N2': 1e-07, 'N3': 0.0001, 'τ': 27}.
# [W 2026-04-23 15:39:41,262] Trial 59 failed with parameters: {'nI': 7, 'nR': 28, 'nO': 4, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.1, 'τ': 28} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:41,262] Trial 59 failed with value (nan, 5.6923623348082115).
# [I 2026-04-23 15:39:41,329] Trial 60 finished with values: [5.587912723005913, 6.030431553877426] and parameters: {'nI': 7, 'nR': 24, 'nO': 4, 'N1': 0.0001, 'N2': 0.0001, 'N3': 0.001, 'τ': 2}.
# [I 2026-04-23 15:39:41,341] Trial 61 finished with values: [3.623068491879487, 0.9492333303291619] and parameters: {'nI': 14, 'nR': 46, 'nO': 4, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.001, 'τ': 13}.
# [W 2026-04-23 15:39:41,469] Trial 62 failed with parameters: {'nI': 25, 'nR': 17, 'nO': 8, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.1, 'τ': 19} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:41,470] Trial 62 failed with value (nan, 3.6458592442403).
# [I 2026-04-23 15:39:41,483] Trial 63 finished with values: [0.399766115824738, 0.9144887283282798] and parameters: {'nI': 20, 'nR': 50, 'nO': 1, 'N1': 1e-05, 'N2': 1e-06, 'N3': 1e-07, 'τ': 22}.
# [W 2026-04-23 15:39:41,524] Trial 64 failed with parameters: {'nI': 13, 'nR': 43, 'nO': 6, 'N1': 1e-07, 'N2': 0.01, 'N3': 0.001, 'τ': 20} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:41,524] Trial 64 failed with value (nan, 4.270055995649926).
# [I 2026-04-23 15:39:41,660] Trial 65 finished with values: [2.1224068973779087, 6.162573497964176] and parameters: {'nI': 20, 'nR': 15, 'nO': 3, 'N1': 1e-07, 'N2': 1e-05, 'N3': 1e-05, 'τ': 17}.
# [I 2026-04-23 15:39:41,670] Trial 66 finished with values: [2.2366094286694707, 0.9534569329673951] and parameters: {'nI': 22, 'nR': 8, 'nO': 5, 'N1': 1e-05, 'N2': 1e-06, 'N3': 0.1, 'τ': 19}.
# [I 2026-04-23 15:39:41,682] Trial 67 finished with values: [2.2705073649848946, 0.9340073970254066] and parameters: {'nI': 14, 'nR': 43, 'nO': 2, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.0001, 'τ': 20}.
# [I 2026-04-23 15:39:41,692] Trial 68 finished with values: [1.0745795622837002, 0.9340344476426111] and parameters: {'nI': 10, 'nR': 9, 'nO': 2, 'N1': 0.01, 'N2': 1e-07, 'N3': 0.0001, 'τ': 15}.
# [I 2026-04-23 15:39:41,709] Trial 69 finished with values: [2.7524702121655436, 0.9594843280868296] and parameters: {'nI': 25, 'nR': 42, 'nO': 7, 'N1': 1e-05, 'N2': 1e-07, 'N3': 1e-07, 'τ': 9}.
# [I 2026-04-23 15:39:41,808] Trial 70 finished with values: [0.011353068233622782, 0.5849670431094024] and parameters: {'nI': 22, 'nR': 50, 'nO': 1, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-05, 'τ': 30}.
# [W 2026-04-23 15:39:41,957] Trial 71 failed with parameters: {'nI': 4, 'nR': 49, 'nO': 9, 'N1': 1e-07, 'N2': 0.1, 'N3': 1e-06, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:41,958] Trial 71 failed with value (nan, 4.1459351139345).
# [I 2026-04-23 15:39:42,092] Trial 72 finished with values: [709.2448174586397, 2.410478497341234] and parameters: {'nI': 12, 'nR': 43, 'nO': 10, 'N1': 0.01, 'N2': 0.01, 'N3': 0.1, 'τ': 28}.
# [I 2026-04-23 15:39:42,101] Trial 73 finished with values: [3.16227766016838, 0.9654303868242743] and parameters: {'nI': 23, 'nR': 2, 'nO': 10, 'N1': 0.1, 'N2': 0.0001, 'N3': 1e-05, 'τ': 11}.
# [I 2026-04-23 15:39:42,113] Trial 74 finished with values: [0.4562751750730329, 0.8151617286124839] and parameters: {'nI': 15, 'nR': 9, 'nO': 10, 'N1': 0.1, 'N2': 0.1, 'N3': 0.001, 'τ': 24}.
# [I 2026-04-23 15:39:42,121] Trial 75 finished with values: [1.6797286468187818, 0.9146553554920421] and parameters: {'nI': 2, 'nR': 2, 'nO': 1, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.001, 'τ': 28}.
# [I 2026-04-23 15:39:42,205] Trial 76 finished with values: [3.3780123700297806, 5.588894243143923] and parameters: {'nI': 5, 'nR': 45, 'nO': 5, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.01, 'τ': 30}.
# [I 2026-04-23 15:39:42,333] Trial 77 finished with values: [4.663427124489539, 3.3598979052719398] and parameters: {'nI': 26, 'nR': 19, 'nO': 9, 'N1': 0.0001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 7}.
# [I 2026-04-23 15:39:42,437] Trial 78 finished with values: [0.02711891683006058, 0.7076606218473137] and parameters: {'nI': 16, 'nR': 12, 'nO': 6, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.001, 'τ': 13}.
# [I 2026-04-23 15:39:42,449] Trial 79 finished with values: [2.449489742783178, 0.9568461604055456] and parameters: {'nI': 20, 'nR': 1, 'nO': 6, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 25}.
# [I 2026-04-23 15:39:42,460] Trial 80 finished with values: [3.197412505707251, 0.9655385474698353] and parameters: {'nI': 6, 'nR': 23, 'nO': 10, 'N1': 0.0001, 'N2': 1e-07, 'N3': 0.0001, 'τ': 20}.
# [W 2026-04-23 15:39:42,502] Trial 81 failed with parameters: {'nI': 29, 'nR': 46, 'nO': 8, 'N1': 1e-07, 'N2': 1e-07, 'N3': 0.1, 'τ': 24} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:42,502] Trial 81 failed with value (nan, 2.939863056380537).
# [W 2026-04-23 15:39:42,657] Trial 82 failed with parameters: {'nI': 8, 'nR': 45, 'nO': 10, 'N1': 1e-07, 'N2': 0.01, 'N3': 0.0001, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:42,658] Trial 82 failed with value (nan, 3.770912480919152).
# [I 2026-04-23 15:39:42,736] Trial 83 finished with values: [0.036169703996418404, 0.7302023212439731] and parameters: {'nI': 9, 'nR': 41, 'nO': 2, 'N1': 0.01, 'N2': 0.001, 'N3': 0.0001, 'τ': 12}.
# [I 2026-04-23 15:39:42,747] Trial 84 finished with values: [4.1198028779941565, 0.9618928512102243] and parameters: {'nI': 14, 'nR': 29, 'nO': 8, 'N1': 1e-05, 'N2': 0.0001, 'N3': 1e-05, 'τ': 21}.
# [W 2026-04-23 15:39:42,883] Trial 85 failed with parameters: {'nI': 12, 'nR': 25, 'nO': 8, 'N1': 0.01, 'N2': 0.01, 'N3': 0.1, 'τ': 24} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:42,883] Trial 85 failed with value (nan, 4.072802014318516).
# [I 2026-04-23 15:39:42,933] Trial 86 finished with values: [0.03525798723142081, 0.37636062846598173] and parameters: {'nI': 30, 'nR': 22, 'nO': 5, 'N1': 0.1, 'N2': 0.1, 'N3': 0.01, 'τ': 23}.
# [I 2026-04-23 15:39:43,050] Trial 87 finished with values: [0.0012341337106434275, 0.5408606426838631] and parameters: {'nI': 6, 'nR': 8, 'nO': 1, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.1, 'τ': 1}.
# [I 2026-04-23 15:39:43,165] Trial 88 finished with values: [0.017112426559407645, 1.3333493318197702] and parameters: {'nI': 27, 'nR': 15, 'nO': 1, 'N1': 0.1, 'N2': 0.001, 'N3': 1e-07, 'τ': 23}.
# [I 2026-04-23 15:39:43,175] Trial 89 finished with values: [2.1820956052616136, 0.9629780929749457] and parameters: {'nI': 20, 'nR': 34, 'nO': 9, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.001, 'τ': 22}.
# [W 2026-04-23 15:39:43,318] Trial 90 failed with parameters: {'nI': 13, 'nR': 36, 'nO': 6, 'N1': 1e-07, 'N2': 1e-06, 'N3': 0.1, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:43,318] Trial 90 failed with value (nan, 4.747398607672962).
# [I 2026-04-23 15:39:43,345] Trial 91 finished with values: [0.04786347372070696, 0.6110611126169715] and parameters: {'nI': 16, 'nR': 44, 'nO': 1, 'N1': 1e-06, 'N2': 1e-07, 'N3': 0.0001, 'τ': 14}.
# [W 2026-04-23 15:39:43,486] Trial 92 failed with parameters: {'nI': 3, 'nR': 26, 'nO': 4, 'N1': 1e-06, 'N2': 0.01, 'N3': 1e-07, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:43,487] Trial 92 failed with value (nan, 6.272255450822589).
# [W 2026-04-23 15:39:43,620] Trial 93 failed with parameters: {'nI': 14, 'nR': 13, 'nO': 7, 'N1': 1e-05, 'N2': 0.001, 'N3': 0.01, 'τ': 2} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:43,622] Trial 93 failed with value (nan, 4.342362028293453).
# [W 2026-04-23 15:39:43,733] Trial 94 failed with parameters: {'nI': 11, 'nR': 34, 'nO': 6, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.01, 'τ': 26} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:43,733] Trial 94 failed with value (nan, 4.795585176204106).
# [I 2026-04-23 15:39:43,795] Trial 95 finished with values: [0.05286926210826308, 0.4841679515233315] and parameters: {'nI': 23, 'nR': 34, 'nO': 9, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-07, 'τ': 26}.
# [I 2026-04-23 15:39:43,891] Trial 96 finished with values: [1.9179386410047103, 5.721722452747184] and parameters: {'nI': 29, 'nR': 25, 'nO': 3, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-07, 'τ': 24}.
# [I 2026-04-23 15:39:44,004] Trial 97 finished with values: [0.018155079253553336, 0.6130352418287315] and parameters: {'nI': 9, 'nR': 16, 'nO': 5, 'N1': 0.1, 'N2': 1e-07, 'N3': 0.001, 'τ': 8}.
# [I 2026-04-23 15:39:44,016] Trial 98 finished with values: [1.248343646775553, 0.9340450323756709] and parameters: {'nI': 6, 'nR': 37, 'nO': 2, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-05, 'τ': 1}.
# [I 2026-04-23 15:39:44,035] Trial 99 finished with values: [4.637024493512112, 0.7899577748954439] and parameters: {'nI': 10, 'nR': 33, 'nO': 7, 'N1': 1e-06, 'N2': 1e-07, 'N3': 1e-06, 'τ': 12}.
# [I 2026-04-23 15:39:44,045] Trial 100 finished with values: [1.4638649827274433, 0.9492623844849485] and parameters: {'nI': 6, 'nR': 31, 'nO': 4, 'N1': 0.001, 'N2': 1e-07, 'N3': 0.001, 'τ': 24}.
# [I 2026-04-23 15:39:44,137] Trial 101 finished with values: [0.06141505766781185, 0.8812536029029171] and parameters: {'nI': 14, 'nR': 25, 'nO': 6, 'N1': 0.01, 'N2': 0.01, 'N3': 1e-07, 'τ': 5}.
# [I 2026-04-23 15:39:44,146] Trial 102 finished with values: [2.20825603694839, 0.9568705998857062] and parameters: {'nI': 18, 'nR': 10, 'nO': 6, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.001, 'τ': 9}.
# [I 2026-04-23 15:39:44,158] Trial 103 finished with values: [3.485762664655707, 0.6457115973338685] and parameters: {'nI': 22, 'nR': 14, 'nO': 10, 'N1': 0.001, 'N2': 0.001, 'N3': 1e-07, 'τ': 21}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:71: RuntimeWarning: invalid value encountered in multiply
#   hP = self.hP*(1-1/self.τ) +Activation(uS,self.act)/self.τ
# [W 2026-04-23 15:39:44,274] Trial 104 failed with parameters: {'nI': 28, 'nR': 50, 'nO': 10, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.001, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:44,274] Trial 104 failed with value (nan, 3.1065554196800074).
# [W 2026-04-23 15:39:44,362] Trial 105 failed with parameters: {'nI': 2, 'nR': 37, 'nO': 2, 'N1': 0.0001, 'N2': 0.01, 'N3': 1e-05, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:44,366] Trial 105 failed with value (nan, 8.470140226913365).
# [I 2026-04-23 15:39:44,477] Trial 106 finished with values: [0.17538942272175623, 1.8626680483372016] and parameters: {'nI': 24, 'nR': 23, 'nO': 6, 'N1': 0.01, 'N2': 0.01, 'N3': 0.0001, 'τ': 18}.
# [I 2026-04-23 15:39:44,488] Trial 107 finished with values: [2.2383467203552763, 0.9619152765008396] and parameters: {'nI': 6, 'nR': 2, 'nO': 8, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-07, 'τ': 24}.
# [I 2026-04-23 15:39:44,547] Trial 108 finished with values: [0.04979761572423306, 0.3620700519722342] and parameters: {'nI': 10, 'nR': 46, 'nO': 4, 'N1': 0.01, 'N2': 0.0001, 'N3': 0.0001, 'τ': 7}.
# [I 2026-04-23 15:39:44,558] Trial 109 finished with values: [3.5398840260100437, 0.9596084593700254] and parameters: {'nI': 16, 'nR': 46, 'nO': 7, 'N1': 1e-06, 'N2': 1e-07, 'N3': 1e-05, 'τ': 6}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:113: RuntimeWarning: overflow encountered in scalar multiply
#   self.εY = ((self.εY*self.ΣW) + (W*ΔY[0]))/ΣW
# [W 2026-04-23 15:39:44,664] Trial 110 failed with parameters: {'nI': 29, 'nR': 23, 'nO': 8, 'N1': 0.01, 'N2': 0.0001, 'N3': 0.1, 'τ': 23} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:44,665] Trial 110 failed with value (nan, 3.509205399141374).
# [I 2026-04-23 15:39:44,716] Trial 111 finished with values: [0.36398410754803556, 0.5542689930906523] and parameters: {'nI': 26, 'nR': 44, 'nO': 6, 'N1': 0.001, 'N2': 0.01, 'N3': 0.1, 'τ': 24}.
# [W 2026-04-23 15:39:44,834] Trial 112 failed with parameters: {'nI': 14, 'nR': 43, 'nO': 6, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.01, 'τ': 20} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:44,837] Trial 112 failed with value (nan, 4.732155094880852).
# [I 2026-04-23 15:39:44,848] Trial 113 finished with values: [4.346935659473961, 0.9638530514710946] and parameters: {'nI': 7, 'nR': 49, 'nO': 9, 'N1': 0.0001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 19}.
# [I 2026-04-23 15:39:44,860] Trial 114 finished with values: [3.823604945810473, 0.9619143654933355] and parameters: {'nI': 7, 'nR': 46, 'nO': 8, 'N1': 1e-07, 'N2': 1e-06, 'N3': 1e-07, 'τ': 24}.
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_10208\173534297.py:72: RuntimeWarning: invalid value encountered in matmul
#   yP = self.wO @ hP
# [W 2026-04-23 15:39:45,020] Trial 115 failed with parameters: {'nI': 4, 'nR': 36, 'nO': 6, 'N1': 1e-07, 'N2': 0.0001, 'N3': 0.1, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:45,021] Trial 115 failed with value (nan, 5.128584775071198).
# [I 2026-04-23 15:39:45,066] Trial 116 finished with values: [5.841232423771083, 5.048891038266933] and parameters: {'nI': 23, 'nR': 24, 'nO': 4, 'N1': 1e-05, 'N2': 0.0001, 'N3': 1e-06, 'τ': 18}.
# [I 2026-04-23 15:39:45,091] Trial 117 finished with values: [16.77103148622266, 3.5264338790537795] and parameters: {'nI': 24, 'nR': 23, 'nO': 6, 'N1': 1e-06, 'N2': 1e-05, 'N3': 0.01, 'τ': 26}.
# [I 2026-04-23 15:39:45,237] Trial 118 finished with values: [1.386764221068417, 5.7643100695007226] and parameters: {'nI': 13, 'nR': 30, 'nO': 4, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.1, 'τ': 25}.
# [I 2026-04-23 15:39:45,345] Trial 119 finished with values: [0.49700411870718963, 3.5070062238905546] and parameters: {'nI': 23, 'nR': 20, 'nO': 9, 'N1': 0.01, 'N2': 0.001, 'N3': 1e-06, 'τ': 28}.
# [W 2026-04-23 15:39:45,449] Trial 120 failed with parameters: {'nI': 20, 'nR': 42, 'nO': 10, 'N1': 0.0001, 'N2': 0.1, 'N3': 1e-07, 'τ': 21} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:45,449] Trial 120 failed with value (nan, 3.400952942301384).
# [I 2026-04-23 15:39:45,505] Trial 121 finished with values: [0.03381751528836769, 0.5056987455502351] and parameters: {'nI': 27, 'nR': 37, 'nO': 4, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-06, 'τ': 23}.
# [I 2026-04-23 15:39:45,520] Trial 122 finished with values: [1.9209678143395694, 0.965539086417071] and parameters: {'nI': 5, 'nR': 24, 'nO': 10, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.0001, 'τ': 9}.
# [I 2026-04-23 15:39:45,541] Trial 123 finished with values: [3.6341387442484234, 0.9596391787207249] and parameters: {'nI': 10, 'nR': 23, 'nO': 7, 'N1': 1e-07, 'N2': 0.0001, 'N3': 1e-05, 'τ': 3}.
# [I 2026-04-23 15:39:45,648] Trial 124 finished with values: [1.286606871203407, 1.7773595966268467] and parameters: {'nI': 29, 'nR': 26, 'nO': 2, 'N1': 1e-07, 'N2': 1e-07, 'N3': 0.0001, 'τ': 15}.
# [I 2026-04-23 15:39:45,713] Trial 125 finished with values: [0.5010968685197198, 7.621811231599124] and parameters: {'nI': 15, 'nR': 46, 'nO': 2, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 19}.
# [I 2026-04-23 15:39:45,721] Trial 126 finished with values: [1.3799427187958444, 0.9433129599970111] and parameters: {'nI': 6, 'nR': 8, 'nO': 3, 'N1': 0.01, 'N2': 1e-06, 'N3': 1e-07, 'τ': 5}.
# [I 2026-04-23 15:39:45,798] Trial 127 finished with values: [0.09262167402447384, 1.2195125827826256] and parameters: {'nI': 9, 'nR': 23, 'nO': 1, 'N1': 0.001, 'N2': 0.01, 'N3': 0.1, 'τ': 24}.
# [I 2026-04-23 15:39:45,809] Trial 128 finished with values: [3.5417635917281722, 0.9618928512102243] and parameters: {'nI': 14, 'nR': 48, 'nO': 8, 'N1': 1e-06, 'N2': 0.0001, 'N3': 0.001, 'τ': 11}.
# [W 2026-04-23 15:39:45,970] Trial 129 failed with parameters: {'nI': 14, 'nR': 43, 'nO': 7, 'N1': 0.1, 'N2': 1e-06, 'N3': 1e-06, 'τ': 3} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:45,971] Trial 129 failed with value (nan, 4.3449480217351955).
# [I 2026-04-23 15:39:46,096] Trial 130 finished with values: [0.01939586660758887, 1.0206898016720036] and parameters: {'nI': 17, 'nR': 32, 'nO': 4, 'N1': 0.1, 'N2': 0.01, 'N3': 0.0001, 'τ': 22}.
# [I 2026-04-23 15:39:46,217] Trial 131 finished with values: [4.671656166017467, 3.9979999530809724] and parameters: {'nI': 23, 'nR': 25, 'nO': 7, 'N1': 1e-07, 'N2': 1e-05, 'N3': 0.0001, 'τ': 23}.
# [I 2026-04-23 15:39:46,362] Trial 132 finished with values: [2.272518860295507, 4.612949696621893] and parameters: {'nI': 16, 'nR': 25, 'nO': 6, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.0001, 'τ': 14}.
# [I 2026-04-23 15:39:46,372] Trial 133 finished with values: [2.5970314879739913, 0.9569306182693826] and parameters: {'nI': 2, 'nR': 23, 'nO': 6, 'N1': 1e-05, 'N2': 1e-05, 'N3': 1e-05, 'τ': 1}.
# [I 2026-04-23 15:39:46,408] Trial 134 finished with values: [0.5362720969125429, 0.414370498693219] and parameters: {'nI': 30, 'nR': 12, 'nO': 6, 'N1': 0.01, 'N2': 1e-05, 'N3': 1e-05, 'τ': 6}.
# [W 2026-04-23 15:39:46,546] Trial 135 failed with parameters: {'nI': 3, 'nR': 19, 'nO': 8, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.1, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:46,547] Trial 135 failed with value (nan, 4.485035955351051).
# [I 2026-04-23 15:39:46,564] Trial 136 finished with values: [1.9147191032346351, 0.9433145349433799] and parameters: {'nI': 2, 'nR': 10, 'nO': 3, 'N1': 1e-07, 'N2': 1e-06, 'N3': 0.0001, 'τ': 25}.
# [I 2026-04-23 15:39:46,649] Trial 137 finished with values: [0.22423198943609884, 8.497824301379653] and parameters: {'nI': 2, 'nR': 26, 'nO': 2, 'N1': 0.01, 'N2': 1e-06, 'N3': 1e-05, 'τ': 20}.
# [I 2026-04-23 15:39:46,757] Trial 138 finished with values: [0.05132387759786364, 1.0796504463523895] and parameters: {'nI': 21, 'nR': 33, 'nO': 9, 'N1': 0.1, 'N2': 0.01, 'N3': 0.001, 'τ': 29}.
# [I 2026-04-23 15:39:46,770] Trial 139 finished with values: [3.59792115978177, 0.9655395592215512] and parameters: {'nI': 2, 'nR': 21, 'nO': 10, 'N1': 0.0001, 'N2': 1e-06, 'N3': 1e-07, 'τ': 14}.
# [I 2026-04-23 15:39:46,829] Trial 140 finished with values: [0.12190546266671434, 1.4315392436249608] and parameters: {'nI': 26, 'nR': 34, 'nO': 1, 'N1': 0.0001, 'N2': 0.1, 'N3': 1e-07, 'τ': 27}.
# [I 2026-04-23 15:39:46,841] Trial 141 finished with values: [5.979128258291137, 0.9567105727202255] and parameters: {'nI': 27, 'nR': 46, 'nO': 6, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.001, 'τ': 18}.
# [W 2026-04-23 15:39:46,995] Trial 142 failed with parameters: {'nI': 16, 'nR': 29, 'nO': 8, 'N1': 1e-07, 'N2': 0.01, 'N3': 0.1, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:46,995] Trial 142 failed with value (nan, 3.962918561846942).
# [I 2026-04-23 15:39:47,008] Trial 143 finished with values: [2.0, 0.9489056404789502] and parameters: {'nI': 30, 'nR': 1, 'nO': 4, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 30}.
# [I 2026-04-23 15:39:47,018] Trial 144 finished with values: [3.2028202534738055, 0.9653582016139464] and parameters: {'nI': 27, 'nR': 2, 'nO': 10, 'N1': 0.001, 'N2': 1e-07, 'N3': 1e-05, 'τ': 18}.
# [I 2026-04-23 15:39:47,112] Trial 145 finished with values: [0.1193286201532584, 1.4371926696832025] and parameters: {'nI': 13, 'nR': 42, 'nO': 3, 'N1': 0.01, 'N2': 0.01, 'N3': 1e-06, 'τ': 20}.
# [I 2026-04-23 15:39:47,113] Trial 146 finished with values: [2.7595607895296084, 0.9619158604873137] and parameters: {'nI': 5, 'nR': 4, 'nO': 8, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 27}.
# [I 2026-04-23 15:39:47,132] Trial 147 finished with values: [2.3662311625210557, 0.9492254384598304] and parameters: {'nI': 15, 'nR': 31, 'nO': 4, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.001, 'τ': 29}.
# [I 2026-04-23 15:39:47,141] Trial 148 finished with values: [4.099068211594665, 0.9655385474698353] and parameters: {'nI': 6, 'nR': 49, 'nO': 10, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-05, 'τ': 11}.
# [I 2026-04-23 15:39:47,151] Trial 149 finished with values: [4.977558681770859, 0.9655057941652769] and parameters: {'nI': 16, 'nR': 11, 'nO': 10, 'N1': 1e-07, 'N2': 1e-06, 'N3': 0.0001, 'τ': 5}.
# [I 2026-04-23 15:39:47,153] Trial 150 finished with values: [3.7192256969461948, 0.9637414583290859] and parameters: {'nI': 23, 'nR': 46, 'nO': 9, 'N1': 1e-06, 'N2': 1e-05, 'N3': 0.0001, 'τ': 25}.
# [I 2026-04-23 15:39:47,274] Trial 151 finished with values: [2.633569165128777, 4.023370236151935] and parameters: {'nI': 15, 'nR': 38, 'nO': 8, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.01, 'τ': 10}.
# [I 2026-04-23 15:39:47,290] Trial 152 finished with values: [1.7357842859673154, 0.9433116497154055] and parameters: {'nI': 7, 'nR': 5, 'nO': 3, 'N1': 1e-06, 'N2': 0.01, 'N3': 0.1, 'τ': 21}.
# [I 2026-04-23 15:39:47,295] Trial 153 finished with values: [4.974813622690992, 0.9637070425819694] and parameters: {'nI': 25, 'nR': 49, 'nO': 9, 'N1': 1e-05, 'N2': 1e-06, 'N3': 0.0001, 'τ': 7}.
# [I 2026-04-23 15:39:47,403] Trial 154 finished with values: [0.11740530422773307, 0.9586617492597046] and parameters: {'nI': 18, 'nR': 46, 'nO': 6, 'N1': 0.001, 'N2': 1e-07, 'N3': 0.1, 'τ': 10}.
# [I 2026-04-23 15:39:47,545] Trial 155 finished with values: [31.183517862825788, 3.080066793864794] and parameters: {'nI': 21, 'nR': 28, 'nO': 8, 'N1': 0.01, 'N2': 0.1, 'N3': 1e-06, 'τ': 28}.
# [I 2026-04-23 15:39:47,554] Trial 156 finished with values: [6.3298973981129265, 0.9636875065255525] and parameters: {'nI': 26, 'nR': 43, 'nO': 9, 'N1': 1e-07, 'N2': 1e-05, 'N3': 1e-06, 'τ': 26}.
# [I 2026-04-23 15:39:47,671] Trial 157 finished with values: [9.24813537229267, 5.917874312139712] and parameters: {'nI': 25, 'nR': 40, 'nO': 3, 'N1': 1e-06, 'N2': 1e-07, 'N3': 0.01, 'τ': 7}.
# [I 2026-04-23 15:39:47,682] Trial 158 finished with values: [2.2062532954358915, 0.9535518445268601] and parameters: {'nI': 14, 'nR': 3, 'nO': 5, 'N1': 1e-05, 'N2': 1e-07, 'N3': 1e-05, 'τ': 12}.
# [I 2026-04-23 15:39:47,694] Trial 159 finished with values: [1.6299822254068566, 0.9340450323756709] and parameters: {'nI': 6, 'nR': 39, 'nO': 2, 'N1': 1e-07, 'N2': 1e-05, 'N3': 1e-05, 'τ': 25}.
# [I 2026-04-23 15:39:47,747] Trial 160 finished with values: [0.02002158332326447, 0.3062464021842722] and parameters: {'nI': 25, 'nR': 25, 'nO': 10, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.001, 'τ': 7}.
# [I 2026-04-23 15:39:47,755] Trial 161 finished with values: [3.596947011081864, 0.959632298724427] and parameters: {'nI': 12, 'nR': 25, 'nO': 7, 'N1': 0.0001, 'N2': 1e-07, 'N3': 0.0001, 'τ': 13}.
# [I 2026-04-23 15:39:47,764] Trial 162 finished with values: [1.4554276293368147, 0.9430604533263595] and parameters: {'nI': 26, 'nR': 9, 'nO': 3, 'N1': 1e-07, 'N2': 0.01, 'N3': 1e-06, 'τ': 18}.
# [I 2026-04-23 15:39:47,829] Trial 163 finished with values: [0.0026386532749243614, 0.5698130185034928] and parameters: {'nI': 8, 'nR': 24, 'nO': 2, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-05, 'τ': 3}.
# [W 2026-04-23 15:39:47,950] Trial 164 failed with parameters: {'nI': 11, 'nR': 32, 'nO': 10, 'N1': 0.001, 'N2': 0.01, 'N3': 0.1, 'τ': 22} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:47,950] Trial 164 failed with value (nan, 3.684787984389495).
# [I 2026-04-23 15:39:47,961] Trial 165 finished with values: [1.709226630329414, 0.9535632409013094] and parameters: {'nI': 12, 'nR': 45, 'nO': 5, 'N1': 0.001, 'N2': 1e-06, 'N3': 1e-05, 'τ': 19}.
# [I 2026-04-23 15:39:47,974] Trial 166 finished with values: [0.41796351590145303, 0.9619112759514514] and parameters: {'nI': 9, 'nR': 21, 'nO': 8, 'N1': 0.01, 'N2': 1e-05, 'N3': 1e-07, 'τ': 16}.
# [W 2026-04-23 15:39:48,093] Trial 167 failed with parameters: {'nI': 13, 'nR': 35, 'nO': 4, 'N1': 0.001, 'N2': 1e-07, 'N3': 0.1, 'τ': 13} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:48,095] Trial 167 failed with value (nan, 5.783981988532714).
# [I 2026-04-23 15:39:48,161] Trial 168 finished with values: [0.005995719985328346, 0.3794205690230569] and parameters: {'nI': 10, 'nR': 44, 'nO': 4, 'N1': 0.1, 'N2': 0.1, 'N3': 0.1, 'τ': 7}.
# [W 2026-04-23 15:39:48,257] Trial 169 failed with parameters: {'nI': 15, 'nR': 12, 'nO': 10, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.1, 'τ': 16} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:48,258] Trial 169 failed with value (nan, 3.5806471337797667).
# [I 2026-04-23 15:39:48,365] Trial 170 finished with values: [0.014423680084023416, 0.6290264735124266] and parameters: {'nI': 15, 'nR': 26, 'nO': 8, 'N1': 0.1, 'N2': 1e-06, 'N3': 1e-06, 'τ': 8}.
# [I 2026-04-23 15:39:48,466] Trial 171 finished with values: [5.781961081019063, 0.9440934248044606] and parameters: {'nI': 24, 'nR': 11, 'nO': 10, 'N1': 1e-07, 'N2': 0.001, 'N3': 0.0001, 'τ': 11}.
# [I 2026-04-23 15:39:48,475] Trial 172 finished with values: [1.7816439889625615, 0.9533950284099736] and parameters: {'nI': 25, 'nR': 7, 'nO': 5, 'N1': 1e-06, 'N2': 0.01, 'N3': 0.0001, 'τ': 27}.
# [I 2026-04-23 15:39:48,487] Trial 173 finished with values: [2.1165518910536094, 0.9655178780716711] and parameters: {'nI': 14, 'nR': 39, 'nO': 10, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.0001, 'τ': 5}.
# [I 2026-04-23 15:39:48,495] Trial 174 finished with values: [0.37304365558636793, 0.9655348572635032] and parameters: {'nI': 9, 'nR': 5, 'nO': 10, 'N1': 0.1, 'N2': 0.01, 'N3': 1e-05, 'τ': 1}.
# [I 2026-04-23 15:39:48,580] Trial 175 finished with values: [19.46738328453981, 0.6275315045842234] and parameters: {'nI': 14, 'nR': 50, 'nO': 5, 'N1': 0.1, 'N2': 1e-06, 'N3': 1e-07, 'τ': 1}.
# [I 2026-04-23 15:39:48,591] Trial 176 finished with values: [3.3820087605702676, 0.9655395592215512] and parameters: {'nI': 2, 'nR': 35, 'nO': 10, 'N1': 0.0001, 'N2': 0.0001, 'N3': 1e-05, 'τ': 16}.
# [W 2026-04-23 15:39:48,726] Trial 177 failed with parameters: {'nI': 25, 'nR': 46, 'nO': 7, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.001, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:48,726] Trial 177 failed with value (nan, 3.9283027217795197).
# [W 2026-04-23 15:39:48,861] Trial 178 failed with parameters: {'nI': 12, 'nR': 25, 'nO': 8, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.0001, 'τ': 14} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:48,862] Trial 178 failed with value (nan, 4.1234422238292465).
# [W 2026-04-23 15:39:48,972] Trial 179 failed with parameters: {'nI': 5, 'nR': 40, 'nO': 9, 'N1': 1e-07, 'N2': 1e-05, 'N3': 0.1, 'τ': 25} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:48,972] Trial 179 failed with value (nan, 3.6068406938304887).
# [W 2026-04-23 15:39:48,997] Trial 180 failed with parameters: {'nI': 29, 'nR': 49, 'nO': 10, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.0001, 'τ': 8} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:48,997] Trial 180 failed with value (nan, 2.4071875009560957).
# [I 2026-04-23 15:39:49,112] Trial 181 finished with values: [1.5385593010729581, 5.326801775025748] and parameters: {'nI': 30, 'nR': 12, 'nO': 2, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.01, 'τ': 25}.
# [W 2026-04-23 15:39:49,250] Trial 182 failed with parameters: {'nI': 21, 'nR': 12, 'nO': 9, 'N1': 0.0001, 'N2': 1e-07, 'N3': 0.1, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:49,250] Trial 182 failed with value (nan, 3.543364881004066).
# [I 2026-04-23 15:39:49,294] Trial 183 finished with values: [36.48255836633422, 4.1239134091189324] and parameters: {'nI': 18, 'nR': 26, 'nO': 7, 'N1': 1e-06, 'N2': 1e-05, 'N3': 0.01, 'τ': 16}.
# [I 2026-04-23 15:39:49,303] Trial 184 finished with values: [0.905258366084784, 0.9145370984054007] and parameters: {'nI': 18, 'nR': 10, 'nO': 1, 'N1': 0.0001, 'N2': 0.1, 'N3': 1e-07, 'τ': 23}.
# [I 2026-04-23 15:39:49,315] Trial 185 finished with values: [2.4708150022095547, 0.9492542058833584] and parameters: {'nI': 10, 'nR': 23, 'nO': 4, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-05, 'τ': 25}.
# [I 2026-04-23 15:39:49,445] Trial 186 finished with values: [3.946345830047896, 3.539874427275695] and parameters: {'nI': 21, 'nR': 34, 'nO': 9, 'N1': 1e-07, 'N2': 0.001, 'N3': 1e-06, 'τ': 24}.
# [I 2026-04-23 15:39:49,457] Trial 187 finished with values: [3.025494613613377, 0.9490626116933045] and parameters: {'nI': 25, 'nR': 34, 'nO': 4, 'N1': 0.0001, 'N2': 1e-07, 'N3': 1e-06, 'τ': 19}.
# [W 2026-04-23 15:39:49,561] Trial 188 failed with parameters: {'nI': 27, 'nR': 22, 'nO': 9, 'N1': 0.01, 'N2': 0.001, 'N3': 0.1, 'τ': 27} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:49,562] Trial 188 failed with value (nan, 3.3495212509692696).
# [I 2026-04-23 15:39:49,569] Trial 189 finished with values: [2.8493355608427926, 0.9568461604055456] and parameters: {'nI': 20, 'nR': 10, 'nO': 6, 'N1': 0.0001, 'N2': 0.0001, 'N3': 0.0001, 'τ': 26}.
# [I 2026-04-23 15:39:49,682] Trial 190 finished with values: [45.24324750103058, 1.897008157612437] and parameters: {'nI': 4, 'nR': 36, 'nO': 9, 'N1': 1e-06, 'N2': 1e-07, 'N3': 0.1, 'τ': 16}.
# [W 2026-04-23 15:39:49,774] Trial 191 failed with parameters: {'nI': 9, 'nR': 49, 'nO': 6, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.001, 'τ': 12} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:49,774] Trial 191 failed with value (nan, 4.953631947077311).
# [W 2026-04-23 15:39:49,886] Trial 192 failed with parameters: {'nI': 2, 'nR': 39, 'nO': 8, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.1, 'τ': 18} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:49,886] Trial 192 failed with value (nan, 4.52647033271369).
# [I 2026-04-23 15:39:49,904] Trial 193 finished with values: [3.3157762406026086, 0.9655057941652769] and parameters: {'nI': 16, 'nR': 7, 'nO': 10, 'N1': 1e-05, 'N2': 1e-05, 'N3': 1e-07, 'τ': 24}.
# [I 2026-04-23 15:39:49,917] Trial 194 finished with values: [1.0784915350778166, 0.9638544839568226] and parameters: {'nI': 5, 'nR': 2, 'nO': 9, 'N1': 0.1, 'N2': 0.001, 'N3': 0.0001, 'τ': 9}.
# [I 2026-04-23 15:39:49,928] Trial 195 finished with values: [2.9990257771768274, 0.9655395592215512] and parameters: {'nI': 2, 'nR': 31, 'nO': 10, 'N1': 0.0001, 'N2': 1e-06, 'N3': 1e-06, 'τ': 14}.
# [I 2026-04-23 15:39:49,940] Trial 196 finished with values: [3.425398778114968, 0.9611974272788212] and parameters: {'nI': 10, 'nR': 32, 'nO': 8, 'N1': 1e-07, 'N2': 0.001, 'N3': 1e-06, 'τ': 4}.
# [W 2026-04-23 15:39:50,015] Trial 197 failed with parameters: {'nI': 12, 'nR': 32, 'nO': 6, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.01, 'τ': 2} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:50,015] Trial 197 failed with value (nan, 4.8232477164490835).
# [I 2026-04-23 15:39:50,024] Trial 198 finished with values: [3.9109378275407254, 0.9638478687412239] and parameters: {'nI': 10, 'nR': 16, 'nO': 9, 'N1': 0.0001, 'N2': 1e-07, 'N3': 0.0001, 'τ': 26}.
# [I 2026-04-23 15:39:50,034] Trial 199 finished with values: [0.8845753430916091, 0.914603904652114] and parameters: {'nI': 14, 'nR': 1, 'nO': 1, 'N1': 0.1, 'N2': 1e-07, 'N3': 0.0001, 'τ': 27}.
# [I 2026-04-23 15:39:50,085] Trial 200 finished with values: [2.693256655476338, 0.8792093902997022] and parameters: {'nI': 18, 'nR': 4, 'nO': 5, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.01, 'τ': 30}.
# [W 2026-04-23 15:39:50,178] Trial 201 failed with parameters: {'nI': 3, 'nR': 28, 'nO': 4, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-06, 'τ': 4} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:39:50,178] Trial 201 failed with value (nan, 6.300155550234093).
# [I 2026-04-23 15:39:50,186] Trial 202 finished with values: [2.9617283176228515, 0.9638033878907609] and parameters: {'nI': 18, 'nR': 10, 'nO': 9, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-05, 'τ': 21}.
# [I 2026-04-23 15:39:50,198] Trial 203 finished with values: [0.9263180043455556, 0.9339853014472771] and parameters: {'nI': 16, 'nR': 8, 'nO': 2, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-05, 'τ': 9}.
# [I 2026-04-23 15:39:50,344] Trial 204 finished with values: [0.4565664677383222, 9.709858668556128] and parameters: {'nI': 21, 'nR': 37, 'nO': 1, 'N1': 0.0001, 'N2': 1e-06, 'N3': 0.001, 'τ': 27}.
# [I 2026-04-23 15:39:50,353] Trial 205 finished with values: [3.162277660168379, 0.9654697643479566] and parameters: {'nI': 20, 'nR': 1, 'nO': 10, 'N1': 0.1, 'N2': 0.1, 'N3': 0.0001, 'τ': 1}.
# ...
# [I 2026-04-23 15:51:29,280] Trial 9932 finished with values: [0.3694340853299046, 6.93239655733213] and parameters: {'nI': 27, 'nR': 37, 'nO': 2, 'N1': 0.001, 'N2': 0.0001, 'N3': 0.01, 'τ': 2}.
# [I 2026-04-23 15:51:29,303] Trial 9933 finished with values: [6.26809530865857, 0.9636434493685323] and parameters: {'nI': 28, 'nR': 24, 'nO': 9, 'N1': 1e-06, 'N2': 1e-06, 'N3': 1e-05, 'τ': 7}.
# [I 2026-04-23 15:51:29,526] Trial 9934 finished with values: [0.01891123049480467, 0.6123320746377106] and parameters: {'nI': 30, 'nR': 42, 'nO': 1, 'N1': 0.01, 'N2': 0.01, 'N3': 0.01, 'τ': 4}.
# [I 2026-04-23 15:51:29,545] Trial 9935 finished with values: [2.0, 0.9491938862506036] and parameters: {'nI': 18, 'nR': 2, 'nO': 4, 'N1': 1e-06, 'N2': 1e-05, 'N3': 0.001, 'τ': 22}.
# [I 2026-04-23 15:51:29,878] Trial 9936 finished with values: [0.040597457334365296, 2.225288605758857] and parameters: {'nI': 20, 'nR': 29, 'nO': 1, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 21}.
# [I 2026-04-23 15:51:29,910] Trial 9937 finished with values: [0.2366415574249214, 0.9146552759458597] and parameters: {'nI': 3, 'nR': 39, 'nO': 1, 'N1': 1e-06, 'N2': 1e-07, 'N3': 1e-05, 'τ': 11}.
# [I 2026-04-23 15:51:29,926] Trial 9938 finished with values: [5.401537669637098, 0.9617977414318601] and parameters: {'nI': 23, 'nR': 36, 'nO': 8, 'N1': 1e-07, 'N2': 1e-07, 'N3': 1e-06, 'τ': 1}.
# [I 2026-04-23 15:51:29,957] Trial 9939 finished with values: [2.52935754003127, 0.9569300491578812] and parameters: {'nI': 5, 'nR': 46, 'nO': 6, 'N1': 1e-05, 'N2': 0.001, 'N3': 1e-05, 'τ': 4}.
# [I 2026-04-23 15:51:29,988] Trial 9940 finished with values: [3.5286817851677044, 0.9655395592215512] and parameters: {'nI': 2, 'nR': 49, 'nO': 10, 'N1': 1e-07, 'N2': 1e-06, 'N3': 1e-06, 'τ': 18}.
# [I 2026-04-23 15:51:30,004] Trial 9941 finished with values: [2.4453662206857874, 0.9566549616415844] and parameters: {'nI': 29, 'nR': 3, 'nO': 6, 'N1': 1e-06, 'N2': 0.01, 'N3': 1e-07, 'τ': 23}.
# [I 2026-04-23 15:51:30,179] Trial 9942 finished with values: [1.6723082065844528, 3.334379501317656] and parameters: {'nI': 30, 'nR': 45, 'nO': 9, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-07, 'τ': 28}.
# [I 2026-04-23 15:51:30,210] Trial 9943 finished with values: [2.447249152338897, 0.9430604533263595] and parameters: {'nI': 26, 'nR': 25, 'nO': 3, 'N1': 1e-05, 'N2': 0.0001, 'N3': 1e-07, 'τ': 29}.
# [I 2026-04-23 15:51:30,258] Trial 9944 finished with values: [0.10230317342113675, 0.5751395677131661] and parameters: {'nI': 7, 'nR': 5, 'nO': 2, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.001, 'τ': 18}.
# [I 2026-04-23 15:51:30,465] Trial 9945 finished with values: [3.2204885739566063, 0.7851863756658195] and parameters: {'nI': 21, 'nR': 23, 'nO': 10, 'N1': 0.001, 'N2': 1e-07, 'N3': 0.001, 'τ': 9}.
# [I 2026-04-23 15:51:30,633] Trial 9946 finished with values: [0.06474845345845026, 0.6880685304196599] and parameters: {'nI': 2, 'nR': 25, 'nO': 8, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-05, 'τ': 13}.
# [W 2026-04-23 15:51:30,998] Trial 9947 failed with parameters: {'nI': 3, 'nR': 13, 'nO': 2, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.0001, 'τ': 9} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:30,998] Trial 9947 failed with value (nan, 8.448001777807841).
# [I 2026-04-23 15:51:31,030] Trial 9948 finished with values: [2.474056375563728, 0.9595903280183681] and parameters: {'nI': 18, 'nR': 42, 'nO': 7, 'N1': 1e-07, 'N2': 1e-07, 'N3': 1e-05, 'τ': 25}.
# [I 2026-04-23 15:51:31,340] Trial 9949 finished with values: [0.6025051439344823, 4.8790247836179255] and parameters: {'nI': 20, 'nR': 17, 'nO': 3, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.1, 'τ': 9}.
# [I 2026-04-23 15:51:31,366] Trial 9950 finished with values: [2.948525731352876, 0.9619152765008396] and parameters: {'nI': 6, 'nR': 31, 'nO': 8, 'N1': 1e-07, 'N2': 0.001, 'N3': 1e-07, 'τ': 20}.
# [I 2026-04-23 15:51:31,647] Trial 9951 finished with values: [2.21343385699713, 1.9283068470804872] and parameters: {'nI': 20, 'nR': 32, 'nO': 4, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.001, 'τ': 17}.
# [I 2026-04-23 15:51:31,671] Trial 9952 finished with values: [3.4639502153730004, 0.9490464710177742] and parameters: {'nI': 25, 'nR': 10, 'nO': 4, 'N1': 0.0001, 'N2': 1e-07, 'N3': 1e-05, 'τ': 1}.
# [I 2026-04-23 15:51:32,065] Trial 9953 finished with values: [63.7502586813536, 4.137695287454267] and parameters: {'nI': 4, 'nR': 19, 'nO': 9, 'N1': 1e-07, 'N2': 1e-07, 'N3': 0.1, 'τ': 14}.
# [I 2026-04-23 15:51:32,350] Trial 9954 finished with values: [0.28075197017011855, 1.2796486961795557] and parameters: {'nI': 9, 'nR': 31, 'nO': 8, 'N1': 0.001, 'N2': 0.001, 'N3': 0.01, 'τ': 3}.
# [W 2026-04-23 15:51:32,796] Trial 9955 failed with parameters: {'nI': 10, 'nR': 41, 'nO': 5, 'N1': 1e-06, 'N2': 0.1, 'N3': 0.0001, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:32,796] Trial 9955 failed with value (nan, 5.31540717547067).
# [I 2026-04-23 15:51:32,817] Trial 9956 finished with values: [2.2599068524637067, 0.9595537284947498] and parameters: {'nI': 21, 'nR': 5, 'nO': 7, 'N1': 0.1, 'N2': 1e-07, 'N3': 0.0001, 'τ': 11}.
# [W 2026-04-23 15:51:32,959] Trial 9957 failed with parameters: {'nI': 7, 'nR': 37, 'nO': 7, 'N1': 0.0001, 'N2': 0.01, 'N3': 1e-05, 'τ': 13} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:32,959] Trial 9957 failed with value (nan, 4.4309036740156085).
# [I 2026-04-23 15:51:32,990] Trial 9958 finished with values: [0.8275673233460309, 0.9339387560914921] and parameters: {'nI': 19, 'nR': 28, 'nO': 2, 'N1': 1e-06, 'N2': 1e-05, 'N3': 0.0001, 'τ': 13}.
# [I 2026-04-23 15:51:33,254] Trial 9959 finished with values: [0.1874737375629482, 10.915522540525503] and parameters: {'nI': 7, 'nR': 21, 'nO': 1, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.01, 'τ': 23}.
# [W 2026-04-23 15:51:33,516] Trial 9960 failed with parameters: {'nI': 13, 'nR': 17, 'nO': 3, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.01, 'τ': 1} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:33,516] Trial 9960 failed with value (nan, 6.55912497791131).
# [I 2026-04-23 15:51:33,808] Trial 9961 finished with values: [0.030786306317314858, 0.8554229206927484] and parameters: {'nI': 9, 'nR': 45, 'nO': 3, 'N1': 0.01, 'N2': 0.01, 'N3': 0.01, 'τ': 7}.
# [W 2026-04-23 15:51:34,099] Trial 9962 failed with parameters: {'nI': 27, 'nR': 2, 'nO': 10, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.1, 'τ': 7} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:34,100] Trial 9962 failed with value (nan, 3.141439322658709).
# [I 2026-04-23 15:51:34,124] Trial 9963 finished with values: [1.125620995586402, 0.9638500917585976] and parameters: {'nI': 9, 'nR': 6, 'nO': 9, 'N1': 0.01, 'N2': 0.01, 'N3': 0.01, 'τ': 29}.
# [I 2026-04-23 15:51:34,141] Trial 9964 finished with values: [4.320845155909594, 0.9636875065255525] and parameters: {'nI': 26, 'nR': 42, 'nO': 9, 'N1': 1e-07, 'N2': 1e-06, 'N3': 1e-07, 'τ': 17}.
# [I 2026-04-23 15:51:34,173] Trial 9965 finished with values: [3.7892763688582387, 0.9655348572635032] and parameters: {'nI': 9, 'nR': 47, 'nO': 10, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.0001, 'τ': 14}.
# [I 2026-04-23 15:51:34,205] Trial 9966 finished with values: [1.4271231572682759, 0.9339971630212335] and parameters: {'nI': 15, 'nR': 20, 'nO': 2, 'N1': 1e-05, 'N2': 0.0001, 'N3': 1e-05, 'τ': 20}.
# [I 2026-04-23 15:51:34,225] Trial 9967 finished with values: [2.969627219867277, 0.9596469315170163] and parameters: {'nI': 3, 'nR': 29, 'nO': 7, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.0001, 'τ': 21}.
# [I 2026-04-23 15:51:34,441] Trial 9968 finished with values: [0.01681253123191707, 0.23201935352539255] and parameters: {'nI': 6, 'nR': 49, 'nO': 9, 'N1': 0.1, 'N2': 1e-07, 'N3': 0.01, 'τ': 16}.
# [I 2026-04-23 15:51:34,472] Trial 9969 finished with values: [2.7085356331939465, 0.9535798287747057] and parameters: {'nI': 3, 'nR': 34, 'nO': 5, 'N1': 1e-05, 'N2': 1e-07, 'N3': 0.001, 'τ': 25}.
# [W 2026-04-23 15:51:34,711] Trial 9970 failed with parameters: {'nI': 20, 'nR': 14, 'nO': 4, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.1, 'τ': 26} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:34,721] Trial 9970 failed with value (nan, 4.26169334509185).
# [W 2026-04-23 15:51:34,803] Trial 9971 failed with parameters: {'nI': 13, 'nR': 17, 'nO': 3, 'N1': 1e-05, 'N2': 0.001, 'N3': 0.01, 'τ': 13} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:34,803] Trial 9971 failed with value (nan, 6.051160314245991).
# [I 2026-04-23 15:51:34,815] Trial 9972 finished with values: [5.179112429489176, 0.9655364987181043] and parameters: {'nI': 8, 'nR': 40, 'nO': 10, 'N1': 1e-05, 'N2': 1e-05, 'N3': 1e-06, 'τ': 9}.
# [I 2026-04-23 15:51:34,826] Trial 9973 finished with values: [0.23127794886938616, 0.9260207901408144] and parameters: {'nI': 4, 'nR': 4, 'nO': 2, 'N1': 0.01, 'N2': 1e-07, 'N3': 0.001, 'τ': 6}.
# [W 2026-04-23 15:51:34,933] Trial 9974 failed with parameters: {'nI': 15, 'nR': 32, 'nO': 9, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.0001, 'τ': 22} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:34,934] Trial 9974 failed with value (nan, 3.7967508172045408).
# [I 2026-04-23 15:51:34,942] Trial 9975 finished with values: [3.276440967577068, 0.9652871058836359] and parameters: {'nI': 30, 'nR': 8, 'nO': 10, 'N1': 1e-07, 'N2': 0.001, 'N3': 0.0001, 'τ': 1}.
# [I 2026-04-23 15:51:35,055] Trial 9976 finished with values: [0.07186830865078257, 1.1715574962196569] and parameters: {'nI': 26, 'nR': 14, 'nO': 7, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-05, 'τ': 25}.
# [I 2026-04-23 15:51:35,071] Trial 9977 finished with values: [1.8405368809153986, 0.9433145349433799] and parameters: {'nI': 2, 'nR': 48, 'nO': 3, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-07, 'τ': 1}.
# [I 2026-04-23 15:51:35,191] Trial 9978 finished with values: [1.8849893938644202, 4.077068837834211] and parameters: {'nI': 21, 'nR': 18, 'nO': 7, 'N1': 0.001, 'N2': 0.001, 'N3': 1e-07, 'τ': 19}.
# [I 2026-04-23 15:51:35,247] Trial 9979 finished with values: [0.21806011886598825, 0.475924128327928] and parameters: {'nI': 27, 'nR': 30, 'nO': 10, 'N1': 0.01, 'N2': 0.0001, 'N3': 1e-07, 'τ': 15}.
# [I 2026-04-23 15:51:35,333] Trial 9980 finished with values: [0.1031348615677206, 3.6934722254843093] and parameters: {'nI': 6, 'nR': 13, 'nO': 1, 'N1': 0.001, 'N2': 1e-07, 'N3': 0.01, 'τ': 9}.
# [W 2026-04-23 15:51:35,470] Trial 9981 failed with parameters: {'nI': 22, 'nR': 13, 'nO': 3, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-05, 'τ': 8} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:35,470] Trial 9981 failed with value (nan, 6.057404573450191).
# [W 2026-04-23 15:51:35,600] Trial 9982 failed with parameters: {'nI': 11, 'nR': 15, 'nO': 4, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.01, 'τ': 20} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:35,600] Trial 9982 failed with value (nan, 5.8756328038827705).
# [I 2026-04-23 15:51:35,610] Trial 9983 finished with values: [1.4313941197030604, 0.9336283319589754] and parameters: {'nI': 29, 'nR': 2, 'nO': 2, 'N1': 0.01, 'N2': 0.1, 'N3': 1e-05, 'τ': 4}.
# [I 2026-04-23 15:51:35,720] Trial 9984 finished with values: [6.393111727797319, 3.1913705539439414] and parameters: {'nI': 26, 'nR': 27, 'nO': 10, 'N1': 1e-06, 'N2': 1e-05, 'N3': 1e-06, 'τ': 18}.
# [I 2026-04-23 15:51:35,732] Trial 9985 finished with values: [2.9539837445213197, 0.9596277090821476] and parameters: {'nI': 13, 'nR': 19, 'nO': 7, 'N1': 0.0001, 'N2': 1e-07, 'N3': 0.001, 'τ': 23}.
# [I 2026-04-23 15:51:35,738] Trial 9986 finished with values: [3.0, 0.9636875065255525] and parameters: {'nI': 26, 'nR': 4, 'nO': 9, 'N1': 0.1, 'N2': 0.001, 'N3': 1e-05, 'τ': 6}.
# [I 2026-04-23 15:51:35,870] Trial 9987 finished with values: [1.5349081422110378, 3.1553369432322924] and parameters: {'nI': 26, 'nR': 16, 'nO': 10, 'N1': 0.001, 'N2': 1e-06, 'N3': 1e-07, 'τ': 3}.
# [I 2026-04-23 15:51:35,878] Trial 9988 finished with values: [1.9757647199368051, 0.9432996283545023] and parameters: {'nI': 11, 'nR': 16, 'nO': 3, 'N1': 0.0001, 'N2': 1e-05, 'N3': 1e-05, 'τ': 15}.
# [I 2026-04-23 15:51:36,020] Trial 9989 finished with values: [7.337188276053573, 4.161881188141497] and parameters: {'nI': 11, 'nR': 28, 'nO': 8, 'N1': 1e-05, 'N2': 0.001, 'N3': 0.001, 'τ': 11}.
# [I 2026-04-23 15:51:36,032] Trial 9990 finished with values: [4.139400266681095, 0.9655348572635032] and parameters: {'nI': 9, 'nR': 38, 'nO': 10, 'N1': 1e-05, 'N2': 0.001, 'N3': 1e-07, 'τ': 27}.
# [I 2026-04-23 15:51:36,044] Trial 9991 finished with values: [1.0359785700655868, 0.9491653762004172] and parameters: {'nI': 20, 'nR': 38, 'nO': 4, 'N1': 0.001, 'N2': 1e-06, 'N3': 1e-07, 'τ': 25}.
# [I 2026-04-23 15:51:36,113] Trial 9992 finished with values: [1.7975075869021013, 0.33313112192589817] and parameters: {'nI': 4, 'nR': 14, 'nO': 5, 'N1': 1e-07, 'N2': 1e-06, 'N3': 1e-05, 'τ': 15}.
# [I 2026-04-23 15:51:36,120] Trial 9993 finished with values: [2.251760004646307, 0.9535032332233994] and parameters: {'nI': 19, 'nR': 39, 'nO': 5, 'N1': 1e-07, 'N2': 1e-05, 'N3': 1e-06, 'τ': 18}.
# [W 2026-04-23 15:51:36,219] Trial 9994 failed with parameters: {'nI': 19, 'nR': 16, 'nO': 7, 'N1': 0.0001, 'N2': 0.01, 'N3': 0.01, 'τ': 21} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:36,220] Trial 9994 failed with value (nan, 4.186111565079886).
# [I 2026-04-23 15:51:36,224] Trial 9995 finished with values: [2.8284271247461894, 0.9617977414318601] and parameters: {'nI': 23, 'nR': 2, 'nO': 8, 'N1': 1e-05, 'N2': 0.1, 'N3': 0.01, 'τ': 5}.
# [I 2026-04-23 15:51:36,312] Trial 9996 finished with values: [4.983996875126904, 5.421032944970224] and parameters: {'nI': 21, 'nR': 49, 'nO': 4, 'N1': 1e-05, 'N2': 0.0001, 'N3': 0.01, 'τ': 21}.
# [I 2026-04-23 15:51:36,370] Trial 9997 finished with values: [1.283134428731254e+21, 2.4607651567269984] and parameters: {'nI': 21, 'nR': 48, 'nO': 9, 'N1': 1e-05, 'N2': 0.01, 'N3': 1e-07, 'τ': 28}.
# [I 2026-04-23 15:51:36,378] Trial 9998 finished with values: [1.67117644920586, 0.9432881068561532] and parameters: {'nI': 13, 'nR': 5, 'nO': 3, 'N1': 0.001, 'N2': 0.0001, 'N3': 1e-06, 'τ': 11}.
# [W 2026-04-23 15:51:36,491] Trial 9999 failed with parameters: {'nI': 16, 'nR': 33, 'nO': 3, 'N1': 0.0001, 'N2': 0.01, 'N3': 1e-06, 'τ': 8} because of the following error: The value nan is not acceptable.
# [W 2026-04-23 15:51:36,491] Trial 9999 failed with value (nan, 6.406881157847397).
# Encontrados 12 modelos na Fronteira de Pareto:
# Erro_M = 0.514722, Erro_R = 0.129311 Parâmetros: {'nI': 21, 'nR': 14, 'nO': 8, 'N1': 0.01, 'N2': 1e-06, 'N3': 1e-07, 'τ': 22}
# Erro_M = 0.001066, Erro_R = 0.501517 Parâmetros: {'nI': 8, 'nR': 33, 'nO': 1, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.01, 'τ': 5}
# Erro_M = 0.000522, Erro_R = 0.570564 Parâmetros: {'nI': 4, 'nR': 24, 'nO': 1, 'N1': 0.1, 'N2': 1e-07, 'N3': 0.001, 'τ': 1}
# Erro_M = 0.010973, Erro_R = 0.273955 Parâmetros: {'nI': 24, 'nR': 45, 'nO': 3, 'N1': 0.1, 'N2': 0.001, 'N3': 1e-07, 'τ': 15}
# Erro_M = 0.031638, Erro_R = 0.190802 Parâmetros: {'nI': 5, 'nR': 31, 'nO': 9, 'N1': 0.1, 'N2': 0.001, 'N3': 0.0001, 'τ': 19}
# Erro_M = 0.012964, Erro_R = 0.244449 Parâmetros: {'nI': 6, 'nR': 31, 'nO': 9, 'N1': 0.1, 'N2': 0.1, 'N3': 0.001, 'τ': 6}
# Erro_M = 0.001144, Erro_R = 0.438767 Parâmetros: {'nI': 5, 'nR': 24, 'nO': 3, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.0001, 'τ': 3}
# Erro_M = 0.000775, Erro_R = 0.568481 Parâmetros: {'nI': 8, 'nR': 14, 'nO': 1, 'N1': 1e-07, 'N2': 0.1, 'N3': 0.1, 'τ': 1}
# Erro_M = 0.044993, Erro_R = 0.172378 Parâmetros: {'nI': 28, 'nR': 32, 'nO': 10, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.001, 'τ': 21}
# Erro_M = 0.001489, Erro_R = 0.383069 Parâmetros: {'nI': 16, 'nR': 22, 'nO': 1, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-06, 'τ': 1}
# Erro_M = 0.003293, Erro_R = 0.306683 Parâmetros: {'nI': 16, 'nR': 43, 'nO': 1, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.001, 'τ': 15}
# Erro_M = 0.016813, Erro_R = 0.232019 Parâmetros: {'nI': 6, 'nR': 49, 'nO': 9, 'N1': 0.1, 'N2': 1e-07, 'N3': 0.01, 'τ': 16}

# %% [markdown]
# Erro_M = 0.028123, Erro_R = 0.199588 Parâmetros: {'nI': 3, 'nR': 19, 'nO': 10, 'N1': 0.1, 'N2': 1e-05, 'N3': 1e-07, 'τ': 17}\
# Erro_M = 0.044993, Erro_R = 0.172378 Parâmetros: {'nI': 28, 'nR': 32, 'nO': 10, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.001, 'τ': 21}\
# Erro_M = 0.030462, Erro_R = 0.170331 Parâmetros: {'nI': 15, 'nR': 29, 'nO': 10, 'N1': 0.1, 'N2': 0.0001, 'N3': 1e-07, 'τ': 17}

# %%
params={'nI': 28, 'nR': 32, 'nO': 10, 'N1': 0.1, 'N2': 1e-06, 'N3': 0.001, 'τ': 21}
params = list(params.values())
#params = [8, 41, 1, 0.1, 0.01, 0.001, 2]

# %%
nI,nR,nO,N1,N2,N3,τ= params
X,Y = PrepareDataAhead(sig,n=nI,m=nO)
X,Y = X[:-1],Y[:-1]
rnn = RTLO(nI,nR,nO,[N1,N2,N3],τ)
rnn.ref = len(sig)-nI
for i in range(len(X[:])):
    rnn.PredRul(x=X[i],store=True,maxRul=len(sig)-nI,lim=0.75)
    #rnn.PredRulIntr2(x=X[i],maxRul=len(sig)-nI,store=True,show=False)
    rnn.fit(X[i],Y[i],store=True,show=False)
#print(.wR[0])
print(rnn.εM,rnn.εR)  
PlotPredErrorPLY(rnn)
# Out:
# 0.044993047584040366 0.1723784698684209

# %%
i=50
r_m = np.mean(rnn.rulR[:i])
r_mL = np.mean(rnn.rulR[:i])*0.3
r_mU = np.mean(rnn.rulR[:i])*1.05
p_m = (np.mean(rnn.rulP[:i]))

print('lower:',r_mL,'mid:',r_m,'upper:',r_mU)
print('pred:',p_m)
# Out:
# lower: 28.65 mid: 95.5 upper: 100.275
# pred: 86.14

# %%
#params =  [14, 8, 14, 0.001, 0.01, 1e-06, 1e-07, 29]
nI,nR,nO,N1,N2,N3,τ= params
ηS = [N1,N2,N3]
X,Y = PrepareDataAhead(sig,n=nI,m=nO)
rnn = RTLO(nI,nR,nO,ηS,τ)
rnn.ref = len(sig)-nI

i=0

# %%
#rnn.PredRul(x=X[i],store=True)
print('iteration:',i)
print('xP:',X[i])
print('yR:',Y[i])
rnn.PredRulIntr2(x=X[i],store=True,show=True)
rnn.fit(X[i],Y[i],store=True,show=False)
i=i+1
# Out:
# iteration: 1
# xP: [0.91429178 0.91121962 0.90817817 0.90519636 0.90227154 0.89941598]
# yR: [0.89663373 0.8939275  0.89128272 0.88870303 0.88617045 0.88366572]
# [np.float64(-0.03730620483456837), np.float64(-0.04602629367076666), np.float64(-0.05561926571854693)]

# %%
v = [np.float64(-0.03730620483456837), np.float64(-0.04602629367076666), np.float64(-0.05561926571854693)]
v = sorted(v)
print(v)
# Out:
# [np.float64(-0.05561926571854693), np.float64(-0.04602629367076666), np.float64(-0.03730620483456837)]
