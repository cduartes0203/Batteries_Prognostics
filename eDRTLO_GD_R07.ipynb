# %%
import ast
import pandas as pd
import numpy as np
import ipynbname
from Testing.DRTLO_GD_R2 import *
from Functions.AutoCloud import *
from Functions.Utils import *
from Functions.Graphs import *
from Functions.TedaGraphs import *
from Functions.Utils_OPT import *
import optuna
from optuna.samplers import RandomSampler
from optuna.exceptions import TrialPruned

FileName = ipynbname.name()
dfs = [pd.read_csv(f'Optimization\\eDRTLO_GD\\multi\\Optimization.csv')]
RS = pd.read_excel(r'Dataset\RS.xlsx')
HI = pd.read_csv(r'Dataset\Bearing1_1.csv')
sig = HI['PC1'].values

# %%
params =  [2.0, 5, '[58, 11, 64, 31, 32]', 15, 5, 0.0754386941522406,6.688979613494848e-06, 0.0029919547064531, 10.168345750070529,'ahead', 'tanh']

m,nI,nR,nO,mO,N1,N2,N3,τ,mode,act = params
X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
nI = len(Y[0])
if isinstance(nR, str): nR = ast.literal_eval(nR)

teda=AutoCloud(m=m,nI=nI,nR=nR,nO=nO+mO,ηS=[N1,N2,N3],mode=mode,act=act,
               tau=τ,rho=0.001,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
for j,_ in enumerate(X[:]):
    teda.run(X[j])
    teda.RUL_Prediction(Y[j],mode='interval',lim=len(sig)-nI+1,show=False)
    teda.WAPE_HI2(Y[j],Z[j])
    teda.Adapt(Y[j],Z[j])

#teda.c = np.append(teda.c,teda.gm)  
#PlotDSI_3D_PLT(teda)

# %%
print(xxx)

# %%
def Optimize(
        FileName=None,OptDim=None,OptSampler=None,OptSeed=None,OptPrune=False,
        n_study=None,timeout=None,n_trials=None,
        patience=None,
        mS =None,nIS=None,nLS=None,nRS=None,nOS =None,mOS=None,
        N1S=None,N2S=None,N3S=None,τS =None,mdS=None,actS=None):

    '''
        OptSampler modes available: None, Auto, GP, NSGAII, Random, TPE
    
        None: sampler default, suport multivariate optimization

        GP: suport multivariate optimization

        Auto: suport multivariate optimization
        
        NSGAII: poorly suport multivariate optimization
        
        Random: poorly suport multivariate optimization

        TPE: suport multivariate optimization
    '''

    if OptDim == 1 or OptDim is None: SingleObj = True
    elif OptDim > 1: SingleObj = False    
    if n_study is None: n_study = 1
    if timeout is None: timeout = 60
    if n_trials is None and patience is None: 
        n_trials = 25
        patience = 25
    elif n_trials < 100 and patience is None:
        patience = int(0.25*n_trials)
    elif n_trials >= 1e2 and n_trials < 1e3 and patience is None:
        patience = int(0.20*n_trials)
    elif n_trials >= 1e3 and n_trials < 5e3 and patience is None:
        patience = int(0.150*n_trials)
    elif n_trials >= 5e3 and n_trials < 1e4 and patience is None:
        patience = int(0.125*n_trials)    
    elif n_trials >= 1e4 and patience is None:
        patience = int(0.03*n_trials)   

    if mS  is None: mS  = [1.75,4.25]
    if nIS is None: nIS = [2,40]
    if nLS is None: nLS = [1,5]
    if nRS is None: nRS = [1,60]
    if nOS is None: nOS = [1,40]
    if mOS is None: mOS = [0,40]
    if N1S is None: N1S = [1,9]
    if N2S is None: N2S = [1,9]
    if N3S is None: N3S = [1,9]
    if τS  is None: τS  = [1,25]
    if mdS is None: mdS = [0,1]
    if actS is None: actS = [0,1,2]

    if SingleObj: names = ['MAPE_RUL*MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N1', 'N2', 'N3','TAU','past/ahead','activation']
    else: names = ['MAPE_RUL','MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N1', 'N2', 'N3','TAU','past/ahead','activation']
    study_dir, out_path = df_ParamsTable(names,FileName)

    for i in range(n_study):
        print('iteration:',i+1)
        def objective(trial):
            m = trial.suggest_float('m', mS[0], mS[1],step=0.25)
            nI = trial.suggest_int('nI', nIS[0], nIS[1]) 
            n_layers = trial.suggest_int('n_layers', nLS[0], nLS[1])
            nR = [trial.suggest_int(f'nR_layer_{l}', nRS[0], nRS[1]) for l in range(n_layers)]
            nO = trial.suggest_int('nO', nOS[0], nOS[1]) 
            N1 = trial.suggest_int('N1', N1S[0], N1S[1])
            N2 = trial.suggest_int('N2', N2S[0], N2S[1])
            N3 = trial.suggest_int('N3', N3S[0], N3S[1])
            τ = trial.suggest_float('τ', τS[0], τS[1])
            mode = trial.suggest_int('mode', mdS[0], mdS[1])  
            act = trial.suggest_int('act', actS[0], actS[1])  

            if mode == 'past' or mode == 0:
                mO = trial.suggest_int('mO', 0, 0) 
                if nO > nI: raise TrialPruned()

            elif mode == 'ahead' or mode == 1:
                mO = trial.suggest_int('mO', mOS[0], mOS[1]) 
                if   nI > 20 or nO > 20: raise TrialPruned()
                elif mO > nI: raise TrialPruned()
                
            X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
            
            teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N1,N2,N3],mode=mode,act=act,
                           tau=τ,rho=0.0,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
            for j,_ in enumerate(X[:]):
                teda.run(X[j])
                teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1)
                teda.Adapt(Y[j],Z[j])
                #teda.WAPE_HI2(Y[j],Z[j])

                if np.isinf(teda.hiP[-1]) or np.isnan(teda.hiP[-1]): raise TrialPruned()
                if not OptPrune: continue
        
                if j >=60 and j%5==0:
                    if teda.wape_RUL > 0.6: raise TrialPruned()
                    if teda.wape_HI  > 0.3: raise TrialPruned()

                if SingleObj and j%35==0:
                    trial.report(teda.wape_RUL+teda.wape_HI, j)
                    if trial.should_prune():
                        raise optuna.TrialPruned()

            if SingleObj: return teda.wape_RUL + teda.wape_HI
            else: return teda.wape_RUL,teda.wape_HI

        pruner=optuna.pruners.HyperbandPruner()
        if SingleObj: study = optuna.create_study(direction='minimize',pruner=pruner,sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        else: study = optuna.create_study(directions=['minimize','minimize'],sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        study.optimize(objective, n_trials=n_trials, timeout=timeout, callbacks=[EarlyStoppingCallback(patience=patience)])

        vec = []
        if SingleObj:
            trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
            for trial in trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N1'],p['N2'],p['N3'],p['τ'],p['mode'],p['act']]   
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
            df2 = df2.sort_values(by=df2.columns[0], ascending=False)[-5:]

        elif not SingleObj: 
            for trial in study.best_trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],trial.values[1],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N1'],p['N2'],p['N3'],p['τ'],p['mode'],p['act']]
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
        
    if os.path.isfile(out_path) and out_path.startswith(study_dir):
        df1 = pd.read_csv(out_path)
        df_stdy = pd.concat([df1, df2], ignore_index=True)
    
    else: df_stdy = df2
    
    df_stdy.to_csv(out_path, index=False)
    opt_path = os.path.join(study_dir,f'opt_{len(os.listdir(study_dir))-1}.csv')
    
    if df2.shape[0] > 0: df2.to_csv(opt_path, index=False)

    return [df_stdy, df2 ]

# %%
dfs = Optimize(FileName=FileName[:-4],OptDim=2,OptSampler=None,OptPrune=False,
                         n_study=1,timeout=1200,n_trials=1e2,patience=1e3,
                         mS=[2.0,4.5],nRS=[1,70],mdS=[1,1],actS=[0,1])

# %%
for i in range(1,6):
    dfs = Optimize(FileName=FileName[:-4],OptDim=2,OptSampler=None,OptPrune=False,
                         n_study=6,timeout=1680,n_trials=1e4,patience=1e3,
                        mS=[2.0,4.5],nLS=[i,i],nRS=[1,70],mdS=[1,1],actS=[0,1])
# Out:
# [I 2026-08-13 16:32:23,897] A new study created in memory with name: no-name-f82709a6-77d4-476d-900e-5806f771f60b
# [I 2026-08-13 16:32:23,899] Trial 0 pruned.
# [I 2026-08-13 16:32:23,900] Trial 1 pruned.
# [I 2026-08-13 16:32:23,903] Trial 2 pruned.
# [I 2026-08-13 16:32:23,905] Trial 3 pruned.
# [I 2026-08-13 16:32:23,907] Trial 4 pruned.
# [I 2026-08-13 16:32:23,908] Trial 5 pruned.
# [I 2026-08-13 16:32:23,911] Trial 6 pruned.
# [I 2026-08-13 16:32:23,914] Trial 7 pruned.
# [I 2026-08-13 16:32:23,917] Trial 8 pruned.
# [I 2026-08-13 16:32:23,919] Trial 9 pruned.
# [I 2026-08-13 16:32:23,922] Trial 10 pruned.
# [I 2026-08-13 16:32:23,923] Trial 11 pruned.
# [I 2026-08-13 16:32:23,948] Trial 12 finished with values: [0.9773375071143996, 0.9396565974858256] and parameters: {'m': 2.5, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 20, 'N1': 6, 'N2': 5, 'N3': 9, 'τ': 18.419518752604816, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:32:23,950] Trial 13 pruned.
# [I 2026-08-13 16:32:23,952] Trial 14 pruned.
# [I 2026-08-13 16:32:23,953] Trial 15 pruned.
# [I 2026-08-13 16:32:23,955] Trial 16 pruned.
# [I 2026-08-13 16:32:23,957] Trial 17 pruned.
# [I 2026-08-13 16:32:23,959] Trial 18 pruned.
# [I 2026-08-13 16:32:23,960] Trial 19 pruned.
# [I 2026-08-13 16:32:23,962] Trial 20 pruned.
# [I 2026-08-13 16:32:23,964] Trial 21 pruned.
# [I 2026-08-13 16:32:23,965] Trial 22 pruned.
# [I 2026-08-13 16:32:23,968] Trial 23 pruned.
# iteration: 1
# [I 2026-08-13 16:32:24,086] Trial 24 finished with values: [2.269502866913204, 0.7493496254081884] and parameters: {'m': 2.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 6, 'N1': 7, 'N2': 1, 'N3': 3, 'τ': 1.811030018677874, 'mode': 1, 'act': 0, 'mO': 7}.
# [I 2026-08-13 16:32:24,088] Trial 25 pruned.
# [I 2026-08-13 16:32:24,089] Trial 26 pruned.
# [I 2026-08-13 16:32:24,091] Trial 27 pruned.
# [I 2026-08-13 16:32:24,092] Trial 28 pruned.
# [I 2026-08-13 16:32:24,094] Trial 29 pruned.
# [I 2026-08-13 16:32:24,096] Trial 30 pruned.
# [I 2026-08-13 16:32:24,099] Trial 31 pruned.
# [I 2026-08-13 16:32:24,101] Trial 32 pruned.
# [I 2026-08-13 16:32:24,125] Trial 33 finished with values: [0.9755356179830367, 1.054033174490142] and parameters: {'m': 4.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 19, 'nO': 18, 'N1': 4, 'N2': 7, 'N3': 5, 'τ': 15.096920922361877, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:32:24,127] Trial 34 pruned.
# [I 2026-08-13 16:32:24,130] Trial 35 pruned.
# [I 2026-08-13 16:32:24,132] Trial 36 pruned.
# [I 2026-08-13 16:32:24,133] Trial 37 pruned.
# [I 2026-08-13 16:32:24,135] Trial 38 pruned.
# [I 2026-08-13 16:32:24,137] Trial 39 pruned.
# [I 2026-08-13 16:32:24,140] Trial 40 pruned.
# [I 2026-08-13 16:32:24,142] Trial 41 pruned.
# [I 2026-08-13 16:32:24,143] Trial 42 pruned.
# [I 2026-08-13 16:32:24,146] Trial 43 pruned.
# [I 2026-08-13 16:32:24,148] Trial 44 pruned.
# [I 2026-08-13 16:32:24,149] Trial 45 pruned.
# [I 2026-08-13 16:32:24,153] Trial 46 pruned.
# [I 2026-08-13 16:32:24,155] Trial 47 pruned.
# [I 2026-08-13 16:32:24,362] Trial 48 finished with values: [1.6802721602303352, 0.2774575892286749] and parameters: {'m': 4.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 9, 'N1': 3, 'N2': 5, 'N3': 6, 'τ': 14.73520458889933, 'mode': 1, 'act': 0, 'mO': 19}.
# [I 2026-08-13 16:32:24,363] Trial 49 pruned.
# [I 2026-08-13 16:32:24,365] Trial 50 pruned.
# [I 2026-08-13 16:32:24,366] Trial 51 pruned.
# [I 2026-08-13 16:32:24,368] Trial 52 pruned.
# [I 2026-08-13 16:32:24,369] Trial 53 pruned.
# [I 2026-08-13 16:32:24,370] Trial 54 pruned.
# [I 2026-08-13 16:32:24,371] Trial 55 pruned.
# [I 2026-08-13 16:32:24,373] Trial 56 pruned.
# [I 2026-08-13 16:32:24,374] Trial 57 pruned.
# [I 2026-08-13 16:32:24,376] Trial 58 pruned.
# [I 2026-08-13 16:32:24,377] Trial 59 pruned.
# [I 2026-08-13 16:32:24,379] Trial 60 pruned.
# [I 2026-08-13 16:32:24,381] Trial 61 pruned.
# [I 2026-08-13 16:32:24,383] Trial 62 pruned.
# [I 2026-08-13 16:32:24,384] Trial 63 pruned.
# [I 2026-08-13 16:32:24,386] Trial 64 pruned.
# [I 2026-08-13 16:32:24,387] Trial 65 pruned.
# [I 2026-08-13 16:32:24,388] Trial 66 pruned.
# [I 2026-08-13 16:32:24,390] Trial 67 pruned.
# [I 2026-08-13 16:32:24,392] Trial 68 pruned.
# [I 2026-08-13 16:32:24,394] Trial 69 pruned.
# [I 2026-08-13 16:32:24,395] Trial 70 pruned.
# [I 2026-08-13 16:32:24,397] Trial 71 pruned.
# [I 2026-08-13 16:32:24,398] Trial 72 pruned.
# [I 2026-08-13 16:32:24,399] Trial 73 pruned.
# [I 2026-08-13 16:32:24,402] Trial 74 pruned.
# [I 2026-08-13 16:32:24,403] Trial 75 pruned.
# [I 2026-08-13 16:32:24,405] Trial 76 pruned.
# [I 2026-08-13 16:32:24,407] Trial 77 pruned.
# [I 2026-08-13 16:32:24,408] Trial 78 pruned.
# [I 2026-08-13 16:32:24,410] Trial 79 pruned.
# [I 2026-08-13 16:32:24,532] Trial 80 finished with values: [0.8216742306247761, 161.13563838217962] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 20, 'N1': 9, 'N2': 7, 'N3': 1, 'τ': 24.548493504348293, 'mode': 1, 'act': 1, 'mO': 12}.
# [I 2026-08-13 16:32:24,534] Trial 81 pruned.
# [I 2026-08-13 16:32:24,535] Trial 82 pruned.
# [I 2026-08-13 16:32:24,537] Trial 83 pruned.
# [I 2026-08-13 16:32:24,538] Trial 84 pruned.
# [I 2026-08-13 16:32:24,560] Trial 85 finished with values: [0.9739418946590507, 2.2842178589299147] and parameters: {'m': 3.0, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 14, 'N1': 8, 'N2': 5, 'N3': 3, 'τ': 18.804442230371627, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:32:24,621] Trial 86 finished with values: [0.9785870127876546, 0.40671852631082406] and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 27, 'nO': 15, 'N1': 3, 'N2': 2, 'N3': 5, 'τ': 2.785416275781932, 'mode': 1, 'act': 0, 'mO': 18}.
# [I 2026-08-13 16:32:24,623] Trial 87 pruned.
# [I 2026-08-13 16:32:24,625] Trial 88 pruned.
# [I 2026-08-13 16:32:24,668] Trial 89 finished with values: [0.6988869380945424, 0.3631233101729043] and parameters: {'m': 4.0, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 7, 'N2': 6, 'N3': 9, 'τ': 9.909767079646684, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:32:24,669] Trial 90 pruned.
# [I 2026-08-13 16:32:24,671] Trial 91 pruned.
# [I 2026-08-13 16:32:24,939] Trial 92 finished with values: [2.6170837295632894, 0.995641584968884] and parameters: {'m': 3.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 56, 'nO': 5, 'N1': 3, 'N2': 6, 'N3': 4, 'τ': 18.000101175402442, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:32:24,940] Trial 93 pruned.
# [I 2026-08-13 16:32:24,941] Trial 94 pruned.
# [I 2026-08-13 16:32:24,943] Trial 95 pruned.
# [I 2026-08-13 16:32:24,944] Trial 96 pruned.
# [I 2026-08-13 16:32:24,969] Trial 97 finished with values: [0.9662456299583165, 1.353593953463361] and parameters: {'m': 4.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 56, 'nO': 3, 'N1': 9, 'N2': 7, 'N3': 8, 'τ': 24.933582141660512, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:32:24,971] Trial 98 pruned.
# [I 2026-08-13 16:32:24,973] Trial 99 pruned.
# [I 2026-08-13 16:32:24,975] Trial 100 pruned.
# [I 2026-08-13 16:32:24,976] Trial 101 pruned.
# [I 2026-08-13 16:32:24,978] Trial 102 pruned.
# [I 2026-08-13 16:32:24,980] Trial 103 pruned.
# [I 2026-08-13 16:32:24,982] Trial 104 pruned.
# [I 2026-08-13 16:32:24,986] Trial 105 pruned.
# [I 2026-08-13 16:32:24,989] Trial 106 pruned.
# [I 2026-08-13 16:32:24,992] Trial 107 pruned.
# [I 2026-08-13 16:32:24,994] Trial 108 pruned.
# [I 2026-08-13 16:32:24,996] Trial 109 pruned.
# [I 2026-08-13 16:32:24,999] Trial 110 pruned.
# [I 2026-08-13 16:32:25,000] Trial 111 pruned.
# [I 2026-08-13 16:32:25,002] Trial 112 pruned.
# [I 2026-08-13 16:32:25,004] Trial 113 pruned.
# [I 2026-08-13 16:32:25,007] Trial 114 pruned.
# [I 2026-08-13 16:32:25,009] Trial 115 pruned.
# [I 2026-08-13 16:32:25,012] Trial 116 pruned.
# [I 2026-08-13 16:32:25,014] Trial 117 pruned.
# [I 2026-08-13 16:32:25,017] Trial 118 pruned.
# [I 2026-08-13 16:32:25,020] Trial 119 pruned.
# [I 2026-08-13 16:32:25,023] Trial 120 pruned.
# [I 2026-08-13 16:32:25,026] Trial 121 pruned.
# [I 2026-08-13 16:32:25,028] Trial 122 pruned.
# [I 2026-08-13 16:32:25,031] Trial 123 pruned.
# [I 2026-08-13 16:32:25,034] Trial 124 pruned.
# [I 2026-08-13 16:32:25,036] Trial 125 pruned.
# [I 2026-08-13 16:32:25,038] Trial 126 pruned.
# [I 2026-08-13 16:32:25,040] Trial 127 pruned.
# [I 2026-08-13 16:32:25,043] Trial 128 pruned.
# [I 2026-08-13 16:32:25,045] Trial 129 pruned.
# [I 2026-08-13 16:32:25,047] Trial 130 pruned.
# [I 2026-08-13 16:32:25,049] Trial 131 pruned.
# [I 2026-08-13 16:32:25,052] Trial 132 pruned.
# [I 2026-08-13 16:32:25,054] Trial 133 pruned.
# [I 2026-08-13 16:32:25,057] Trial 134 pruned.
# [I 2026-08-13 16:32:25,059] Trial 135 pruned.
# [I 2026-08-13 16:32:25,062] Trial 136 pruned.
# [I 2026-08-13 16:32:25,065] Trial 137 pruned.
# [I 2026-08-13 16:32:25,117] Trial 138 finished with values: [0.97003816455584, 2.6969920597179904] and parameters: {'m': 2.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 7, 'N1': 9, 'N2': 3, 'N3': 5, 'τ': 3.677631195232766, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:32:25,120] Trial 139 pruned.
# [I 2026-08-13 16:32:25,122] Trial 140 pruned.
# [I 2026-08-13 16:32:25,125] Trial 141 pruned.
# [I 2026-08-13 16:32:25,128] Trial 142 pruned.
# [I 2026-08-13 16:32:25,130] Trial 143 pruned.
# [I 2026-08-13 16:32:25,132] Trial 144 pruned.
# [I 2026-08-13 16:32:25,133] Trial 145 pruned.
# [I 2026-08-13 16:32:25,135] Trial 146 pruned.
# [I 2026-08-13 16:32:25,137] Trial 147 pruned.
# [I 2026-08-13 16:32:25,139] Trial 148 pruned.
# [I 2026-08-13 16:32:25,141] Trial 149 pruned.
# [I 2026-08-13 16:32:25,143] Trial 150 pruned.
# [I 2026-08-13 16:32:25,145] Trial 151 pruned.
# [I 2026-08-13 16:32:25,147] Trial 152 pruned.
# [I 2026-08-13 16:32:25,148] Trial 153 pruned.
# [I 2026-08-13 16:32:25,150] Trial 154 pruned.
# [I 2026-08-13 16:32:25,196] Trial 155 finished with values: [0.967079048127866, 1.1040317096807981] and parameters: {'m': 3.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 4, 'N1': 7, 'N2': 8, 'N3': 3, 'τ': 6.262369642727327, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:32:25,198] Trial 156 pruned.
# [I 2026-08-13 16:32:25,200] Trial 157 pruned.
# [I 2026-08-13 16:32:25,202] Trial 158 pruned.
# [I 2026-08-13 16:32:25,292] Trial 159 finished with values: [0.6018827215154079, 0.2505284634980427] and parameters: {'m': 4.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 10, 'N1': 7, 'N2': 4, 'N3': 3, 'τ': 14.519467338572387, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:32:25,294] Trial 160 pruned.
# [I 2026-08-13 16:32:25,295] Trial 161 pruned.
# [I 2026-08-13 16:32:25,297] Trial 162 pruned.
# [I 2026-08-13 16:32:25,298] Trial 163 pruned.
# [I 2026-08-13 16:32:25,299] Trial 164 pruned.
# [I 2026-08-13 16:32:25,302] Trial 165 pruned.
# [I 2026-08-13 16:32:25,303] Trial 166 pruned.
# [I 2026-08-13 16:32:25,368] Trial 167 finished with values: [1.6010153654635226, 0.5577549722909346] and parameters: {'m': 4.25, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 14, 'N1': 4, 'N2': 8, 'N3': 3, 'τ': 4.586654011805466, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:32:25,370] Trial 168 pruned.
# [I 2026-08-13 16:32:25,372] Trial 169 pruned.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:181: RuntimeWarning: overflow encountered in matmul
#   uP = (self.wR[l] @ hP) + (self.wI[l] @ curr_in)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:186: RuntimeWarning: overflow encountered in matmul
#   yP = (self.wO @ self.hP2[-1])
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:181: RuntimeWarning: invalid value encountered in matmul
#   uP = (self.wR[l] @ hP) + (self.wI[l] @ curr_in)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:109: RuntimeWarning: overflow encountered in matmul
#   yP = self.wO @ new_hP[-1]
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:118: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2 * np.outer((self.BS[l] @ eS), np.ones(self.nR[l])) * self.pS[l]
# [I 2026-08-13 16:32:25,398] Trial 170 pruned.
# [I 2026-08-13 16:32:25,400] Trial 171 pruned.
# [I 2026-08-13 16:32:25,401] Trial 172 pruned.
# [I 2026-08-13 16:32:25,402] Trial 173 pruned.
# [I 2026-08-13 16:32:25,404] Trial 174 pruned.
# [I 2026-08-13 16:32:25,405] Trial 175 pruned.
# [I 2026-08-13 16:32:25,407] Trial 176 pruned.
# [I 2026-08-13 16:32:25,408] Trial 177 pruned.
# [I 2026-08-13 16:32:25,409] Trial 178 pruned.
# [I 2026-08-13 16:32:25,411] Trial 179 pruned.
# [I 2026-08-13 16:32:25,413] Trial 180 pruned.
# [I 2026-08-13 16:32:25,416] Trial 181 pruned.
# [I 2026-08-13 16:32:25,418] Trial 182 pruned.
# [I 2026-08-13 16:32:25,420] Trial 183 pruned.
# [I 2026-08-13 16:32:25,423] Trial 184 pruned.
# [I 2026-08-13 16:32:25,426] Trial 185 pruned.
# [I 2026-08-13 16:32:25,429] Trial 186 pruned.
# [I 2026-08-13 16:32:25,432] Trial 187 pruned.
# [I 2026-08-13 16:32:25,433] Trial 188 pruned.
# [I 2026-08-13 16:32:25,435] Trial 189 pruned.
# [I 2026-08-13 16:32:25,437] Trial 190 pruned.
# [I 2026-08-13 16:32:25,439] Trial 191 pruned.
# [I 2026-08-13 16:32:25,441] Trial 192 pruned.
# [I 2026-08-13 16:32:25,444] Trial 193 pruned.
# [I 2026-08-13 16:32:25,469] Trial 194 finished with values: [0.9723189452384868, 2.137066871468738] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 61, 'nO': 10, 'N1': 9, 'N2': 9, 'N3': 6, 'τ': 9.858071501196623, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:32:25,472] Trial 195 pruned.
# [I 2026-08-13 16:32:25,473] Trial 196 pruned.
# [I 2026-08-13 16:32:25,475] Trial 197 pruned.
# [I 2026-08-13 16:32:25,477] Trial 198 pruned.
# [I 2026-08-13 16:32:25,478] Trial 199 pruned.
# [I 2026-08-13 16:32:25,480] Trial 200 pruned.
# [I 2026-08-13 16:32:25,482] Trial 201 pruned.
# [I 2026-08-13 16:32:25,484] Trial 202 pruned.
# [I 2026-08-13 16:32:25,485] Trial 203 pruned.
# [I 2026-08-13 16:32:25,487] Trial 204 pruned.
# [I 2026-08-13 16:32:25,488] Trial 205 pruned.
# [I 2026-08-13 16:32:25,489] Trial 206 pruned.
# [I 2026-08-13 16:32:25,491] Trial 207 pruned.
# [I 2026-08-13 16:32:25,492] Trial 208 pruned.
# [I 2026-08-13 16:32:25,494] Trial 209 pruned.
# [I 2026-08-13 16:32:25,496] Trial 210 pruned.
# [I 2026-08-13 16:32:25,498] Trial 211 pruned.
# [I 2026-08-13 16:32:25,499] Trial 212 pruned.
# [I 2026-08-13 16:32:25,501] Trial 213 pruned.
# [I 2026-08-13 16:32:25,502] Trial 214 pruned.
# [I 2026-08-13 16:32:25,505] Trial 215 pruned.
# [I 2026-08-13 16:32:25,506] Trial 216 pruned.
# [I 2026-08-13 16:32:25,509] Trial 217 pruned.
# [I 2026-08-13 16:32:25,510] Trial 218 pruned.
# [I 2026-08-13 16:32:25,512] Trial 219 pruned.
# [I 2026-08-13 16:32:25,513] Trial 220 pruned.
# [I 2026-08-13 16:32:25,514] Trial 221 pruned.
# [I 2026-08-13 16:32:25,516] Trial 222 pruned.
# [I 2026-08-13 16:32:25,517] Trial 223 pruned.
# [I 2026-08-13 16:32:25,540] Trial 224 finished with values: [0.9691126949627142, 1.0021209579729826] and parameters: {'m': 3.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 9, 'N1': 7, 'N2': 3, 'N3': 2, 'τ': 3.7738546377781095, 'mode': 1, 'act': 1, 'mO': 15}.
# [I 2026-08-13 16:32:25,542] Trial 225 pruned.
# [I 2026-08-13 16:32:25,544] Trial 226 pruned.
# [I 2026-08-13 16:32:25,545] Trial 227 pruned.
# [I 2026-08-13 16:32:25,547] Trial 228 pruned.
# [I 2026-08-13 16:32:25,548] Trial 229 pruned.
# [I 2026-08-13 16:32:25,549] Trial 230 pruned.
# [I 2026-08-13 16:32:25,552] Trial 231 pruned.
# [I 2026-08-13 16:32:25,553] Trial 232 pruned.
# [I 2026-08-13 16:32:25,555] Trial 233 pruned.
# [I 2026-08-13 16:32:25,556] Trial 234 pruned.
# [I 2026-08-13 16:32:25,557] Trial 235 pruned.
# [I 2026-08-13 16:32:25,559] Trial 236 pruned.
# [I 2026-08-13 16:32:25,561] Trial 237 pruned.
# [I 2026-08-13 16:32:25,562] Trial 238 pruned.
# [I 2026-08-13 16:32:25,587] Trial 239 finished with values: [0.9634352646521059, 0.8072498523039588] and parameters: {'m': 3.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 5, 'N1': 6, 'N2': 4, 'N3': 6, 'τ': 11.04960498428116, 'mode': 1, 'act': 0, 'mO': 4}.
# [I 2026-08-13 16:32:25,589] Trial 240 pruned.
# [I 2026-08-13 16:32:25,591] Trial 241 pruned.
# [I 2026-08-13 16:32:25,593] Trial 242 pruned.
# [I 2026-08-13 16:32:25,594] Trial 243 pruned.
# [I 2026-08-13 16:32:25,596] Trial 244 pruned.
# [I 2026-08-13 16:32:25,598] Trial 245 pruned.
# [I 2026-08-13 16:32:25,600] Trial 246 pruned.
# [I 2026-08-13 16:32:25,602] Trial 247 pruned.
# [I 2026-08-13 16:32:25,602] Trial 248 pruned.
# [I 2026-08-13 16:32:25,605] Trial 249 pruned.
# [I 2026-08-13 16:32:25,606] Trial 250 pruned.
# [I 2026-08-13 16:32:25,608] Trial 251 pruned.
# [I 2026-08-13 16:32:25,610] Trial 252 pruned.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:186: RuntimeWarning: invalid value encountered in matmul
#   yP = (self.wO @ self.hP2[-1])
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:181: RuntimeWarning: invalid value encountered in add
#   uP = (self.wR[l] @ hP) + (self.wI[l] @ curr_in)
# c:\Users\Claudio\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\numeric.py:961: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:102: RuntimeWarning: overflow encountered in matmul
#   u = self.wR[l] @ self.hP[l] + self.wI[l] @ curr_in
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:131: RuntimeWarning: invalid value encountered in add
#   self.wO += δOS
# [I 2026-08-13 16:32:25,638] Trial 253 pruned.
# [I 2026-08-13 16:32:25,640] Trial 254 pruned.
# [I 2026-08-13 16:32:25,642] Trial 255 pruned.
# [I 2026-08-13 16:32:25,644] Trial 256 pruned.
# [I 2026-08-13 16:32:25,645] Trial 257 pruned.
# [I 2026-08-13 16:32:25,647] Trial 258 pruned.
# [I 2026-08-13 16:32:25,649] Trial 259 pruned.
# [I 2026-08-13 16:32:25,651] Trial 260 pruned.
# [I 2026-08-13 16:32:25,652] Trial 261 pruned.
# [I 2026-08-13 16:32:25,655] Trial 262 pruned.
# [I 2026-08-13 16:32:25,656] Trial 263 pruned.
# [I 2026-08-13 16:32:25,658] Trial 264 pruned.
# [I 2026-08-13 16:32:25,662] Trial 265 pruned.
# [I 2026-08-13 16:32:25,665] Trial 266 pruned.
# [I 2026-08-13 16:32:25,668] Trial 267 pruned.
# [I 2026-08-13 16:32:25,670] Trial 268 pruned.
# [I 2026-08-13 16:32:25,673] Trial 269 pruned.
# [I 2026-08-13 16:32:25,674] Trial 270 pruned.
# [I 2026-08-13 16:32:25,677] Trial 271 pruned.
# [I 2026-08-13 16:32:25,680] Trial 272 pruned.
# [I 2026-08-13 16:32:25,681] Trial 273 pruned.
# [I 2026-08-13 16:32:25,683] Trial 274 pruned.
# [I 2026-08-13 16:32:25,685] Trial 275 pruned.
# [I 2026-08-13 16:32:25,687] Trial 276 pruned.
# [I 2026-08-13 16:32:25,689] Trial 277 pruned.
# [I 2026-08-13 16:32:25,691] Trial 278 pruned.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:118: RuntimeWarning: overflow encountered in multiply
#   δRS = η2 * np.outer((self.BS[l] @ eS), np.ones(self.nR[l])) * self.pS[l]
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_GD_R2.py:122: RuntimeWarning: invalid value encountered in add
#   self.wR[l] += δRS
# [I 2026-08-13 16:32:25,733] Trial 279 pruned.
# [I 2026-08-13 16:32:25,734] Trial 280 pruned.
# [I 2026-08-13 16:32:25,736] Trial 281 pruned.
# [I 2026-08-13 16:32:25,738] Trial 282 pruned.
# [I 2026-08-13 16:32:25,739] Trial 283 pruned.
# [I 2026-08-13 16:32:25,741] Trial 284 pruned.
# [I 2026-08-13 16:32:25,742] Trial 285 pruned.
# [I 2026-08-13 16:32:25,743] Trial 286 pruned.
# [I 2026-08-13 16:32:25,745] Trial 287 pruned.
# [I 2026-08-13 16:32:25,746] Trial 288 pruned.
# [I 2026-08-13 16:32:25,748] Trial 289 pruned.
# [I 2026-08-13 16:32:25,749] Trial 290 pruned.
# [I 2026-08-13 16:32:25,751] Trial 291 pruned.
# [I 2026-08-13 16:32:25,752] Trial 292 pruned.
# [I 2026-08-13 16:32:25,754] Trial 293 pruned.
# [I 2026-08-13 16:32:25,756] Trial 294 pruned.
# [I 2026-08-13 16:32:25,758] Trial 295 pruned.
# [I 2026-08-13 16:32:25,759] Trial 296 pruned.
# [I 2026-08-13 16:32:25,760] Trial 297 pruned.
# [I 2026-08-13 16:32:25,762] Trial 298 pruned.
# [I 2026-08-13 16:32:25,764] Trial 299 pruned.
# [I 2026-08-13 16:32:25,765] Trial 300 pruned.
# [I 2026-08-13 16:32:25,767] Trial 301 pruned.
# [I 2026-08-13 16:32:25,768] Trial 302 pruned.
# [I 2026-08-13 16:32:25,771] Trial 303 pruned.
# [I 2026-08-13 16:32:25,772] Trial 304 pruned.
# [I 2026-08-13 16:32:25,773] Trial 305 pruned.
# [I 2026-08-13 16:32:25,775] Trial 306 pruned.
# [I 2026-08-13 16:32:25,776] Trial 307 pruned.
# [I 2026-08-13 16:32:25,779] Trial 308 pruned.
# [I 2026-08-13 16:32:25,781] Trial 309 pruned.
# [I 2026-08-13 16:32:25,782] Trial 310 pruned.
# [I 2026-08-13 16:32:25,784] Trial 311 pruned.
# [I 2026-08-13 16:32:25,786] Trial 312 pruned.
# [I 2026-08-13 16:32:25,788] Trial 313 pruned.
# [I 2026-08-13 16:32:25,789] Trial 314 pruned.
# [I 2026-08-13 16:32:25,791] Trial 315 pruned.
# [I 2026-08-13 16:32:25,792] Trial 316 pruned.
# [I 2026-08-13 16:32:26,086] Trial 317 finished with values: [2.6333360487637614, 0.7894525797053753] and parameters: {'m': 2.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 4, 'N1': 3, 'N2': 7, 'N3': 5, 'τ': 9.944284726393349, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:32:26,088] Trial 318 pruned.
# [I 2026-08-13 16:32:26,090] Trial 319 pruned.
# [I 2026-08-13 16:32:26,091] Trial 320 pruned.
# [I 2026-08-13 16:32:26,093] Trial 321 pruned.
# [I 2026-08-13 16:32:26,094] Trial 322 pruned.
# [I 2026-08-13 16:32:26,095] Trial 323 pruned.
# [I 2026-08-13 16:32:26,097] Trial 324 pruned.
# [I 2026-08-13 16:32:26,099] Trial 325 pruned.
# [I 2026-08-13 16:32:26,101] Trial 326 pruned.
# [I 2026-08-13 16:32:26,102] Trial 327 pruned.
# [I 2026-08-13 16:32:26,104] Trial 328 pruned.
# [I 2026-08-13 16:32:26,105] Trial 329 pruned.
# [I 2026-08-13 16:32:26,107] Trial 330 pruned.
# [I 2026-08-13 16:32:26,109] Trial 331 pruned.
# [I 2026-08-13 16:32:26,110] Trial 332 pruned.
# [I 2026-08-13 16:32:26,112] Trial 333 pruned.
# [I 2026-08-13 16:32:26,113] Trial 334 pruned.
# [I 2026-08-13 16:32:26,115] Trial 335 pruned.
# [I 2026-08-13 16:32:26,117] Trial 336 pruned.
# [I 2026-08-13 16:32:26,118] Trial 337 pruned.
# [I 2026-08-13 16:32:26,120] Trial 338 pruned.
# [I 2026-08-13 16:32:26,122] Trial 339 pruned.
# [I 2026-08-13 16:32:26,123] Trial 340 pruned.
# [I 2026-08-13 16:32:26,126] Trial 341 pruned.
# [I 2026-08-13 16:32:26,127] Trial 342 pruned.
# [I 2026-08-13 16:32:26,128] Trial 343 pruned.
# [I 2026-08-13 16:32:26,130] Trial 344 pruned.
# [I 2026-08-13 16:32:26,131] Trial 345 pruned.
# [I 2026-08-13 16:32:26,133] Trial 346 pruned.
# [I 2026-08-13 16:32:26,135] Trial 347 pruned.
# [I 2026-08-13 16:32:26,137] Trial 348 pruned.
# [I 2026-08-13 16:32:26,138] Trial 349 pruned.
# [I 2026-08-13 16:32:26,140] Trial 350 pruned.
# [I 2026-08-13 16:32:26,143] Trial 351 pruned.
# [I 2026-08-13 16:32:26,144] Trial 352 pruned.
# [I 2026-08-13 16:32:26,146] Trial 353 pruned.
# [I 2026-08-13 16:32:26,147] Trial 354 pruned.
# [I 2026-08-13 16:32:26,149] Trial 355 pruned.
# [I 2026-08-13 16:32:26,151] Trial 356 pruned.
# [I 2026-08-13 16:32:26,152] Trial 357 pruned.
# [I 2026-08-13 16:32:26,154] Trial 358 pruned.
# [I 2026-08-13 16:32:26,155] Trial 359 pruned.
# [I 2026-08-13 16:32:26,157] Trial 360 pruned.
# [I 2026-08-13 16:32:26,159] Trial 361 pruned.
# [I 2026-08-13 16:32:26,161] Trial 362 pruned.
# [I 2026-08-13 16:32:26,162] Trial 363 pruned.
# [I 2026-08-13 16:32:26,163] Trial 364 pruned.
# [I 2026-08-13 16:32:26,164] Trial 365 pruned.
# [I 2026-08-13 16:32:26,165] Trial 366 pruned.
# [I 2026-08-13 16:32:26,168] Trial 367 pruned.
# [I 2026-08-13 16:32:26,170] Trial 368 pruned.
# [I 2026-08-13 16:32:26,172] Trial 369 pruned.
# [I 2026-08-13 16:32:26,173] Trial 370 pruned.
# [I 2026-08-13 16:32:26,175] Trial 371 pruned.
# [I 2026-08-13 16:32:26,178] Trial 372 pruned.
# [I 2026-08-13 16:32:26,182] Trial 373 pruned.
# [I 2026-08-13 16:32:26,185] Trial 374 pruned.
# [I 2026-08-13 16:32:26,187] Trial 375 pruned.
# [I 2026-08-13 16:32:26,189] Trial 376 pruned.
# [I 2026-08-13 16:32:26,192] Trial 377 pruned.
# [I 2026-08-13 16:32:26,195] Trial 378 pruned.
# [I 2026-08-13 16:32:26,197] Trial 379 pruned.
# [I 2026-08-13 16:32:26,199] Trial 380 pruned.
# [I 2026-08-13 16:32:26,202] Trial 381 pruned.
# [I 2026-08-13 16:32:26,204] Trial 382 pruned.
# [I 2026-08-13 16:32:26,206] Trial 383 pruned.
# [I 2026-08-13 16:32:26,209] Trial 384 pruned.
# [I 2026-08-13 16:32:26,212] Trial 385 pruned.
# [I 2026-08-13 16:32:26,215] Trial 386 pruned.
# [I 2026-08-13 16:32:26,216] Trial 387 pruned.
# [I 2026-08-13 16:32:26,219] Trial 388 pruned.
# [I 2026-08-13 16:32:26,222] Trial 389 pruned.
# [I 2026-08-13 16:32:26,225] Trial 390 pruned.
# [I 2026-08-13 16:32:26,228] Trial 391 pruned.
# [I 2026-08-13 16:32:26,598] Trial 392 finished with values: [1.9074109074657288, 0.06276676522671298] and parameters: {'m': 3.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 15, 'N1': 2, 'N2': 6, 'N3': 7, 'τ': 16.819647943175717, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:32:26,600] Trial 393 pruned.
# [I 2026-08-13 16:32:26,602] Trial 394 pruned.
# [I 2026-08-13 16:32:26,604] Trial 395 pruned.
# [I 2026-08-13 16:32:26,606] Trial 396 pruned.
# [I 2026-08-13 16:32:26,607] Trial 397 pruned.
# [I 2026-08-13 16:32:26,609] Trial 398 pruned.
# [I 2026-08-13 16:32:26,611] Trial 399 pruned.
# [I 2026-08-13 16:32:26,613] Trial 400 pruned.
# [I 2026-08-13 16:32:26,614] Trial 401 pruned.
# [I 2026-08-13 16:32:26,616] Trial 402 pruned.
# [I 2026-08-13 16:32:26,641] Trial 403 finished with values: [0.9638019371423672, 0.6641370283794149] and parameters: {'m': 4.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 57, 'nO': 2, 'N1': 4, 'N2': 8, 'N3': 2, 'τ': 20.657545724742306, 'mode': 1, 'act': 0, 'mO': 8}.
# [I 2026-08-13 16:32:26,643] Trial 404 pruned.
# [I 2026-08-13 16:32:26,646] Trial 405 pruned.
# [I 2026-08-13 16:32:26,647] Trial 406 pruned.
# [I 2026-08-13 16:32:26,649] Trial 407 pruned.
# [I 2026-08-13 16:32:26,944] Trial 408 finished with values: [2.095550421406283, 10.594232943796708] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 44, 'nO': 11, 'N1': 6, 'N2': 5, 'N3': 2, 'τ': 6.656873081751278, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:32:26,946] Trial 409 pruned.
# [I 2026-08-13 16:32:26,948] Trial 410 pruned.
# [I 2026-08-13 16:32:26,950] Trial 411 pruned.
# [I 2026-08-13 16:32:26,951] Trial 412 pruned.
# [I 2026-08-13 16:32:26,953] Trial 413 pruned.
# [I 2026-08-13 16:32:26,955] Trial 414 pruned.
# [I 2026-08-13 16:32:26,957] Trial 415 pruned.
# [I 2026-08-13 16:32:26,959] Trial 416 pruned.
# [I 2026-08-13 16:32:27,218] Trial 417 finished with values: [1.7649862090330288, 0.6698608744899304] and parameters: {'m': 4.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 58, 'nO': 16, 'N1': 3, 'N2': 3, 'N3': 3, 'τ': 8.879239538821533, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:32:27,219] Trial 418 pruned.
# [I 2026-08-13 16:32:27,221] Trial 419 pruned.
# [I 2026-08-13 16:32:27,222] Trial 420 pruned.
# [I 2026-08-13 16:32:27,224] Trial 421 pruned.
# [I 2026-08-13 16:32:27,225] Trial 422 pruned.
# [I 2026-08-13 16:32:27,226] Trial 423 pruned.
# [I 2026-08-13 16:32:27,229] Trial 424 pruned.
# [I 2026-08-13 16:32:27,231] Trial 425 pruned.
# [I 2026-08-13 16:32:27,234] Trial 426 pruned.
# [I 2026-08-13 16:32:27,237] Trial 427 pruned.
# [I 2026-08-13 16:32:27,238] Trial 428 pruned.
# [I 2026-08-13 16:32:27,240] Trial 429 pruned.
# [I 2026-08-13 16:32:27,242] Trial 430 pruned.
# [I 2026-08-13 16:32:27,244] Trial 431 pruned.
# [I 2026-08-13 16:32:27,270] Trial 432 pruned.
# [I 2026-08-13 16:32:27,273] Trial 433 pruned.
# [I 2026-08-13 16:32:27,276] Trial 434 pruned.
# [I 2026-08-13 16:32:27,278] Trial 435 pruned.
# [I 2026-08-13 16:32:27,280] Trial 436 pruned.
# [I 2026-08-13 16:32:27,283] Trial 437 pruned.
# [I 2026-08-13 16:32:27,287] Trial 438 pruned.
# [I 2026-08-13 16:32:27,290] Trial 439 pruned.
# [I 2026-08-13 16:32:27,293] Trial 440 pruned.
# [I 2026-08-13 16:32:27,630] Trial 441 finished with values: [1.6850739677208808, 0.009598306370997263] and parameters: {'m': 2.75, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 10, 'nO': 1, 'N1': 1, 'N2': 3, 'N3': 6, 'τ': 4.851460996387638, 'mode': 1, 'act': 0, 'mO': 9}.
# [I 2026-08-13 16:32:27,632] Trial 442 pruned.
# [I 2026-08-13 16:32:27,634] Trial 443 pruned.
# [I 2026-08-13 16:32:27,636] Trial 444 pruned.
# [I 2026-08-13 16:32:27,638] Trial 445 pruned.
# [I 2026-08-13 16:32:27,639] Trial 446 pruned.
# [I 2026-08-13 16:32:27,641] Trial 447 pruned.
# [I 2026-08-13 16:32:27,643] Trial 448 pruned.
# [I 2026-08-13 16:32:27,646] Trial 449 pruned.
# [I 2026-08-13 16:32:27,647] Trial 450 pruned.
# [I 2026-08-13 16:32:27,649] Trial 451 pruned.
# [I 2026-08-13 16:32:27,651] Trial 452 pruned.
# [I 2026-08-13 16:32:27,777] Trial 453 finished with values: [0.16666338607129275, 0.18617167999801915] and parameters: {'m': 4.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 10, 'N1': 5, 'N2': 4, 'N3': 9, 'τ': 16.32010803705539, 'mode': 1, 'act': 1, 'mO': 4}.
# [I 2026-08-13 16:32:27,779] Trial 454 pruned.
# [I 2026-08-13 16:32:27,811] Trial 455 finished with values: [0.9752326801367313, 0.6482704507758904] and parameters: {'m': 4.5, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 21, 'nO': 15, 'N1': 4, 'N2': 4, 'N3': 4, 'τ': 10.86445103536671, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:32:27,813] Trial 456 pruned.
# [I 2026-08-13 16:32:27,814] Trial 457 pruned.
# [I 2026-08-13 16:32:27,817] Trial 458 pruned.
# [I 2026-08-13 16:32:27,820] Trial 459 pruned.
# [I 2026-08-13 16:32:27,822] Trial 460 pruned.
# [I 2026-08-13 16:32:27,825] Trial 461 pruned.
# [I 2026-08-13 16:32:27,828] Trial 462 pruned.
# [I 2026-08-13 16:32:27,830] Trial 463 pruned.
# [I 2026-08-13 16:32:27,868] Trial 464 finished with values: [0.808665423222502, 0.3715022737378722] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 9, 'nO': 6, 'N1': 1, 'N2': 2, 'N3': 5, 'τ': 14.352633529763526, 'mode': 1, 'act': 1, 'mO': 12}.
# [I 2026-08-13 16:32:27,870] Trial 465 pruned.
# [I 2026-08-13 16:32:27,872] Trial 466 pruned.
# [I 2026-08-13 16:32:27,873] Trial 467 pruned.
# [I 2026-08-13 16:32:27,875] Trial 468 pruned.
# [I 2026-08-13 16:32:27,899] Trial 469 finished with values: [0.9719304523201535, 1.0545015090199528] and parameters: {'m': 4.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 2, 'nO': 8, 'N1': 7, 'N2': 2, 'N3': 4, 'τ': 8.204072514171187, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:32:27,901] Trial 470 pruned.
# [I 2026-08-13 16:32:27,903] Trial 471 pruned.
# [I 2026-08-13 16:32:27,905] Trial 472 pruned.
# [I 2026-08-13 16:32:27,907] Trial 473 pruned.
# [I 2026-08-13 16:32:27,908] Trial 474 pruned.
# [I 2026-08-13 16:32:27,910] Trial 475 pruned.
# [I 2026-08-13 16:32:27,911] Trial 476 pruned.
# [I 2026-08-13 16:32:27,913] Trial 477 pruned.
# [I 2026-08-13 16:32:27,915] Trial 478 pruned.
# [I 2026-08-13 16:32:27,917] Trial 479 pruned.
# [I 2026-08-13 16:32:27,918] Trial 480 pruned.
# [I 2026-08-13 16:32:27,921] Trial 481 pruned.
# [I 2026-08-13 16:32:27,923] Trial 482 pruned.
# [I 2026-08-13 16:32:27,926] Trial 483 pruned.
# [I 2026-08-13 16:32:27,928] Trial 484 pruned.
# [I 2026-08-13 16:32:27,930] Trial 485 pruned.
# [I 2026-08-13 16:32:27,932] Trial 486 pruned.
# [I 2026-08-13 16:32:27,933] Trial 487 pruned.
# [I 2026-08-13 16:32:27,935] Trial 488 pruned.
# [I 2026-08-13 16:32:27,937] Trial 489 pruned.
# [I 2026-08-13 16:32:27,938] Trial 490 pruned.
# [I 2026-08-13 16:32:27,940] Trial 491 pruned.
# [I 2026-08-13 16:32:28,215] Trial 492 finished with values: [1.650897532450098, 0.14042339506496856] and parameters: {'m': 3.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 19, 'N1': 9, 'N2': 7, 'N3': 4, 'τ': 8.036774060060662, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:32:28,217] Trial 493 pruned.
# [I 2026-08-13 16:32:28,219] Trial 494 pruned.
# [I 2026-08-13 16:32:28,220] Trial 495 pruned.
# [I 2026-08-13 16:32:28,221] Trial 496 pruned.
# [I 2026-08-13 16:32:28,223] Trial 497 pruned.
# [I 2026-08-13 16:32:28,224] Trial 498 pruned.
# [I 2026-08-13 16:32:28,227] Trial 499 pruned.
# [I 2026-08-13 16:32:28,229] Trial 500 pruned.
# [I 2026-08-13 16:32:28,230] Trial 501 pruned.
# [I 2026-08-13 16:32:28,232] Trial 502 pruned.
# [I 2026-08-13 16:32:28,234] Trial 503 pruned.
# [I 2026-08-13 16:32:28,235] Trial 504 pruned.
# [I 2026-08-13 16:32:28,236] Trial 505 pruned.
# [I 2026-08-13 16:32:28,238] Trial 506 pruned.
# [I 2026-08-13 16:32:28,239] Trial 507 pruned.
# [I 2026-08-13 16:32:28,241] Trial 508 pruned.
# [I 2026-08-13 16:32:28,243] Trial 509 pruned.
# [I 2026-08-13 16:32:28,245] Trial 510 pruned.
# [I 2026-08-13 16:32:28,246] Trial 511 pruned.
# [I 2026-08-13 16:32:28,280] Trial 512 finished with values: [0.9131794886637173, 0.4747284578895064] and parameters: {'m': 4.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 20, 'N1': 6, 'N2': 6, 'N3': 3, 'τ': 13.061116015954457, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:32:28,281] Trial 513 pruned.
# [I 2026-08-13 16:32:28,309] Trial 514 finished with values: [0.9681282777971321, 0.6899402735842977] and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 7, 'N1': 7, 'N2': 8, 'N3': 5, 'τ': 16.2728056811274, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:32:28,311] Trial 515 pruned.
# [I 2026-08-13 16:32:28,313] Trial 516 pruned.
# [I 2026-08-13 16:32:28,315] Trial 517 pruned.
# [I 2026-08-13 16:32:28,317] Trial 518 pruned.
# [I 2026-08-13 16:32:28,318] Trial 519 pruned.
# [I 2026-08-13 16:32:28,320] Trial 520 pruned.
# [I 2026-08-13 16:32:28,322] Trial 521 pruned.
# [I 2026-08-13 16:32:28,621] Trial 522 finished with values: [2.288550165804611, 0.26174132390985305] and parameters: {'m': 3.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 18, 'nO': 8, 'N1': 2, 'N2': 3, 'N3': 7, 'τ': 6.514351166855629, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:32:28,624] Trial 523 pruned.
# [I 2026-08-13 16:32:28,626] Trial 524 pruned.
# [I 2026-08-13 16:32:28,629] Trial 525 pruned.
# [I 2026-08-13 16:32:28,631] Trial 526 pruned.
# [I 2026-08-13 16:32:28,633] Trial 527 pruned.
# [I 2026-08-13 16:32:28,635] Trial 528 pruned.
# [I 2026-08-13 16:32:28,637] Trial 529 pruned.
# [I 2026-08-13 16:32:28,639] Trial 530 pruned.
# [I 2026-08-13 16:32:28,642] Trial 531 pruned.
# [I 2026-08-13 16:32:28,645] Trial 532 pruned.
# [I 2026-08-13 16:32:28,646] Trial 533 pruned.
# [I 2026-08-13 16:32:28,648] Trial 534 pruned.
# [I 2026-08-13 16:32:28,651] Trial 535 pruned.
# [I 2026-08-13 16:32:28,653] Trial 536 pruned.
# [I 2026-08-13 16:32:28,656] Trial 537 pruned.
# [I 2026-08-13 16:32:28,660] Trial 538 pruned.
# [I 2026-08-13 16:32:28,663] Trial 539 pruned.
# [I 2026-08-13 16:32:28,666] Trial 540 pruned.
# [I 2026-08-13 16:32:28,668] Trial 541 pruned.
# [I 2026-08-13 16:32:28,671] Trial 542 pruned.
# [I 2026-08-13 16:32:28,674] Trial 543 pruned.
# [I 2026-08-13 16:32:28,676] Trial 544 pruned.
# [I 2026-08-13 16:32:28,679] Trial 545 pruned.
# [I 2026-08-13 16:32:28,682] Trial 546 pruned.
# [I 2026-08-13 16:32:28,685] Trial 547 pruned.
# [I 2026-08-13 16:32:28,688] Trial 548 pruned.
# [I 2026-08-13 16:32:28,691] Trial 549 pruned.
# [I 2026-08-13 16:32:28,693] Trial 550 pruned.
# [I 2026-08-13 16:32:28,696] Trial 551 pruned.
# [I 2026-08-13 16:32:28,699] Trial 552 pruned.
# [I 2026-08-13 16:32:28,703] Trial 553 pruned.
# [I 2026-08-13 16:32:28,706] Trial 554 pruned.
# [I 2026-08-13 16:32:28,710] Trial 555 pruned.
# [I 2026-08-13 16:32:28,713] Trial 556 pruned.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Functions\AutoCloud.py:342: RuntimeWarning: invalid value encountered in scalar multiply
#   Pred = [w*c.rnn.PredictSingle(xP,True) for w,c in zip(ws,self.c)]
# [I 2026-08-13 16:32:28,814] Trial 557 pruned.
# [I 2026-08-13 16:32:28,816] Trial 558 pruned.
# [I 2026-08-13 16:32:28,818] Trial 559 pruned.
# [I 2026-08-13 16:32:28,820] Trial 560 pruned.
# [I 2026-08-13 16:32:28,822] Trial 561 pruned.
# [I 2026-08-13 16:32:28,824] Trial 562 pruned.
# [I 2026-08-13 16:32:28,825] Trial 563 pruned.
# [I 2026-08-13 16:32:28,828] Trial 564 pruned.
# [I 2026-08-13 16:32:28,831] Trial 565 pruned.
# [I 2026-08-13 16:32:28,835] Trial 566 pruned.
# [I 2026-08-13 16:32:28,838] Trial 567 pruned.
# [I 2026-08-13 16:32:28,840] Trial 568 pruned.
# [I 2026-08-13 16:32:28,842] Trial 569 pruned.
# [I 2026-08-13 16:32:28,844] Trial 570 pruned.
# [I 2026-08-13 16:32:28,847] Trial 571 pruned.
# [I 2026-08-13 16:32:28,850] Trial 572 pruned.
# [I 2026-08-13 16:32:28,852] Trial 573 pruned.
# [I 2026-08-13 16:32:28,856] Trial 574 pruned.
# [I 2026-08-13 16:32:28,860] Trial 575 pruned.
# [I 2026-08-13 16:32:28,863] Trial 576 pruned.
# [I 2026-08-13 16:32:28,867] Trial 577 pruned.
# [I 2026-08-13 16:32:28,869] Trial 578 pruned.
# [I 2026-08-13 16:32:28,872] Trial 579 pruned.
# [I 2026-08-13 16:32:28,875] Trial 580 pruned.
# [I 2026-08-13 16:32:28,877] Trial 581 pruned.
# [I 2026-08-13 16:32:28,879] Trial 582 pruned.
# [I 2026-08-13 16:32:28,881] Trial 583 pruned.
# [I 2026-08-13 16:32:28,883] Trial 584 pruned.
# [I 2026-08-13 16:32:28,884] Trial 585 pruned.
# [I 2026-08-13 16:32:28,924] Trial 586 finished with values: [0.7151987234322563, 0.4301013725297904] and parameters: {'m': 2.75, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 20, 'N1': 4, 'N2': 4, 'N3': 3, 'τ': 6.5129810921280935, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:32:28,927] Trial 587 pruned.
# [I 2026-08-13 16:32:28,928] Trial 588 pruned.
# [I 2026-08-13 16:32:28,930] Trial 589 pruned.
# [I 2026-08-13 16:32:28,931] Trial 590 pruned.
# [I 2026-08-13 16:32:28,933] Trial 591 pruned.
# [I 2026-08-13 16:32:28,935] Trial 592 pruned.
# [I 2026-08-13 16:32:28,938] Trial 593 pruned.
# [I 2026-08-13 16:32:28,939] Trial 594 pruned.
# [I 2026-08-13 16:32:28,941] Trial 595 pruned.
# [I 2026-08-13 16:32:28,943] Trial 596 pruned.
# [I 2026-08-13 16:32:28,945] Trial 597 pruned.
# [I 2026-08-13 16:32:28,947] Trial 598 pruned.
# [I 2026-08-13 16:32:28,949] Trial 599 pruned.
# [I 2026-08-13 16:32:28,951] Trial 600 pruned.
# [I 2026-08-13 16:32:28,953] Trial 601 pruned.
# [I 2026-08-13 16:32:28,955] Trial 602 pruned.
# [I 2026-08-13 16:32:28,957] Trial 603 pruned.
# [I 2026-08-13 16:32:28,959] Trial 604 pruned.
# [I 2026-08-13 16:32:28,961] Trial 605 pruned.
# [I 2026-08-13 16:32:28,963] Trial 606 pruned.
# [I 2026-08-13 16:32:28,965] Trial 607 pruned.
# [I 2026-08-13 16:32:29,074] Trial 608 pruned.
# [I 2026-08-13 16:32:29,076] Trial 609 pruned.
# [I 2026-08-13 16:32:29,077] Trial 610 pruned.
# [I 2026-08-13 16:32:29,079] Trial 611 pruned.
# [I 2026-08-13 16:32:29,081] Trial 612 pruned.
# [I 2026-08-13 16:32:29,082] Trial 613 pruned.
# [I 2026-08-13 16:32:29,084] Trial 614 pruned.
# [I 2026-08-13 16:32:29,086] Trial 615 pruned.
# [I 2026-08-13 16:32:29,088] Trial 616 pruned.
# [I 2026-08-13 16:32:29,089] Trial 617 pruned.
# [I 2026-08-13 16:32:29,091] Trial 618 pruned.
# [I 2026-08-13 16:32:29,092] Trial 619 pruned.
# [I 2026-08-13 16:32:29,365] Trial 620 finished with values: [1.7849386197787107, 0.006577154096553861] and parameters: {'m': 3.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 44, 'nO': 6, 'N1': 1, 'N2': 9, 'N3': 9, 'τ': 15.01069938183943, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:32:29,367] Trial 621 pruned.
# [I 2026-08-13 16:32:29,368] Trial 622 pruned.
# [I 2026-08-13 16:32:29,370] Trial 623 pruned.
# [I 2026-08-13 16:32:29,371] Trial 624 pruned.
# [I 2026-08-13 16:32:29,372] Trial 625 pruned.
# [I 2026-08-13 16:32:29,373] Trial 626 pruned.
# [I 2026-08-13 16:32:29,529] Trial 627 pruned.
# [I 2026-08-13 16:32:29,531] Trial 628 pruned.
# [I 2026-08-13 16:32:29,532] Trial 629 pruned.
# [I 2026-08-13 16:32:29,534] Trial 630 pruned.
# [I 2026-08-13 16:32:29,535] Trial 631 pruned.
# [I 2026-08-13 16:32:29,559] Trial 632 finished with values: [0.9719304452113653, 1.05852438733156] and parameters: {'m': 3.75, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 54, 'nO': 10, 'N1': 7, 'N2': 6, 'N3': 5, 'τ': 21.78499061355783, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:32:29,561] Trial 633 pruned.
# [I 2026-08-13 16:32:29,563] Trial 634 pruned.
# [I 2026-08-13 16:32:29,565] Trial 635 pruned.
# [I 2026-08-13 16:32:29,566] Trial 636 pruned.
# [I 2026-08-13 16:32:29,568] Trial 637 pruned.
# [I 2026-08-13 16:32:29,569] Trial 638 pruned.
# [I 2026-08-13 16:32:29,706] Trial 639 finished with values: [1.608272597688139, 0.37999383548249244] and parameters: {'m': 4.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 26, 'nO': 12, 'N1': 5, 'N2': 3, 'N3': 8, 'τ': 6.195084367420228, 'mode': 1, 'act': 0, 'mO': 14}.
# [I 2026-08-13 16:32:29,708] Trial 640 pruned.
# [I 2026-08-13 16:32:29,709] Trial 641 pruned.
# [I 2026-08-13 16:32:29,713] Trial 642 pruned.
# [I 2026-08-13 16:32:29,714] Trial 643 pruned.
# [I 2026-08-13 16:32:29,716] Trial 644 pruned.
# [I 2026-08-13 16:32:29,718] Trial 645 pruned.
# [I 2026-08-13 16:32:29,720] Trial 646 pruned.
# [I 2026-08-13 16:32:29,722] Trial 647 pruned.
# [I 2026-08-13 16:32:29,724] Trial 648 pruned.
# [I 2026-08-13 16:32:29,725] Trial 649 pruned.
# [I 2026-08-13 16:32:29,727] Trial 650 pruned.
# [I 2026-08-13 16:32:29,729] Trial 651 pruned.
# [I 2026-08-13 16:32:29,731] Trial 652 pruned.
# [I 2026-08-13 16:32:30,049] Trial 653 finished with values: [1.9037406314106753, 0.03549644293667605] and parameters: {'m': 3.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 25, 'nO': 14, 'N1': 2, 'N2': 5, 'N3': 7, 'τ': 6.554184158360506, 'mode': 1, 'act': 0, 'mO': 8}.
# [I 2026-08-13 16:32:30,052] Trial 654 pruned.
# [I 2026-08-13 16:32:30,054] Trial 655 pruned.
# [I 2026-08-13 16:32:30,057] Trial 656 pruned.
# [I 2026-08-13 16:32:30,060] Trial 657 pruned.
# [I 2026-08-13 16:32:30,063] Trial 658 pruned.
# [I 2026-08-13 16:32:30,066] Trial 659 pruned.
# [I 2026-08-13 16:32:30,068] Trial 660 pruned.
# [I 2026-08-13 16:32:30,071] Trial 661 pruned.
# [I 2026-08-13 16:32:30,074] Trial 662 pruned.
# [I 2026-08-13 16:32:30,102] Trial 663 finished with values: [0.9719304272758905, 0.7714145853484095] and parameters: {'m': 3.75, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 12, 'N1': 6, 'N2': 9, 'N3': 2, 'τ': 17.143748991444326, 'mode': 1, 'act': 0, 'mO': 7}.
# [I 2026-08-13 16:32:30,104] Trial 664 pruned.
# [I 2026-08-13 16:32:30,106] Trial 665 pruned.
# [I 2026-08-13 16:32:30,108] Trial 666 pruned.
# [I 2026-08-13 16:32:30,110] Trial 667 pruned.
# [I 2026-08-13 16:32:30,112] Trial 668 pruned.
# [I 2026-08-13 16:32:30,114] Trial 669 pruned.
# [I 2026-08-13 16:32:30,115] Trial 670 pruned.
# [I 2026-08-13 16:32:30,117] Trial 671 pruned.
# [I 2026-08-13 16:32:30,118] Trial 672 pruned.
# [I 2026-08-13 16:32:30,121] Trial 673 pruned.
# [I 2026-08-13 16:32:30,123] Trial 674 pruned.
# [I 2026-08-13 16:32:30,145] Trial 675 finished with values: [0.9755356407086938, 0.7177324653988291] and parameters: {'m': 3.75, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 10, 'nO': 15, 'N1': 3, 'N2': 6, 'N3': 6, 'τ': 5.790048034587843, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:32:30,147] Trial 676 pruned.
# [I 2026-08-13 16:32:30,171] Trial 677 finished with values: [0.9686282355406938, 1.8441606319919714] and parameters: {'m': 4.0, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 18, 'nO': 4, 'N1': 6, 'N2': 5, 'N3': 9, 'τ': 20.560480484758422, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:32:30,173] Trial 678 pruned.
# [I 2026-08-13 16:32:30,176] Trial 679 pruned.
# [I 2026-08-13 16:32:30,179] Trial 680 pruned.
# [I 2026-08-13 16:32:30,182] Trial 681 pruned.
# [I 2026-08-13 16:32:30,185] Trial 682 pruned.
# [I 2026-08-13 16:32:30,188] Trial 683 pruned.
# [I 2026-08-13 16:32:30,190] Trial 684 pruned.
# [I 2026-08-13 16:32:30,192] Trial 685 pruned.
# [I 2026-08-13 16:32:30,215] Trial 686 finished with values: [0.973770997215942, 1.150951710944028] and parameters: {'m': 2.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 65, 'nO': 16, 'N1': 8, 'N2': 6, 'N3': 4, 'τ': 12.27734991265243, 'mode': 1, 'act': 1, 'mO': 16}.
# [I 2026-08-13 16:32:30,217] Trial 687 pruned.
# [I 2026-08-13 16:32:30,219] Trial 688 pruned.
# [I 2026-08-13 16:32:30,287] Trial 689 finished with values: [0.6492145429690369, 0.28132759829487] and parameters: {'m': 2.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 51, 'nO': 18, 'N1': 5, 'N2': 6, 'N3': 6, 'τ': 21.02288276470427, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:32:30,289] Trial 690 pruned.
# [I 2026-08-13 16:32:30,291] Trial 691 pruned.
# [I 2026-08-13 16:32:30,293] Trial 692 pruned.
# [I 2026-08-13 16:32:30,295] Trial 693 pruned.
# [I 2026-08-13 16:32:30,297] Trial 694 pruned.
# [I 2026-08-13 16:32:30,298] Trial 695 pruned.
# [I 2026-08-13 16:32:30,299] Trial 696 pruned.
# [I 2026-08-13 16:32:30,301] Trial 697 pruned.
# [I 2026-08-13 16:32:30,302] Trial 698 pruned.
# [I 2026-08-13 16:32:30,304] Trial 699 pruned.
# [I 2026-08-13 16:32:30,305] Trial 700 pruned.
# [I 2026-08-13 16:32:30,307] Trial 701 pruned.
# [I 2026-08-13 16:32:30,309] Trial 702 pruned.
# [I 2026-08-13 16:32:30,310] Trial 703 pruned.
# [I 2026-08-13 16:32:30,312] Trial 704 pruned.
# [I 2026-08-13 16:32:30,313] Trial 705 pruned.
# [I 2026-08-13 16:32:30,314] Trial 706 pruned.
# [I 2026-08-13 16:32:30,316] Trial 707 pruned.
# [I 2026-08-13 16:32:30,318] Trial 708 pruned.
# [I 2026-08-13 16:32:30,320] Trial 709 pruned.
# [I 2026-08-13 16:32:30,321] Trial 710 pruned.
# [I 2026-08-13 16:32:30,322] Trial 711 pruned.
# [I 2026-08-13 16:32:30,324] Trial 712 pruned.
# [I 2026-08-13 16:32:30,326] Trial 713 pruned.
# [I 2026-08-13 16:32:30,327] Trial 714 pruned.
# [I 2026-08-13 16:32:30,329] Trial 715 pruned.
# [I 2026-08-13 16:32:30,331] Trial 716 pruned.
# [I 2026-08-13 16:32:30,332] Trial 717 pruned.
# [I 2026-08-13 16:32:30,334] Trial 718 pruned.
# [I 2026-08-13 16:32:30,335] Trial 719 pruned.
# [I 2026-08-13 16:32:30,337] Trial 720 pruned.
# [I 2026-08-13 16:32:30,338] Trial 721 pruned.
# [I 2026-08-13 16:32:30,340] Trial 722 pruned.
# [I 2026-08-13 16:32:30,341] Trial 723 pruned.
# [I 2026-08-13 16:32:30,342] Trial 724 pruned.
# [I 2026-08-13 16:32:30,344] Trial 725 pruned.
# [I 2026-08-13 16:32:30,345] Trial 726 pruned.
# [I 2026-08-13 16:32:30,346] Trial 727 pruned.
# [I 2026-08-13 16:32:30,347] Trial 728 pruned.
# [I 2026-08-13 16:32:30,349] Trial 729 pruned.
# [I 2026-08-13 16:32:30,351] Trial 730 pruned.
# [I 2026-08-13 16:32:30,352] Trial 731 pruned.
# [I 2026-08-13 16:32:30,355] Trial 732 pruned.
# [I 2026-08-13 16:32:30,356] Trial 733 pruned.
# [I 2026-08-13 16:32:30,559] Trial 734 finished with values: [1.8572447168011805, 0.1851259280567198] and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 4, 'nO': 15, 'N1': 2, 'N2': 4, 'N3': 3, 'τ': 8.562459035661423, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:32:30,561] Trial 735 pruned.
# [I 2026-08-13 16:32:30,563] Trial 736 pruned.
# [I 2026-08-13 16:32:30,565] Trial 737 pruned.
# [I 2026-08-13 16:32:30,567] Trial 738 pruned.
# [I 2026-08-13 16:32:30,568] Trial 739 pruned.
# [I 2026-08-13 16:32:30,569] Trial 740 pruned.
# [I 2026-08-13 16:32:30,572] Trial 741 pruned.
# [I 2026-08-13 16:32:30,573] Trial 742 pruned.
# [I 2026-08-13 16:32:30,575] Trial 743 pruned.
# [I 2026-08-13 16:32:30,576] Trial 744 pruned.
# [I 2026-08-13 16:32:30,577] Trial 745 pruned.
# [I 2026-08-13 16:32:30,580] Trial 746 pruned.
# [I 2026-08-13 16:32:30,582] Trial 747 pruned.
# [I 2026-08-13 16:32:30,583] Trial 748 pruned.
# [I 2026-08-13 16:32:30,585] Trial 749 pruned.
# [I 2026-08-13 16:32:30,587] Trial 750 pruned.
# [I 2026-08-13 16:32:30,588] Trial 751 pruned.
# [I 2026-08-13 16:32:30,589] Trial 752 pruned.
# [I 2026-08-13 16:32:30,591] Trial 753 pruned.
# [I 2026-08-13 16:32:30,592] Trial 754 pruned.
# [I 2026-08-13 16:32:30,593] Trial 755 pruned.
# [I 2026-08-13 16:32:30,595] Trial 756 pruned.
# [I 2026-08-13 16:32:30,596] Trial 757 pruned.
# [I 2026-08-13 16:32:30,598] Trial 758 pruned.
# [I 2026-08-13 16:32:30,599] Trial 759 pruned.
# [I 2026-08-13 16:32:30,600] Trial 760 pruned.
# [I 2026-08-13 16:32:30,601] Trial 761 pruned.
# [I 2026-08-13 16:32:30,603] Trial 762 pruned.
# [I 2026-08-13 16:32:30,604] Trial 763 pruned.
# [I 2026-08-13 16:32:30,606] Trial 764 pruned.
# [I 2026-08-13 16:32:30,607] Trial 765 pruned.
# [I 2026-08-13 16:32:30,609] Trial 766 pruned.
# [I 2026-08-13 16:32:30,610] Trial 767 pruned.
# [I 2026-08-13 16:32:30,612] Trial 768 pruned.
# [I 2026-08-13 16:32:30,614] Trial 769 pruned.
# [I 2026-08-13 16:32:30,615] Trial 770 pruned.
# [I 2026-08-13 16:32:30,616] Trial 771 pruned.
# [I 2026-08-13 16:32:30,618] Trial 772 pruned.
# [I 2026-08-13 16:32:30,619] Trial 773 pruned.
# [I 2026-08-13 16:32:30,620] Trial 774 pruned.
# [I 2026-08-13 16:32:30,622] Trial 775 pruned.
# [I 2026-08-13 16:32:30,623] Trial 776 pruned.
# ...
# [I 2026-08-13 16:41:20,275] Trial 2982 finished with values: [0.8395499941010868, 0.007592872022598173] and parameters: {'m': 2.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 5, 'N3': 7, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:20,583] Trial 2983 finished with values: [0.055476085589442135, 0.009715126443636717] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:20,824] Trial 2984 finished with values: [0.1833332132437868, 0.011495130780710272] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 12, 'N1': 1, 'N2': 4, 'N3': 2, 'τ': 1.8602155655098356, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:21,212] Trial 2985 finished with values: [1.1865414249466633, 0.0030740109903966517] and parameters: {'m': 3.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 20, 'N1': 1, 'N2': 4, 'N3': 9, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:21,480] Trial 2986 finished with values: [0.33275590717348275, 0.013799191163331219] and parameters: {'m': 2.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 20, 'N1': 1, 'N2': 6, 'N3': 1, 'τ': 4.851460996387638, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:41:21,485] Trial 2987 pruned.
# [I 2026-08-13 16:41:22,017] Trial 2988 finished with values: [1.6898630887834347, 0.003938996651568028] and parameters: {'m': 3.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 4, 'N3': 4, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:22,344] Trial 2989 finished with values: [1.5376218850471894, 0.0030529555568670334] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 6, 'τ': 1.8602155655098356, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:22,830] Trial 2990 finished with values: [1.6899017670746939, 0.014996464016769772] and parameters: {'m': 2.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 5, 'N3': 2, 'τ': 3.027390801084519, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:23,366] Trial 2991 finished with values: [2.265551722926692, 0.0010580289626757743] and parameters: {'m': 2.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 8, 'N1': 1, 'N2': 6, 'N3': 1, 'τ': 4.851460996387638, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:41:23,699] Trial 2992 finished with values: [0.35998339645350846, 0.0046080101597450185] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 4, 'N3': 2, 'τ': 1.8602155655098356, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:23,784] Trial 2993 pruned.
# [I 2026-08-13 16:41:24,341] Trial 2994 finished with values: [1.689213704115973, 0.010250675865937321] and parameters: {'m': 3.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 6, 'N3': 2, 'τ': 1.8602155655098356, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:41:24,660] Trial 2995 finished with values: [0.10393614453527929, 0.006902937683435143] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 4, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:24,697] Trial 2996 pruned.
# [I 2026-08-13 16:41:25,198] Trial 2997 finished with values: [1.457674944676666, 0.0059865375765440435] and parameters: {'m': 2.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 8, 'N1': 1, 'N2': 6, 'N3': 2, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:25,238] Trial 2998 finished with values: [0.9723189186497607, 0.7383788103683371] and parameters: {'m': 3.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 4, 'nO': 13, 'N1': 1, 'N2': 9, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:25,533] Trial 2999 finished with values: [0.22436164559113064, 0.008506539495774757] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 4.851460996387638, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:41:25,758] Trial 3000 finished with values: [0.055476085589442135, 0.009715126443636717] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:26,324] Trial 3001 finished with values: [2.2658735466647935, 0.0018676569023577674] and parameters: {'m': 3.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 8, 'N1': 1, 'N2': 6, 'N3': 1, 'τ': 6.554184158360506, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:41:26,942] Trial 3002 finished with values: [2.088779956427015, 0.020687107229662265] and parameters: {'m': 4.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 10, 'N1': 1, 'N2': 4, 'N3': 8, 'τ': 1.8602155655098356, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:41:27,468] Trial 3003 finished with values: [1.6899545523454709, 0.01629235746783504] and parameters: {'m': 4.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:27,473] Trial 3004 pruned.
# [I 2026-08-13 16:41:27,478] Trial 3005 pruned.
# [I 2026-08-13 16:41:27,735] Trial 3006 finished with values: [0.36030659195431536, 0.004598710751857741] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 2, 'τ': 1.8602155655098356, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:27,741] Trial 3007 pruned.
# [I 2026-08-13 16:41:28,157] Trial 3008 finished with values: [1.7399629772735257, 0.017234285356177374] and parameters: {'m': 2.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 8, 'N1': 1, 'N2': 5, 'N3': 9, 'τ': 14.147121142406828, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:41:28,521] Trial 3009 finished with values: [1.4390660355878484, 0.12939465122424013] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 15, 'N1': 5, 'N2': 9, 'N3': 7, 'τ': 16.819647943175717, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:28,530] Trial 3010 pruned.
# [I 2026-08-13 16:41:28,841] Trial 3011 finished with values: [0.10378796816535141, 0.006893006919378674] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:29,250] Trial 3012 finished with values: [0.791014061060787, 0.004585006736447579] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 4, 'τ': 16.32010803705539, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:29,512] Trial 3013 finished with values: [0.1449062145794048, 0.006463213856950993] and parameters: {'m': 3.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 13, 'N1': 1, 'N2': 9, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:29,517] Trial 3014 pruned.
# [I 2026-08-13 16:41:29,524] Trial 3015 pruned.
# [I 2026-08-13 16:41:29,930] Trial 3016 finished with values: [0.45848257505017653, 0.003704450954352594] and parameters: {'m': 4.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 13, 'N1': 1, 'N2': 6, 'N3': 4, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:30,191] Trial 3017 finished with values: [0.228474865759136, 0.010024668368388065] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 2, 'τ': 15.360220723399774, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:41:30,437] Trial 3018 finished with values: [0.560989567041419, 0.011003248668629775] and parameters: {'m': 4.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 4.851460996387638, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:41:30,714] Trial 3019 finished with values: [0.16141825494214104, 0.006364555545544241] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 15, 'N1': 1, 'N2': 9, 'N3': 4, 'τ': 6.554184158360506, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:31,251] Trial 3020 finished with values: [1.7837901786532118, 0.005700171200966748] and parameters: {'m': 3.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 11, 'N1': 1, 'N2': 4, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:31,529] Trial 3021 finished with values: [0.055476085589442135, 0.009715126443636717] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:31,820] Trial 3022 finished with values: [0.27959203332831833, 0.004951775366482813] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 2, 'N3': 2, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:32,263] Trial 3023 finished with values: [1.001388842067993, 0.0027581361429741785] and parameters: {'m': 3.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 4, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:32,552] Trial 3024 finished with values: [0.10378796816535141, 0.006893096356904021] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 6, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:32,831] Trial 3025 finished with values: [0.9187922056415257, 0.056387221940317256] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 2, 'N2': 9, 'N3': 9, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:33,153] Trial 3026 finished with values: [0.14678368522966254, 0.008261014570822971] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 8, 'τ': 1.8602155655098356, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:33,157] Trial 3027 pruned.
# [I 2026-08-13 16:41:33,613] Trial 3028 finished with values: [1.3678196219342735, 0.017281544712356732] and parameters: {'m': 4.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 9, 'τ': 14.631027168363463, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:33,784] Trial 3029 finished with values: [0.2624305254145745, 0.013133427970797083] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:34,203] Trial 3030 finished with values: [1.5863252368494825, 0.013469399364280238] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 26, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 11.716292712310526, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:34,257] Trial 3031 finished with values: [0.9480483256286673, 1.6757193778039756] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 5, 'N2': 4, 'N3': 2, 'τ': 17.03770714061097, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:41:34,477] Trial 3032 finished with values: [0.12242431261425762, 0.00880653392415597] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 8, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:41:34,738] Trial 3033 finished with values: [0.35494702343005025, 0.020511868725270707] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:41:34,990] Trial 3034 finished with values: [0.24327670015878358, 0.0057962592173067306] and parameters: {'m': 3.75, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 3, 'τ': 1.8602155655098356, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:34,997] Trial 3035 pruned.
# [I 2026-08-13 16:41:35,390] Trial 3036 finished with values: [0.2383491052593411, 0.006301263339298766] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 2, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:35,396] Trial 3037 pruned.
# [I 2026-08-13 16:41:35,916] Trial 3038 finished with values: [2.0592068966262005, 0.019657280115459284] and parameters: {'m': 2.5, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 3, 'N1': 1, 'N2': 6, 'N3': 2, 'τ': 1.8602155655098356, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:41:36,220] Trial 3039 finished with values: [0.4887705257825801, 0.008980517956918068] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 20, 'N1': 1, 'N2': 9, 'N3': 2, 'τ': 4.851460996387638, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:36,656] Trial 3040 finished with values: [1.5690474719791856, 0.009225943646825224] and parameters: {'m': 2.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:36,685] Trial 3041 finished with values: [0.975831232634736, 0.9999770726621181] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 5, 'nO': 20, 'N1': 1, 'N2': 5, 'N3': 2, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:36,991] Trial 3042 finished with values: [0.35951408108462074, 0.0047145923370427115] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 1.8602155655098356, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:37,231] Trial 3043 finished with values: [0.05572145873087859, 0.009942615294366242] and parameters: {'m': 3.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 7, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:37,646] Trial 3044 finished with values: [0.8099872598337656, 0.007341747128097695] and parameters: {'m': 3.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 9, 'N1': 1, 'N2': 5, 'N3': 7, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:37,863] Trial 3045 finished with values: [0.055476085589442135, 0.009715126443636717] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 2, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:37,906] Trial 3046 finished with values: [0.9770777658284987, 1.3860036927420725] and parameters: {'m': 4.5, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 20, 'N1': 4, 'N2': 3, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:38,238] Trial 3047 finished with values: [1.409362072031813, 0.007654345957070067] and parameters: {'m': 3.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 20, 'N1': 1, 'N2': 5, 'N3': 8, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 9}.
# [I 2026-08-13 16:41:38,667] Trial 3048 finished with values: [1.5911603974027464, 0.010202306790491798] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 20, 'N1': 1, 'N2': 3, 'N3': 1, 'τ': 16.32010803705539, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:39,054] Trial 3049 finished with values: [1.4508597211174268, 0.003647610088714365] and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 36, 'nO': 8, 'N1': 1, 'N2': 2, 'N3': 2, 'τ': 6.554184158360506, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:41:39,503] Trial 3050 finished with values: [1.248701927424975, 0.00557320280106351] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 44, 'nO': 13, 'N1': 1, 'N2': 3, 'N3': 6, 'τ': 4.851460996387638, 'mode': 1, 'act': 1, 'mO': 2}.

# %%
df = dfs[0]
#df = df[(df.iloc[:,0] <= 0.07)]
params_list = df.values[:,-11:]
df

# %%
tedas = []
for i,params in enumerate(params_list[-3:]):
    m,nI,nR,nO,mO,N1,N2,N3,τ,mode,act = params
    X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
    if isinstance(nR, str): nR = ast.literal_eval(nR)

    teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N1,N2,N3],mode=mode,act=act,
                tau=τ,rho=0.001,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
    for j,_ in enumerate(X[:]):
        teda.run(X[j])
        teda.RUL_Prediction(Y[j],mode='interval',lim=len(sig)-nI+1,show=False)
        teda.Adapt(Y[j],Z[j])

    teda.c = np.append(teda.c,teda.gm)  
    tedas.append(teda)
    #PlotSeriesPLY(ySeries=[teda.wape_HI_hist,teda.wape_RUL_hist])

# %%
PlotDSI_3D_PLT(tedas[0])
