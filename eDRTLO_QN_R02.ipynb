# %%
import math
import ast
import ipynbname
import pandas as pd
import numpy as np
import optuna
from Testing.DRTLO_QN_R1 import *
from Functions.AutoCloud_V2 import *
from Functions.DataCloud_V2 import *
from Functions.Utils import *
from Functions.Graphs import *
from Functions.TedaGraphs import *
from Functions.Utils_OPT import *

FileName = ipynbname.name()
out_path = f'Optimization\\eDRTLO_QN\\multi\\Optimization.csv'
RS = pd.read_excel(r'Dataset\RS.xlsx')
HI = pd.read_csv(r'Dataset\Bearing1_1.csv')
sig = HI['PC1'].values

# %%
params =  {'nI': 3, 'nR': 3, 'nO': 3, 'N1': 0.1,
            'τ': 23, 'mode': 1, 'act': 0}

nI,nR,nO,N1,τ,mode,act= list(params.values())
X, Y, Z = PrepareData(RS, HI, nX=nI, nY=nO, mY=0, nZ=1, mode='past')

teda=AutoCloud(m=2.5,nI=nI,nR=[nR],nO=nO,ηS=[N1],mode=mode,
               tau=τ,rho=0.01,eol=0.3,ref=len(sig)-nI,wtaG=True,wtaP=True) 
for j,_ in enumerate(X[:]):
    teda.run(X[j])
    teda.RUL_Prediction(Y[j],mode='interval',lim=len(sig)-nI+1,show=False)
    teda.Adapt(Y[j],Z[j])

#teda.RUL_Granularity()
#print(teda.wape_HI,teda.wape_RUL)
#PlotDSI_3D_PLT(teda)
#teda.c = np.append(teda.c,teda.gm)   
#PlotGranulesSpace(teda,w=700,h=700)

# %%
print(xxx)

# %%
def Optimize(
        FileName=None,OptDim=None,OptSampler=None,OptSeed=None,OptPrune=False,
        n_study=None,timeout=None,n_trials=None,
        patience=None,
        mS =None,nIS=None,nLS=None,nRS=None,nOS =None,mOS=None,
        NS=None,τS =None,mdS=None,actS=None):

    '''
        OptSampler modes available: None, Auto, GP, NSGAII, Random, TPE
    
        None: sampler default, suport multivariate optimization

        GP: suport multivariate optimization

        Auto: suport multivariate optimization
        
        NSGAII: poorly suport multivariate optimization
        
        Random: poorly suport multivariate optimization

        TPE: suport multivariate optimization
    '''

    if OptDim == 1 or OptDim is None: SingleObj = True
    elif OptDim > 1: SingleObj = False    
    if n_study is None: n_study = 1
    if timeout is None: timeout = 60
    if n_trials is None and patience is None: 
        n_trials = 25
        patience = 25
    elif n_trials < 100 and patience is None:
        patience = int(0.25*n_trials)
    elif n_trials >= 1e2 and n_trials < 1e3 and patience is None:
        patience = int(0.20*n_trials)
    elif n_trials >= 1e3 and n_trials < 5e3 and patience is None:
        patience = int(0.150*n_trials)
    elif n_trials >= 5e3 and n_trials < 1e4 and patience is None:
        patience = int(0.125*n_trials)    
    elif n_trials >= 1e4 and patience is None:
        patience = int(0.03*n_trials)   

    if mS  is None: mS  = [1.75,4.25]
    if nIS is None: nIS = [2,40]
    if nLS is None: nLS = [1,5]
    if nRS is None: nRS = [1,60]
    if nOS is None: nOS = [1,40]
    if mOS is None: mOS = [0,40]
    if NS is None: NS = [1,9]
    if τS  is None: τS  = [1,25]
    if mdS is None: mdS = [0,1]
    if actS is None: actS = [0,1,2]

    if SingleObj: names = ['MAPE_RUL*MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N','TAU','past/ahead','activation']
    else: names = ['MAPE_RUL','MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N', 'TAU','past/ahead','activation']
    study_dir, out_path = df_ParamsTable(names,FileName)

    for i in range(n_study):
        print('iteration:',i+1)
        def objective(trial):
            m = trial.suggest_float('m', mS[0], mS[1],step=0.25)
            nI = trial.suggest_int('nI', nIS[0], nIS[1]) 
            n_layers = trial.suggest_int('n_layers', nLS[0], nLS[1])
            nR = [trial.suggest_int(f'nR_layer_{l}', nRS[0], nRS[1]) for l in range(n_layers)]
            nO = trial.suggest_int('nO', nOS[0], nOS[1]) 
            N = trial.suggest_int('N', NS[0], NS[1])
            τ = trial.suggest_float('τ', τS[0], τS[1])
            mode = trial.suggest_int('mode', mdS[0], mdS[1])  
            act = trial.suggest_int('act', actS[0], actS[1])  

            if mode == 'past' or mode == 0:
                mO = trial.suggest_int('mO', 0, 0) 
                if nO > nI: raise TrialPruned()

            elif mode == 'ahead' or mode == 1:
                mO = trial.suggest_int('mO', mOS[0], mOS[1]) 
                if   nI > 20 or nO > 20: raise TrialPruned()
                elif mO > nI: raise TrialPruned()
                
            X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
            
            teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N],mode=mode,act=act,
                           tau=τ,rho=0.0,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
            
            for j,_ in enumerate(X[:]):
                teda.run(X[j])
                teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1)
                teda.Adapt(Y[j],Z[j])
                #teda.WAPE_HI2(Y[j],Z[j])

                if np.isinf(teda.hiP[-1]) or np.isnan(teda.hiP[-1]): raise TrialPruned()
                if not OptPrune: continue
        
                if j >=60 and j%5==0:
                    if teda.wape_RUL > 0.6: raise TrialPruned()
                    if teda.wape_HI  > 0.3: raise TrialPruned()

                if SingleObj and j%35==0:
                    trial.report(teda.wape_RUL+teda.wape_HI, j)
                    if trial.should_prune():
                        raise optuna.TrialPruned()

            if SingleObj: return teda.wape_RUL + teda.wape_HI
            else: return teda.wape_RUL,teda.wape_HI

        pruner=optuna.pruners.HyperbandPruner()
        if SingleObj: study = optuna.create_study(direction='minimize',pruner=pruner,sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        else: study = optuna.create_study(directions=['minimize','minimize'],sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        study.optimize(objective, n_trials=n_trials, timeout=timeout, callbacks=[EarlyStoppingCallback(patience=patience)])

        vec = []
        if SingleObj:
            trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
            for trial in trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]   
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
            df2 = df2.sort_values(by=df2.columns[0], ascending=False)[-5:]

        elif not SingleObj: 
            for trial in study.best_trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],trial.values[1],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
        
    if os.path.isfile(out_path) and out_path.startswith(study_dir):
        df1 = pd.read_csv(out_path)
        df_stdy = pd.concat([df1, df2], ignore_index=True)
    
    else: df_stdy = df2
    
    df_stdy.to_csv(out_path, index=False)
    opt_path = os.path.join(study_dir,f'opt_{len(os.listdir(study_dir))-1}.csv')
    
    if df2.shape[0] > 0: df2.to_csv(opt_path, index=False)

    return [df_stdy, df2 ]

# %%
dfs = Optimize(FileName=FileName[:-4],OptDim=1,OptSampler='tpe',OptPrune=False,
                         n_study=1,timeout=60,n_trials=0.5e3,patience=None,
                         mS=[2.0,4.5],nRS=[1,70],mdS=[1,1],actS=[0,1])

# %%
for i in range(1,6):
    dfs = Optimize(FileName=FileName[:-4],OptDim=1,OptSampler='tpe',OptPrune=False,
                         n_study=6,timeout=1680,n_trials=1e4,patience=1e3,
                         mS=[2.0,4.5],nLS=[i,i],nRS=[1,70],mdS=[1,1],actS=[0,1])
# Out:
# c:\Users\Claudio\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# c:\Users\Claudio\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``group`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# [I 2026-08-13 16:33:28,522] A new study created in memory with name: no-name-93426cb2-41a0-4727-900c-5c7009b857b5
# [I 2026-08-13 16:33:28,526] Trial 0 pruned.
# iteration: 1
# [I 2026-08-13 16:33:28,726] Trial 1 finished with value: 2.713686044499932 and parameters: {'m': 3.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 18, 'N': 3, 'τ': 12.912607034762253, 'mode': 1, 'act': 0, 'mO': 8}. Best is trial 1 with value: 2.713686044499932.
# [I 2026-08-13 16:33:28,969] Trial 2 finished with value: 1.781961102914613 and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 11, 'nO': 20, 'N': 7, 'τ': 13.270868626965136, 'mode': 1, 'act': 0, 'mO': 7}. Best is trial 2 with value: 1.781961102914613.
# [I 2026-08-13 16:33:28,971] Trial 3 pruned.
# [I 2026-08-13 16:33:28,973] Trial 4 pruned.
# [I 2026-08-13 16:33:28,975] Trial 5 pruned.
# [I 2026-08-13 16:33:28,977] Trial 6 pruned.
# [I 2026-08-13 16:33:28,979] Trial 7 pruned.
# [I 2026-08-13 16:33:28,981] Trial 8 pruned.
# [I 2026-08-13 16:33:28,982] Trial 9 pruned.
# [I 2026-08-13 16:33:28,984] Trial 10 pruned.
# [I 2026-08-13 16:33:28,986] Trial 11 pruned.
# [I 2026-08-13 16:33:28,988] Trial 12 pruned.
# [I 2026-08-13 16:33:28,990] Trial 13 pruned.
# [I 2026-08-13 16:33:28,992] Trial 14 pruned.
# [I 2026-08-13 16:33:28,995] Trial 15 pruned.
# [I 2026-08-13 16:33:28,997] Trial 16 pruned.
# [I 2026-08-13 16:33:28,999] Trial 17 pruned.
# [I 2026-08-13 16:33:29,001] Trial 18 pruned.
# [I 2026-08-13 16:33:29,002] Trial 19 pruned.
# [I 2026-08-13 16:33:29,004] Trial 20 pruned.
# [I 2026-08-13 16:33:29,006] Trial 21 pruned.
# [I 2026-08-13 16:33:29,045] Trial 22 finished with value: 1.6041076644808732 and parameters: {'m': 4.5, 'nI': 3, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 13, 'N': 7, 'τ': 17.282443865186245, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 22 with value: 1.6041076644808732.
# [I 2026-08-13 16:33:29,090] Trial 23 finished with value: 4.266657913109929 and parameters: {'m': 2.75, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 18, 'N': 5, 'τ': 17.37037407068974, 'mode': 1, 'act': 0, 'mO': 1}. Best is trial 22 with value: 1.6041076644808732.
# [I 2026-08-13 16:33:29,093] Trial 24 pruned.
# [I 2026-08-13 16:33:29,096] Trial 25 pruned.
# [I 2026-08-13 16:33:29,098] Trial 26 pruned.
# [I 2026-08-13 16:33:29,100] Trial 27 pruned.
# [I 2026-08-13 16:33:29,102] Trial 28 pruned.
# [I 2026-08-13 16:33:29,105] Trial 29 pruned.
# [I 2026-08-13 16:33:29,108] Trial 30 pruned.
# [I 2026-08-13 16:33:29,111] Trial 31 pruned.
# [I 2026-08-13 16:33:29,114] Trial 32 pruned.
# [I 2026-08-13 16:33:29,117] Trial 33 pruned.
# [I 2026-08-13 16:33:29,120] Trial 34 pruned.
# [I 2026-08-13 16:33:29,123] Trial 35 pruned.
# [I 2026-08-13 16:33:29,126] Trial 36 pruned.
# [I 2026-08-13 16:33:29,130] Trial 37 pruned.
# [I 2026-08-13 16:33:29,133] Trial 38 pruned.
# [I 2026-08-13 16:33:29,135] Trial 39 pruned.
# [I 2026-08-13 16:33:29,138] Trial 40 pruned.
# [I 2026-08-13 16:33:29,141] Trial 41 pruned.
# [I 2026-08-13 16:33:29,146] Trial 42 pruned.
# [I 2026-08-13 16:33:29,149] Trial 43 pruned.
# [I 2026-08-13 16:33:29,153] Trial 44 pruned.
# [I 2026-08-13 16:33:29,156] Trial 45 pruned.
# [I 2026-08-13 16:33:29,159] Trial 46 pruned.
# [I 2026-08-13 16:33:29,162] Trial 47 pruned.
# [I 2026-08-13 16:33:29,163] Trial 48 pruned.
# [I 2026-08-13 16:33:29,166] Trial 49 pruned.
# [I 2026-08-13 16:33:29,169] Trial 50 pruned.
# [I 2026-08-13 16:33:29,172] Trial 51 pruned.
# [I 2026-08-13 16:33:29,175] Trial 52 pruned.
# [I 2026-08-13 16:33:29,177] Trial 53 pruned.
# [I 2026-08-13 16:33:29,180] Trial 54 pruned.
# [I 2026-08-13 16:33:29,183] Trial 55 pruned.
# [I 2026-08-13 16:33:29,185] Trial 56 pruned.
# [I 2026-08-13 16:33:29,187] Trial 57 pruned.
# [I 2026-08-13 16:33:29,190] Trial 58 pruned.
# [I 2026-08-13 16:33:29,229] Trial 59 finished with value: 2.0233074573774408 and parameters: {'m': 2.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 29, 'nO': 16, 'N': 9, 'τ': 6.408772326741762, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 22 with value: 1.6041076644808732.
# [I 2026-08-13 16:33:29,233] Trial 60 pruned.
# [I 2026-08-13 16:33:29,235] Trial 61 pruned.
# [I 2026-08-13 16:33:29,451] Trial 62 finished with value: 8.022361629041358 and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 13, 'N': 1, 'τ': 23.44343295488836, 'mode': 1, 'act': 0, 'mO': 9}. Best is trial 22 with value: 1.6041076644808732.
# [I 2026-08-13 16:33:29,453] Trial 63 pruned.
# [I 2026-08-13 16:33:29,456] Trial 64 pruned.
# [I 2026-08-13 16:33:29,458] Trial 65 pruned.
# [I 2026-08-13 16:33:29,460] Trial 66 pruned.
# [I 2026-08-13 16:33:29,462] Trial 67 pruned.
# [I 2026-08-13 16:33:29,463] Trial 68 pruned.
# [I 2026-08-13 16:33:29,466] Trial 69 pruned.
# [I 2026-08-13 16:33:29,470] Trial 70 pruned.
# [I 2026-08-13 16:33:29,472] Trial 71 pruned.
# [I 2026-08-13 16:33:29,473] Trial 72 pruned.
# [I 2026-08-13 16:33:29,476] Trial 73 pruned.
# [I 2026-08-13 16:33:29,478] Trial 74 pruned.
# [I 2026-08-13 16:33:29,481] Trial 75 pruned.
# [I 2026-08-13 16:33:29,483] Trial 76 pruned.
# [I 2026-08-13 16:33:29,485] Trial 77 pruned.
# [I 2026-08-13 16:33:29,488] Trial 78 pruned.
# [I 2026-08-13 16:33:29,490] Trial 79 pruned.
# [I 2026-08-13 16:33:29,492] Trial 80 pruned.
# [I 2026-08-13 16:33:29,796] Trial 81 finished with value: 1.879917363799179 and parameters: {'m': 2.5, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 17, 'N': 4, 'τ': 18.1727773064923, 'mode': 1, 'act': 1, 'mO': 9}. Best is trial 22 with value: 1.6041076644808732.
# [I 2026-08-13 16:33:29,798] Trial 82 pruned.
# [I 2026-08-13 16:33:29,800] Trial 83 pruned.
# [I 2026-08-13 16:33:29,802] Trial 84 pruned.
# [I 2026-08-13 16:33:29,804] Trial 85 pruned.
# [I 2026-08-13 16:33:29,805] Trial 86 pruned.
# [I 2026-08-13 16:33:29,808] Trial 87 pruned.
# [I 2026-08-13 16:33:29,810] Trial 88 pruned.
# [I 2026-08-13 16:33:29,812] Trial 89 pruned.
# [I 2026-08-13 16:33:29,814] Trial 90 pruned.
# [I 2026-08-13 16:33:29,817] Trial 91 pruned.
# [I 2026-08-13 16:33:29,819] Trial 92 pruned.
# [I 2026-08-13 16:33:29,822] Trial 93 pruned.
# [I 2026-08-13 16:33:29,824] Trial 94 pruned.
# [I 2026-08-13 16:33:29,826] Trial 95 pruned.
# [I 2026-08-13 16:33:29,829] Trial 96 pruned.
# [I 2026-08-13 16:33:29,830] Trial 97 pruned.
# [I 2026-08-13 16:33:29,834] Trial 98 pruned.
# [I 2026-08-13 16:33:29,892] Trial 99 finished with value: 1.060508784084449 and parameters: {'m': 3.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 13, 'N': 9, 'τ': 14.598691913386551, 'mode': 1, 'act': 0, 'mO': 3}. Best is trial 99 with value: 1.060508784084449.
# [I 2026-08-13 16:33:29,895] Trial 100 pruned.
# [I 2026-08-13 16:33:29,897] Trial 101 pruned.
# [I 2026-08-13 16:33:29,899] Trial 102 pruned.
# [I 2026-08-13 16:33:29,903] Trial 103 pruned.
# [I 2026-08-13 16:33:29,906] Trial 104 pruned.
# [I 2026-08-13 16:33:29,910] Trial 105 pruned.
# [I 2026-08-13 16:33:29,940] Trial 106 finished with value: 2.611696760112286 and parameters: {'m': 2.75, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 2, 'N': 5, 'τ': 5.090166233723418, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 99 with value: 1.060508784084449.
# [I 2026-08-13 16:33:29,943] Trial 107 pruned.
# [I 2026-08-13 16:33:29,945] Trial 108 pruned.
# [I 2026-08-13 16:33:29,947] Trial 109 pruned.
# [I 2026-08-13 16:33:29,949] Trial 110 pruned.
# [I 2026-08-13 16:33:29,952] Trial 111 pruned.
# [I 2026-08-13 16:33:29,955] Trial 112 pruned.
# [I 2026-08-13 16:33:29,958] Trial 113 pruned.
# [I 2026-08-13 16:33:29,960] Trial 114 pruned.
# [I 2026-08-13 16:33:29,963] Trial 115 pruned.
# [I 2026-08-13 16:33:29,966] Trial 116 pruned.
# [I 2026-08-13 16:33:29,969] Trial 117 pruned.
# [I 2026-08-13 16:33:29,972] Trial 118 pruned.
# [I 2026-08-13 16:33:29,975] Trial 119 pruned.
# [I 2026-08-13 16:33:29,978] Trial 120 pruned.
# [I 2026-08-13 16:33:29,982] Trial 121 pruned.
# [I 2026-08-13 16:33:29,985] Trial 122 pruned.
# [I 2026-08-13 16:33:29,989] Trial 123 pruned.
# [I 2026-08-13 16:33:29,993] Trial 124 pruned.
# [I 2026-08-13 16:33:29,995] Trial 125 pruned.
# [I 2026-08-13 16:33:29,997] Trial 126 pruned.
# [I 2026-08-13 16:33:30,001] Trial 127 pruned.
# [I 2026-08-13 16:33:30,005] Trial 128 pruned.
# [I 2026-08-13 16:33:30,008] Trial 129 pruned.
# [I 2026-08-13 16:33:30,011] Trial 130 pruned.
# [I 2026-08-13 16:33:30,013] Trial 131 pruned.
# [I 2026-08-13 16:33:30,017] Trial 132 pruned.
# [I 2026-08-13 16:33:30,120] Trial 133 finished with value: 0.6770997114590853 and parameters: {'m': 4.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 6, 'N': 3, 'τ': 20.272450698062386, 'mode': 1, 'act': 1, 'mO': 13}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:30,124] Trial 134 pruned.
# [I 2026-08-13 16:33:30,127] Trial 135 pruned.
# [I 2026-08-13 16:33:30,131] Trial 136 pruned.
# [I 2026-08-13 16:33:30,132] Trial 137 pruned.
# [I 2026-08-13 16:33:30,135] Trial 138 pruned.
# [I 2026-08-13 16:33:30,139] Trial 139 pruned.
# [I 2026-08-13 16:33:30,175] Trial 140 finished with value: 1.3741011113295023 and parameters: {'m': 4.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 19, 'N': 7, 'τ': 3.4893419161995496, 'mode': 1, 'act': 0, 'mO': 7}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:30,179] Trial 141 pruned.
# [I 2026-08-13 16:33:30,183] Trial 142 pruned.
# [I 2026-08-13 16:33:30,187] Trial 143 pruned.
# [I 2026-08-13 16:33:30,191] Trial 144 pruned.
# [I 2026-08-13 16:33:30,195] Trial 145 pruned.
# [I 2026-08-13 16:33:30,198] Trial 146 pruned.
# [I 2026-08-13 16:33:30,202] Trial 147 pruned.
# [I 2026-08-13 16:33:30,206] Trial 148 pruned.
# [I 2026-08-13 16:33:30,209] Trial 149 pruned.
# [I 2026-08-13 16:33:30,213] Trial 150 pruned.
# [I 2026-08-13 16:33:30,216] Trial 151 pruned.
# [I 2026-08-13 16:33:30,220] Trial 152 pruned.
# [I 2026-08-13 16:33:30,223] Trial 153 pruned.
# [I 2026-08-13 16:33:30,582] Trial 154 finished with value: 1.8867438613552312 and parameters: {'m': 3.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 17, 'N': 2, 'τ': 15.509347156046239, 'mode': 1, 'act': 0, 'mO': 4}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:30,585] Trial 155 pruned.
# [I 2026-08-13 16:33:30,589] Trial 156 pruned.
# [I 2026-08-13 16:33:30,591] Trial 157 pruned.
# [I 2026-08-13 16:33:30,594] Trial 158 pruned.
# [I 2026-08-13 16:33:30,624] Trial 159 finished with value: 2.504989405018132 and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 17, 'N': 5, 'τ': 6.432482732577132, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:30,626] Trial 160 pruned.
# [I 2026-08-13 16:33:30,630] Trial 161 pruned.
# [I 2026-08-13 16:33:30,632] Trial 162 pruned.
# [I 2026-08-13 16:33:30,635] Trial 163 pruned.
# [I 2026-08-13 16:33:30,638] Trial 164 pruned.
# [I 2026-08-13 16:33:30,665] Trial 165 finished with value: 2.0609601576982373 and parameters: {'m': 4.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 5, 'N': 6, 'τ': 12.74507882561261, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:30,669] Trial 166 pruned.
# [I 2026-08-13 16:33:30,671] Trial 167 pruned.
# [I 2026-08-13 16:33:30,723] Trial 168 finished with value: 1.6353085057993577 and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 1, 'N': 6, 'τ': 24.599014916626825, 'mode': 1, 'act': 1, 'mO': 10}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:30,726] Trial 169 pruned.
# [I 2026-08-13 16:33:30,729] Trial 170 pruned.
# [I 2026-08-13 16:33:30,733] Trial 171 pruned.
# [I 2026-08-13 16:33:30,735] Trial 172 pruned.
# [I 2026-08-13 16:33:30,739] Trial 173 pruned.
# [I 2026-08-13 16:33:30,742] Trial 174 pruned.
# [I 2026-08-13 16:33:30,745] Trial 175 pruned.
# [I 2026-08-13 16:33:30,747] Trial 176 pruned.
# [I 2026-08-13 16:33:30,751] Trial 177 pruned.
# [I 2026-08-13 16:33:30,754] Trial 178 pruned.
# [I 2026-08-13 16:33:30,756] Trial 179 pruned.
# [I 2026-08-13 16:33:30,760] Trial 180 pruned.
# [I 2026-08-13 16:33:30,763] Trial 181 pruned.
# [I 2026-08-13 16:33:30,766] Trial 182 pruned.
# [I 2026-08-13 16:33:30,769] Trial 183 pruned.
# [I 2026-08-13 16:33:30,772] Trial 184 pruned.
# [I 2026-08-13 16:33:30,774] Trial 185 pruned.
# [I 2026-08-13 16:33:30,777] Trial 186 pruned.
# [I 2026-08-13 16:33:30,779] Trial 187 pruned.
# [I 2026-08-13 16:33:30,782] Trial 188 pruned.
# [I 2026-08-13 16:33:30,784] Trial 189 pruned.
# [I 2026-08-13 16:33:30,788] Trial 190 pruned.
# [I 2026-08-13 16:33:30,790] Trial 191 pruned.
# [I 2026-08-13 16:33:30,793] Trial 192 pruned.
# [I 2026-08-13 16:33:30,819] Trial 193 finished with value: 1.8500315820249456 and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 9, 'nO': 12, 'N': 3, 'τ': 4.2522048064104645, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:30,821] Trial 194 pruned.
# [I 2026-08-13 16:33:30,823] Trial 195 pruned.
# [I 2026-08-13 16:33:30,827] Trial 196 pruned.
# [I 2026-08-13 16:33:30,831] Trial 197 pruned.
# [I 2026-08-13 16:33:30,834] Trial 198 pruned.
# [I 2026-08-13 16:33:30,836] Trial 199 pruned.
# [I 2026-08-13 16:33:30,839] Trial 200 pruned.
# [I 2026-08-13 16:33:30,842] Trial 201 pruned.
# [I 2026-08-13 16:33:30,844] Trial 202 pruned.
# [I 2026-08-13 16:33:30,847] Trial 203 pruned.
# [I 2026-08-13 16:33:30,849] Trial 204 pruned.
# [I 2026-08-13 16:33:30,852] Trial 205 pruned.
# [I 2026-08-13 16:33:30,854] Trial 206 pruned.
# [I 2026-08-13 16:33:30,858] Trial 207 pruned.
# [I 2026-08-13 16:33:30,862] Trial 208 pruned.
# [I 2026-08-13 16:33:30,865] Trial 209 pruned.
# [I 2026-08-13 16:33:30,868] Trial 210 pruned.
# [I 2026-08-13 16:33:30,871] Trial 211 pruned.
# [I 2026-08-13 16:33:30,873] Trial 212 pruned.
# [I 2026-08-13 16:33:30,876] Trial 213 pruned.
# [I 2026-08-13 16:33:30,879] Trial 214 pruned.
# [I 2026-08-13 16:33:30,882] Trial 215 pruned.
# [I 2026-08-13 16:33:30,885] Trial 216 pruned.
# [I 2026-08-13 16:33:30,888] Trial 217 pruned.
# [I 2026-08-13 16:33:30,891] Trial 218 pruned.
# [I 2026-08-13 16:33:30,894] Trial 219 pruned.
# [I 2026-08-13 16:33:30,898] Trial 220 pruned.
# [I 2026-08-13 16:33:30,901] Trial 221 pruned.
# [I 2026-08-13 16:33:30,905] Trial 222 pruned.
# [I 2026-08-13 16:33:30,909] Trial 223 pruned.
# [I 2026-08-13 16:33:30,912] Trial 224 pruned.
# [I 2026-08-13 16:33:30,916] Trial 225 pruned.
# [I 2026-08-13 16:33:30,919] Trial 226 pruned.
# [I 2026-08-13 16:33:30,922] Trial 227 pruned.
# [I 2026-08-13 16:33:30,926] Trial 228 pruned.
# [I 2026-08-13 16:33:30,931] Trial 229 pruned.
# [I 2026-08-13 16:33:30,934] Trial 230 pruned.
# [I 2026-08-13 16:33:30,936] Trial 231 pruned.
# [I 2026-08-13 16:33:30,939] Trial 232 pruned.
# [I 2026-08-13 16:33:30,941] Trial 233 pruned.
# [I 2026-08-13 16:33:30,944] Trial 234 pruned.
# [I 2026-08-13 16:33:30,946] Trial 235 pruned.
# [I 2026-08-13 16:33:30,949] Trial 236 pruned.
# [I 2026-08-13 16:33:30,953] Trial 237 pruned.
# [I 2026-08-13 16:33:30,958] Trial 238 pruned.
# [I 2026-08-13 16:33:30,961] Trial 239 pruned.
# [I 2026-08-13 16:33:30,963] Trial 240 pruned.
# [I 2026-08-13 16:33:30,966] Trial 241 pruned.
# [I 2026-08-13 16:33:30,970] Trial 242 pruned.
# [I 2026-08-13 16:33:31,293] Trial 243 finished with value: 2.903116679388008 and parameters: {'m': 4.0, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 12, 'N': 8, 'τ': 13.382335194923272, 'mode': 1, 'act': 0, 'mO': 10}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:31,296] Trial 244 pruned.
# [I 2026-08-13 16:33:31,298] Trial 245 pruned.
# [I 2026-08-13 16:33:31,300] Trial 246 pruned.
# [I 2026-08-13 16:33:31,302] Trial 247 pruned.
# [I 2026-08-13 16:33:31,306] Trial 248 pruned.
# [I 2026-08-13 16:33:31,308] Trial 249 pruned.
# [I 2026-08-13 16:33:31,311] Trial 250 pruned.
# [I 2026-08-13 16:33:31,314] Trial 251 pruned.
# [I 2026-08-13 16:33:31,735] Trial 252 finished with value: 2.269362253765917 and parameters: {'m': 2.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 18, 'N': 4, 'τ': 7.6558286722714195, 'mode': 1, 'act': 1, 'mO': 9}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:31,738] Trial 253 pruned.
# [I 2026-08-13 16:33:31,741] Trial 254 pruned.
# [I 2026-08-13 16:33:31,744] Trial 255 pruned.
# [I 2026-08-13 16:33:31,746] Trial 256 pruned.
# [I 2026-08-13 16:33:31,749] Trial 257 pruned.
# [I 2026-08-13 16:33:31,751] Trial 258 pruned.
# [I 2026-08-13 16:33:31,754] Trial 259 pruned.
# [I 2026-08-13 16:33:31,757] Trial 260 pruned.
# [I 2026-08-13 16:33:31,760] Trial 261 pruned.
# [I 2026-08-13 16:33:31,764] Trial 262 pruned.
# [I 2026-08-13 16:33:31,767] Trial 263 pruned.
# [I 2026-08-13 16:33:31,770] Trial 264 pruned.
# [I 2026-08-13 16:33:31,773] Trial 265 pruned.
# [I 2026-08-13 16:33:31,775] Trial 266 pruned.
# [I 2026-08-13 16:33:31,778] Trial 267 pruned.
# [I 2026-08-13 16:33:31,781] Trial 268 pruned.
# [I 2026-08-13 16:33:31,785] Trial 269 pruned.
# [I 2026-08-13 16:33:31,789] Trial 270 pruned.
# [I 2026-08-13 16:33:31,793] Trial 271 pruned.
# [I 2026-08-13 16:33:31,797] Trial 272 pruned.
# [I 2026-08-13 16:33:31,801] Trial 273 pruned.
# [I 2026-08-13 16:33:31,804] Trial 274 pruned.
# [I 2026-08-13 16:33:31,807] Trial 275 pruned.
# [I 2026-08-13 16:33:31,810] Trial 276 pruned.
# [I 2026-08-13 16:33:31,814] Trial 277 pruned.
# [I 2026-08-13 16:33:31,817] Trial 278 pruned.
# [I 2026-08-13 16:33:31,821] Trial 279 pruned.
# [I 2026-08-13 16:33:31,824] Trial 280 pruned.
# [I 2026-08-13 16:33:31,827] Trial 281 pruned.
# [I 2026-08-13 16:33:31,830] Trial 282 pruned.
# [I 2026-08-13 16:33:31,858] Trial 283 finished with value: 2.2705752820635543 and parameters: {'m': 4.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 11, 'nO': 17, 'N': 9, 'τ': 19.726051859839888, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:31,862] Trial 284 pruned.
# [I 2026-08-13 16:33:31,866] Trial 285 pruned.
# [I 2026-08-13 16:33:31,869] Trial 286 pruned.
# [I 2026-08-13 16:33:31,872] Trial 287 pruned.
# [I 2026-08-13 16:33:31,876] Trial 288 pruned.
# [I 2026-08-13 16:33:31,880] Trial 289 pruned.
# [I 2026-08-13 16:33:31,884] Trial 290 pruned.
# [I 2026-08-13 16:33:31,887] Trial 291 pruned.
# [I 2026-08-13 16:33:31,889] Trial 292 pruned.
# [I 2026-08-13 16:33:31,892] Trial 293 pruned.
# [I 2026-08-13 16:33:31,895] Trial 294 pruned.
# [I 2026-08-13 16:33:31,898] Trial 295 pruned.
# [I 2026-08-13 16:33:31,900] Trial 296 pruned.
# [I 2026-08-13 16:33:31,903] Trial 297 pruned.
# [I 2026-08-13 16:33:31,906] Trial 298 pruned.
# [I 2026-08-13 16:33:31,909] Trial 299 pruned.
# [I 2026-08-13 16:33:31,911] Trial 300 pruned.
# [I 2026-08-13 16:33:31,914] Trial 301 pruned.
# [I 2026-08-13 16:33:31,917] Trial 302 pruned.
# [I 2026-08-13 16:33:31,921] Trial 303 pruned.
# [I 2026-08-13 16:33:31,925] Trial 304 pruned.
# [I 2026-08-13 16:33:31,928] Trial 305 pruned.
# [I 2026-08-13 16:33:31,931] Trial 306 pruned.
# [I 2026-08-13 16:33:31,934] Trial 307 pruned.
# [I 2026-08-13 16:33:31,937] Trial 308 pruned.
# [I 2026-08-13 16:33:31,941] Trial 309 pruned.
# [I 2026-08-13 16:33:31,945] Trial 310 pruned.
# [I 2026-08-13 16:33:31,950] Trial 311 pruned.
# [I 2026-08-13 16:33:31,953] Trial 312 pruned.
# [I 2026-08-13 16:33:31,957] Trial 313 pruned.
# [I 2026-08-13 16:33:31,961] Trial 314 pruned.
# [I 2026-08-13 16:33:31,965] Trial 315 pruned.
# [I 2026-08-13 16:33:31,969] Trial 316 pruned.
# [I 2026-08-13 16:33:31,973] Trial 317 pruned.
# [I 2026-08-13 16:33:31,975] Trial 318 pruned.
# [I 2026-08-13 16:33:31,980] Trial 319 pruned.
# [I 2026-08-13 16:33:31,984] Trial 320 pruned.
# [I 2026-08-13 16:33:31,987] Trial 321 pruned.
# [I 2026-08-13 16:33:31,991] Trial 322 pruned.
# [I 2026-08-13 16:33:31,994] Trial 323 pruned.
# [I 2026-08-13 16:33:31,997] Trial 324 pruned.
# [I 2026-08-13 16:33:32,001] Trial 325 pruned.
# [I 2026-08-13 16:33:32,004] Trial 326 pruned.
# [I 2026-08-13 16:33:32,007] Trial 327 pruned.
# [I 2026-08-13 16:33:32,010] Trial 328 pruned.
# [I 2026-08-13 16:33:32,015] Trial 329 pruned.
# [I 2026-08-13 16:33:32,018] Trial 330 pruned.
# [I 2026-08-13 16:33:32,021] Trial 331 pruned.
# [I 2026-08-13 16:33:32,026] Trial 332 pruned.
# [I 2026-08-13 16:33:32,030] Trial 333 pruned.
# [I 2026-08-13 16:33:32,034] Trial 334 pruned.
# [I 2026-08-13 16:33:32,037] Trial 335 pruned.
# [I 2026-08-13 16:33:32,042] Trial 336 pruned.
# [I 2026-08-13 16:33:32,045] Trial 337 pruned.
# [I 2026-08-13 16:33:32,049] Trial 338 pruned.
# [I 2026-08-13 16:33:32,053] Trial 339 pruned.
# [I 2026-08-13 16:33:32,058] Trial 340 pruned.
# [I 2026-08-13 16:33:32,060] Trial 341 pruned.
# [I 2026-08-13 16:33:32,065] Trial 342 pruned.
# [I 2026-08-13 16:33:32,069] Trial 343 pruned.
# [I 2026-08-13 16:33:32,073] Trial 344 pruned.
# [I 2026-08-13 16:33:32,076] Trial 345 pruned.
# [I 2026-08-13 16:33:32,105] Trial 346 finished with value: 2.524828176141927 and parameters: {'m': 4.0, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 9, 'N': 8, 'τ': 20.746809502176433, 'mode': 1, 'act': 0, 'mO': 5}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:32,109] Trial 347 pruned.
# [I 2026-08-13 16:33:32,112] Trial 348 pruned.
# [I 2026-08-13 16:33:32,115] Trial 349 pruned.
# [I 2026-08-13 16:33:32,119] Trial 350 pruned.
# [I 2026-08-13 16:33:32,122] Trial 351 pruned.
# [I 2026-08-13 16:33:32,125] Trial 352 pruned.
# [I 2026-08-13 16:33:32,129] Trial 353 pruned.
# [I 2026-08-13 16:33:32,132] Trial 354 pruned.
# [I 2026-08-13 16:33:32,135] Trial 355 pruned.
# [I 2026-08-13 16:33:32,139] Trial 356 pruned.
# [I 2026-08-13 16:33:32,143] Trial 357 pruned.
# [I 2026-08-13 16:33:32,146] Trial 358 pruned.
# [I 2026-08-13 16:33:32,149] Trial 359 pruned.
# [I 2026-08-13 16:33:32,154] Trial 360 pruned.
# [I 2026-08-13 16:33:32,159] Trial 361 pruned.
# [I 2026-08-13 16:33:32,163] Trial 362 pruned.
# [I 2026-08-13 16:33:32,167] Trial 363 pruned.
# [I 2026-08-13 16:33:32,171] Trial 364 pruned.
# [I 2026-08-13 16:33:32,174] Trial 365 pruned.
# [I 2026-08-13 16:33:32,178] Trial 366 pruned.
# [I 2026-08-13 16:33:32,182] Trial 367 pruned.
# [I 2026-08-13 16:33:32,186] Trial 368 pruned.
# [I 2026-08-13 16:33:32,190] Trial 369 pruned.
# [I 2026-08-13 16:33:32,193] Trial 370 pruned.
# [I 2026-08-13 16:33:32,228] Trial 371 finished with value: 1.6455634573033624 and parameters: {'m': 4.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 15, 'nO': 10, 'N': 6, 'τ': 21.59240176020463, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:32,232] Trial 372 pruned.
# [I 2026-08-13 16:33:32,235] Trial 373 pruned.
# [I 2026-08-13 16:33:32,240] Trial 374 pruned.
# [I 2026-08-13 16:33:32,244] Trial 375 pruned.
# [I 2026-08-13 16:33:32,247] Trial 376 pruned.
# [I 2026-08-13 16:33:32,251] Trial 377 pruned.
# [I 2026-08-13 16:33:32,256] Trial 378 pruned.
# [I 2026-08-13 16:33:32,260] Trial 379 pruned.
# [I 2026-08-13 16:33:32,265] Trial 380 pruned.
# [I 2026-08-13 16:33:32,269] Trial 381 pruned.
# [I 2026-08-13 16:33:32,273] Trial 382 pruned.
# [I 2026-08-13 16:33:32,276] Trial 383 pruned.
# [I 2026-08-13 16:33:32,279] Trial 384 pruned.
# [I 2026-08-13 16:33:32,282] Trial 385 pruned.
# [I 2026-08-13 16:33:32,285] Trial 386 pruned.
# [I 2026-08-13 16:33:32,289] Trial 387 pruned.
# [I 2026-08-13 16:33:32,292] Trial 388 pruned.
# [I 2026-08-13 16:33:32,297] Trial 389 pruned.
# [I 2026-08-13 16:33:32,303] Trial 390 pruned.
# [I 2026-08-13 16:33:32,307] Trial 391 pruned.
# [I 2026-08-13 16:33:32,312] Trial 392 pruned.
# [I 2026-08-13 16:33:32,317] Trial 393 pruned.
# [I 2026-08-13 16:33:32,322] Trial 394 pruned.
# [I 2026-08-13 16:33:32,643] Trial 395 finished with value: 4.385477638797598 and parameters: {'m': 3.0, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 13, 'nO': 20, 'N': 1, 'τ': 5.149225308240579, 'mode': 1, 'act': 0, 'mO': 1}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:32,647] Trial 396 pruned.
# [I 2026-08-13 16:33:32,651] Trial 397 pruned.
# [I 2026-08-13 16:33:32,653] Trial 398 pruned.
# [I 2026-08-13 16:33:32,657] Trial 399 pruned.
# [I 2026-08-13 16:33:32,660] Trial 400 pruned.
# [I 2026-08-13 16:33:32,662] Trial 401 pruned.
# [I 2026-08-13 16:33:32,666] Trial 402 pruned.
# [I 2026-08-13 16:33:32,670] Trial 403 pruned.
# [I 2026-08-13 16:33:32,674] Trial 404 pruned.
# [I 2026-08-13 16:33:32,677] Trial 405 pruned.
# [I 2026-08-13 16:33:32,680] Trial 406 pruned.
# [I 2026-08-13 16:33:32,683] Trial 407 pruned.
# [I 2026-08-13 16:33:32,686] Trial 408 pruned.
# [I 2026-08-13 16:33:32,689] Trial 409 pruned.
# [I 2026-08-13 16:33:32,692] Trial 410 pruned.
# [I 2026-08-13 16:33:32,695] Trial 411 pruned.
# [I 2026-08-13 16:33:32,698] Trial 412 pruned.
# [I 2026-08-13 16:33:32,702] Trial 413 pruned.
# [I 2026-08-13 16:33:32,727] Trial 414 finished with value: 1.948851343473204 and parameters: {'m': 4.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 19, 'N': 7, 'τ': 10.333695288585083, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:32,731] Trial 415 pruned.
# [I 2026-08-13 16:33:32,735] Trial 416 pruned.
# [I 2026-08-13 16:33:32,739] Trial 417 pruned.
# [I 2026-08-13 16:33:32,742] Trial 418 pruned.
# [I 2026-08-13 16:33:32,747] Trial 419 pruned.
# [I 2026-08-13 16:33:32,751] Trial 420 pruned.
# [I 2026-08-13 16:33:32,755] Trial 421 pruned.
# [I 2026-08-13 16:33:32,759] Trial 422 pruned.
# [I 2026-08-13 16:33:32,765] Trial 423 pruned.
# [I 2026-08-13 16:33:32,769] Trial 424 pruned.
# [I 2026-08-13 16:33:32,772] Trial 425 pruned.
# [I 2026-08-13 16:33:32,777] Trial 426 pruned.
# [I 2026-08-13 16:33:32,782] Trial 427 pruned.
# [I 2026-08-13 16:33:32,786] Trial 428 pruned.
# [I 2026-08-13 16:33:32,790] Trial 429 pruned.
# [I 2026-08-13 16:33:32,794] Trial 430 pruned.
# [I 2026-08-13 16:33:32,797] Trial 431 pruned.
# [I 2026-08-13 16:33:32,800] Trial 432 pruned.
# [I 2026-08-13 16:33:32,803] Trial 433 pruned.
# [I 2026-08-13 16:33:32,806] Trial 434 pruned.
# [I 2026-08-13 16:33:32,809] Trial 435 pruned.
# [I 2026-08-13 16:33:32,812] Trial 436 pruned.
# [I 2026-08-13 16:33:32,815] Trial 437 pruned.
# [I 2026-08-13 16:33:32,818] Trial 438 pruned.
# [I 2026-08-13 16:33:32,825] Trial 439 pruned.
# [I 2026-08-13 16:33:32,853] Trial 440 finished with value: 2.3386141149740203 and parameters: {'m': 3.75, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 22, 'nO': 8, 'N': 8, 'τ': 15.534149529782223, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:32,857] Trial 441 pruned.
# [I 2026-08-13 16:33:32,860] Trial 442 pruned.
# [I 2026-08-13 16:33:32,864] Trial 443 pruned.
# [I 2026-08-13 16:33:32,868] Trial 444 pruned.
# [I 2026-08-13 16:33:32,871] Trial 445 pruned.
# [I 2026-08-13 16:33:32,875] Trial 446 pruned.
# [I 2026-08-13 16:33:32,878] Trial 447 pruned.
# [I 2026-08-13 16:33:32,881] Trial 448 pruned.
# [I 2026-08-13 16:33:32,885] Trial 449 pruned.
# [I 2026-08-13 16:33:32,889] Trial 450 pruned.
# [I 2026-08-13 16:33:32,893] Trial 451 pruned.
# [I 2026-08-13 16:33:32,896] Trial 452 pruned.
# [I 2026-08-13 16:33:32,899] Trial 453 pruned.
# [I 2026-08-13 16:33:32,904] Trial 454 pruned.
# [I 2026-08-13 16:33:32,907] Trial 455 pruned.
# [I 2026-08-13 16:33:32,911] Trial 456 pruned.
# [I 2026-08-13 16:33:32,915] Trial 457 pruned.
# [I 2026-08-13 16:33:32,919] Trial 458 pruned.
# [I 2026-08-13 16:33:32,923] Trial 459 pruned.
# [I 2026-08-13 16:33:32,926] Trial 460 pruned.
# [I 2026-08-13 16:33:32,929] Trial 461 pruned.
# [I 2026-08-13 16:33:32,932] Trial 462 pruned.
# [I 2026-08-13 16:33:32,936] Trial 463 pruned.
# [I 2026-08-13 16:33:32,940] Trial 464 pruned.
# [I 2026-08-13 16:33:32,944] Trial 465 pruned.
# [I 2026-08-13 16:33:32,948] Trial 466 pruned.
# [I 2026-08-13 16:33:32,952] Trial 467 pruned.
# [I 2026-08-13 16:33:32,956] Trial 468 pruned.
# [I 2026-08-13 16:33:32,959] Trial 469 pruned.
# [I 2026-08-13 16:33:32,962] Trial 470 pruned.
# [I 2026-08-13 16:33:33,003] Trial 471 finished with value: 2.1598116463051293 and parameters: {'m': 2.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 58, 'nO': 12, 'N': 4, 'τ': 17.605882613650866, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:33,006] Trial 472 pruned.
# [I 2026-08-13 16:33:33,009] Trial 473 pruned.
# [I 2026-08-13 16:33:33,013] Trial 474 pruned.
# [I 2026-08-13 16:33:33,018] Trial 475 pruned.
# [I 2026-08-13 16:33:33,021] Trial 476 pruned.
# [I 2026-08-13 16:33:33,027] Trial 477 pruned.
# [I 2026-08-13 16:33:33,032] Trial 478 pruned.
# [I 2026-08-13 16:33:33,460] Trial 479 finished with value: 3.767120695626715 and parameters: {'m': 3.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 22, 'nO': 1, 'N': 4, 'τ': 14.191332870375483, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:33,464] Trial 480 pruned.
# [I 2026-08-13 16:33:33,468] Trial 481 pruned.
# [I 2026-08-13 16:33:33,472] Trial 482 pruned.
# [I 2026-08-13 16:33:33,520] Trial 483 finished with value: 1.628983751670463 and parameters: {'m': 4.0, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 14, 'nO': 10, 'N': 7, 'τ': 16.93131540334699, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:33,525] Trial 484 pruned.
# [I 2026-08-13 16:33:33,923] Trial 485 finished with value: 2.80966855265033 and parameters: {'m': 3.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 3, 'nO': 5, 'N': 2, 'τ': 4.8349004145026635, 'mode': 1, 'act': 0, 'mO': 10}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:33,927] Trial 486 pruned.
# [I 2026-08-13 16:33:33,933] Trial 487 pruned.
# [I 2026-08-13 16:33:33,936] Trial 488 pruned.
# [I 2026-08-13 16:33:33,940] Trial 489 pruned.
# [I 2026-08-13 16:33:33,944] Trial 490 pruned.
# [I 2026-08-13 16:33:33,947] Trial 491 pruned.
# [I 2026-08-13 16:33:33,978] Trial 492 finished with value: 2.0189403936244545 and parameters: {'m': 2.25, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 3, 'nO': 2, 'N': 8, 'τ': 4.262909869983541, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:33,982] Trial 493 pruned.
# [I 2026-08-13 16:33:33,987] Trial 494 pruned.
# [I 2026-08-13 16:33:33,991] Trial 495 pruned.
# [I 2026-08-13 16:33:33,996] Trial 496 pruned.
# [I 2026-08-13 16:33:34,000] Trial 497 pruned.
# [I 2026-08-13 16:33:34,005] Trial 498 pruned.
# [I 2026-08-13 16:33:34,010] Trial 499 pruned.
# [I 2026-08-13 16:33:34,015] Trial 500 pruned.
# [I 2026-08-13 16:33:34,020] Trial 501 pruned.
# [I 2026-08-13 16:33:34,025] Trial 502 pruned.
# [I 2026-08-13 16:33:34,029] Trial 503 pruned.
# [I 2026-08-13 16:33:34,035] Trial 504 pruned.
# [I 2026-08-13 16:33:34,040] Trial 505 pruned.
# [I 2026-08-13 16:33:34,045] Trial 506 pruned.
# [I 2026-08-13 16:33:34,049] Trial 507 pruned.
# [I 2026-08-13 16:33:34,088] Trial 508 finished with value: 1.9034035584031266 and parameters: {'m': 2.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 8, 'N': 5, 'τ': 20.962682701869078, 'mode': 1, 'act': 1, 'mO': 15}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:34,093] Trial 509 pruned.
# [I 2026-08-13 16:33:34,097] Trial 510 pruned.
# [I 2026-08-13 16:33:34,101] Trial 511 pruned.
# [I 2026-08-13 16:33:34,106] Trial 512 pruned.
# [I 2026-08-13 16:33:34,110] Trial 513 pruned.
# [I 2026-08-13 16:33:34,113] Trial 514 pruned.
# [I 2026-08-13 16:33:34,118] Trial 515 pruned.
# [I 2026-08-13 16:33:34,123] Trial 516 pruned.
# [I 2026-08-13 16:33:34,127] Trial 517 pruned.
# [I 2026-08-13 16:33:34,131] Trial 518 pruned.
# [I 2026-08-13 16:33:34,135] Trial 519 pruned.
# [I 2026-08-13 16:33:34,139] Trial 520 pruned.
# [I 2026-08-13 16:33:34,143] Trial 521 pruned.
# [I 2026-08-13 16:33:34,189] Trial 522 finished with value: 1.8321238902831083 and parameters: {'m': 2.5, 'nI': 2, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 18, 'N': 3, 'τ': 6.129943619780009, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:34,193] Trial 523 pruned.
# [I 2026-08-13 16:33:34,197] Trial 524 pruned.
# [I 2026-08-13 16:33:34,201] Trial 525 pruned.
# [I 2026-08-13 16:33:34,205] Trial 526 pruned.
# [I 2026-08-13 16:33:34,208] Trial 527 pruned.
# [I 2026-08-13 16:33:34,212] Trial 528 pruned.
# [I 2026-08-13 16:33:34,217] Trial 529 pruned.
# [I 2026-08-13 16:33:34,221] Trial 530 pruned.
# [I 2026-08-13 16:33:34,225] Trial 531 pruned.
# [I 2026-08-13 16:33:34,228] Trial 532 pruned.
# [I 2026-08-13 16:33:34,232] Trial 533 pruned.
# [I 2026-08-13 16:33:34,237] Trial 534 pruned.
# [I 2026-08-13 16:33:34,240] Trial 535 pruned.
# [I 2026-08-13 16:33:34,244] Trial 536 pruned.
# [I 2026-08-13 16:33:34,248] Trial 537 pruned.
# [I 2026-08-13 16:33:34,458] Trial 538 finished with value: 69.53819606466539 and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 31, 'nO': 15, 'N': 2, 'τ': 9.364123811055226, 'mode': 1, 'act': 0, 'mO': 12}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:34,462] Trial 539 pruned.
# [I 2026-08-13 16:33:34,466] Trial 540 pruned.
# [I 2026-08-13 16:33:34,470] Trial 541 pruned.
# [I 2026-08-13 16:33:34,475] Trial 542 pruned.
# [I 2026-08-13 16:33:34,481] Trial 543 pruned.
# [I 2026-08-13 16:33:34,524] Trial 544 finished with value: 2.5278321530309302 and parameters: {'m': 3.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 17, 'N': 3, 'τ': 5.657771857569859, 'mode': 1, 'act': 0, 'mO': 11}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:34,528] Trial 545 pruned.
# [I 2026-08-13 16:33:34,531] Trial 546 pruned.
# [I 2026-08-13 16:33:34,535] Trial 547 pruned.
# [I 2026-08-13 16:33:34,539] Trial 548 pruned.
# [I 2026-08-13 16:33:34,543] Trial 549 pruned.
# [I 2026-08-13 16:33:34,546] Trial 550 pruned.
# [I 2026-08-13 16:33:34,549] Trial 551 pruned.
# [I 2026-08-13 16:33:34,556] Trial 552 pruned.
# [I 2026-08-13 16:33:34,560] Trial 553 pruned.
# [I 2026-08-13 16:33:34,565] Trial 554 pruned.
# [I 2026-08-13 16:33:34,572] Trial 555 pruned.
# [I 2026-08-13 16:33:34,578] Trial 556 pruned.
# [I 2026-08-13 16:33:34,584] Trial 557 pruned.
# [I 2026-08-13 16:33:34,589] Trial 558 pruned.
# [I 2026-08-13 16:33:34,594] Trial 559 pruned.
# [I 2026-08-13 16:33:34,597] Trial 560 pruned.
# [I 2026-08-13 16:33:34,602] Trial 561 pruned.
# [I 2026-08-13 16:33:34,607] Trial 562 pruned.
# [I 2026-08-13 16:33:34,612] Trial 563 pruned.
# [I 2026-08-13 16:33:34,619] Trial 564 pruned.
# [I 2026-08-13 16:33:34,625] Trial 565 pruned.
# [I 2026-08-13 16:33:34,631] Trial 566 pruned.
# [I 2026-08-13 16:33:34,637] Trial 567 pruned.
# [I 2026-08-13 16:33:34,642] Trial 568 pruned.
# [I 2026-08-13 16:33:34,648] Trial 569 pruned.
# [I 2026-08-13 16:33:34,653] Trial 570 pruned.
# [I 2026-08-13 16:33:34,659] Trial 571 pruned.
# [I 2026-08-13 16:33:34,665] Trial 572 pruned.
# [I 2026-08-13 16:33:34,671] Trial 573 pruned.
# [I 2026-08-13 16:33:34,676] Trial 574 pruned.
# [I 2026-08-13 16:33:34,683] Trial 575 pruned.
# [I 2026-08-13 16:33:34,687] Trial 576 pruned.
# [I 2026-08-13 16:33:34,691] Trial 577 pruned.
# [I 2026-08-13 16:33:34,697] Trial 578 pruned.
# [I 2026-08-13 16:33:34,702] Trial 579 pruned.
# [I 2026-08-13 16:33:34,708] Trial 580 pruned.
# [I 2026-08-13 16:33:34,713] Trial 581 pruned.
# [I 2026-08-13 16:33:34,719] Trial 582 pruned.
# [I 2026-08-13 16:33:34,933] Trial 583 finished with value: 3.291364657534815 and parameters: {'m': 3.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 5, 'nO': 2, 'N': 3, 'τ': 7.185216321701474, 'mode': 1, 'act': 0, 'mO': 11}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:34,937] Trial 584 pruned.
# [I 2026-08-13 16:33:34,941] Trial 585 pruned.
# [I 2026-08-13 16:33:34,947] Trial 586 pruned.
# [I 2026-08-13 16:33:34,953] Trial 587 pruned.
# [I 2026-08-13 16:33:34,957] Trial 588 pruned.
# [I 2026-08-13 16:33:34,961] Trial 589 pruned.
# [I 2026-08-13 16:33:34,964] Trial 590 pruned.
# [I 2026-08-13 16:33:34,968] Trial 591 pruned.
# [I 2026-08-13 16:33:34,972] Trial 592 pruned.
# [I 2026-08-13 16:33:34,976] Trial 593 pruned.
# [I 2026-08-13 16:33:34,980] Trial 594 pruned.
# [I 2026-08-13 16:33:34,985] Trial 595 pruned.
# [I 2026-08-13 16:33:34,989] Trial 596 pruned.
# [I 2026-08-13 16:33:34,993] Trial 597 pruned.
# [I 2026-08-13 16:33:34,996] Trial 598 pruned.
# [I 2026-08-13 16:33:35,082] Trial 599 finished with value: 0.8824215679504401 and parameters: {'m': 2.75, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 54, 'nO': 4, 'N': 5, 'τ': 8.303265980496725, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:35,087] Trial 600 pruned.
# [I 2026-08-13 16:33:35,093] Trial 601 pruned.
# [I 2026-08-13 16:33:35,191] Trial 602 finished with value: 0.9911247422010114 and parameters: {'m': 2.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 9, 'nO': 5, 'N': 9, 'τ': 7.539551571832768, 'mode': 1, 'act': 0, 'mO': 12}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:35,195] Trial 603 pruned.
# [I 2026-08-13 16:33:35,199] Trial 604 pruned.
# [I 2026-08-13 16:33:35,233] Trial 605 finished with value: 1.5661466736154495 and parameters: {'m': 2.75, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 18, 'nO': 15, 'N': 8, 'τ': 5.1600991691281175, 'mode': 1, 'act': 0, 'mO': 7}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:35,237] Trial 606 pruned.
# [I 2026-08-13 16:33:35,240] Trial 607 pruned.
# [I 2026-08-13 16:33:35,244] Trial 608 pruned.
# [I 2026-08-13 16:33:35,248] Trial 609 pruned.
# [I 2026-08-13 16:33:35,251] Trial 610 pruned.
# [I 2026-08-13 16:33:35,255] Trial 611 pruned.
# [I 2026-08-13 16:33:35,259] Trial 612 pruned.
# [I 2026-08-13 16:33:35,262] Trial 613 pruned.
# [I 2026-08-13 16:33:35,268] Trial 614 pruned.
# [I 2026-08-13 16:33:35,272] Trial 615 pruned.
# [I 2026-08-13 16:33:35,276] Trial 616 pruned.
# [I 2026-08-13 16:33:35,280] Trial 617 pruned.
# [I 2026-08-13 16:33:35,285] Trial 618 pruned.
# [I 2026-08-13 16:33:35,289] Trial 619 pruned.
# [I 2026-08-13 16:33:35,293] Trial 620 pruned.
# [I 2026-08-13 16:33:35,394] Trial 621 finished with value: 2483.5376020566655 and parameters: {'m': 3.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 16, 'N': 1, 'τ': 24.463965291929703, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:35,398] Trial 622 pruned.
# [I 2026-08-13 16:33:35,402] Trial 623 pruned.
# [I 2026-08-13 16:33:35,406] Trial 624 pruned.
# [I 2026-08-13 16:33:35,410] Trial 625 pruned.
# [I 2026-08-13 16:33:35,414] Trial 626 pruned.
# [I 2026-08-13 16:33:35,419] Trial 627 pruned.
# [I 2026-08-13 16:33:35,425] Trial 628 pruned.
# [I 2026-08-13 16:33:35,430] Trial 629 pruned.
# [I 2026-08-13 16:33:35,435] Trial 630 pruned.
# [I 2026-08-13 16:33:35,439] Trial 631 pruned.
# [I 2026-08-13 16:33:35,442] Trial 632 pruned.
# [I 2026-08-13 16:33:35,446] Trial 633 pruned.
# [I 2026-08-13 16:33:35,451] Trial 634 pruned.
# [I 2026-08-13 16:33:35,455] Trial 635 pruned.
# [I 2026-08-13 16:33:35,459] Trial 636 pruned.
# [I 2026-08-13 16:33:35,463] Trial 637 pruned.
# [I 2026-08-13 16:33:35,467] Trial 638 pruned.
# [I 2026-08-13 16:33:35,471] Trial 639 pruned.
# [I 2026-08-13 16:33:35,475] Trial 640 pruned.
# [I 2026-08-13 16:33:35,479] Trial 641 pruned.
# [I 2026-08-13 16:33:35,484] Trial 642 pruned.
# [I 2026-08-13 16:33:35,488] Trial 643 pruned.
# [I 2026-08-13 16:33:35,492] Trial 644 pruned.
# [I 2026-08-13 16:33:35,496] Trial 645 pruned.
# [I 2026-08-13 16:33:35,501] Trial 646 pruned.
# [I 2026-08-13 16:33:35,505] Trial 647 pruned.
# [I 2026-08-13 16:33:35,510] Trial 648 pruned.
# [I 2026-08-13 16:33:35,518] Trial 649 pruned.
# [I 2026-08-13 16:33:35,524] Trial 650 pruned.
# [I 2026-08-13 16:33:35,529] Trial 651 pruned.
# [I 2026-08-13 16:33:35,535] Trial 652 pruned.
# [I 2026-08-13 16:33:35,542] Trial 653 pruned.
# [I 2026-08-13 16:33:35,546] Trial 654 pruned.
# [I 2026-08-13 16:33:35,550] Trial 655 pruned.
# [I 2026-08-13 16:33:35,553] Trial 656 pruned.
# [I 2026-08-13 16:33:35,557] Trial 657 pruned.
# [I 2026-08-13 16:33:35,560] Trial 658 pruned.
# [I 2026-08-13 16:33:35,565] Trial 659 pruned.
# [I 2026-08-13 16:33:35,569] Trial 660 pruned.
# [I 2026-08-13 16:33:35,573] Trial 661 pruned.
# [I 2026-08-13 16:33:35,576] Trial 662 pruned.
# [I 2026-08-13 16:33:35,580] Trial 663 pruned.
# [I 2026-08-13 16:33:35,585] Trial 664 pruned.
# [I 2026-08-13 16:33:35,589] Trial 665 pruned.
# [I 2026-08-13 16:33:36,095] Trial 666 finished with value: 2.274337017492073 and parameters: {'m': 3.25, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 11, 'N': 3, 'τ': 11.5623344579597, 'mode': 1, 'act': 1, 'mO': 8}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:36,131] Trial 667 finished with value: 2.7745437780513753 and parameters: {'m': 2.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 61, 'nO': 19, 'N': 5, 'τ': 5.846658787737412, 'mode': 1, 'act': 1, 'mO': 17}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:36,137] Trial 668 pruned.
# [I 2026-08-13 16:33:36,140] Trial 669 pruned.
# [I 2026-08-13 16:33:36,537] Trial 670 finished with value: 2.267530709830502 and parameters: {'m': 2.25, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 32, 'nO': 11, 'N': 8, 'τ': 21.26078085921185, 'mode': 1, 'act': 0, 'mO': 5}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:36,543] Trial 671 pruned.
# [I 2026-08-13 16:33:36,547] Trial 672 pruned.
# [I 2026-08-13 16:33:36,551] Trial 673 pruned.
# [I 2026-08-13 16:33:36,555] Trial 674 pruned.
# [I 2026-08-13 16:33:36,892] Trial 675 finished with value: 3.107747947633981 and parameters: {'m': 4.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 14, 'N': 2, 'τ': 20.48240836648052, 'mode': 1, 'act': 0, 'mO': 6}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:36,896] Trial 676 pruned.
# [I 2026-08-13 16:33:37,008] Trial 677 finished with value: 2.5497304900472066 and parameters: {'m': 2.25, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 7, 'N': 5, 'τ': 20.043083992056232, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:37,359] Trial 678 finished with value: 2.9941938325382873 and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 18, 'N': 1, 'τ': 21.276309516464032, 'mode': 1, 'act': 0, 'mO': 8}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:37,364] Trial 679 pruned.
# [I 2026-08-13 16:33:37,370] Trial 680 pruned.
# [I 2026-08-13 16:33:37,375] Trial 681 pruned.
# [I 2026-08-13 16:33:37,380] Trial 682 pruned.
# [I 2026-08-13 16:33:37,384] Trial 683 pruned.
# [I 2026-08-13 16:33:37,388] Trial 684 pruned.
# [I 2026-08-13 16:33:37,392] Trial 685 pruned.
# [I 2026-08-13 16:33:37,396] Trial 686 pruned.
# [I 2026-08-13 16:33:37,402] Trial 687 pruned.
# [I 2026-08-13 16:33:37,407] Trial 688 pruned.
# [I 2026-08-13 16:33:37,414] Trial 689 pruned.
# [I 2026-08-13 16:33:37,418] Trial 690 pruned.
# [I 2026-08-13 16:33:37,423] Trial 691 pruned.
# [I 2026-08-13 16:33:37,428] Trial 692 pruned.
# [I 2026-08-13 16:33:37,432] Trial 693 pruned.
# [I 2026-08-13 16:33:37,436] Trial 694 pruned.
# [I 2026-08-13 16:33:37,440] Trial 695 pruned.
# [I 2026-08-13 16:33:37,446] Trial 696 pruned.
# [I 2026-08-13 16:33:37,452] Trial 697 pruned.
# [I 2026-08-13 16:33:37,457] Trial 698 pruned.
# [I 2026-08-13 16:33:37,462] Trial 699 pruned.
# [I 2026-08-13 16:33:37,468] Trial 700 pruned.
# [I 2026-08-13 16:33:37,472] Trial 701 pruned.
# [I 2026-08-13 16:33:37,476] Trial 702 pruned.
# [I 2026-08-13 16:33:37,481] Trial 703 pruned.
# [I 2026-08-13 16:33:37,672] Trial 704 finished with value: 2.733372903057002 and parameters: {'m': 2.5, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 5, 'nO': 10, 'N': 7, 'τ': 20.892013621141224, 'mode': 1, 'act': 0, 'mO': 1}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:37,676] Trial 705 pruned.
# [I 2026-08-13 16:33:37,680] Trial 706 pruned.
# [I 2026-08-13 16:33:37,705] Trial 707 finished with value: 1.9797238869390943 and parameters: {'m': 2.25, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 10, 'N': 8, 'τ': 19.598951052737533, 'mode': 1, 'act': 0, 'mO': 1}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:37,709] Trial 708 pruned.
# [I 2026-08-13 16:33:37,713] Trial 709 pruned.
# [I 2026-08-13 16:33:37,718] Trial 710 pruned.
# [I 2026-08-13 16:33:37,723] Trial 711 pruned.
# [I 2026-08-13 16:33:37,726] Trial 712 pruned.
# [I 2026-08-13 16:33:37,730] Trial 713 pruned.
# [I 2026-08-13 16:33:37,734] Trial 714 pruned.
# [I 2026-08-13 16:33:37,738] Trial 715 pruned.
# [I 2026-08-13 16:33:37,742] Trial 716 pruned.
# [I 2026-08-13 16:33:38,021] Trial 717 finished with value: 95.78618658573637 and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 10, 'nO': 14, 'N': 1, 'τ': 10.906457364689901, 'mode': 1, 'act': 1, 'mO': 12}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:38,026] Trial 718 pruned.
# [I 2026-08-13 16:33:38,030] Trial 719 pruned.
# [I 2026-08-13 16:33:38,035] Trial 720 pruned.
# [I 2026-08-13 16:33:38,457] Trial 721 finished with value: 2.3315900536283958 and parameters: {'m': 4.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 7, 'N': 1, 'τ': 17.496556646522563, 'mode': 1, 'act': 0, 'mO': 15}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:38,465] Trial 722 pruned.
# [I 2026-08-13 16:33:38,469] Trial 723 pruned.
# [I 2026-08-13 16:33:38,474] Trial 724 pruned.
# [I 2026-08-13 16:33:38,479] Trial 725 pruned.
# [I 2026-08-13 16:33:38,484] Trial 726 pruned.
# [I 2026-08-13 16:33:38,490] Trial 727 pruned.
# [I 2026-08-13 16:33:38,553] Trial 728 finished with value: 2.9789975238187374 and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 8, 'N': 4, 'τ': 5.321529846330128, 'mode': 1, 'act': 0, 'mO': 12}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:38,560] Trial 729 pruned.
# [I 2026-08-13 16:33:38,564] Trial 730 pruned.
# [I 2026-08-13 16:33:38,571] Trial 731 pruned.
# [I 2026-08-13 16:33:38,575] Trial 732 pruned.
# [I 2026-08-13 16:33:38,579] Trial 733 pruned.
# [I 2026-08-13 16:33:38,583] Trial 734 pruned.
# [I 2026-08-13 16:33:38,588] Trial 735 pruned.
# [I 2026-08-13 16:33:38,594] Trial 736 pruned.
# [I 2026-08-13 16:33:38,598] Trial 737 pruned.
# [I 2026-08-13 16:33:38,601] Trial 738 pruned.
# [I 2026-08-13 16:33:38,606] Trial 739 pruned.
# [I 2026-08-13 16:33:38,610] Trial 740 pruned.
# [I 2026-08-13 16:33:38,614] Trial 741 pruned.
# [I 2026-08-13 16:33:38,619] Trial 742 pruned.
# [I 2026-08-13 16:33:38,625] Trial 743 pruned.
# [I 2026-08-13 16:33:38,631] Trial 744 pruned.
# [I 2026-08-13 16:33:38,636] Trial 745 pruned.
# [I 2026-08-13 16:33:38,641] Trial 746 pruned.
# [I 2026-08-13 16:33:38,646] Trial 747 pruned.
# [I 2026-08-13 16:33:38,650] Trial 748 pruned.
# [I 2026-08-13 16:33:38,656] Trial 749 pruned.
# [I 2026-08-13 16:33:38,661] Trial 750 pruned.
# [I 2026-08-13 16:33:38,668] Trial 751 pruned.
# [I 2026-08-13 16:33:38,672] Trial 752 pruned.
# [I 2026-08-13 16:33:38,678] Trial 753 pruned.
# [I 2026-08-13 16:33:38,683] Trial 754 pruned.
# [I 2026-08-13 16:33:38,689] Trial 755 pruned.
# [I 2026-08-13 16:33:38,694] Trial 756 pruned.
# [I 2026-08-13 16:33:38,698] Trial 757 pruned.
# [I 2026-08-13 16:33:38,705] Trial 758 pruned.
# [I 2026-08-13 16:33:38,711] Trial 759 pruned.
# [I 2026-08-13 16:33:38,715] Trial 760 pruned.
# [I 2026-08-13 16:33:38,720] Trial 761 pruned.
# [I 2026-08-13 16:33:38,725] Trial 762 pruned.
# [I 2026-08-13 16:33:38,731] Trial 763 pruned.
# [I 2026-08-13 16:33:38,737] Trial 764 pruned.
# [I 2026-08-13 16:33:38,743] Trial 765 pruned.
# [I 2026-08-13 16:33:38,783] Trial 766 finished with value: 2.666705540022039 and parameters: {'m': 4.25, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 19, 'N': 3, 'τ': 2.8018066442164917, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 133 with value: 0.6770997114590853.
# [I 2026-08-13 16:33:38,789] Trial 767 pruned.
# [I 2026-08-13 16:33:38,795] Trial 768 pruned.
# [I 2026-08-13 16:33:38,799] Trial 769 pruned.
# [I 2026-08-13 16:33:38,803] Trial 770 pruned.
# [I 2026-08-13 16:33:38,810] Trial 771 pruned.
# [I 2026-08-13 16:33:38,817] Trial 772 pruned.
# ...
# [I 2026-08-13 16:35:33,818] Trial 1856 pruned.
# [I 2026-08-13 16:35:33,849] Trial 1857 pruned.
# [I 2026-08-13 16:35:33,887] Trial 1858 pruned.
# [I 2026-08-13 16:35:33,921] Trial 1859 pruned.
# [I 2026-08-13 16:35:33,956] Trial 1860 pruned.
# [I 2026-08-13 16:35:33,983] Trial 1861 pruned.
# [I 2026-08-13 16:35:34,014] Trial 1862 pruned.
# [I 2026-08-13 16:35:34,112] Trial 1863 finished with value: 2.3951190688533703 and parameters: {'m': 4.0, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 58, 'nO': 2, 'N': 7, 'τ': 3.6468200409765776, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:34,171] Trial 1864 finished with value: 1.4497923034842795 and parameters: {'m': 3.75, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 11, 'N': 5, 'τ': 4.584379001083738, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:34,225] Trial 1865 finished with value: 2.3373069977801317 and parameters: {'m': 3.75, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 3, 'N': 6, 'τ': 2.7388045175823974, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:34,285] Trial 1866 finished with value: 2.0162809467969383 and parameters: {'m': 4.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 8, 'N': 4, 'τ': 1.1858517475459434, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:34,842] Trial 1867 finished with value: 3.4852650324752723 and parameters: {'m': 4.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 2, 'N': 6, 'τ': 4.99273402117221, 'mode': 1, 'act': 1, 'mO': 15}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:34,881] Trial 1868 pruned.
# [I 2026-08-13 16:35:34,964] Trial 1869 finished with value: 1.5775233850115167 and parameters: {'m': 3.5, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 58, 'nO': 9, 'N': 4, 'τ': 4.321904640367061, 'mode': 1, 'act': 1, 'mO': 9}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:35,025] Trial 1870 finished with value: 1.7853721990143792 and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 1, 'N': 5, 'τ': 1.0791628173092251, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:35,512] Trial 1871 finished with value: 3.958804032997966 and parameters: {'m': 4.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 32, 'nO': 5, 'N': 4, 'τ': 10.979125341941199, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:35,540] Trial 1872 pruned.
# [I 2026-08-13 16:35:35,612] Trial 1873 finished with value: 2.1987273478642795 and parameters: {'m': 3.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 53, 'nO': 15, 'N': 5, 'τ': 10.825145989333091, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:35,640] Trial 1874 pruned.
# [I 2026-08-13 16:35:35,665] Trial 1875 pruned.
# [I 2026-08-13 16:35:35,698] Trial 1876 pruned.
# [I 2026-08-13 16:35:35,721] Trial 1877 pruned.
# [I 2026-08-13 16:35:35,748] Trial 1878 pruned.
# [I 2026-08-13 16:35:35,776] Trial 1879 pruned.
# [I 2026-08-13 16:35:36,406] Trial 1880 finished with value: 2.892797450563327 and parameters: {'m': 4.5, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 31, 'nO': 4, 'N': 2, 'τ': 2.4668109803555165, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:36,589] Trial 1881 finished with value: 0.3515498152328918 and parameters: {'m': 4.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 13, 'N': 4, 'τ': 7.097263698707389, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:37,119] Trial 1882 finished with value: 2.587893006473173 and parameters: {'m': 3.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 2, 'N': 4, 'τ': 15.334411482383615, 'mode': 1, 'act': 1, 'mO': 12}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:37,190] Trial 1883 finished with value: 2.4002303530921374 and parameters: {'m': 4.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 6, 'N': 5, 'τ': 5.3320083482614615, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:37,219] Trial 1884 pruned.
# [I 2026-08-13 16:35:37,255] Trial 1885 pruned.
# [I 2026-08-13 16:35:37,439] Trial 1886 finished with value: 0.29615082565307044 and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 50, 'nO': 16, 'N': 4, 'τ': 6.216434147392358, 'mode': 1, 'act': 1, 'mO': 13}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:37,520] Trial 1887 finished with value: 2.41286999220529 and parameters: {'m': 4.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 10, 'N': 4, 'τ': 7.415965885325625, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:37,547] Trial 1888 pruned.
# [I 2026-08-13 16:35:37,571] Trial 1889 pruned.
# [I 2026-08-13 16:35:38,177] Trial 1890 finished with value: 2.6712385876102567 and parameters: {'m': 3.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 6, 'N': 9, 'τ': 1.7279747749887295, 'mode': 1, 'act': 1, 'mO': 12}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:38,207] Trial 1891 pruned.
# [I 2026-08-13 16:35:38,571] Trial 1892 finished with value: 1.302781004166177 and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 20, 'N': 3, 'τ': 6.798356226022991, 'mode': 1, 'act': 1, 'mO': 10}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:38,599] Trial 1893 pruned.
# [I 2026-08-13 16:35:38,628] Trial 1894 pruned.
# [I 2026-08-13 16:35:38,653] Trial 1895 pruned.
# [I 2026-08-13 16:35:39,244] Trial 1896 finished with value: 3.3166156528101873 and parameters: {'m': 4.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 3, 'N': 7, 'τ': 4.488092243065731, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:39,795] Trial 1897 finished with value: 3.8796924575449476 and parameters: {'m': 3.75, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 1, 'N': 4, 'τ': 1.920508748597218, 'mode': 1, 'act': 0, 'mO': 11}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:39,818] Trial 1898 pruned.
# [I 2026-08-13 16:35:39,918] Trial 1899 finished with value: 2.480134813056557 and parameters: {'m': 3.75, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 12, 'N': 4, 'τ': 4.358188922307562, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:40,002] Trial 1900 finished with value: 1.709797231719329 and parameters: {'m': 4.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 19, 'N': 5, 'τ': 7.418058695059443, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:40,160] Trial 1901 finished with value: 0.75410786092338 and parameters: {'m': 4.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 12, 'N': 3, 'τ': 8.007374419908972, 'mode': 1, 'act': 1, 'mO': 8}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:40,233] Trial 1902 finished with value: 3.4076308396809947 and parameters: {'m': 4.5, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 9, 'N': 4, 'τ': 6.546528564192251, 'mode': 1, 'act': 1, 'mO': 11}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:40,260] Trial 1903 pruned.
# [I 2026-08-13 16:35:40,749] Trial 1904 finished with value: 2.2151106962553766 and parameters: {'m': 4.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 50, 'nO': 15, 'N': 2, 'τ': 8.323811151578305, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:40,776] Trial 1905 pruned.
# [I 2026-08-13 16:35:40,805] Trial 1906 pruned.
# [I 2026-08-13 16:35:41,474] Trial 1907 finished with value: 4.56255833869519 and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 31, 'nO': 1, 'N': 5, 'τ': 9.376248476399942, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:41,498] Trial 1908 pruned.
# [I 2026-08-13 16:35:41,558] Trial 1909 finished with value: 1.5134277129793126 and parameters: {'m': 4.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 36, 'nO': 9, 'N': 8, 'τ': 20.97443144621289, 'mode': 1, 'act': 0, 'mO': 8}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:41,670] Trial 1910 finished with value: 0.9184334654946946 and parameters: {'m': 4.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 53, 'nO': 11, 'N': 7, 'τ': 1.5246505946638726, 'mode': 1, 'act': 1, 'mO': 9}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:41,701] Trial 1911 pruned.
# [I 2026-08-13 16:35:41,726] Trial 1912 pruned.
# [I 2026-08-13 16:35:41,761] Trial 1913 pruned.
# [I 2026-08-13 16:35:41,801] Trial 1914 pruned.
# [I 2026-08-13 16:35:41,895] Trial 1915 finished with value: 2.50218145645713 and parameters: {'m': 4.25, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 60, 'nO': 10, 'N': 4, 'τ': 11.008394096261306, 'mode': 1, 'act': 1, 'mO': 13}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:41,976] Trial 1916 finished with value: 1.2761536843885943 and parameters: {'m': 3.75, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 13, 'nO': 16, 'N': 9, 'τ': 10.793860410900297, 'mode': 1, 'act': 1, 'mO': 15}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:42,485] Trial 1917 finished with value: 2.1547531045520927 and parameters: {'m': 4.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 14, 'N': 2, 'τ': 17.79644609954826, 'mode': 1, 'act': 1, 'mO': 10}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:42,511] Trial 1918 pruned.
# [I 2026-08-13 16:35:42,575] Trial 1919 finished with value: 1.6684871668950234 and parameters: {'m': 3.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 18, 'N': 4, 'τ': 5.466710432464847, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:42,600] Trial 1920 pruned.
# [I 2026-08-13 16:35:42,626] Trial 1921 pruned.
# [I 2026-08-13 16:35:42,664] Trial 1922 pruned.
# [I 2026-08-13 16:35:42,705] Trial 1923 pruned.
# [I 2026-08-13 16:35:42,781] Trial 1924 finished with value: 3.3344291973324793 and parameters: {'m': 3.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 61, 'nO': 2, 'N': 5, 'τ': 1.4095282269712044, 'mode': 1, 'act': 1, 'mO': 11}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:42,810] Trial 1925 pruned.
# [I 2026-08-13 16:35:42,921] Trial 1926 finished with value: 1.2078681006995258 and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 50, 'nO': 9, 'N': 4, 'τ': 7.082661670835603, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:42,993] Trial 1927 finished with value: 1.82809440887649 and parameters: {'m': 3.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 22, 'nO': 2, 'N': 9, 'τ': 11.497007143470977, 'mode': 1, 'act': 0, 'mO': 10}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:43,022] Trial 1928 pruned.
# [I 2026-08-13 16:35:43,052] Trial 1929 pruned.
# [I 2026-08-13 16:35:43,138] Trial 1930 finished with value: 2.002894107871391 and parameters: {'m': 4.0, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 36, 'nO': 4, 'N': 4, 'τ': 3.226799592379991, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:43,563] Trial 1931 finished with value: 2.4239044443112263 and parameters: {'m': 4.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 9, 'N': 6, 'τ': 20.56826830719723, 'mode': 1, 'act': 1, 'mO': 15}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:43,649] Trial 1932 finished with value: 1.590082309225504 and parameters: {'m': 3.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 16, 'N': 3, 'τ': 4.0161486138135505, 'mode': 1, 'act': 1, 'mO': 11}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:43,744] Trial 1933 finished with value: 2.862935338683717 and parameters: {'m': 4.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 1, 'N': 8, 'τ': 8.05955421217694, 'mode': 1, 'act': 1, 'mO': 14}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:43,776] Trial 1934 pruned.
# [I 2026-08-13 16:35:43,801] Trial 1935 pruned.
# [I 2026-08-13 16:35:43,897] Trial 1936 finished with value: 2.5591016261381956 and parameters: {'m': 4.0, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 6, 'N': 4, 'τ': 8.527268975213758, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:43,924] Trial 1937 pruned.
# [I 2026-08-13 16:35:43,953] Trial 1938 pruned.
# [I 2026-08-13 16:35:44,045] Trial 1939 finished with value: 1.4326064883390817 and parameters: {'m': 3.75, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 31, 'nO': 9, 'N': 5, 'τ': 1.6904287366248836, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:44,070] Trial 1940 pruned.
# [I 2026-08-13 16:35:44,140] Trial 1941 finished with value: 1.829752145464434 and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 7, 'N': 5, 'τ': 7.303614144765407, 'mode': 1, 'act': 1, 'mO': 11}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:44,198] Trial 1942 finished with value: 1.8703292813739247 and parameters: {'m': 4.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 11, 'N': 6, 'τ': 24.42273395058598, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:44,270] Trial 1943 finished with value: 1.279709245657013 and parameters: {'m': 3.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 2, 'N': 4, 'τ': 8.753741705412812, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:44,297] Trial 1944 pruned.
# [I 2026-08-13 16:35:44,327] Trial 1945 pruned.
# [I 2026-08-13 16:35:44,396] Trial 1946 finished with value: 2.348575262964484 and parameters: {'m': 3.75, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 16, 'N': 4, 'τ': 10.106572064366961, 'mode': 1, 'act': 1, 'mO': 9}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:44,523] Trial 1947 finished with value: 1.2862172481245115 and parameters: {'m': 3.75, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 6, 'N': 4, 'τ': 11.903268378647232, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:44,646] Trial 1948 finished with value: 1.0482333349486241 and parameters: {'m': 4.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 50, 'nO': 11, 'N': 5, 'τ': 4.668350767496767, 'mode': 1, 'act': 1, 'mO': 13}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:45,042] Trial 1949 finished with value: 2.5568534427688454 and parameters: {'m': 4.5, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 14, 'N': 3, 'τ': 14.996139876287092, 'mode': 1, 'act': 1, 'mO': 13}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:45,112] Trial 1950 finished with value: 1.4502889545393278 and parameters: {'m': 4.5, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 9, 'N': 5, 'τ': 11.041307749275266, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1484 with value: 0.21002613752681598.
# [I 2026-08-13 16:35:45,142] Trial 1951 pruned.
# [I 2026-08-13 16:35:45,390] Trial 1952 finished with value: 0.30926261389773047 and parameters: {'m': 4.0, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 54, 'nO': 1, 'N': 6, 'τ': 5.43957141035515, 'mode': 1, 'act': 1, 'mO': 8}. Best is trial 1484 with value: 0.21002613752681598.

# %%
df = dfs[0]
#df = df[(df.iloc[:,0] <= 0.07)]
params_list = df.values[:,-9:]
df

# %%
tedas = []
for i,params in enumerate(params_list):
    m,nI,nR,nO,mO,N1,τ,mode,act = params
    X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
    if isinstance(nR, str): nR = ast.literal_eval(nR)

    teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N1],mode=mode,act=act,
                tau=τ,rho=0.03,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
    for j,_ in enumerate(X[:]):
        teda.run(X[j])
        teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1,show=False)
        teda.Adapt(Y[j],Z[j])

    teda.c = np.append(teda.c,teda.gm)  
    tedas.append(teda)
    #PlotSeriesPLY(ySeries=[teda.wape_HI_hist,teda.wape_RUL_hist])

# %%
PlotDSI_3D_PLT(tedas[0])
