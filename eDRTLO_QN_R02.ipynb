# %%
import math
import ast
import ipynbname
import pandas as pd
import numpy as np
import optuna
from Testing.DRTLO_QN_R1 import *
from Functions.AutoCloud_V2 import *
from Functions.DataCloud_V2 import *
from Functions.Utils import *
from Functions.Graphs import *
from Functions.TedaGraphs import *
from Functions.Utils_OPT import *

FileName = ipynbname.name()
out_path = f'Optimization\\eDRTLO_QN\\multi\\Optimization.csv'
RS = pd.read_excel(r'Dataset\RS.xlsx')
HI = pd.read_csv(r'Dataset\Bearing1_1.csv')
sig = HI['PC1'].values

# %%
params =  {'nI': 3, 'nR': 3, 'nO': 3, 'N1': 0.1,
            'τ': 23, 'mode': 1, 'act': 0}

nI,nR,nO,N1,τ,mode,act= list(params.values())
X, Y, Z = PrepareData(RS, HI, nX=nI, nY=nO, mY=0, nZ=1, mode='past')

teda=AutoCloud(m=2.5,nI=nI,nR=[nR],nO=nO,ηS=[N1],mode=mode,
               tau=τ,rho=0.01,eol=0.3,ref=len(sig)-nI,wtaG=True,wtaP=True) 
for j,_ in enumerate(X[:]):
    teda.run(X[j])
    teda.RUL_Prediction(Y[j],mode='interval',lim=len(sig)-nI+1,show=False)
    teda.Adapt(Y[j],Z[j])

#teda.RUL_Granularity()
#print(teda.wape_HI,teda.wape_RUL)
#PlotDSI_3D_PLT(teda)
#teda.c = np.append(teda.c,teda.gm)   
#PlotGranulesSpace(teda,w=700,h=700)

# %%
print(xxx)

# %%
def Optimize(
        FileName=None,OptDim=None,OptSampler=None,OptSeed=None,OptPrune=False,
        n_study=None,timeout=None,n_trials=None,
        patience=None,
        mS =None,nIS=None,nLS=None,nRS=None,nOS =None,mOS=None,
        NS=None,τS =None,mdS=None,actS=None):

    '''
        OptSampler modes available: None, Auto, GP, NSGAII, Random, TPE
    
        None: sampler default, suport multivariate optimization

        GP: suport multivariate optimization

        Auto: suport multivariate optimization
        
        NSGAII: poorly suport multivariate optimization
        
        Random: poorly suport multivariate optimization

        TPE: suport multivariate optimization
    '''

    if OptDim == 1 or OptDim is None: SingleObj = True
    elif OptDim > 1: SingleObj = False    
    if n_study is None: n_study = 1
    if timeout is None: timeout = 60
    if n_trials is None and patience is None: 
        n_trials = 25
        patience = 25
    elif n_trials < 100 and patience is None:
        patience = int(0.25*n_trials)
    elif n_trials >= 1e2 and n_trials < 1e3 and patience is None:
        patience = int(0.20*n_trials)
    elif n_trials >= 1e3 and n_trials < 5e3 and patience is None:
        patience = int(0.150*n_trials)
    elif n_trials >= 5e3 and n_trials < 1e4 and patience is None:
        patience = int(0.125*n_trials)    
    elif n_trials >= 1e4 and patience is None:
        patience = int(0.03*n_trials)   

    if mS  is None: mS  = [1.75,4.25]
    if nIS is None: nIS = [2,40]
    if nLS is None: nLS = [1,5]
    if nRS is None: nRS = [1,60]
    if nOS is None: nOS = [1,40]
    if mOS is None: mOS = [0,40]
    if NS is None: NS = [1,9]
    if τS  is None: τS  = [1,25]
    if mdS is None: mdS = [0,1]
    if actS is None: actS = [0,1,2]

    if SingleObj: names = ['MAPE_RUL*MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N','TAU','past/ahead','activation']
    else: names = ['MAPE_RUL','MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N', 'TAU','past/ahead','activation']
    study_dir, out_path = df_ParamsTable(names,FileName)

    for i in range(n_study):
        print('iteration:',i+1)
        def objective(trial):
            m = trial.suggest_float('m', mS[0], mS[1],step=0.25)
            nI = trial.suggest_int('nI', nIS[0], nIS[1]) 
            n_layers = trial.suggest_int('n_layers', nLS[0], nLS[1])
            nR = [trial.suggest_int(f'nR_layer_{l}', nRS[0], nRS[1]) for l in range(n_layers)]
            nO = trial.suggest_int('nO', nOS[0], nOS[1]) 
            N = trial.suggest_int('N', NS[0], NS[1])
            τ = trial.suggest_int('τ', τS[0], τS[1])
            mode = trial.suggest_int('mode', mdS[0], mdS[1])  
            act = trial.suggest_int('act', actS[0], actS[1])  

            if mode == 'past' or mode == 0:
                mO = trial.suggest_int('mO', 0, 0) 
                if nO > nI: raise TrialPruned()

            elif mode == 'ahead' or mode == 1:
                mO = trial.suggest_int('mO', mOS[0], mOS[1]) 
                if   nI > 20 or nO > 20: raise TrialPruned()
                elif mO > nI: raise TrialPruned()
                
            X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
            
            teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N],mode=mode,act=act,
                           tau=τ,rho=0.0,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
            
            for j,_ in enumerate(X[:]):
                teda.run(X[j])
                teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1)
                teda.Adapt(Y[j],Z[j])
                #teda.WAPE_HI2(Y[j],Z[j])

                if np.isinf(teda.hiP[-1]) or np.isnan(teda.hiP[-1]): raise TrialPruned()
                if not OptPrune: continue
        
                if j >=60 and j%5==0:
                    if teda.wape_RUL > 0.6: raise TrialPruned()
                    if teda.wape_HI  > 0.3: raise TrialPruned()

                if SingleObj and j%35==0:
                    trial.report(teda.wape_RUL+teda.wape_HI, j)
                    if trial.should_prune():
                        raise optuna.TrialPruned()

            if SingleObj: return teda.wape_RUL + teda.wape_HI
            else: return teda.wape_RUL,teda.wape_HI

        pruner=optuna.pruners.HyperbandPruner()
        if SingleObj: study = optuna.create_study(direction='minimize',pruner=pruner,sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        else: study = optuna.create_study(directions=['minimize','minimize'],sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        study.optimize(objective, n_trials=n_trials, timeout=timeout, callbacks=[EarlyStoppingCallback(patience=patience)])

        vec = []
        if SingleObj:
            trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
            for trial in trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]   
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
            df2 = df2.sort_values(by=df2.columns[0], ascending=False)[-5:]

        elif not SingleObj: 
            for trial in study.best_trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],trial.values[1],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
        
    if os.path.isfile(out_path) and out_path.startswith(study_dir):
        df1 = pd.read_csv(out_path)
        df_stdy = pd.concat([df1, df2], ignore_index=True)
    
    else: df_stdy = df2
    
    df_stdy.to_csv(out_path, index=False)
    opt_path = os.path.join(study_dir,f'opt_{len(os.listdir(study_dir))-1}.csv')
    
    if df2.shape[0] > 0: df2.to_csv(opt_path, index=False)

    return [df_stdy, df2 ]

# %%
dfs = Optimize(FileName=FileName[:-4],OptDim=1,OptSampler='tpe',OptPrune=False,
                         n_study=1,timeout=60,n_trials=0.5e3,patience=None,
                         mS=[2.0,4.5],nRS=[1,70],mdS=[1,1],actS=[0,1])

# %%
for i in range(1,6):
    dfs = Optimize(FileName=FileName[:-4],OptDim=1,OptSampler='tpe',OptPrune=False,
                         n_study=6,timeout=1680,n_trials=1e4,patience=1e3,
                         mS=[2.0,4.5],nLS=[i,i],nRS=[1,70],mdS=[1,1],actS=[0,1])
# Out:
# [I 2026-08-13 16:41:03,749] A new study created in memory with name: no-name-e96930cb-fc2a-4309-a252-d7eee90854e0
# [I 2026-08-13 16:41:03,750] Trial 0 pruned.
# [I 2026-08-13 16:41:03,752] Trial 1 pruned.
# [I 2026-08-13 16:41:03,755] Trial 2 pruned.
# [I 2026-08-13 16:41:03,758] Trial 3 pruned.
# [I 2026-08-13 16:41:03,760] Trial 4 pruned.
# [I 2026-08-13 16:41:03,763] Trial 5 pruned.
# [I 2026-08-13 16:41:03,765] Trial 6 pruned.
# [I 2026-08-13 16:41:03,768] Trial 7 pruned.
# [I 2026-08-13 16:41:03,771] Trial 8 pruned.
# [I 2026-08-13 16:41:03,773] Trial 9 pruned.
# [I 2026-08-13 16:41:03,776] Trial 10 pruned.
# [I 2026-08-13 16:41:03,778] Trial 11 pruned.
# [I 2026-08-13 16:41:03,780] Trial 12 pruned.
# [I 2026-08-13 16:41:03,783] Trial 13 pruned.
# [I 2026-08-13 16:41:03,785] Trial 14 pruned.
# [I 2026-08-13 16:41:03,788] Trial 15 pruned.
# [I 2026-08-13 16:41:03,790] Trial 16 pruned.
# [I 2026-08-13 16:41:03,793] Trial 17 pruned.
# [I 2026-08-13 16:41:03,796] Trial 18 pruned.
# [I 2026-08-13 16:41:03,799] Trial 19 pruned.
# [I 2026-08-13 16:41:03,801] Trial 20 pruned.
# [I 2026-08-13 16:41:03,804] Trial 21 pruned.
# [I 2026-08-13 16:41:03,807] Trial 22 pruned.
# [I 2026-08-13 16:41:03,810] Trial 23 pruned.
# [I 2026-08-13 16:41:03,812] Trial 24 pruned.
# [I 2026-08-13 16:41:03,815] Trial 25 pruned.
# [I 2026-08-13 16:41:03,817] Trial 26 pruned.
# [I 2026-08-13 16:41:03,821] Trial 27 pruned.
# [I 2026-08-13 16:41:03,823] Trial 28 pruned.
# [I 2026-08-13 16:41:03,826] Trial 29 pruned.
# [I 2026-08-13 16:41:03,831] Trial 30 pruned.
# [I 2026-08-13 16:41:03,909] Trial 31 finished with value: 2.3764908194297045 and parameters: {'m': 4.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 1, 'N': 5, 'τ': 24, 'mode': 1, 'act': 0, 'mO': 4}. Best is trial 31 with value: 2.3764908194297045.
# iteration: 1
# [I 2026-08-13 16:41:04,372] Trial 32 finished with value: 10.626644494221638 and parameters: {'m': 4.0, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 13, 'N': 1, 'τ': 13, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 31 with value: 2.3764908194297045.
# [I 2026-08-13 16:41:04,711] Trial 33 finished with value: 1.8477825531197591 and parameters: {'m': 3.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 18, 'N': 4, 'τ': 23, 'mode': 1, 'act': 1, 'mO': 19}. Best is trial 33 with value: 1.8477825531197591.
# [I 2026-08-13 16:41:04,713] Trial 34 pruned.
# [I 2026-08-13 16:41:04,716] Trial 35 pruned.
# [I 2026-08-13 16:41:04,719] Trial 36 pruned.
# [I 2026-08-13 16:41:04,722] Trial 37 pruned.
# [I 2026-08-13 16:41:04,725] Trial 38 pruned.
# [I 2026-08-13 16:41:04,729] Trial 39 pruned.
# [I 2026-08-13 16:41:04,732] Trial 40 pruned.
# [I 2026-08-13 16:41:04,734] Trial 41 pruned.
# [I 2026-08-13 16:41:04,737] Trial 42 pruned.
# [I 2026-08-13 16:41:04,741] Trial 43 pruned.
# [I 2026-08-13 16:41:04,744] Trial 44 pruned.
# [I 2026-08-13 16:41:04,747] Trial 45 pruned.
# [I 2026-08-13 16:41:04,750] Trial 46 pruned.
# [I 2026-08-13 16:41:04,754] Trial 47 pruned.
# [I 2026-08-13 16:41:04,758] Trial 48 pruned.
# [I 2026-08-13 16:41:04,760] Trial 49 pruned.
# [I 2026-08-13 16:41:04,763] Trial 50 pruned.
# [I 2026-08-13 16:41:04,766] Trial 51 pruned.
# [I 2026-08-13 16:41:04,767] Trial 52 pruned.
# [I 2026-08-13 16:41:04,770] Trial 53 pruned.
# [I 2026-08-13 16:41:04,773] Trial 54 pruned.
# [I 2026-08-13 16:41:04,777] Trial 55 pruned.
# [I 2026-08-13 16:41:04,779] Trial 56 pruned.
# [I 2026-08-13 16:41:04,781] Trial 57 pruned.
# [I 2026-08-13 16:41:04,784] Trial 58 pruned.
# [I 2026-08-13 16:41:04,787] Trial 59 pruned.
# [I 2026-08-13 16:41:04,790] Trial 60 pruned.
# [I 2026-08-13 16:41:04,792] Trial 61 pruned.
# [I 2026-08-13 16:41:04,795] Trial 62 pruned.
# [I 2026-08-13 16:41:04,827] Trial 63 finished with value: 1.6718809826762846 and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 29, 'nO': 1, 'N': 8, 'τ': 16, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 63 with value: 1.6718809826762846.
# [I 2026-08-13 16:41:04,830] Trial 64 pruned.
# [I 2026-08-13 16:41:04,833] Trial 65 pruned.
# [I 2026-08-13 16:41:04,836] Trial 66 pruned.
# [I 2026-08-13 16:41:04,839] Trial 67 pruned.
# [I 2026-08-13 16:41:04,841] Trial 68 pruned.
# [I 2026-08-13 16:41:04,844] Trial 69 pruned.
# [I 2026-08-13 16:41:04,847] Trial 70 pruned.
# [I 2026-08-13 16:41:04,849] Trial 71 pruned.
# [I 2026-08-13 16:41:04,853] Trial 72 pruned.
# [I 2026-08-13 16:41:04,855] Trial 73 pruned.
# [I 2026-08-13 16:41:04,859] Trial 74 pruned.
# [I 2026-08-13 16:41:04,861] Trial 75 pruned.
# [I 2026-08-13 16:41:04,864] Trial 76 pruned.
# [I 2026-08-13 16:41:04,867] Trial 77 pruned.
# [I 2026-08-13 16:41:04,870] Trial 78 pruned.
# [I 2026-08-13 16:41:04,873] Trial 79 pruned.
# [I 2026-08-13 16:41:04,875] Trial 80 pruned.
# [I 2026-08-13 16:41:04,949] Trial 81 finished with value: 1.5530352243766257 and parameters: {'m': 3.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 4, 'N': 8, 'τ': 10, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 81 with value: 1.5530352243766257.
# [I 2026-08-13 16:41:04,952] Trial 82 pruned.
# [I 2026-08-13 16:41:04,954] Trial 83 pruned.
# [I 2026-08-13 16:41:04,958] Trial 84 pruned.
# [I 2026-08-13 16:41:04,960] Trial 85 pruned.
# [I 2026-08-13 16:41:04,963] Trial 86 pruned.
# [I 2026-08-13 16:41:04,966] Trial 87 pruned.
# [I 2026-08-13 16:41:04,969] Trial 88 pruned.
# [I 2026-08-13 16:41:04,972] Trial 89 pruned.
# [I 2026-08-13 16:41:04,975] Trial 90 pruned.
# [I 2026-08-13 16:41:04,978] Trial 91 pruned.
# [I 2026-08-13 16:41:04,982] Trial 92 pruned.
# [I 2026-08-13 16:41:04,985] Trial 93 pruned.
# [I 2026-08-13 16:41:04,988] Trial 94 pruned.
# [I 2026-08-13 16:41:04,992] Trial 95 pruned.
# [I 2026-08-13 16:41:04,995] Trial 96 pruned.
# [I 2026-08-13 16:41:04,997] Trial 97 pruned.
# [I 2026-08-13 16:41:05,000] Trial 98 pruned.
# [I 2026-08-13 16:41:05,003] Trial 99 pruned.
# [I 2026-08-13 16:41:05,007] Trial 100 pruned.
# [I 2026-08-13 16:41:05,010] Trial 101 pruned.
# [I 2026-08-13 16:41:05,014] Trial 102 pruned.
# [I 2026-08-13 16:41:05,018] Trial 103 pruned.
# [I 2026-08-13 16:41:05,021] Trial 104 pruned.
# [I 2026-08-13 16:41:05,025] Trial 105 pruned.
# [I 2026-08-13 16:41:05,090] Trial 106 finished with value: 1.1816415986111484 and parameters: {'m': 3.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 11, 'nO': 13, 'N': 3, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 106 with value: 1.1816415986111484.
# [I 2026-08-13 16:41:05,093] Trial 107 pruned.
# [I 2026-08-13 16:41:05,095] Trial 108 pruned.
# [I 2026-08-13 16:41:05,149] Trial 109 finished with value: 1.988568342594757 and parameters: {'m': 2.25, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 4, 'N': 3, 'τ': 25, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 106 with value: 1.1816415986111484.
# [I 2026-08-13 16:41:05,153] Trial 110 pruned.
# [I 2026-08-13 16:41:05,157] Trial 111 pruned.
# [I 2026-08-13 16:41:05,161] Trial 112 pruned.
# [I 2026-08-13 16:41:05,165] Trial 113 pruned.
# [I 2026-08-13 16:41:05,167] Trial 114 pruned.
# [I 2026-08-13 16:41:05,169] Trial 115 pruned.
# [I 2026-08-13 16:41:05,171] Trial 116 pruned.
# [I 2026-08-13 16:41:05,174] Trial 117 pruned.
# [I 2026-08-13 16:41:05,176] Trial 118 pruned.
# [I 2026-08-13 16:41:05,179] Trial 119 pruned.
# [I 2026-08-13 16:41:05,182] Trial 120 pruned.
# [I 2026-08-13 16:41:05,185] Trial 121 pruned.
# [I 2026-08-13 16:41:05,187] Trial 122 pruned.
# [I 2026-08-13 16:41:05,222] Trial 123 finished with value: 1.8611060343486463 and parameters: {'m': 2.0, 'nI': 2, 'n_layers': 1, 'nR_layer_0': 3, 'nO': 20, 'N': 9, 'τ': 14, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 106 with value: 1.1816415986111484.
# [I 2026-08-13 16:41:05,226] Trial 124 pruned.
# [I 2026-08-13 16:41:05,230] Trial 125 pruned.
# [I 2026-08-13 16:41:05,234] Trial 126 pruned.
# [I 2026-08-13 16:41:05,238] Trial 127 pruned.
# [I 2026-08-13 16:41:05,242] Trial 128 pruned.
# [I 2026-08-13 16:41:05,246] Trial 129 pruned.
# [I 2026-08-13 16:41:05,250] Trial 130 pruned.
# [I 2026-08-13 16:41:05,253] Trial 131 pruned.
# [I 2026-08-13 16:41:05,256] Trial 132 pruned.
# [I 2026-08-13 16:41:05,260] Trial 133 pruned.
# [I 2026-08-13 16:41:05,264] Trial 134 pruned.
# [I 2026-08-13 16:41:05,268] Trial 135 pruned.
# [I 2026-08-13 16:41:05,272] Trial 136 pruned.
# [I 2026-08-13 16:41:05,277] Trial 137 pruned.
# [I 2026-08-13 16:41:05,281] Trial 138 pruned.
# [I 2026-08-13 16:41:05,284] Trial 139 pruned.
# [I 2026-08-13 16:41:05,288] Trial 140 pruned.
# [I 2026-08-13 16:41:05,293] Trial 141 pruned.
# [I 2026-08-13 16:41:05,297] Trial 142 pruned.
# [I 2026-08-13 16:41:05,300] Trial 143 pruned.
# [I 2026-08-13 16:41:05,304] Trial 144 pruned.
# [I 2026-08-13 16:41:05,308] Trial 145 pruned.
# [I 2026-08-13 16:41:05,311] Trial 146 pruned.
# [I 2026-08-13 16:41:05,316] Trial 147 pruned.
# [I 2026-08-13 16:41:05,320] Trial 148 pruned.
# [I 2026-08-13 16:41:05,324] Trial 149 pruned.
# [I 2026-08-13 16:41:05,328] Trial 150 pruned.
# [I 2026-08-13 16:41:05,332] Trial 151 pruned.
# [I 2026-08-13 16:41:05,335] Trial 152 pruned.
# [I 2026-08-13 16:41:05,339] Trial 153 pruned.
# [I 2026-08-13 16:41:05,343] Trial 154 pruned.
# [I 2026-08-13 16:41:05,348] Trial 155 pruned.
# [I 2026-08-13 16:41:05,351] Trial 156 pruned.
# [I 2026-08-13 16:41:05,355] Trial 157 pruned.
# [I 2026-08-13 16:41:05,359] Trial 158 pruned.
# [I 2026-08-13 16:41:05,364] Trial 159 pruned.
# [I 2026-08-13 16:41:05,368] Trial 160 pruned.
# [I 2026-08-13 16:41:05,372] Trial 161 pruned.
# [I 2026-08-13 16:41:05,376] Trial 162 pruned.
# [I 2026-08-13 16:41:05,379] Trial 163 pruned.
# [I 2026-08-13 16:41:05,382] Trial 164 pruned.
# [I 2026-08-13 16:41:05,386] Trial 165 pruned.
# [I 2026-08-13 16:41:05,390] Trial 166 pruned.
# [I 2026-08-13 16:41:05,394] Trial 167 pruned.
# [I 2026-08-13 16:41:05,398] Trial 168 pruned.
# [I 2026-08-13 16:41:05,402] Trial 169 pruned.
# [I 2026-08-13 16:41:05,404] Trial 170 pruned.
# [I 2026-08-13 16:41:05,408] Trial 171 pruned.
# [I 2026-08-13 16:41:05,413] Trial 172 pruned.
# [I 2026-08-13 16:41:05,416] Trial 173 pruned.
# [I 2026-08-13 16:41:05,420] Trial 174 pruned.
# [I 2026-08-13 16:41:05,424] Trial 175 pruned.
# [I 2026-08-13 16:41:05,427] Trial 176 pruned.
# [I 2026-08-13 16:41:05,431] Trial 177 pruned.
# [I 2026-08-13 16:41:05,434] Trial 178 pruned.
# [I 2026-08-13 16:41:05,436] Trial 179 pruned.
# [I 2026-08-13 16:41:05,439] Trial 180 pruned.
# [I 2026-08-13 16:41:05,442] Trial 181 pruned.
# [I 2026-08-13 16:41:05,445] Trial 182 pruned.
# [I 2026-08-13 16:41:05,448] Trial 183 pruned.
# [I 2026-08-13 16:41:05,452] Trial 184 pruned.
# [I 2026-08-13 16:41:05,455] Trial 185 pruned.
# [I 2026-08-13 16:41:06,062] Trial 186 finished with value: 2.2689048089576325 and parameters: {'m': 2.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 56, 'nO': 12, 'N': 8, 'τ': 8, 'mode': 1, 'act': 0, 'mO': 9}. Best is trial 106 with value: 1.1816415986111484.
# [I 2026-08-13 16:41:06,066] Trial 187 pruned.
# [I 2026-08-13 16:41:06,071] Trial 188 pruned.
# [I 2026-08-13 16:41:06,076] Trial 189 pruned.
# [I 2026-08-13 16:41:06,081] Trial 190 pruned.
# [I 2026-08-13 16:41:06,084] Trial 191 pruned.
# [I 2026-08-13 16:41:06,626] Trial 192 finished with value: 2.040070079712602 and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 63, 'nO': 17, 'N': 8, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 106 with value: 1.1816415986111484.
# [I 2026-08-13 16:41:06,631] Trial 193 pruned.
# [I 2026-08-13 16:41:06,635] Trial 194 pruned.
# [I 2026-08-13 16:41:06,638] Trial 195 pruned.
# [I 2026-08-13 16:41:06,641] Trial 196 pruned.
# [I 2026-08-13 16:41:06,643] Trial 197 pruned.
# [I 2026-08-13 16:41:06,757] Trial 198 finished with value: 0.8674086847002369 and parameters: {'m': 3.25, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 66, 'nO': 1, 'N': 9, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 12}. Best is trial 198 with value: 0.8674086847002369.
# [I 2026-08-13 16:41:06,760] Trial 199 pruned.
# [I 2026-08-13 16:41:06,764] Trial 200 pruned.
# [I 2026-08-13 16:41:06,768] Trial 201 pruned.
# [I 2026-08-13 16:41:06,772] Trial 202 pruned.
# [I 2026-08-13 16:41:06,775] Trial 203 pruned.
# [I 2026-08-13 16:41:06,777] Trial 204 pruned.
# [I 2026-08-13 16:41:06,779] Trial 205 pruned.
# [I 2026-08-13 16:41:06,781] Trial 206 pruned.
# [I 2026-08-13 16:41:06,784] Trial 207 pruned.
# [I 2026-08-13 16:41:06,787] Trial 208 pruned.
# [I 2026-08-13 16:41:06,790] Trial 209 pruned.
# [I 2026-08-13 16:41:06,794] Trial 210 pruned.
# [I 2026-08-13 16:41:06,796] Trial 211 pruned.
# [I 2026-08-13 16:41:06,799] Trial 212 pruned.
# [I 2026-08-13 16:41:06,803] Trial 213 pruned.
# [I 2026-08-13 16:41:06,805] Trial 214 pruned.
# [I 2026-08-13 16:41:06,808] Trial 215 pruned.
# [I 2026-08-13 16:41:06,810] Trial 216 pruned.
# [I 2026-08-13 16:41:06,812] Trial 217 pruned.
# [I 2026-08-13 16:41:06,815] Trial 218 pruned.
# [I 2026-08-13 16:41:06,818] Trial 219 pruned.
# [I 2026-08-13 16:41:06,822] Trial 220 pruned.
# [I 2026-08-13 16:41:06,825] Trial 221 pruned.
# [I 2026-08-13 16:41:06,828] Trial 222 pruned.
# [I 2026-08-13 16:41:06,831] Trial 223 pruned.
# [I 2026-08-13 16:41:06,835] Trial 224 pruned.
# [I 2026-08-13 16:41:06,839] Trial 225 pruned.
# [I 2026-08-13 16:41:06,841] Trial 226 pruned.
# [I 2026-08-13 16:41:06,844] Trial 227 pruned.
# [I 2026-08-13 16:41:06,847] Trial 228 pruned.
# [I 2026-08-13 16:41:06,849] Trial 229 pruned.
# [I 2026-08-13 16:41:06,854] Trial 230 pruned.
# [I 2026-08-13 16:41:06,857] Trial 231 pruned.
# [I 2026-08-13 16:41:06,860] Trial 232 pruned.
# [I 2026-08-13 16:41:06,863] Trial 233 pruned.
# [I 2026-08-13 16:41:06,867] Trial 234 pruned.
# [I 2026-08-13 16:41:06,870] Trial 235 pruned.
# [I 2026-08-13 16:41:06,872] Trial 236 pruned.
# [I 2026-08-13 16:41:06,876] Trial 237 pruned.
# [I 2026-08-13 16:41:06,882] Trial 238 pruned.
# [I 2026-08-13 16:41:07,252] Trial 239 finished with value: 2.0576614666374975 and parameters: {'m': 4.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 59, 'nO': 13, 'N': 3, 'τ': 25, 'mode': 1, 'act': 0, 'mO': 11}. Best is trial 198 with value: 0.8674086847002369.
# [I 2026-08-13 16:41:07,256] Trial 240 pruned.
# [I 2026-08-13 16:41:07,259] Trial 241 pruned.
# [I 2026-08-13 16:41:07,264] Trial 242 pruned.
# [I 2026-08-13 16:41:07,268] Trial 243 pruned.
# [I 2026-08-13 16:41:07,272] Trial 244 pruned.
# [I 2026-08-13 16:41:07,275] Trial 245 pruned.
# [I 2026-08-13 16:41:07,281] Trial 246 pruned.
# [I 2026-08-13 16:41:07,325] Trial 247 finished with value: 3.752914407080108 and parameters: {'m': 2.75, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 40, 'nO': 12, 'N': 6, 'τ': 1, 'mode': 1, 'act': 0, 'mO': 12}. Best is trial 198 with value: 0.8674086847002369.
# [I 2026-08-13 16:41:07,329] Trial 248 pruned.
# [I 2026-08-13 16:41:07,332] Trial 249 pruned.
# [I 2026-08-13 16:41:07,335] Trial 250 pruned.
# [I 2026-08-13 16:41:07,337] Trial 251 pruned.
# [I 2026-08-13 16:41:07,340] Trial 252 pruned.
# [I 2026-08-13 16:41:07,344] Trial 253 pruned.
# [I 2026-08-13 16:41:07,347] Trial 254 pruned.
# [I 2026-08-13 16:41:07,350] Trial 255 pruned.
# [I 2026-08-13 16:41:07,353] Trial 256 pruned.
# [I 2026-08-13 16:41:07,385] Trial 257 finished with value: 1.5541701094740414 and parameters: {'m': 2.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 14, 'nO': 9, 'N': 6, 'τ': 13, 'mode': 1, 'act': 0, 'mO': 3}. Best is trial 198 with value: 0.8674086847002369.
# [I 2026-08-13 16:41:07,387] Trial 258 pruned.
# [I 2026-08-13 16:41:07,392] Trial 259 pruned.
# [I 2026-08-13 16:41:07,872] Trial 260 finished with value: 2.1475912366521195 and parameters: {'m': 2.5, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 59, 'nO': 15, 'N': 2, 'τ': 24, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 198 with value: 0.8674086847002369.
# [I 2026-08-13 16:41:07,877] Trial 261 pruned.
# [I 2026-08-13 16:41:07,880] Trial 262 pruned.
# [I 2026-08-13 16:41:07,883] Trial 263 pruned.
# [I 2026-08-13 16:41:07,886] Trial 264 pruned.
# [I 2026-08-13 16:41:07,889] Trial 265 pruned.
# [I 2026-08-13 16:41:07,892] Trial 266 pruned.
# [I 2026-08-13 16:41:07,894] Trial 267 pruned.
# [I 2026-08-13 16:41:07,898] Trial 268 pruned.
# [I 2026-08-13 16:41:07,900] Trial 269 pruned.
# [I 2026-08-13 16:41:07,903] Trial 270 pruned.
# [I 2026-08-13 16:41:07,906] Trial 271 pruned.
# [I 2026-08-13 16:41:07,908] Trial 272 pruned.
# [I 2026-08-13 16:41:07,911] Trial 273 pruned.
# [I 2026-08-13 16:41:07,915] Trial 274 pruned.
# [I 2026-08-13 16:41:07,920] Trial 275 pruned.
# [I 2026-08-13 16:41:07,925] Trial 276 pruned.
# [I 2026-08-13 16:41:07,928] Trial 277 pruned.
# [I 2026-08-13 16:41:07,931] Trial 278 pruned.
# [I 2026-08-13 16:41:07,934] Trial 279 pruned.
# [I 2026-08-13 16:41:07,938] Trial 280 pruned.
# [I 2026-08-13 16:41:07,941] Trial 281 pruned.
# [I 2026-08-13 16:41:07,944] Trial 282 pruned.
# [I 2026-08-13 16:41:07,947] Trial 283 pruned.
# [I 2026-08-13 16:41:07,950] Trial 284 pruned.
# [I 2026-08-13 16:41:07,953] Trial 285 pruned.
# [I 2026-08-13 16:41:07,957] Trial 286 pruned.
# [I 2026-08-13 16:41:08,207] Trial 287 finished with value: 0.8007590064606651 and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 51, 'nO': 13, 'N': 4, 'τ': 7, 'mode': 1, 'act': 1, 'mO': 10}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:08,560] Trial 288 finished with value: 2.4674607395011026 and parameters: {'m': 4.0, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 11, 'N': 9, 'τ': 22, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:08,564] Trial 289 pruned.
# [I 2026-08-13 16:41:08,569] Trial 290 pruned.
# [I 2026-08-13 16:41:08,573] Trial 291 pruned.
# [I 2026-08-13 16:41:08,577] Trial 292 pruned.
# [I 2026-08-13 16:41:08,582] Trial 293 pruned.
# [I 2026-08-13 16:41:08,584] Trial 294 pruned.
# [I 2026-08-13 16:41:08,587] Trial 295 pruned.
# [I 2026-08-13 16:41:08,591] Trial 296 pruned.
# [I 2026-08-13 16:41:08,595] Trial 297 pruned.
# [I 2026-08-13 16:41:08,598] Trial 298 pruned.
# [I 2026-08-13 16:41:08,602] Trial 299 pruned.
# [I 2026-08-13 16:41:08,604] Trial 300 pruned.
# [I 2026-08-13 16:41:08,608] Trial 301 pruned.
# [I 2026-08-13 16:41:08,611] Trial 302 pruned.
# [I 2026-08-13 16:41:08,614] Trial 303 pruned.
# [I 2026-08-13 16:41:08,616] Trial 304 pruned.
# [I 2026-08-13 16:41:08,619] Trial 305 pruned.
# [I 2026-08-13 16:41:08,623] Trial 306 pruned.
# [I 2026-08-13 16:41:08,626] Trial 307 pruned.
# [I 2026-08-13 16:41:08,631] Trial 308 pruned.
# [I 2026-08-13 16:41:08,633] Trial 309 pruned.
# [I 2026-08-13 16:41:08,636] Trial 310 pruned.
# [I 2026-08-13 16:41:08,960] Trial 311 finished with value: 4.9397635888006715 and parameters: {'m': 3.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 40, 'nO': 18, 'N': 2, 'τ': 9, 'mode': 1, 'act': 0, 'mO': 14}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:08,963] Trial 312 pruned.
# [I 2026-08-13 16:41:08,966] Trial 313 pruned.
# [I 2026-08-13 16:41:08,969] Trial 314 pruned.
# [I 2026-08-13 16:41:08,973] Trial 315 pruned.
# [I 2026-08-13 16:41:08,976] Trial 316 pruned.
# [I 2026-08-13 16:41:08,978] Trial 317 pruned.
# [I 2026-08-13 16:41:08,981] Trial 318 pruned.
# [I 2026-08-13 16:41:08,986] Trial 319 pruned.
# [I 2026-08-13 16:41:08,990] Trial 320 pruned.
# [I 2026-08-13 16:41:08,994] Trial 321 pruned.
# [I 2026-08-13 16:41:08,998] Trial 322 pruned.
# [I 2026-08-13 16:41:09,003] Trial 323 pruned.
# [I 2026-08-13 16:41:09,007] Trial 324 pruned.
# [I 2026-08-13 16:41:09,011] Trial 325 pruned.
# [I 2026-08-13 16:41:09,016] Trial 326 pruned.
# [I 2026-08-13 16:41:09,021] Trial 327 pruned.
# [I 2026-08-13 16:41:09,024] Trial 328 pruned.
# [I 2026-08-13 16:41:09,028] Trial 329 pruned.
# [I 2026-08-13 16:41:09,031] Trial 330 pruned.
# [I 2026-08-13 16:41:09,036] Trial 331 pruned.
# [I 2026-08-13 16:41:09,039] Trial 332 pruned.
# [I 2026-08-13 16:41:09,042] Trial 333 pruned.
# [I 2026-08-13 16:41:09,046] Trial 334 pruned.
# [I 2026-08-13 16:41:09,049] Trial 335 pruned.
# [I 2026-08-13 16:41:09,076] Trial 336 finished with value: 1.7876172368419665 and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 20, 'N': 6, 'τ': 12, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:09,081] Trial 337 pruned.
# [I 2026-08-13 16:41:09,085] Trial 338 pruned.
# [I 2026-08-13 16:41:09,088] Trial 339 pruned.
# [I 2026-08-13 16:41:09,092] Trial 340 pruned.
# [I 2026-08-13 16:41:09,095] Trial 341 pruned.
# [I 2026-08-13 16:41:09,100] Trial 342 pruned.
# [I 2026-08-13 16:41:09,105] Trial 343 pruned.
# [I 2026-08-13 16:41:09,140] Trial 344 finished with value: 1.7117032383657849 and parameters: {'m': 4.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 10, 'nO': 2, 'N': 3, 'τ': 10, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:09,143] Trial 345 pruned.
# [I 2026-08-13 16:41:09,147] Trial 346 pruned.
# [I 2026-08-13 16:41:09,150] Trial 347 pruned.
# [I 2026-08-13 16:41:09,153] Trial 348 pruned.
# [I 2026-08-13 16:41:09,156] Trial 349 pruned.
# [I 2026-08-13 16:41:09,160] Trial 350 pruned.
# [I 2026-08-13 16:41:09,164] Trial 351 pruned.
# [I 2026-08-13 16:41:09,166] Trial 352 pruned.
# [I 2026-08-13 16:41:09,172] Trial 353 pruned.
# [I 2026-08-13 16:41:09,175] Trial 354 pruned.
# [I 2026-08-13 16:41:09,181] Trial 355 pruned.
# [I 2026-08-13 16:41:09,184] Trial 356 pruned.
# [I 2026-08-13 16:41:09,188] Trial 357 pruned.
# [I 2026-08-13 16:41:09,191] Trial 358 pruned.
# [I 2026-08-13 16:41:09,196] Trial 359 pruned.
# [I 2026-08-13 16:41:09,201] Trial 360 pruned.
# [I 2026-08-13 16:41:09,205] Trial 361 pruned.
# [I 2026-08-13 16:41:09,208] Trial 362 pruned.
# [I 2026-08-13 16:41:09,215] Trial 363 pruned.
# [I 2026-08-13 16:41:09,244] Trial 364 finished with value: 2.2219457611258844 and parameters: {'m': 2.5, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 19, 'N': 6, 'τ': 13, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:09,249] Trial 365 pruned.
# [I 2026-08-13 16:41:09,624] Trial 366 finished with value: 1.0273193058019914 and parameters: {'m': 2.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 2, 'N': 9, 'τ': 22, 'mode': 1, 'act': 0, 'mO': 3}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:09,628] Trial 367 pruned.
# [I 2026-08-13 16:41:09,632] Trial 368 pruned.
# [I 2026-08-13 16:41:09,636] Trial 369 pruned.
# [I 2026-08-13 16:41:09,639] Trial 370 pruned.
# [I 2026-08-13 16:41:09,642] Trial 371 pruned.
# [I 2026-08-13 16:41:09,647] Trial 372 pruned.
# [I 2026-08-13 16:41:09,650] Trial 373 pruned.
# [I 2026-08-13 16:41:09,655] Trial 374 pruned.
# [I 2026-08-13 16:41:09,658] Trial 375 pruned.
# [I 2026-08-13 16:41:09,661] Trial 376 pruned.
# [I 2026-08-13 16:41:09,665] Trial 377 pruned.
# [I 2026-08-13 16:41:09,671] Trial 378 pruned.
# [I 2026-08-13 16:41:09,944] Trial 379 finished with value: 1.132719503193782 and parameters: {'m': 3.25, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 5, 'N': 2, 'τ': 10, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:09,948] Trial 380 pruned.
# [I 2026-08-13 16:41:09,950] Trial 381 pruned.
# [I 2026-08-13 16:41:09,953] Trial 382 pruned.
# [I 2026-08-13 16:41:09,957] Trial 383 pruned.
# [I 2026-08-13 16:41:09,960] Trial 384 pruned.
# [I 2026-08-13 16:41:09,966] Trial 385 pruned.
# [I 2026-08-13 16:41:09,970] Trial 386 pruned.
# [I 2026-08-13 16:41:09,975] Trial 387 pruned.
# [I 2026-08-13 16:41:09,978] Trial 388 pruned.
# [I 2026-08-13 16:41:09,982] Trial 389 pruned.
# [I 2026-08-13 16:41:09,985] Trial 390 pruned.
# [I 2026-08-13 16:41:09,988] Trial 391 pruned.
# [I 2026-08-13 16:41:09,991] Trial 392 pruned.
# [I 2026-08-13 16:41:09,997] Trial 393 pruned.
# [I 2026-08-13 16:41:10,000] Trial 394 pruned.
# [I 2026-08-13 16:41:10,004] Trial 395 pruned.
# [I 2026-08-13 16:41:10,008] Trial 396 pruned.
# [I 2026-08-13 16:41:10,012] Trial 397 pruned.
# [I 2026-08-13 16:41:10,016] Trial 398 pruned.
# [I 2026-08-13 16:41:10,020] Trial 399 pruned.
# [I 2026-08-13 16:41:10,023] Trial 400 pruned.
# [I 2026-08-13 16:41:10,028] Trial 401 pruned.
# [I 2026-08-13 16:41:10,031] Trial 402 pruned.
# [I 2026-08-13 16:41:10,430] Trial 403 finished with value: 2.155143359836042 and parameters: {'m': 3.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 54, 'nO': 16, 'N': 9, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 11}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:10,435] Trial 404 pruned.
# [I 2026-08-13 16:41:10,847] Trial 405 finished with value: 3.2324820821705864 and parameters: {'m': 2.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 5, 'N': 1, 'τ': 1, 'mode': 1, 'act': 1, 'mO': 15}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:10,851] Trial 406 pruned.
# [I 2026-08-13 16:41:10,854] Trial 407 pruned.
# [I 2026-08-13 16:41:10,857] Trial 408 pruned.
# [I 2026-08-13 16:41:10,860] Trial 409 pruned.
# [I 2026-08-13 16:41:10,865] Trial 410 pruned.
# [I 2026-08-13 16:41:10,869] Trial 411 pruned.
# [I 2026-08-13 16:41:10,874] Trial 412 pruned.
# [I 2026-08-13 16:41:10,877] Trial 413 pruned.
# [I 2026-08-13 16:41:10,880] Trial 414 pruned.
# [I 2026-08-13 16:41:10,884] Trial 415 pruned.
# [I 2026-08-13 16:41:10,888] Trial 416 pruned.
# [I 2026-08-13 16:41:10,892] Trial 417 pruned.
# [I 2026-08-13 16:41:10,897] Trial 418 pruned.
# [I 2026-08-13 16:41:10,901] Trial 419 pruned.
# [I 2026-08-13 16:41:10,906] Trial 420 pruned.
# [I 2026-08-13 16:41:10,910] Trial 421 pruned.
# [I 2026-08-13 16:41:10,916] Trial 422 pruned.
# [I 2026-08-13 16:41:10,919] Trial 423 pruned.
# [I 2026-08-13 16:41:10,923] Trial 424 pruned.
# [I 2026-08-13 16:41:10,927] Trial 425 pruned.
# [I 2026-08-13 16:41:10,970] Trial 426 finished with value: 1.8029785760132522 and parameters: {'m': 4.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 19, 'nO': 7, 'N': 3, 'τ': 19, 'mode': 1, 'act': 0, 'mO': 11}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:10,974] Trial 427 pruned.
# [I 2026-08-13 16:41:10,977] Trial 428 pruned.
# [I 2026-08-13 16:41:10,980] Trial 429 pruned.
# [I 2026-08-13 16:41:10,984] Trial 430 pruned.
# [I 2026-08-13 16:41:10,987] Trial 431 pruned.
# [I 2026-08-13 16:41:10,991] Trial 432 pruned.
# [I 2026-08-13 16:41:10,996] Trial 433 pruned.
# [I 2026-08-13 16:41:10,999] Trial 434 pruned.
# [I 2026-08-13 16:41:11,002] Trial 435 pruned.
# [I 2026-08-13 16:41:11,006] Trial 436 pruned.
# [I 2026-08-13 16:41:11,010] Trial 437 pruned.
# [I 2026-08-13 16:41:11,016] Trial 438 pruned.
# [I 2026-08-13 16:41:11,052] Trial 439 finished with value: 2.0075705394303682 and parameters: {'m': 3.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 4, 'nO': 13, 'N': 6, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 13}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:11,056] Trial 440 pruned.
# [I 2026-08-13 16:41:11,060] Trial 441 pruned.
# [I 2026-08-13 16:41:11,065] Trial 442 pruned.
# [I 2026-08-13 16:41:11,069] Trial 443 pruned.
# [I 2026-08-13 16:41:11,075] Trial 444 pruned.
# [I 2026-08-13 16:41:11,079] Trial 445 pruned.
# [I 2026-08-13 16:41:11,083] Trial 446 pruned.
# [I 2026-08-13 16:41:11,086] Trial 447 pruned.
# [I 2026-08-13 16:41:11,090] Trial 448 pruned.
# [I 2026-08-13 16:41:11,095] Trial 449 pruned.
# [I 2026-08-13 16:41:11,098] Trial 450 pruned.
# [I 2026-08-13 16:41:11,101] Trial 451 pruned.
# [I 2026-08-13 16:41:11,104] Trial 452 pruned.
# [I 2026-08-13 16:41:11,107] Trial 453 pruned.
# [I 2026-08-13 16:41:11,111] Trial 454 pruned.
# [I 2026-08-13 16:41:11,116] Trial 455 pruned.
# [I 2026-08-13 16:41:11,120] Trial 456 pruned.
# [I 2026-08-13 16:41:11,124] Trial 457 pruned.
# [I 2026-08-13 16:41:11,129] Trial 458 pruned.
# [I 2026-08-13 16:41:11,134] Trial 459 pruned.
# [I 2026-08-13 16:41:11,139] Trial 460 pruned.
# [I 2026-08-13 16:41:11,145] Trial 461 pruned.
# [I 2026-08-13 16:41:11,149] Trial 462 pruned.
# [I 2026-08-13 16:41:11,152] Trial 463 pruned.
# [I 2026-08-13 16:41:11,192] Trial 464 finished with value: 1.8677109592060264 and parameters: {'m': 3.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 10, 'N': 8, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:11,196] Trial 465 pruned.
# [I 2026-08-13 16:41:11,200] Trial 466 pruned.
# [I 2026-08-13 16:41:11,203] Trial 467 pruned.
# [I 2026-08-13 16:41:11,208] Trial 468 pruned.
# [I 2026-08-13 16:41:11,213] Trial 469 pruned.
# [I 2026-08-13 16:41:11,217] Trial 470 pruned.
# [I 2026-08-13 16:41:11,221] Trial 471 pruned.
# [I 2026-08-13 16:41:11,225] Trial 472 pruned.
# [I 2026-08-13 16:41:11,230] Trial 473 pruned.
# [I 2026-08-13 16:41:11,234] Trial 474 pruned.
# [I 2026-08-13 16:41:11,240] Trial 475 pruned.
# [I 2026-08-13 16:41:11,245] Trial 476 pruned.
# [I 2026-08-13 16:41:11,250] Trial 477 pruned.
# [I 2026-08-13 16:41:11,256] Trial 478 pruned.
# [I 2026-08-13 16:41:11,259] Trial 479 pruned.
# [I 2026-08-13 16:41:11,264] Trial 480 pruned.
# [I 2026-08-13 16:41:11,270] Trial 481 pruned.
# [I 2026-08-13 16:41:11,277] Trial 482 pruned.
# [I 2026-08-13 16:41:11,281] Trial 483 pruned.
# [I 2026-08-13 16:41:11,286] Trial 484 pruned.
# [I 2026-08-13 16:41:11,292] Trial 485 pruned.
# [I 2026-08-13 16:41:11,296] Trial 486 pruned.
# [I 2026-08-13 16:41:11,301] Trial 487 pruned.
# [I 2026-08-13 16:41:11,305] Trial 488 pruned.
# [I 2026-08-13 16:41:11,308] Trial 489 pruned.
# [I 2026-08-13 16:41:11,313] Trial 490 pruned.
# [I 2026-08-13 16:41:11,318] Trial 491 pruned.
# [I 2026-08-13 16:41:11,324] Trial 492 pruned.
# [I 2026-08-13 16:41:11,328] Trial 493 pruned.
# [I 2026-08-13 16:41:11,331] Trial 494 pruned.
# [I 2026-08-13 16:41:11,335] Trial 495 pruned.
# [I 2026-08-13 16:41:11,340] Trial 496 pruned.
# [I 2026-08-13 16:41:11,345] Trial 497 pruned.
# [I 2026-08-13 16:41:11,349] Trial 498 pruned.
# [I 2026-08-13 16:41:11,353] Trial 499 pruned.
# [I 2026-08-13 16:41:11,359] Trial 500 pruned.
# [I 2026-08-13 16:41:11,408] Trial 501 finished with value: 1.5698166635416593 and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 16, 'N': 4, 'τ': 7, 'mode': 1, 'act': 1, 'mO': 12}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:11,414] Trial 502 pruned.
# [I 2026-08-13 16:41:11,419] Trial 503 pruned.
# [I 2026-08-13 16:41:11,914] Trial 504 finished with value: 2.016310248059085 and parameters: {'m': 3.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 13, 'N': 1, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:11,959] Trial 505 finished with value: 1.8675226313575315 and parameters: {'m': 4.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 13, 'N': 4, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:11,963] Trial 506 pruned.
# [I 2026-08-13 16:41:11,966] Trial 507 pruned.
# [I 2026-08-13 16:41:11,972] Trial 508 pruned.
# [I 2026-08-13 16:41:11,977] Trial 509 pruned.
# [I 2026-08-13 16:41:11,980] Trial 510 pruned.
# [I 2026-08-13 16:41:11,984] Trial 511 pruned.
# [I 2026-08-13 16:41:11,987] Trial 512 pruned.
# [I 2026-08-13 16:41:11,991] Trial 513 pruned.
# [I 2026-08-13 16:41:11,994] Trial 514 pruned.
# [I 2026-08-13 16:41:11,998] Trial 515 pruned.
# [I 2026-08-13 16:41:12,000] Trial 516 pruned.
# [I 2026-08-13 16:41:12,007] Trial 517 pruned.
# [I 2026-08-13 16:41:12,011] Trial 518 pruned.
# [I 2026-08-13 16:41:12,015] Trial 519 pruned.
# [I 2026-08-13 16:41:12,019] Trial 520 pruned.
# [I 2026-08-13 16:41:12,025] Trial 521 pruned.
# [I 2026-08-13 16:41:12,029] Trial 522 pruned.
# [I 2026-08-13 16:41:12,033] Trial 523 pruned.
# [I 2026-08-13 16:41:12,365] Trial 524 finished with value: 2.57676821864431 and parameters: {'m': 4.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 9, 'N': 8, 'τ': 10, 'mode': 1, 'act': 0, 'mO': 17}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:12,369] Trial 525 pruned.
# [I 2026-08-13 16:41:12,374] Trial 526 pruned.
# [I 2026-08-13 16:41:12,378] Trial 527 pruned.
# [I 2026-08-13 16:41:12,382] Trial 528 pruned.
# [I 2026-08-13 16:41:12,412] Trial 529 finished with value: 2.0487437564511213 and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 9, 'nO': 5, 'N': 8, 'τ': 16, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:12,416] Trial 530 pruned.
# [I 2026-08-13 16:41:12,420] Trial 531 pruned.
# [I 2026-08-13 16:41:12,425] Trial 532 pruned.
# [I 2026-08-13 16:41:12,431] Trial 533 pruned.
# [I 2026-08-13 16:41:12,475] Trial 534 finished with value: 2.5218609085480916 and parameters: {'m': 3.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 8, 'N': 5, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:12,481] Trial 535 pruned.
# [I 2026-08-13 16:41:12,863] Trial 536 finished with value: 2.068231562448447 and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 17, 'N': 2, 'τ': 4, 'mode': 1, 'act': 0, 'mO': 10}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:12,870] Trial 537 pruned.
# [I 2026-08-13 16:41:12,876] Trial 538 pruned.
# [I 2026-08-13 16:41:12,882] Trial 539 pruned.
# [I 2026-08-13 16:41:12,887] Trial 540 pruned.
# [I 2026-08-13 16:41:12,894] Trial 541 pruned.
# [I 2026-08-13 16:41:12,899] Trial 542 pruned.
# [I 2026-08-13 16:41:12,939] Trial 543 finished with value: 1.5202810912256584 and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 29, 'nO': 7, 'N': 3, 'τ': 1, 'mode': 1, 'act': 0, 'mO': 10}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:12,945] Trial 544 pruned.
# [I 2026-08-13 16:41:12,951] Trial 545 pruned.
# [I 2026-08-13 16:41:12,955] Trial 546 pruned.
# [I 2026-08-13 16:41:12,961] Trial 547 pruned.
# [I 2026-08-13 16:41:12,968] Trial 548 pruned.
# [I 2026-08-13 16:41:12,971] Trial 549 pruned.
# [I 2026-08-13 16:41:12,976] Trial 550 pruned.
# [I 2026-08-13 16:41:12,981] Trial 551 pruned.
# [I 2026-08-13 16:41:12,988] Trial 552 pruned.
# [I 2026-08-13 16:41:12,992] Trial 553 pruned.
# [I 2026-08-13 16:41:12,999] Trial 554 pruned.
# [I 2026-08-13 16:41:13,004] Trial 555 pruned.
# [I 2026-08-13 16:41:13,010] Trial 556 pruned.
# [I 2026-08-13 16:41:13,014] Trial 557 pruned.
# [I 2026-08-13 16:41:13,018] Trial 558 pruned.
# [I 2026-08-13 16:41:13,431] Trial 559 finished with value: 3.2324823955327515 and parameters: {'m': 3.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 6, 'N': 1, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:13,437] Trial 560 pruned.
# [I 2026-08-13 16:41:13,440] Trial 561 pruned.
# [I 2026-08-13 16:41:13,444] Trial 562 pruned.
# [I 2026-08-13 16:41:13,448] Trial 563 pruned.
# [I 2026-08-13 16:41:13,452] Trial 564 pruned.
# [I 2026-08-13 16:41:13,455] Trial 565 pruned.
# [I 2026-08-13 16:41:13,458] Trial 566 pruned.
# [I 2026-08-13 16:41:13,462] Trial 567 pruned.
# [I 2026-08-13 16:41:13,466] Trial 568 pruned.
# [I 2026-08-13 16:41:13,470] Trial 569 pruned.
# [I 2026-08-13 16:41:13,473] Trial 570 pruned.
# [I 2026-08-13 16:41:13,478] Trial 571 pruned.
# [I 2026-08-13 16:41:13,482] Trial 572 pruned.
# [I 2026-08-13 16:41:13,486] Trial 573 pruned.
# [I 2026-08-13 16:41:13,490] Trial 574 pruned.
# [I 2026-08-13 16:41:13,493] Trial 575 pruned.
# [I 2026-08-13 16:41:13,497] Trial 576 pruned.
# [I 2026-08-13 16:41:13,500] Trial 577 pruned.
# [I 2026-08-13 16:41:13,506] Trial 578 pruned.
# [I 2026-08-13 16:41:13,539] Trial 579 finished with value: 1.708157120086038 and parameters: {'m': 4.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 2, 'nO': 7, 'N': 8, 'τ': 19, 'mode': 1, 'act': 0, 'mO': 18}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:13,544] Trial 580 pruned.
# [I 2026-08-13 16:41:13,548] Trial 581 pruned.
# [I 2026-08-13 16:41:13,582] Trial 582 finished with value: 2.0847684666240607 and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 2, 'N': 7, 'τ': 8, 'mode': 1, 'act': 0, 'mO': 3}. Best is trial 287 with value: 0.8007590064606651.
# [I 2026-08-13 16:41:13,588] Trial 583 pruned.
# [I 2026-08-13 16:41:13,592] Trial 584 pruned.
# [I 2026-08-13 16:41:13,596] Trial 585 pruned.
# [I 2026-08-13 16:41:13,601] Trial 586 pruned.
# [I 2026-08-13 16:41:13,606] Trial 587 pruned.
# [I 2026-08-13 16:41:13,610] Trial 588 pruned.
# [I 2026-08-13 16:41:13,615] Trial 589 pruned.
# [I 2026-08-13 16:41:13,619] Trial 590 pruned.
# [I 2026-08-13 16:41:13,624] Trial 591 pruned.
# [I 2026-08-13 16:41:13,627] Trial 592 pruned.
# [I 2026-08-13 16:41:13,631] Trial 593 pruned.
# [I 2026-08-13 16:41:13,635] Trial 594 pruned.
# [I 2026-08-13 16:41:13,640] Trial 595 pruned.
# [I 2026-08-13 16:41:13,643] Trial 596 pruned.
# [I 2026-08-13 16:41:13,646] Trial 597 pruned.
# [I 2026-08-13 16:41:13,650] Trial 598 pruned.
# [I 2026-08-13 16:41:13,654] Trial 599 pruned.
# [I 2026-08-13 16:41:13,659] Trial 600 pruned.
# [I 2026-08-13 16:41:13,662] Trial 601 pruned.
# [I 2026-08-13 16:41:13,666] Trial 602 pruned.
# [I 2026-08-13 16:41:13,670] Trial 603 pruned.
# [I 2026-08-13 16:41:13,676] Trial 604 pruned.
# [I 2026-08-13 16:41:13,683] Trial 605 pruned.
# [I 2026-08-13 16:41:13,687] Trial 606 pruned.
# [I 2026-08-13 16:41:13,691] Trial 607 pruned.
# [I 2026-08-13 16:41:13,695] Trial 608 pruned.
# [I 2026-08-13 16:41:13,699] Trial 609 pruned.
# [I 2026-08-13 16:41:13,704] Trial 610 pruned.
# [I 2026-08-13 16:41:13,708] Trial 611 pruned.
# [I 2026-08-13 16:41:13,712] Trial 612 pruned.
# [I 2026-08-13 16:41:13,716] Trial 613 pruned.
# [I 2026-08-13 16:41:13,720] Trial 614 pruned.
# [I 2026-08-13 16:41:13,724] Trial 615 pruned.
# [I 2026-08-13 16:41:13,727] Trial 616 pruned.
# [I 2026-08-13 16:41:13,732] Trial 617 pruned.
# [I 2026-08-13 16:41:13,736] Trial 618 pruned.
# [I 2026-08-13 16:41:13,740] Trial 619 pruned.
# [I 2026-08-13 16:41:13,745] Trial 620 pruned.
# [I 2026-08-13 16:41:13,749] Trial 621 pruned.
# [I 2026-08-13 16:41:13,753] Trial 622 pruned.
# [I 2026-08-13 16:41:13,757] Trial 623 pruned.
# [I 2026-08-13 16:41:13,761] Trial 624 pruned.
# [I 2026-08-13 16:41:13,766] Trial 625 pruned.
# [I 2026-08-13 16:41:13,770] Trial 626 pruned.
# [I 2026-08-13 16:41:13,774] Trial 627 pruned.
# [I 2026-08-13 16:41:13,778] Trial 628 pruned.
# [I 2026-08-13 16:41:13,782] Trial 629 pruned.
# [I 2026-08-13 16:41:13,785] Trial 630 pruned.
# [I 2026-08-13 16:41:13,789] Trial 631 pruned.
# [I 2026-08-13 16:41:13,793] Trial 632 pruned.
# [I 2026-08-13 16:41:13,797] Trial 633 pruned.
# [I 2026-08-13 16:41:13,802] Trial 634 pruned.
# [I 2026-08-13 16:41:13,805] Trial 635 pruned.
# [I 2026-08-13 16:41:13,812] Trial 636 pruned.
# [I 2026-08-13 16:41:13,819] Trial 637 pruned.
# [I 2026-08-13 16:41:14,030] Trial 638 finished with value: 0.5559525415834471 and parameters: {'m': 2.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 1, 'N': 9, 'τ': 9, 'mode': 1, 'act': 1, 'mO': 18}. Best is trial 638 with value: 0.5559525415834471.
# [I 2026-08-13 16:41:14,035] Trial 639 pruned.
# [I 2026-08-13 16:41:14,040] Trial 640 pruned.
# [I 2026-08-13 16:41:14,046] Trial 641 pruned.
# [I 2026-08-13 16:41:14,052] Trial 642 pruned.
# [I 2026-08-13 16:41:14,059] Trial 643 pruned.
# [I 2026-08-13 16:41:14,065] Trial 644 pruned.
# [I 2026-08-13 16:41:14,071] Trial 645 pruned.
# [I 2026-08-13 16:41:14,075] Trial 646 pruned.
# [I 2026-08-13 16:41:14,081] Trial 647 pruned.
# [I 2026-08-13 16:41:14,087] Trial 648 pruned.
# [I 2026-08-13 16:41:14,092] Trial 649 pruned.
# [I 2026-08-13 16:41:14,098] Trial 650 pruned.
# [I 2026-08-13 16:41:14,103] Trial 651 pruned.
# [I 2026-08-13 16:41:14,107] Trial 652 pruned.
# [I 2026-08-13 16:41:14,112] Trial 653 pruned.
# [I 2026-08-13 16:41:14,116] Trial 654 pruned.
# [I 2026-08-13 16:41:14,120] Trial 655 pruned.
# [I 2026-08-13 16:41:14,125] Trial 656 pruned.
# [I 2026-08-13 16:41:14,130] Trial 657 pruned.
# [I 2026-08-13 16:41:14,136] Trial 658 pruned.
# [I 2026-08-13 16:41:14,143] Trial 659 pruned.
# [I 2026-08-13 16:41:14,150] Trial 660 pruned.
# [I 2026-08-13 16:41:14,585] Trial 661 finished with value: 2.452709815202152 and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 8, 'N': 2, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 638 with value: 0.5559525415834471.
# [I 2026-08-13 16:41:14,589] Trial 662 pruned.
# [I 2026-08-13 16:41:14,593] Trial 663 pruned.
# [I 2026-08-13 16:41:14,596] Trial 664 pruned.
# [I 2026-08-13 16:41:14,601] Trial 665 pruned.
# [I 2026-08-13 16:41:14,605] Trial 666 pruned.
# [I 2026-08-13 16:41:14,611] Trial 667 pruned.
# [I 2026-08-13 16:41:14,615] Trial 668 pruned.
# [I 2026-08-13 16:41:14,621] Trial 669 pruned.
# [I 2026-08-13 16:41:14,626] Trial 670 pruned.
# [I 2026-08-13 16:41:14,633] Trial 671 pruned.
# [I 2026-08-13 16:41:14,641] Trial 672 pruned.
# [I 2026-08-13 16:41:14,645] Trial 673 pruned.
# [I 2026-08-13 16:41:14,652] Trial 674 pruned.
# [I 2026-08-13 16:41:14,660] Trial 675 pruned.
# [I 2026-08-13 16:41:14,666] Trial 676 pruned.
# [I 2026-08-13 16:41:14,674] Trial 677 pruned.
# [I 2026-08-13 16:41:15,198] Trial 678 finished with value: 2.3360971509444948 and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 6, 'N': 4, 'τ': 11, 'mode': 1, 'act': 0, 'mO': 12}. Best is trial 638 with value: 0.5559525415834471.
# [I 2026-08-13 16:41:15,204] Trial 679 pruned.
# [I 2026-08-13 16:41:15,210] Trial 680 pruned.
# [I 2026-08-13 16:41:15,216] Trial 681 pruned.
# [I 2026-08-13 16:41:15,220] Trial 682 pruned.
# [I 2026-08-13 16:41:15,225] Trial 683 pruned.
# [I 2026-08-13 16:41:15,231] Trial 684 pruned.
# [I 2026-08-13 16:41:15,236] Trial 685 pruned.
# [I 2026-08-13 16:41:15,242] Trial 686 pruned.
# [I 2026-08-13 16:41:15,246] Trial 687 pruned.
# [I 2026-08-13 16:41:15,250] Trial 688 pruned.
# [I 2026-08-13 16:41:15,254] Trial 689 pruned.
# [I 2026-08-13 16:41:15,260] Trial 690 pruned.
# [I 2026-08-13 16:41:15,267] Trial 691 pruned.
# [I 2026-08-13 16:41:15,276] Trial 692 pruned.
# [I 2026-08-13 16:41:15,283] Trial 693 pruned.
# [I 2026-08-13 16:41:15,289] Trial 694 pruned.
# [I 2026-08-13 16:41:15,296] Trial 695 pruned.
# [I 2026-08-13 16:41:15,300] Trial 696 pruned.
# [I 2026-08-13 16:41:15,307] Trial 697 pruned.
# [I 2026-08-13 16:41:15,313] Trial 698 pruned.
# [I 2026-08-13 16:41:15,318] Trial 699 pruned.
# [I 2026-08-13 16:41:15,324] Trial 700 pruned.
# [I 2026-08-13 16:41:15,328] Trial 701 pruned.
# [I 2026-08-13 16:41:15,334] Trial 702 pruned.
# [I 2026-08-13 16:41:15,338] Trial 703 pruned.
# [I 2026-08-13 16:41:15,342] Trial 704 pruned.
# [I 2026-08-13 16:41:15,346] Trial 705 pruned.
# [I 2026-08-13 16:41:15,351] Trial 706 pruned.
# [I 2026-08-13 16:41:15,355] Trial 707 pruned.
# [I 2026-08-13 16:41:15,360] Trial 708 pruned.
# [I 2026-08-13 16:41:15,366] Trial 709 pruned.
# [I 2026-08-13 16:41:15,370] Trial 710 pruned.
# [I 2026-08-13 16:41:15,375] Trial 711 pruned.
# [I 2026-08-13 16:41:15,705] Trial 712 finished with value: 0.5798158748926759 and parameters: {'m': 3.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 6, 'N': 6, 'τ': 22, 'mode': 1, 'act': 0, 'mO': 9}. Best is trial 638 with value: 0.5559525415834471.
# [I 2026-08-13 16:41:15,712] Trial 713 pruned.
# [I 2026-08-13 16:41:15,720] Trial 714 pruned.
# [I 2026-08-13 16:41:15,728] Trial 715 pruned.
# [I 2026-08-13 16:41:15,735] Trial 716 pruned.
# [I 2026-08-13 16:41:15,740] Trial 717 pruned.
# [I 2026-08-13 16:41:15,744] Trial 718 pruned.
# [I 2026-08-13 16:41:15,749] Trial 719 pruned.
# [I 2026-08-13 16:41:15,753] Trial 720 pruned.
# [I 2026-08-13 16:41:15,760] Trial 721 pruned.
# [I 2026-08-13 16:41:15,764] Trial 722 pruned.
# [I 2026-08-13 16:41:15,770] Trial 723 pruned.
# [I 2026-08-13 16:41:15,775] Trial 724 pruned.
# [I 2026-08-13 16:41:15,782] Trial 725 pruned.
# [I 2026-08-13 16:41:15,787] Trial 726 pruned.
# [I 2026-08-13 16:41:15,793] Trial 727 pruned.
# [I 2026-08-13 16:41:15,799] Trial 728 pruned.
# [I 2026-08-13 16:41:15,806] Trial 729 pruned.
# [I 2026-08-13 16:41:15,812] Trial 730 pruned.
# [I 2026-08-13 16:41:15,817] Trial 731 pruned.
# [I 2026-08-13 16:41:15,822] Trial 732 pruned.
# [I 2026-08-13 16:41:15,826] Trial 733 pruned.
# [I 2026-08-13 16:41:15,831] Trial 734 pruned.
# [I 2026-08-13 16:41:15,836] Trial 735 pruned.
# [I 2026-08-13 16:41:15,840] Trial 736 pruned.
# [I 2026-08-13 16:41:15,844] Trial 737 pruned.
# [I 2026-08-13 16:41:15,848] Trial 738 pruned.
# [I 2026-08-13 16:41:15,851] Trial 739 pruned.
# [I 2026-08-13 16:41:15,856] Trial 740 pruned.
# [I 2026-08-13 16:41:15,861] Trial 741 pruned.
# [I 2026-08-13 16:41:15,868] Trial 742 pruned.
# [I 2026-08-13 16:41:15,873] Trial 743 pruned.
# [I 2026-08-13 16:41:15,879] Trial 744 pruned.
# [I 2026-08-13 16:41:16,146] Trial 745 finished with value: 2.195612464660317 and parameters: {'m': 3.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 8, 'N': 2, 'τ': 6, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 638 with value: 0.5559525415834471.
# [I 2026-08-13 16:41:16,151] Trial 746 pruned.
# [I 2026-08-13 16:41:16,440] Trial 747 finished with value: 1.8589777125138605 and parameters: {'m': 2.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 11, 'nO': 20, 'N': 5, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 4}. Best is trial 638 with value: 0.5559525415834471.
# [I 2026-08-13 16:41:16,447] Trial 748 pruned.
# [I 2026-08-13 16:41:16,452] Trial 749 pruned.
# [I 2026-08-13 16:41:16,457] Trial 750 pruned.
# [I 2026-08-13 16:41:16,465] Trial 751 pruned.
# [I 2026-08-13 16:41:16,469] Trial 752 pruned.
# [I 2026-08-13 16:41:16,477] Trial 753 pruned.
# [I 2026-08-13 16:41:16,484] Trial 754 pruned.
# [I 2026-08-13 16:41:16,492] Trial 755 pruned.
# [I 2026-08-13 16:41:16,499] Trial 756 pruned.
# [I 2026-08-13 16:41:16,505] Trial 757 pruned.
# [I 2026-08-13 16:41:16,512] Trial 758 pruned.
# [I 2026-08-13 16:41:16,519] Trial 759 pruned.
# [I 2026-08-13 16:41:16,525] Trial 760 pruned.
# [I 2026-08-13 16:41:16,531] Trial 761 pruned.
# [I 2026-08-13 16:41:16,537] Trial 762 pruned.
# [I 2026-08-13 16:41:16,544] Trial 763 pruned.
# [I 2026-08-13 16:41:16,552] Trial 764 pruned.
# [I 2026-08-13 16:41:16,559] Trial 765 pruned.
# [I 2026-08-13 16:41:16,614] Trial 766 finished with value: 2.4705060678238335 and parameters: {'m': 3.0, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 18, 'N': 7, 'τ': 19, 'mode': 1, 'act': 0, 'mO': 5}. Best is trial 638 with value: 0.5559525415834471.
# [I 2026-08-13 16:41:16,622] Trial 767 pruned.
# [I 2026-08-13 16:41:16,629] Trial 768 pruned.
# [I 2026-08-13 16:41:16,636] Trial 769 pruned.
# [I 2026-08-13 16:41:16,641] Trial 770 pruned.
# [I 2026-08-13 16:41:16,647] Trial 771 pruned.
# [I 2026-08-13 16:41:16,653] Trial 772 pruned.
# [I 2026-08-13 16:41:16,658] Trial 773 pruned.
# [I 2026-08-13 16:41:16,664] Trial 774 pruned.
# [I 2026-08-13 16:41:16,669] Trial 775 pruned.
# [I 2026-08-13 16:41:16,674] Trial 776 pruned.
# [I 2026-08-13 16:41:16,679] Trial 777 pruned.
# [I 2026-08-13 16:41:16,686] Trial 778 pruned.
# [I 2026-08-13 16:41:16,694] Trial 779 pruned.
# [I 2026-08-13 16:41:16,699] Trial 780 pruned.
# [I 2026-08-13 16:41:16,705] Trial 781 pruned.
# [I 2026-08-13 16:41:16,710] Trial 782 pruned.
# [I 2026-08-13 16:41:16,717] Trial 783 pruned.
# [I 2026-08-13 16:41:16,722] Trial 784 pruned.
# [I 2026-08-13 16:41:16,727] Trial 785 pruned.
# [I 2026-08-13 16:41:16,731] Trial 786 pruned.
# [I 2026-08-13 16:41:16,736] Trial 787 pruned.
# [I 2026-08-13 16:41:16,741] Trial 788 pruned.
# [I 2026-08-13 16:41:16,746] Trial 789 pruned.
# [I 2026-08-13 16:41:16,754] Trial 790 pruned.
# [I 2026-08-13 16:41:16,760] Trial 791 pruned.
# [I 2026-08-13 16:41:16,765] Trial 792 pruned.
# [I 2026-08-13 16:41:16,769] Trial 793 pruned.
# [I 2026-08-13 16:41:16,776] Trial 794 pruned.
# [I 2026-08-13 16:41:16,781] Trial 795 pruned.
# [I 2026-08-13 16:41:16,788] Trial 796 pruned.
# [I 2026-08-13 16:41:16,793] Trial 797 pruned.
# [I 2026-08-13 16:41:16,799] Trial 798 pruned.
# [I 2026-08-13 16:41:16,805] Trial 799 pruned.
# [I 2026-08-13 16:41:16,810] Trial 800 pruned.
# [I 2026-08-13 16:41:16,817] Trial 801 pruned.
# [I 2026-08-13 16:41:16,825] Trial 802 pruned.
# [I 2026-08-13 16:41:16,831] Trial 803 pruned.
# [I 2026-08-13 16:41:16,835] Trial 804 pruned.
# [I 2026-08-13 16:41:16,840] Trial 805 pruned.
# [I 2026-08-13 16:41:16,845] Trial 806 pruned.
# [I 2026-08-13 16:41:16,850] Trial 807 pruned.
# [I 2026-08-13 16:41:16,854] Trial 808 pruned.
# [I 2026-08-13 16:41:16,858] Trial 809 pruned.
# [I 2026-08-13 16:41:16,863] Trial 810 pruned.
# [I 2026-08-13 16:41:16,867] Trial 811 pruned.
# [I 2026-08-13 16:41:16,872] Trial 812 pruned.
# [I 2026-08-13 16:41:16,878] Trial 813 pruned.
# [I 2026-08-13 16:41:16,883] Trial 814 pruned.
# ...
# [I 2026-08-13 16:41:43,110] Trial 1111 finished with value: 1.9005067399853957 and parameters: {'m': 4.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 3, 'nO': 9, 'N': 3, 'τ': 11, 'mode': 1, 'act': 0, 'mO': 6}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:43,216] Trial 1112 finished with value: 1.5860962949790771 and parameters: {'m': 2.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 11, 'N': 6, 'τ': 9, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:43,310] Trial 1113 finished with value: 2.020669592909856 and parameters: {'m': 2.25, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 1, 'N': 9, 'τ': 24, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:43,418] Trial 1114 finished with value: 1.4870868742487633 and parameters: {'m': 4.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 16, 'N': 3, 'τ': 1, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:43,440] Trial 1115 pruned.
# [I 2026-08-13 16:41:43,464] Trial 1116 pruned.
# [I 2026-08-13 16:41:43,570] Trial 1117 finished with value: 2.329662709540954 and parameters: {'m': 4.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 60, 'nO': 11, 'N': 3, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:43,593] Trial 1118 pruned.
# [I 2026-08-13 16:41:43,619] Trial 1119 pruned.
# [I 2026-08-13 16:41:44,416] Trial 1120 finished with value: 3.0069023042320584 and parameters: {'m': 2.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 27, 'nO': 12, 'N': 4, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:45,177] Trial 1121 finished with value: 1.9782524288345558 and parameters: {'m': 4.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 59, 'nO': 14, 'N': 5, 'τ': 1, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:45,197] Trial 1122 pruned.
# [I 2026-08-13 16:41:45,284] Trial 1123 finished with value: 2.064740610949463 and parameters: {'m': 3.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 4, 'N': 3, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:45,384] Trial 1124 finished with value: 1.6243686542478326 and parameters: {'m': 2.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 25, 'nO': 13, 'N': 4, 'τ': 9, 'mode': 1, 'act': 1, 'mO': 10}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:45,952] Trial 1125 finished with value: 3.040232704353422 and parameters: {'m': 2.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 65, 'nO': 6, 'N': 9, 'τ': 18, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:46,861] Trial 1126 finished with value: 7.3386748053175745 and parameters: {'m': 4.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 3, 'N': 1, 'τ': 16, 'mode': 1, 'act': 1, 'mO': 7}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:47,504] Trial 1127 finished with value: 3.045042063021432 and parameters: {'m': 3.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 10, 'N': 1, 'τ': 7, 'mode': 1, 'act': 0, 'mO': 3}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:47,526] Trial 1128 pruned.
# [I 2026-08-13 16:41:47,549] Trial 1129 pruned.
# [I 2026-08-13 16:41:47,571] Trial 1130 pruned.
# [I 2026-08-13 16:41:47,594] Trial 1131 pruned.
# [I 2026-08-13 16:41:47,616] Trial 1132 pruned.
# [I 2026-08-13 16:41:47,639] Trial 1133 pruned.
# [I 2026-08-13 16:41:48,392] Trial 1134 finished with value: 2.0058604426285402 and parameters: {'m': 2.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 17, 'N': 2, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 11}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:48,415] Trial 1135 pruned.
# [I 2026-08-13 16:41:48,436] Trial 1136 pruned.
# [I 2026-08-13 16:41:48,459] Trial 1137 pruned.
# [I 2026-08-13 16:41:48,482] Trial 1138 pruned.
# [I 2026-08-13 16:41:48,635] Trial 1139 finished with value: 0.9335348199441877 and parameters: {'m': 4.25, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 40, 'nO': 4, 'N': 2, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 2}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:48,973] Trial 1140 finished with value: 0.43482925973329867 and parameters: {'m': 2.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 14, 'N': 7, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 6}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:48,998] Trial 1141 pruned.
# [I 2026-08-13 16:41:49,020] Trial 1142 pruned.
# [I 2026-08-13 16:41:49,261] Trial 1143 finished with value: 2.3406211781766553 and parameters: {'m': 2.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 65, 'nO': 10, 'N': 6, 'τ': 22, 'mode': 1, 'act': 0, 'mO': 5}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:49,406] Trial 1144 finished with value: 2.085890797146675 and parameters: {'m': 4.5, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 11, 'N': 5, 'τ': 19, 'mode': 1, 'act': 0, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:49,432] Trial 1145 pruned.
# [I 2026-08-13 16:41:49,453] Trial 1146 pruned.
# [I 2026-08-13 16:41:49,480] Trial 1147 pruned.
# [I 2026-08-13 16:41:49,683] Trial 1148 finished with value: 1.1331339011685455 and parameters: {'m': 4.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 12, 'N': 4, 'τ': 11, 'mode': 1, 'act': 0, 'mO': 9}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:49,720] Trial 1149 pruned.
# [I 2026-08-13 16:41:49,922] Trial 1150 finished with value: 1.4180927255911016 and parameters: {'m': 4.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 51, 'nO': 7, 'N': 3, 'τ': 12, 'mode': 1, 'act': 0, 'mO': 8}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:50,009] Trial 1151 finished with value: 2.2035788055874166 and parameters: {'m': 4.5, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 58, 'nO': 7, 'N': 4, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:50,665] Trial 1152 finished with value: 0.9517008951258825 and parameters: {'m': 4.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 57, 'nO': 2, 'N': 1, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:51,064] Trial 1153 finished with value: 0.82469684352501 and parameters: {'m': 4.5, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 50, 'nO': 2, 'N': 1, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:52,136] Trial 1154 finished with value: 3.231934326511473 and parameters: {'m': 3.75, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 1, 'N': 2, 'τ': 6, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:52,230] Trial 1155 finished with value: 2.4963889046578336 and parameters: {'m': 4.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 3, 'N': 3, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:52,253] Trial 1156 pruned.
# [I 2026-08-13 16:41:52,275] Trial 1157 pruned.
# [I 2026-08-13 16:41:53,306] Trial 1158 finished with value: 3.0617453962151995 and parameters: {'m': 4.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 56, 'nO': 2, 'N': 2, 'τ': 6, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:53,330] Trial 1159 pruned.
# [I 2026-08-13 16:41:53,357] Trial 1160 pruned.
# [I 2026-08-13 16:41:54,473] Trial 1161 finished with value: 2.797284432528879 and parameters: {'m': 4.5, 'nI': 2, 'n_layers': 1, 'nR_layer_0': 59, 'nO': 1, 'N': 2, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:54,496] Trial 1162 pruned.
# [I 2026-08-13 16:41:55,372] Trial 1163 finished with value: 2.2366896702093007 and parameters: {'m': 4.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 44, 'nO': 11, 'N': 1, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 5}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:55,966] Trial 1164 finished with value: 0.6824191538183759 and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 3, 'N': 1, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:55,988] Trial 1165 pruned.
# [I 2026-08-13 16:41:56,058] Trial 1166 finished with value: 2.370170881538451 and parameters: {'m': 3.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 36, 'nO': 11, 'N': 9, 'τ': 10, 'mode': 1, 'act': 1, 'mO': 19}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:56,081] Trial 1167 pruned.
# [I 2026-08-13 16:41:57,124] Trial 1168 finished with value: 2.1135925187527054 and parameters: {'m': 3.25, 'nI': 3, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 13, 'N': 1, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:57,635] Trial 1169 finished with value: 1.7666598428827276 and parameters: {'m': 4.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 13, 'nO': 17, 'N': 2, 'τ': 11, 'mode': 1, 'act': 0, 'mO': 7}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:58,459] Trial 1170 finished with value: 2.137636022120268 and parameters: {'m': 3.0, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 2, 'nO': 6, 'N': 1, 'τ': 9, 'mode': 1, 'act': 1, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:59,020] Trial 1171 finished with value: 0.7003952255276905 and parameters: {'m': 4.0, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 14, 'N': 3, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 3}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:59,097] Trial 1172 finished with value: 1.914179656754726 and parameters: {'m': 4.25, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 63, 'nO': 18, 'N': 5, 'τ': 12, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:41:59,927] Trial 1173 finished with value: 1.7644374721772578 and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 51, 'nO': 4, 'N': 2, 'τ': 1, 'mode': 1, 'act': 1, 'mO': 6}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:00,388] Trial 1174 finished with value: 2.355297017945819 and parameters: {'m': 3.75, 'nI': 2, 'n_layers': 1, 'nR_layer_0': 53, 'nO': 11, 'N': 2, 'τ': 1, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:01,312] Trial 1175 finished with value: 2.693964427835094 and parameters: {'m': 3.75, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 58, 'nO': 4, 'N': 2, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:02,003] Trial 1176 finished with value: 2.425977566466612 and parameters: {'m': 3.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 26, 'nO': 11, 'N': 1, 'τ': 10, 'mode': 1, 'act': 1, 'mO': 8}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:03,021] Trial 1177 finished with value: 2.4877754069098477 and parameters: {'m': 4.25, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 56, 'nO': 3, 'N': 1, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:03,051] Trial 1178 pruned.
# [I 2026-08-13 16:42:03,333] Trial 1179 finished with value: 0.44849010727653194 and parameters: {'m': 3.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 19, 'N': 3, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:03,980] Trial 1180 finished with value: 0.5971562655348923 and parameters: {'m': 4.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 11, 'N': 1, 'τ': 13, 'mode': 1, 'act': 0, 'mO': 2}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:04,798] Trial 1181 finished with value: 2.1959118676058282 and parameters: {'m': 3.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 13, 'N': 3, 'τ': 13, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:04,821] Trial 1182 pruned.
# [I 2026-08-13 16:42:04,844] Trial 1183 pruned.
# [I 2026-08-13 16:42:05,598] Trial 1184 finished with value: 9.340069545429504 and parameters: {'m': 2.75, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 1, 'N': 1, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:05,843] Trial 1185 finished with value: 0.9517162889679406 and parameters: {'m': 4.0, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 13, 'N': 2, 'τ': 1, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:05,879] Trial 1186 pruned.
# [I 2026-08-13 16:42:05,962] Trial 1187 finished with value: 1.799931128800368 and parameters: {'m': 3.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 16, 'nO': 20, 'N': 4, 'τ': 7, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:06,040] Trial 1188 finished with value: 2.0821650733658226 and parameters: {'m': 2.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 17, 'N': 7, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 11}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:06,063] Trial 1189 pruned.
# [I 2026-08-13 16:42:06,086] Trial 1190 pruned.
# [I 2026-08-13 16:42:06,109] Trial 1191 pruned.
# [I 2026-08-13 16:42:07,065] Trial 1192 finished with value: 2.8563031863823323 and parameters: {'m': 3.75, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 59, 'nO': 4, 'N': 1, 'τ': 11, 'mode': 1, 'act': 0, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:07,097] Trial 1193 pruned.
# [I 2026-08-13 16:42:08,050] Trial 1194 finished with value: 2.2553035217104513 and parameters: {'m': 4.25, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 8, 'N': 1, 'τ': 1, 'mode': 1, 'act': 0, 'mO': 5}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:08,073] Trial 1195 pruned.
# [I 2026-08-13 16:42:08,151] Trial 1196 finished with value: 2.1298069832288173 and parameters: {'m': 3.75, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 10, 'N': 9, 'τ': 13, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:08,179] Trial 1197 pruned.
# [I 2026-08-13 16:42:08,203] Trial 1198 pruned.
# [I 2026-08-13 16:42:08,232] Trial 1199 pruned.
# [I 2026-08-13 16:42:08,777] Trial 1200 finished with value: 1.1024717334408511 and parameters: {'m': 4.25, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 17, 'N': 3, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 3}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:08,940] Trial 1201 finished with value: 0.943023338000849 and parameters: {'m': 3.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 8, 'N': 8, 'τ': 22, 'mode': 1, 'act': 0, 'mO': 3}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:08,966] Trial 1202 pruned.
# [I 2026-08-13 16:42:09,414] Trial 1203 finished with value: 1.727501160193874 and parameters: {'m': 4.0, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 19, 'N': 3, 'τ': 19, 'mode': 1, 'act': 0, 'mO': 0}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:09,437] Trial 1204 pruned.
# [I 2026-08-13 16:42:10,523] Trial 1205 finished with value: 2.2961286903718885 and parameters: {'m': 4.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 3, 'N': 1, 'τ': 1, 'mode': 1, 'act': 1, 'mO': 4}. Best is trial 1064 with value: 0.23505736041911643.
# [I 2026-08-13 16:42:10,547] Trial 1206 pruned.
# [I 2026-08-13 16:42:10,656] Trial 1207 finished with value: 2.1794111986064144 and parameters: {'m': 4.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 15, 'N': 3, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 1}. Best is trial 1064 with value: 0.23505736041911643.

# %%
df = dfs[0]
#df = df[(df.iloc[:,0] <= 0.07)]
params_list = df.values[:,-9:]
df

# %%
tedas = []
for i,params in enumerate(params_list):
    m,nI,nR,nO,mO,N1,τ,mode,act = params
    X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
    if isinstance(nR, str): nR = ast.literal_eval(nR)

    teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N1],mode=mode,act=act,
                tau=τ,rho=0.03,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
    for j,_ in enumerate(X[:]):
        teda.run(X[j])
        teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1,show=False)
        teda.Adapt(Y[j],Z[j])

    teda.c = np.append(teda.c,teda.gm)  
    tedas.append(teda)
    #PlotSeriesPLY(ySeries=[teda.wape_HI_hist,teda.wape_RUL_hist])

# %%
PlotDSI_3D_PLT(tedas[0])
