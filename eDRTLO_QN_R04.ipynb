# %%
import math
import ast
import ipynbname
import pandas as pd
import numpy as np
import optuna
from Testing.DRTLO_QN_R1 import *
from Functions.AutoCloud_V2 import *
from Functions.DataCloud_V2 import *
from Functions.Utils import *
from Functions.Graphs import *
from Functions.TedaGraphs import *
from Functions.Utils_OPT import *

FileName = ipynbname.name()
out_path = f'Optimization\\eDRTLO_QN\\multi\\Optimization.csv'
RS = pd.read_excel(r'Dataset\RS.xlsx')
HI = pd.read_csv(r'Dataset\Bearing1_1.csv')
sig = HI['PC1'].values

# %%
params =  {'nI': 3, 'nR': 3, 'nO': 3, 'N1': 0.1,
            'τ': 23, 'mode': 1, 'act': 0}

nI,nR,nO,N1,τ,mode,act= list(params.values())
X, Y, Z = PrepareData(RS, HI, nX=nI, nY=nO, mY=0, nZ=1, mode='past')

teda=AutoCloud(m=2.5,nI=nI,nR=[nR],nO=nO,ηS=[N1],mode=mode,
               tau=τ,rho=0.01,eol=0.3,ref=len(sig)-nI,wtaG=True,wtaP=True) 
for j,_ in enumerate(X[:]):
    teda.run(X[j])
    teda.RUL_Prediction(Y[j],mode='interval',lim=len(sig)-nI+1,show=False)
    teda.Adapt(Y[j],Z[j])

#teda.RUL_Granularity()
#print(teda.wape_HI,teda.wape_RUL)
#PlotDSI_3D_PLT(teda)
#teda.c = np.append(teda.c,teda.gm)   
#PlotGranulesSpace(teda,w=700,h=700)

# %%
print(xxx)

# %%
def Optimize(
        FileName=None,OptDim=None,OptSampler=None,OptSeed=None,OptPrune=False,
        n_study=None,timeout=None,n_trials=None,
        patience=None,
        mS =None,nIS=None,nLS=None,nRS=None,nOS =None,mOS=None,
        NS=None,τS =None,mdS=None,actS=None):

    '''
        OptSampler modes available: None, Auto, GP, NSGAII, Random, TPE
    
        None: sampler default, suport multivariate optimization

        GP: suport multivariate optimization

        Auto: suport multivariate optimization
        
        NSGAII: poorly suport multivariate optimization
        
        Random: poorly suport multivariate optimization

        TPE: suport multivariate optimization
    '''

    if OptDim == 1 or OptDim is None: SingleObj = True
    elif OptDim > 1: SingleObj = False    
    if n_study is None: n_study = 1
    if timeout is None: timeout = 60
    if n_trials is None and patience is None: 
        n_trials = 25
        patience = 25
    elif n_trials < 100 and patience is None:
        patience = int(0.25*n_trials)
    elif n_trials >= 1e2 and n_trials < 1e3 and patience is None:
        patience = int(0.20*n_trials)
    elif n_trials >= 1e3 and n_trials < 5e3 and patience is None:
        patience = int(0.150*n_trials)
    elif n_trials >= 5e3 and n_trials < 1e4 and patience is None:
        patience = int(0.125*n_trials)    
    elif n_trials >= 1e4 and patience is None:
        patience = int(0.03*n_trials)   

    if mS  is None: mS  = [1.75,4.25]
    if nIS is None: nIS = [2,40]
    if nLS is None: nLS = [1,5]
    if nRS is None: nRS = [1,60]
    if nOS is None: nOS = [1,40]
    if mOS is None: mOS = [0,40]
    if NS is None: NS = [1,9]
    if τS  is None: τS  = [1,25]
    if mdS is None: mdS = [0,1]
    if actS is None: actS = [0,1,2]

    if SingleObj: names = ['MAPE_RUL*MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N','TAU','past/ahead','activation']
    else: names = ['MAPE_RUL','MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N', 'TAU','past/ahead','activation']
    study_dir, out_path = df_ParamsTable(names,FileName)

    for i in range(n_study):
        print('iteration:',i+1)
        def objective(trial):
            m = trial.suggest_float('m', mS[0], mS[1],step=0.25)
            nI = trial.suggest_int('nI', nIS[0], nIS[1]) 
            n_layers = trial.suggest_int('n_layers', nLS[0], nLS[1])
            nR = [trial.suggest_int(f'nR_layer_{l}', nRS[0], nRS[1]) for l in range(n_layers)]
            nO = trial.suggest_int('nO', nOS[0], nOS[1]) 
            N = trial.suggest_int('N', NS[0], NS[1])
            τ = trial.suggest_int('τ', τS[0], τS[1])
            mode = trial.suggest_int('mode', mdS[0], mdS[1])  
            act = trial.suggest_int('act', actS[0], actS[1])  

            if mode == 'past' or mode == 0:
                mO = trial.suggest_int('mO', 0, 0) 
                if nO > nI: raise TrialPruned()

            elif mode == 'ahead' or mode == 1:
                mO = trial.suggest_int('mO', mOS[0], mOS[1]) 
                if   nI > 20 or nO > 20: raise TrialPruned()
                elif mO > nI: raise TrialPruned()
                
            X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
            
            teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N],mode=mode,act=act,
                           tau=τ,rho=0.0,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
            
            for j,_ in enumerate(X[:]):
                teda.run(X[j])
                teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1)
                teda.Adapt(Y[j],Z[j])
                #teda.WAPE_HI2(Y[j],Z[j])

                if np.isinf(teda.hiP[-1]) or np.isnan(teda.hiP[-1]): raise TrialPruned()
                if not OptPrune: continue
        
                if j >=60 and j%5==0:
                    if teda.wape_RUL > 0.6: raise TrialPruned()
                    if teda.wape_HI  > 0.3: raise TrialPruned()

                if SingleObj and j%35==0:
                    trial.report(teda.wape_RUL+teda.wape_HI, j)
                    if trial.should_prune():
                        raise optuna.TrialPruned()

            if SingleObj: return teda.wape_RUL + teda.wape_HI
            else: return teda.wape_RUL,teda.wape_HI

        pruner=optuna.pruners.HyperbandPruner()
        if SingleObj: study = optuna.create_study(direction='minimize',pruner=pruner,sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        else: study = optuna.create_study(directions=['minimize','minimize'],sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        study.optimize(objective, n_trials=n_trials, timeout=timeout, callbacks=[EarlyStoppingCallback(patience=patience)])

        vec = []
        if SingleObj:
            trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
            for trial in trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]   
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
            df2 = df2.sort_values(by=df2.columns[0], ascending=False)[-5:]

        elif not SingleObj: 
            for trial in study.best_trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],trial.values[1],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
        
    if os.path.isfile(out_path) and out_path.startswith(study_dir):
        df1 = pd.read_csv(out_path)
        df_stdy = pd.concat([df1, df2], ignore_index=True)
    
    else: df_stdy = df2
    
    df_stdy.to_csv(out_path, index=False)
    opt_path = os.path.join(study_dir,f'opt_{len(os.listdir(study_dir))-1}.csv')
    
    if df2.shape[0] > 0: df2.to_csv(opt_path, index=False)

    return [df_stdy, df2 ]

# %%
dfs = Optimize(FileName=FileName[:-4],OptDim=2,OptSampler=None,OptPrune=False,
                         n_study=1,timeout=60,n_trials=0.5e3,patience=None,
                         mS=[2.0,4.5],nRS=[1,70],mdS=[1,1],actS=[0,1])

# %%
for i in range(1,6):
    dfs = Optimize(FileName=FileName[:-4],OptDim=2,OptSampler=None,OptPrune=False,
                            n_study=6,timeout=1680,n_trials=2e4,patience=2e3,
                            mS=[2.0,4.5],nLS=[i,i],nRS=[1,70],mdS=[1,1],actS=[0,1])
# Out:
# [I 2026-08-13 16:40:18,948] A new study created in memory with name: no-name-4226856d-dc50-43e1-b4be-7630e65cd002
# [I 2026-08-13 16:40:18,949] Trial 0 pruned.
# iteration: 1
# [I 2026-08-13 16:40:19,145] Trial 1 finished with values: [0.12195228952905594, 0.08421159713137917] and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 6, 'N': 5, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:19,148] Trial 2 pruned.
# [I 2026-08-13 16:40:19,149] Trial 3 pruned.
# [I 2026-08-13 16:40:19,151] Trial 4 pruned.
# [I 2026-08-13 16:40:19,154] Trial 5 pruned.
# [I 2026-08-13 16:40:19,157] Trial 6 pruned.
# [I 2026-08-13 16:40:19,159] Trial 7 pruned.
# [I 2026-08-13 16:40:19,161] Trial 8 pruned.
# [I 2026-08-13 16:40:19,162] Trial 9 pruned.
# [I 2026-08-13 16:40:19,702] Trial 10 finished with values: [2.9879329803290093, 0.4352072191075546] and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 1, 'N': 6, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:19,704] Trial 11 pruned.
# [I 2026-08-13 16:40:19,706] Trial 12 pruned.
# [I 2026-08-13 16:40:19,708] Trial 13 pruned.
# [I 2026-08-13 16:40:19,711] Trial 14 pruned.
# [I 2026-08-13 16:40:20,100] Trial 15 finished with values: [1.837387079599969, 0.6680018410821996] and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 15, 'N': 7, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 16}.
# [I 2026-08-13 16:40:20,102] Trial 16 pruned.
# [I 2026-08-13 16:40:20,104] Trial 17 pruned.
# [I 2026-08-13 16:40:20,107] Trial 18 pruned.
# [I 2026-08-13 16:40:20,109] Trial 19 pruned.
# [I 2026-08-13 16:40:20,139] Trial 20 finished with values: [0.9750783612730076, 1.411298235814392] and parameters: {'m': 3.0, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 16, 'N': 9, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:20,141] Trial 21 pruned.
# [I 2026-08-13 16:40:20,144] Trial 22 pruned.
# [I 2026-08-13 16:40:20,147] Trial 23 pruned.
# [I 2026-08-13 16:40:20,182] Trial 24 finished with values: [0.9656661597176389, 0.7974402953728073] and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 44, 'nO': 4, 'N': 6, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 13}.
# [I 2026-08-13 16:40:20,185] Trial 25 pruned.
# [I 2026-08-13 16:40:20,187] Trial 26 pruned.
# [I 2026-08-13 16:40:20,190] Trial 27 pruned.
# [I 2026-08-13 16:40:20,192] Trial 28 pruned.
# [I 2026-08-13 16:40:20,195] Trial 29 pruned.
# [I 2026-08-13 16:40:20,197] Trial 30 pruned.
# [I 2026-08-13 16:40:20,199] Trial 31 pruned.
# [I 2026-08-13 16:40:20,201] Trial 32 pruned.
# [I 2026-08-13 16:40:20,204] Trial 33 pruned.
# [I 2026-08-13 16:40:20,206] Trial 34 pruned.
# [I 2026-08-13 16:40:20,209] Trial 35 pruned.
# [I 2026-08-13 16:40:20,256] Trial 36 finished with values: [0.9721260549014297, 0.6323521536394271] and parameters: {'m': 3.75, 'nI': 3, 'n_layers': 1, 'nR_layer_0': 64, 'nO': 8, 'N': 7, 'τ': 7, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:40:20,258] Trial 37 pruned.
# [I 2026-08-13 16:40:20,260] Trial 38 pruned.
# [I 2026-08-13 16:40:20,263] Trial 39 pruned.
# [I 2026-08-13 16:40:20,267] Trial 40 pruned.
# [I 2026-08-13 16:40:20,270] Trial 41 pruned.
# [I 2026-08-13 16:40:20,273] Trial 42 pruned.
# [I 2026-08-13 16:40:20,331] Trial 43 finished with values: [0.9753850788697144, 2.182430759270587] and parameters: {'m': 3.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 17, 'N': 8, 'τ': 2, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:40:20,333] Trial 44 pruned.
# [I 2026-08-13 16:40:20,336] Trial 45 pruned.
# [I 2026-08-13 16:40:20,339] Trial 46 pruned.
# [I 2026-08-13 16:40:20,341] Trial 47 pruned.
# [I 2026-08-13 16:40:20,343] Trial 48 pruned.
# [I 2026-08-13 16:40:20,346] Trial 49 pruned.
# [I 2026-08-13 16:40:20,348] Trial 50 pruned.
# [I 2026-08-13 16:40:20,350] Trial 51 pruned.
# [I 2026-08-13 16:40:20,814] Trial 52 finished with values: [0.8910805019075813, 0.03232879009875493] and parameters: {'m': 2.5, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 17, 'N': 1, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:40:20,816] Trial 53 pruned.
# [I 2026-08-13 16:40:20,817] Trial 54 pruned.
# [I 2026-08-13 16:40:20,819] Trial 55 pruned.
# [I 2026-08-13 16:40:21,357] Trial 56 finished with values: [2.394553897784773, 0.9398991181869305] and parameters: {'m': 3.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 7, 'N': 6, 'τ': 21, 'mode': 1, 'act': 0, 'mO': 9}.
# [I 2026-08-13 16:40:21,746] Trial 57 finished with values: [1.6593191883334097, 0.12455038185158725] and parameters: {'m': 4.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 19, 'nO': 11, 'N': 2, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:40:21,747] Trial 58 pruned.
# [I 2026-08-13 16:40:21,749] Trial 59 pruned.
# [I 2026-08-13 16:40:21,751] Trial 60 pruned.
# [I 2026-08-13 16:40:21,753] Trial 61 pruned.
# [I 2026-08-13 16:40:21,755] Trial 62 pruned.
# [I 2026-08-13 16:40:21,781] Trial 63 finished with values: [0.9750783612730076, 1.5326948759006758] and parameters: {'m': 4.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 16, 'N': 8, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:21,783] Trial 64 pruned.
# [I 2026-08-13 16:40:21,784] Trial 65 pruned.
# [I 2026-08-13 16:40:21,786] Trial 66 pruned.
# [I 2026-08-13 16:40:21,788] Trial 67 pruned.
# [I 2026-08-13 16:40:21,789] Trial 68 pruned.
# [I 2026-08-13 16:40:21,791] Trial 69 pruned.
# [I 2026-08-13 16:40:21,793] Trial 70 pruned.
# [I 2026-08-13 16:40:21,795] Trial 71 pruned.
# [I 2026-08-13 16:40:21,796] Trial 72 pruned.
# [I 2026-08-13 16:40:21,798] Trial 73 pruned.
# [I 2026-08-13 16:40:21,801] Trial 74 pruned.
# [I 2026-08-13 16:40:21,804] Trial 75 pruned.
# [I 2026-08-13 16:40:21,806] Trial 76 pruned.
# [I 2026-08-13 16:40:21,808] Trial 77 pruned.
# [I 2026-08-13 16:40:21,811] Trial 78 pruned.
# [I 2026-08-13 16:40:21,813] Trial 79 pruned.
# [I 2026-08-13 16:40:21,815] Trial 80 pruned.
# [I 2026-08-13 16:40:21,817] Trial 81 pruned.
# [I 2026-08-13 16:40:21,820] Trial 82 pruned.
# [I 2026-08-13 16:40:21,822] Trial 83 pruned.
# [I 2026-08-13 16:40:21,824] Trial 84 pruned.
# [I 2026-08-13 16:40:21,826] Trial 85 pruned.
# [I 2026-08-13 16:40:21,828] Trial 86 pruned.
# [I 2026-08-13 16:40:21,829] Trial 87 pruned.
# [I 2026-08-13 16:40:21,831] Trial 88 pruned.
# [I 2026-08-13 16:40:21,834] Trial 89 pruned.
# [I 2026-08-13 16:40:21,836] Trial 90 pruned.
# [I 2026-08-13 16:40:21,838] Trial 91 pruned.
# [I 2026-08-13 16:40:21,840] Trial 92 pruned.
# [I 2026-08-13 16:40:21,842] Trial 93 pruned.
# [I 2026-08-13 16:40:21,845] Trial 94 pruned.
# [I 2026-08-13 16:40:21,847] Trial 95 pruned.
# [I 2026-08-13 16:40:21,849] Trial 96 pruned.
# [I 2026-08-13 16:40:21,851] Trial 97 pruned.
# [I 2026-08-13 16:40:21,853] Trial 98 pruned.
# [I 2026-08-13 16:40:21,856] Trial 99 pruned.
# [I 2026-08-13 16:40:21,858] Trial 100 pruned.
# [I 2026-08-13 16:40:21,860] Trial 101 pruned.
# [I 2026-08-13 16:40:21,863] Trial 102 pruned.
# [I 2026-08-13 16:40:21,864] Trial 103 pruned.
# [I 2026-08-13 16:40:21,866] Trial 104 pruned.
# [I 2026-08-13 16:40:21,868] Trial 105 pruned.
# [I 2026-08-13 16:40:21,870] Trial 106 pruned.
# [I 2026-08-13 16:40:21,871] Trial 107 pruned.
# [I 2026-08-13 16:40:21,873] Trial 108 pruned.
# [I 2026-08-13 16:40:21,876] Trial 109 pruned.
# [I 2026-08-13 16:40:21,879] Trial 110 pruned.
# [I 2026-08-13 16:40:21,929] Trial 111 finished with values: [0.9702609249359534, 1.0009791867349054] and parameters: {'m': 2.0, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 7, 'N': 7, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 8}.
# [I 2026-08-13 16:40:21,931] Trial 112 pruned.
# [I 2026-08-13 16:40:21,967] Trial 113 finished with values: [0.9683802342194404, 1.2728787484045676] and parameters: {'m': 2.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 6, 'N': 4, 'τ': 24, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:21,969] Trial 114 pruned.
# [I 2026-08-13 16:40:21,971] Trial 115 pruned.
# [I 2026-08-13 16:40:21,973] Trial 116 pruned.
# [I 2026-08-13 16:40:21,976] Trial 117 pruned.
# [I 2026-08-13 16:40:21,978] Trial 118 pruned.
# [I 2026-08-13 16:40:21,980] Trial 119 pruned.
# [I 2026-08-13 16:40:21,981] Trial 120 pruned.
# [I 2026-08-13 16:40:21,984] Trial 121 pruned.
# [I 2026-08-13 16:40:21,986] Trial 122 pruned.
# [I 2026-08-13 16:40:21,988] Trial 123 pruned.
# [I 2026-08-13 16:40:21,991] Trial 124 pruned.
# [I 2026-08-13 16:40:21,993] Trial 125 pruned.
# [I 2026-08-13 16:40:21,995] Trial 126 pruned.
# [I 2026-08-13 16:40:21,997] Trial 127 pruned.
# [I 2026-08-13 16:40:21,999] Trial 128 pruned.
# [I 2026-08-13 16:40:22,001] Trial 129 pruned.
# [I 2026-08-13 16:40:22,004] Trial 130 pruned.
# [I 2026-08-13 16:40:22,005] Trial 131 pruned.
# [I 2026-08-13 16:40:22,007] Trial 132 pruned.
# [I 2026-08-13 16:40:22,009] Trial 133 pruned.
# [I 2026-08-13 16:40:22,010] Trial 134 pruned.
# [I 2026-08-13 16:40:22,013] Trial 135 pruned.
# [I 2026-08-13 16:40:22,014] Trial 136 pruned.
# [I 2026-08-13 16:40:22,016] Trial 137 pruned.
# [I 2026-08-13 16:40:22,018] Trial 138 pruned.
# [I 2026-08-13 16:40:22,020] Trial 139 pruned.
# [I 2026-08-13 16:40:22,023] Trial 140 pruned.
# [I 2026-08-13 16:40:22,025] Trial 141 pruned.
# [I 2026-08-13 16:40:22,028] Trial 142 pruned.
# [I 2026-08-13 16:40:22,031] Trial 143 pruned.
# [I 2026-08-13 16:40:22,033] Trial 144 pruned.
# [I 2026-08-13 16:40:22,068] Trial 145 finished with values: [0.9756843538520942, 1.7055896089890812] and parameters: {'m': 3.75, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 16, 'N': 5, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:40:22,070] Trial 146 pruned.
# [I 2026-08-13 16:40:22,072] Trial 147 pruned.
# [I 2026-08-13 16:40:22,075] Trial 148 pruned.
# [I 2026-08-13 16:40:22,078] Trial 149 pruned.
# [I 2026-08-13 16:40:22,080] Trial 150 pruned.
# [I 2026-08-13 16:40:22,082] Trial 151 pruned.
# [I 2026-08-13 16:40:22,084] Trial 152 pruned.
# [I 2026-08-13 16:40:22,086] Trial 153 pruned.
# [I 2026-08-13 16:40:22,089] Trial 154 pruned.
# [I 2026-08-13 16:40:22,092] Trial 155 pruned.
# [I 2026-08-13 16:40:22,094] Trial 156 pruned.
# [I 2026-08-13 16:40:22,097] Trial 157 pruned.
# [I 2026-08-13 16:40:22,099] Trial 158 pruned.
# [I 2026-08-13 16:40:22,102] Trial 159 pruned.
# [I 2026-08-13 16:40:22,104] Trial 160 pruned.
# [I 2026-08-13 16:40:22,592] Trial 161 finished with values: [2.5248898177798926, 0.2751091771205049] and parameters: {'m': 3.25, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 17, 'nO': 6, 'N': 5, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:40:22,595] Trial 162 pruned.
# [I 2026-08-13 16:40:22,596] Trial 163 pruned.
# [I 2026-08-13 16:40:22,599] Trial 164 pruned.
# [I 2026-08-13 16:40:22,603] Trial 165 pruned.
# [I 2026-08-13 16:40:22,604] Trial 166 pruned.
# [I 2026-08-13 16:40:22,628] Trial 167 finished with values: [0.9730645218126718, 0.7606136740570141] and parameters: {'m': 2.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 14, 'N': 6, 'τ': 16, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:22,630] Trial 168 pruned.
# [I 2026-08-13 16:40:22,632] Trial 169 pruned.
# [I 2026-08-13 16:40:22,634] Trial 170 pruned.
# [I 2026-08-13 16:40:22,637] Trial 171 pruned.
# [I 2026-08-13 16:40:22,639] Trial 172 pruned.
# [I 2026-08-13 16:40:22,641] Trial 173 pruned.
# [I 2026-08-13 16:40:22,643] Trial 174 pruned.
# [I 2026-08-13 16:40:22,645] Trial 175 pruned.
# [I 2026-08-13 16:40:22,646] Trial 176 pruned.
# [I 2026-08-13 16:40:22,648] Trial 177 pruned.
# [I 2026-08-13 16:40:22,649] Trial 178 pruned.
# [I 2026-08-13 16:40:22,652] Trial 179 pruned.
# [I 2026-08-13 16:40:22,654] Trial 180 pruned.
# [I 2026-08-13 16:40:22,656] Trial 181 pruned.
# [I 2026-08-13 16:40:22,658] Trial 182 pruned.
# [I 2026-08-13 16:40:22,661] Trial 183 pruned.
# [I 2026-08-13 16:40:22,663] Trial 184 pruned.
# [I 2026-08-13 16:40:22,666] Trial 185 pruned.
# [I 2026-08-13 16:40:22,669] Trial 186 pruned.
# [I 2026-08-13 16:40:22,670] Trial 187 pruned.
# [I 2026-08-13 16:40:22,671] Trial 188 pruned.
# [I 2026-08-13 16:40:22,673] Trial 189 pruned.
# [I 2026-08-13 16:40:22,676] Trial 190 pruned.
# [I 2026-08-13 16:40:22,677] Trial 191 pruned.
# [I 2026-08-13 16:40:22,679] Trial 192 pruned.
# [I 2026-08-13 16:40:22,681] Trial 193 pruned.
# [I 2026-08-13 16:40:22,683] Trial 194 pruned.
# [I 2026-08-13 16:40:22,684] Trial 195 pruned.
# [I 2026-08-13 16:40:22,686] Trial 196 pruned.
# [I 2026-08-13 16:40:22,688] Trial 197 pruned.
# [I 2026-08-13 16:40:22,689] Trial 198 pruned.
# [I 2026-08-13 16:40:22,692] Trial 199 pruned.
# [I 2026-08-13 16:40:22,694] Trial 200 pruned.
# [I 2026-08-13 16:40:22,696] Trial 201 pruned.
# [I 2026-08-13 16:40:22,698] Trial 202 pruned.
# [I 2026-08-13 16:40:22,699] Trial 203 pruned.
# [I 2026-08-13 16:40:22,702] Trial 204 pruned.
# [I 2026-08-13 16:40:23,067] Trial 205 finished with values: [1.5885546925722707, 0.03104734316571655] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 19, 'N': 1, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:40:23,069] Trial 206 pruned.
# [I 2026-08-13 16:40:23,070] Trial 207 pruned.
# [I 2026-08-13 16:40:23,707] Trial 208 finished with values: [2.368672079347876, 0.18485022255518008] and parameters: {'m': 3.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 8, 'N': 1, 'τ': 16, 'mode': 1, 'act': 0, 'mO': 4}.
# [I 2026-08-13 16:40:23,709] Trial 209 pruned.
# [I 2026-08-13 16:40:23,712] Trial 210 pruned.
# [I 2026-08-13 16:40:23,713] Trial 211 pruned.
# [I 2026-08-13 16:40:23,716] Trial 212 pruned.
# [I 2026-08-13 16:40:23,718] Trial 213 pruned.
# [I 2026-08-13 16:40:23,721] Trial 214 pruned.
# [I 2026-08-13 16:40:23,723] Trial 215 pruned.
# [I 2026-08-13 16:40:23,726] Trial 216 pruned.
# [I 2026-08-13 16:40:23,728] Trial 217 pruned.
# [I 2026-08-13 16:40:23,731] Trial 218 pruned.
# [I 2026-08-13 16:40:23,733] Trial 219 pruned.
# [I 2026-08-13 16:40:23,736] Trial 220 pruned.
# [I 2026-08-13 16:40:23,738] Trial 221 pruned.
# [I 2026-08-13 16:40:23,741] Trial 222 pruned.
# [I 2026-08-13 16:40:23,743] Trial 223 pruned.
# [I 2026-08-13 16:40:23,803] Trial 224 finished with values: [0.9719304498535897, 0.6648747882765962] and parameters: {'m': 4.25, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 63, 'nO': 9, 'N': 8, 'τ': 19, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:23,805] Trial 225 pruned.
# [I 2026-08-13 16:40:23,807] Trial 226 pruned.
# [I 2026-08-13 16:40:23,809] Trial 227 pruned.
# [I 2026-08-13 16:40:23,842] Trial 228 finished with values: [0.9761198182324029, 1.530296421207288] and parameters: {'m': 2.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 14, 'nO': 20, 'N': 4, 'τ': 12, 'mode': 1, 'act': 0, 'mO': 9}.
# [I 2026-08-13 16:40:23,844] Trial 229 pruned.
# [I 2026-08-13 16:40:23,847] Trial 230 pruned.
# [I 2026-08-13 16:40:23,849] Trial 231 pruned.
# [I 2026-08-13 16:40:23,850] Trial 232 pruned.
# [I 2026-08-13 16:40:23,852] Trial 233 pruned.
# [I 2026-08-13 16:40:24,390] Trial 234 finished with values: [2.0788058418380015, 0.06630648527038367] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 61, 'nO': 5, 'N': 1, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 14}.
# [I 2026-08-13 16:40:24,392] Trial 235 pruned.
# [I 2026-08-13 16:40:24,395] Trial 236 pruned.
# [I 2026-08-13 16:40:24,396] Trial 237 pruned.
# [I 2026-08-13 16:40:24,399] Trial 238 pruned.
# [I 2026-08-13 16:40:24,456] Trial 239 finished with values: [0.9747638941136872, 1.5097663977700615] and parameters: {'m': 3.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 57, 'nO': 16, 'N': 3, 'τ': 18, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:40:24,458] Trial 240 pruned.
# [I 2026-08-13 16:40:24,461] Trial 241 pruned.
# [I 2026-08-13 16:40:24,607] Trial 242 finished with values: [0.5212671314661441, 0.2710317300267781] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 6, 'N': 7, 'τ': 22, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:40:24,609] Trial 243 pruned.
# [I 2026-08-13 16:40:24,612] Trial 244 pruned.
# [I 2026-08-13 16:40:24,614] Trial 245 pruned.
# [I 2026-08-13 16:40:24,616] Trial 246 pruned.
# [I 2026-08-13 16:40:24,718] Trial 247 finished with values: [0.6039549337170499, 0.28719909188998016] and parameters: {'m': 4.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 16, 'N': 3, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:24,720] Trial 248 pruned.
# [I 2026-08-13 16:40:24,722] Trial 249 pruned.
# [I 2026-08-13 16:40:24,725] Trial 250 pruned.
# [I 2026-08-13 16:40:24,726] Trial 251 pruned.
# [I 2026-08-13 16:40:24,729] Trial 252 pruned.
# [I 2026-08-13 16:40:24,732] Trial 253 pruned.
# [I 2026-08-13 16:40:24,796] Trial 254 finished with values: [0.9242683214978393, 0.7194535525898901] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 65, 'nO': 17, 'N': 4, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:40:24,837] Trial 255 finished with values: [0.9753850962319249, 1.3425696893696228] and parameters: {'m': 2.5, 'nI': 2, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 14, 'N': 9, 'τ': 25, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:40:24,841] Trial 256 pruned.
# [I 2026-08-13 16:40:24,844] Trial 257 pruned.
# [I 2026-08-13 16:40:24,847] Trial 258 pruned.
# [I 2026-08-13 16:40:24,849] Trial 259 pruned.
# [I 2026-08-13 16:40:24,852] Trial 260 pruned.
# [I 2026-08-13 16:40:24,855] Trial 261 pruned.
# [I 2026-08-13 16:40:24,857] Trial 262 pruned.
# [I 2026-08-13 16:40:24,860] Trial 263 pruned.
# [I 2026-08-13 16:40:24,862] Trial 264 pruned.
# [I 2026-08-13 16:40:24,865] Trial 265 pruned.
# [I 2026-08-13 16:40:24,868] Trial 266 pruned.
# [I 2026-08-13 16:40:24,871] Trial 267 pruned.
# [I 2026-08-13 16:40:25,406] Trial 268 finished with values: [2.4999603172531186, 0.5408419665290691] and parameters: {'m': 2.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 6, 'N': 8, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:40:25,408] Trial 269 pruned.
# [I 2026-08-13 16:40:25,410] Trial 270 pruned.
# [I 2026-08-13 16:40:25,412] Trial 271 pruned.
# [I 2026-08-13 16:40:25,414] Trial 272 pruned.
# [I 2026-08-13 16:40:25,415] Trial 273 pruned.
# [I 2026-08-13 16:40:25,417] Trial 274 pruned.
# [I 2026-08-13 16:40:25,419] Trial 275 pruned.
# [I 2026-08-13 16:40:25,421] Trial 276 pruned.
# [I 2026-08-13 16:40:25,425] Trial 277 pruned.
# [I 2026-08-13 16:40:25,427] Trial 278 pruned.
# [I 2026-08-13 16:40:25,429] Trial 279 pruned.
# [I 2026-08-13 16:40:25,432] Trial 280 pruned.
# [I 2026-08-13 16:40:25,459] Trial 281 finished with values: [0.9742770245888963, 0.8167762587005363] and parameters: {'m': 4.5, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 16, 'N': 5, 'τ': 10, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:40:25,461] Trial 282 pruned.
# [I 2026-08-13 16:40:25,463] Trial 283 pruned.
# [I 2026-08-13 16:40:25,465] Trial 284 pruned.
# [I 2026-08-13 16:40:25,466] Trial 285 pruned.
# [I 2026-08-13 16:40:25,468] Trial 286 pruned.
# [I 2026-08-13 16:40:25,469] Trial 287 pruned.
# [I 2026-08-13 16:40:25,471] Trial 288 pruned.
# [I 2026-08-13 16:40:25,474] Trial 289 pruned.
# [I 2026-08-13 16:40:25,476] Trial 290 pruned.
# [I 2026-08-13 16:40:25,478] Trial 291 pruned.
# [I 2026-08-13 16:40:25,480] Trial 292 pruned.
# [I 2026-08-13 16:40:25,483] Trial 293 pruned.
# [I 2026-08-13 16:40:25,484] Trial 294 pruned.
# [I 2026-08-13 16:40:25,486] Trial 295 pruned.
# [I 2026-08-13 16:40:25,490] Trial 296 pruned.
# [I 2026-08-13 16:40:25,493] Trial 297 pruned.
# [I 2026-08-13 16:40:25,495] Trial 298 pruned.
# [I 2026-08-13 16:40:25,496] Trial 299 pruned.
# [I 2026-08-13 16:40:25,498] Trial 300 pruned.
# [I 2026-08-13 16:40:25,539] Trial 301 finished with values: [0.9732446917925628, 1.1355883812896084] and parameters: {'m': 4.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 14, 'N': 6, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:40:25,542] Trial 302 pruned.
# [I 2026-08-13 16:40:25,545] Trial 303 pruned.
# [I 2026-08-13 16:40:25,547] Trial 304 pruned.
# [I 2026-08-13 16:40:25,550] Trial 305 pruned.
# [I 2026-08-13 16:40:25,735] Trial 306 finished with values: [0.1974164008714003, 0.21346163100444462] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 11, 'N': 4, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:40:25,770] Trial 307 finished with values: [0.9723189486407645, 1.4216356644509636] and parameters: {'m': 4.0, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 9, 'N': 5, 'τ': 2, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:40:25,772] Trial 308 pruned.
# [I 2026-08-13 16:40:25,775] Trial 309 pruned.
# [I 2026-08-13 16:40:25,778] Trial 310 pruned.
# [I 2026-08-13 16:40:25,780] Trial 311 pruned.
# [I 2026-08-13 16:40:25,781] Trial 312 pruned.
# [I 2026-08-13 16:40:25,783] Trial 313 pruned.
# [I 2026-08-13 16:40:25,786] Trial 314 pruned.
# [I 2026-08-13 16:40:25,787] Trial 315 pruned.
# [I 2026-08-13 16:40:25,790] Trial 316 pruned.
# [I 2026-08-13 16:40:25,792] Trial 317 pruned.
# [I 2026-08-13 16:40:25,795] Trial 318 pruned.
# [I 2026-08-13 16:40:25,798] Trial 319 pruned.
# [I 2026-08-13 16:40:25,800] Trial 320 pruned.
# [I 2026-08-13 16:40:25,803] Trial 321 pruned.
# [I 2026-08-13 16:40:25,805] Trial 322 pruned.
# [I 2026-08-13 16:40:25,807] Trial 323 pruned.
# [I 2026-08-13 16:40:25,810] Trial 324 pruned.
# [I 2026-08-13 16:40:25,813] Trial 325 pruned.
# [I 2026-08-13 16:40:25,815] Trial 326 pruned.
# [I 2026-08-13 16:40:25,817] Trial 327 pruned.
# [I 2026-08-13 16:40:25,820] Trial 328 pruned.
# [I 2026-08-13 16:40:25,821] Trial 329 pruned.
# [I 2026-08-13 16:40:25,823] Trial 330 pruned.
# [I 2026-08-13 16:40:25,826] Trial 331 pruned.
# [I 2026-08-13 16:40:25,828] Trial 332 pruned.
# [I 2026-08-13 16:40:25,831] Trial 333 pruned.
# [I 2026-08-13 16:40:25,832] Trial 334 pruned.
# [I 2026-08-13 16:40:25,834] Trial 335 pruned.
# [I 2026-08-13 16:40:25,836] Trial 336 pruned.
# [I 2026-08-13 16:40:25,838] Trial 337 pruned.
# [I 2026-08-13 16:40:25,840] Trial 338 pruned.
# [I 2026-08-13 16:40:25,844] Trial 339 pruned.
# [I 2026-08-13 16:40:25,847] Trial 340 pruned.
# [I 2026-08-13 16:40:25,848] Trial 341 pruned.
# [I 2026-08-13 16:40:25,886] Trial 342 finished with values: [0.9662456126629059, 1.000048277232967] and parameters: {'m': 4.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 5, 'N': 6, 'τ': 6, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:40:25,889] Trial 343 pruned.
# [I 2026-08-13 16:40:25,892] Trial 344 pruned.
# [I 2026-08-13 16:40:25,894] Trial 345 pruned.
# [I 2026-08-13 16:40:25,897] Trial 346 pruned.
# [I 2026-08-13 16:40:25,954] Trial 347 finished with values: [0.9704803596781827, 0.5602629891992036] and parameters: {'m': 3.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 11, 'N': 7, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:40:25,957] Trial 348 pruned.
# [I 2026-08-13 16:40:26,235] Trial 349 finished with values: [0.5923633248643712, 0.24942009291071837] and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 3, 'N': 1, 'τ': 8, 'mode': 1, 'act': 0, 'mO': 18}.
# [I 2026-08-13 16:40:26,326] Trial 350 finished with values: [0.6937476425615173, 0.3163331712613157] and parameters: {'m': 2.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 17, 'N': 4, 'τ': 4, 'mode': 1, 'act': 0, 'mO': 12}.
# [I 2026-08-13 16:40:26,329] Trial 351 pruned.
# [I 2026-08-13 16:40:26,331] Trial 352 pruned.
# [I 2026-08-13 16:40:26,333] Trial 353 pruned.
# [I 2026-08-13 16:40:26,335] Trial 354 pruned.
# [I 2026-08-13 16:40:26,337] Trial 355 pruned.
# [I 2026-08-13 16:40:26,364] Trial 356 finished with values: [0.9700381585627488, 0.7563785685005732] and parameters: {'m': 2.75, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 8, 'N': 6, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:26,367] Trial 357 pruned.
# [I 2026-08-13 16:40:26,369] Trial 358 pruned.
# [I 2026-08-13 16:40:26,370] Trial 359 pruned.
# [I 2026-08-13 16:40:26,372] Trial 360 pruned.
# [I 2026-08-13 16:40:26,375] Trial 361 pruned.
# [I 2026-08-13 16:40:26,377] Trial 362 pruned.
# [I 2026-08-13 16:40:26,378] Trial 363 pruned.
# [I 2026-08-13 16:40:26,381] Trial 364 pruned.
# [I 2026-08-13 16:40:26,382] Trial 365 pruned.
# [I 2026-08-13 16:40:26,385] Trial 366 pruned.
# [I 2026-08-13 16:40:26,387] Trial 367 pruned.
# [I 2026-08-13 16:40:26,921] Trial 368 finished with values: [2.499952667028742, 0.3700103822081054] and parameters: {'m': 3.0, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 6, 'N': 3, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:40:26,924] Trial 369 pruned.
# [I 2026-08-13 16:40:26,927] Trial 370 pruned.
# [I 2026-08-13 16:40:26,930] Trial 371 pruned.
# [I 2026-08-13 16:40:26,933] Trial 372 pruned.
# [I 2026-08-13 16:40:26,936] Trial 373 pruned.
# [I 2026-08-13 16:40:26,938] Trial 374 pruned.
# [I 2026-08-13 16:40:26,941] Trial 375 pruned.
# [I 2026-08-13 16:40:26,944] Trial 376 pruned.
# [I 2026-08-13 16:40:26,947] Trial 377 pruned.
# [I 2026-08-13 16:40:26,948] Trial 378 pruned.
# [I 2026-08-13 16:40:26,951] Trial 379 pruned.
# [I 2026-08-13 16:40:26,953] Trial 380 pruned.
# [I 2026-08-13 16:40:26,955] Trial 381 pruned.
# [I 2026-08-13 16:40:26,957] Trial 382 pruned.
# [I 2026-08-13 16:40:27,016] Trial 383 finished with values: [0.9574616567331138, 0.45948101776924344] and parameters: {'m': 2.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 2, 'N': 8, 'τ': 7, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:27,020] Trial 384 pruned.
# [I 2026-08-13 16:40:27,022] Trial 385 pruned.
# [I 2026-08-13 16:40:27,025] Trial 386 pruned.
# [I 2026-08-13 16:40:27,028] Trial 387 pruned.
# [I 2026-08-13 16:40:27,029] Trial 388 pruned.
# [I 2026-08-13 16:40:27,542] Trial 389 finished with values: [2.5341550192030105, 0.18919657171150575] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 59, 'nO': 6, 'N': 4, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 8}.
# [I 2026-08-13 16:40:27,545] Trial 390 pruned.
# [I 2026-08-13 16:40:27,547] Trial 391 pruned.
# [I 2026-08-13 16:40:27,549] Trial 392 pruned.
# [I 2026-08-13 16:40:27,553] Trial 393 pruned.
# [I 2026-08-13 16:40:27,555] Trial 394 pruned.
# [I 2026-08-13 16:40:27,557] Trial 395 pruned.
# [I 2026-08-13 16:40:27,559] Trial 396 pruned.
# [I 2026-08-13 16:40:27,562] Trial 397 pruned.
# [I 2026-08-13 16:40:27,564] Trial 398 pruned.
# [I 2026-08-13 16:40:27,566] Trial 399 pruned.
# [I 2026-08-13 16:40:27,568] Trial 400 pruned.
# [I 2026-08-13 16:40:27,600] Trial 401 finished with values: [0.9730645218126718, 0.8102755422559641] and parameters: {'m': 3.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 14, 'N': 6, 'τ': 18, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:27,603] Trial 402 pruned.
# [I 2026-08-13 16:40:27,606] Trial 403 pruned.
# [I 2026-08-13 16:40:27,609] Trial 404 pruned.
# [I 2026-08-13 16:40:27,611] Trial 405 pruned.
# [I 2026-08-13 16:40:27,613] Trial 406 pruned.
# [I 2026-08-13 16:40:27,615] Trial 407 pruned.
# [I 2026-08-13 16:40:27,871] Trial 408 finished with values: [0.8519156534104788, 673.311555965579] and parameters: {'m': 3.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 1, 'N': 2, 'τ': 19, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:27,874] Trial 409 pruned.
# [I 2026-08-13 16:40:27,877] Trial 410 pruned.
# [I 2026-08-13 16:40:27,880] Trial 411 pruned.
# [I 2026-08-13 16:40:27,882] Trial 412 pruned.
# [I 2026-08-13 16:40:27,885] Trial 413 pruned.
# [I 2026-08-13 16:40:27,888] Trial 414 pruned.
# [I 2026-08-13 16:40:27,890] Trial 415 pruned.
# [I 2026-08-13 16:40:27,892] Trial 416 pruned.
# [I 2026-08-13 16:40:27,895] Trial 417 pruned.
# [I 2026-08-13 16:40:27,898] Trial 418 pruned.
# [I 2026-08-13 16:40:27,902] Trial 419 pruned.
# [I 2026-08-13 16:40:27,904] Trial 420 pruned.
# [I 2026-08-13 16:40:27,950] Trial 421 finished with values: [0.9540574994428349, 0.8034487892643172] and parameters: {'m': 2.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 3, 'N': 4, 'τ': 18, 'mode': 1, 'act': 0, 'mO': 17}.
# [I 2026-08-13 16:40:27,953] Trial 422 pruned.
# [I 2026-08-13 16:40:27,955] Trial 423 pruned.
# [I 2026-08-13 16:40:28,441] Trial 424 finished with values: [2.943010496430385, 0.5634677566222296] and parameters: {'m': 3.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 1, 'N': 4, 'τ': 12, 'mode': 1, 'act': 0, 'mO': 12}.
# [I 2026-08-13 16:40:28,442] Trial 425 pruned.
# [I 2026-08-13 16:40:28,445] Trial 426 pruned.
# [I 2026-08-13 16:40:28,448] Trial 427 pruned.
# [I 2026-08-13 16:40:28,449] Trial 428 pruned.
# [I 2026-08-13 16:40:28,451] Trial 429 pruned.
# [I 2026-08-13 16:40:28,454] Trial 430 pruned.
# [I 2026-08-13 16:40:28,455] Trial 431 pruned.
# [I 2026-08-13 16:40:28,457] Trial 432 pruned.
# [I 2026-08-13 16:40:28,459] Trial 433 pruned.
# [I 2026-08-13 16:40:28,461] Trial 434 pruned.
# [I 2026-08-13 16:40:28,463] Trial 435 pruned.
# [I 2026-08-13 16:40:28,465] Trial 436 pruned.
# [I 2026-08-13 16:40:28,467] Trial 437 pruned.
# [I 2026-08-13 16:40:28,470] Trial 438 pruned.
# [I 2026-08-13 16:40:28,473] Trial 439 pruned.
# [I 2026-08-13 16:40:28,475] Trial 440 pruned.
# [I 2026-08-13 16:40:28,478] Trial 441 pruned.
# [I 2026-08-13 16:40:28,481] Trial 442 pruned.
# [I 2026-08-13 16:40:28,483] Trial 443 pruned.
# [I 2026-08-13 16:40:28,797] Trial 444 finished with values: [1.7544535051633963, 15.24767080690368] and parameters: {'m': 3.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 9, 'nO': 11, 'N': 1, 'τ': 13, 'mode': 1, 'act': 0, 'mO': 15}.
# [I 2026-08-13 16:40:28,801] Trial 445 pruned.
# [I 2026-08-13 16:40:28,805] Trial 446 pruned.
# [I 2026-08-13 16:40:28,807] Trial 447 pruned.
# [I 2026-08-13 16:40:28,810] Trial 448 pruned.
# [I 2026-08-13 16:40:28,812] Trial 449 pruned.
# [I 2026-08-13 16:40:28,815] Trial 450 pruned.
# [I 2026-08-13 16:40:28,817] Trial 451 pruned.
# [I 2026-08-13 16:40:28,854] Trial 452 finished with values: [0.9711197905910537, 0.7963072998440089] and parameters: {'m': 3.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 9, 'N': 8, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:28,856] Trial 453 pruned.
# [I 2026-08-13 16:40:28,955] Trial 454 finished with values: [0.6643437361681286, 0.36245926204688694] and parameters: {'m': 4.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 17, 'nO': 1, 'N': 5, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 11}.
# [I 2026-08-13 16:40:28,959] Trial 455 pruned.
# [I 2026-08-13 16:40:29,004] Trial 456 finished with values: [0.967347784909173, 1.291701729353688] and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 4, 'N': 5, 'τ': 22, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:40:29,007] Trial 457 pruned.
# [I 2026-08-13 16:40:29,010] Trial 458 pruned.
# [I 2026-08-13 16:40:29,012] Trial 459 pruned.
# [I 2026-08-13 16:40:29,014] Trial 460 pruned.
# [I 2026-08-13 16:40:29,017] Trial 461 pruned.
# [I 2026-08-13 16:40:29,018] Trial 462 pruned.
# [I 2026-08-13 16:40:29,021] Trial 463 pruned.
# [I 2026-08-13 16:40:29,024] Trial 464 pruned.
# [I 2026-08-13 16:40:29,027] Trial 465 pruned.
# [I 2026-08-13 16:40:29,030] Trial 466 pruned.
# [I 2026-08-13 16:40:29,033] Trial 467 pruned.
# [I 2026-08-13 16:40:29,035] Trial 468 pruned.
# [I 2026-08-13 16:40:29,038] Trial 469 pruned.
# [I 2026-08-13 16:40:29,504] Trial 470 finished with values: [1.6898173660173847, 0.28709919038983395] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 10, 'nO': 18, 'N': 2, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 9}.
# [I 2026-08-13 16:40:29,506] Trial 471 pruned.
# [I 2026-08-13 16:40:29,509] Trial 472 pruned.
# [I 2026-08-13 16:40:29,511] Trial 473 pruned.
# [I 2026-08-13 16:40:29,513] Trial 474 pruned.
# [I 2026-08-13 16:40:29,517] Trial 475 pruned.
# [I 2026-08-13 16:40:29,519] Trial 476 pruned.
# [I 2026-08-13 16:40:29,521] Trial 477 pruned.
# [I 2026-08-13 16:40:29,522] Trial 478 pruned.
# [I 2026-08-13 16:40:29,811] Trial 479 finished with values: [1.8359022597896988, 0.5549224135239409] and parameters: {'m': 4.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 59, 'nO': 16, 'N': 3, 'τ': 21, 'mode': 1, 'act': 1, 'mO': 4}.
# [I 2026-08-13 16:40:29,814] Trial 480 pruned.
# [I 2026-08-13 16:40:29,815] Trial 481 pruned.
# [I 2026-08-13 16:40:29,818] Trial 482 pruned.
# [I 2026-08-13 16:40:29,819] Trial 483 pruned.
# [I 2026-08-13 16:40:29,821] Trial 484 pruned.
# [I 2026-08-13 16:40:29,823] Trial 485 pruned.
# [I 2026-08-13 16:40:29,825] Trial 486 pruned.
# [I 2026-08-13 16:40:30,017] Trial 487 finished with values: [0.14909719969726457, 0.1488010205404076] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 8, 'τ': 15, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:40:30,065] Trial 488 finished with values: [0.9732011925530087, 0.915791705637956] and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 15, 'N': 7, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:30,104] Trial 489 finished with values: [0.9723189486407645, 2.9002595059433594] and parameters: {'m': 4.0, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 9, 'N': 9, 'τ': 2, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:30,143] Trial 490 finished with values: [0.9747638941136872, 1.1883654799688195] and parameters: {'m': 3.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 48, 'nO': 16, 'N': 3, 'τ': 16, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:40:30,495] Trial 491 finished with values: [2.524187011452278, 0.34708030248961014] and parameters: {'m': 3.75, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 9, 'nO': 6, 'N': 4, 'τ': 13, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:40:30,803] Trial 492 finished with values: [1.0909177090934519, 0.05708679806078189] and parameters: {'m': 4.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 17, 'N': 1, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:40:30,806] Trial 493 pruned.
# [I 2026-08-13 16:40:30,841] Trial 494 finished with values: [0.9750783612730076, 1.411297750748473] and parameters: {'m': 3.75, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 16, 'N': 9, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:30,875] Trial 495 finished with values: [0.9698120457005877, 0.5116402770785075] and parameters: {'m': 2.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 6, 'N': 8, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:40:30,878] Trial 496 pruned.
# [I 2026-08-13 16:40:30,879] Trial 497 pruned.
# [I 2026-08-13 16:40:31,384] Trial 498 finished with values: [2.2243469296932843, 0.041998891647287206] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 9, 'N': 4, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:31,602] Trial 499 finished with values: [0.33496300060118156, 0.15110220023995222] and parameters: {'m': 4.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 11, 'N': 2, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:40:31,604] Trial 500 pruned.
# [I 2026-08-13 16:40:31,626] Trial 501 finished with values: [0.9709097347551789, 0.9384047397729556] and parameters: {'m': 2.5, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 11, 'N': 5, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:31,664] Trial 502 finished with values: [0.9719304498535897, 0.6988349241753797] and parameters: {'m': 4.25, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 63, 'nO': 9, 'N': 8, 'τ': 21, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:31,666] Trial 503 pruned.
# [I 2026-08-13 16:40:31,667] Trial 504 pruned.
# [I 2026-08-13 16:40:31,670] Trial 505 pruned.
# [I 2026-08-13 16:40:31,697] Trial 506 finished with values: [0.9711197905910537, 0.7731035564574851] and parameters: {'m': 3.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 9, 'N': 7, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:40:31,699] Trial 507 pruned.
# [I 2026-08-13 16:40:31,732] Trial 508 finished with values: [0.9723189486407645, 0.9166697175789171] and parameters: {'m': 4.0, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 63, 'nO': 9, 'N': 6, 'τ': 12, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:40:31,760] Trial 509 finished with values: [0.967347784909173, 0.8713687539056492] and parameters: {'m': 3.75, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 4, 'N': 7, 'τ': 22, 'mode': 1, 'act': 1, 'mO': 11}.
# [I 2026-08-13 16:40:32,258] Trial 510 finished with values: [2.142540728106467, 0.3121205899113388] and parameters: {'m': 3.0, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 11, 'N': 3, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:40:32,364] Trial 511 finished with values: [0.570725252587201, 0.29428449566841436] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 6, 'N': 7, 'τ': 22, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:32,365] Trial 512 pruned.
# [I 2026-08-13 16:40:32,536] Trial 513 finished with values: [0.5974254959219338, 0.11662519091024041] and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 14, 'N': 1, 'τ': 8, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:40:32,562] Trial 514 finished with values: [0.9728818914222527, 0.5751766649152047] and parameters: {'m': 3.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 15, 'N': 7, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:40:32,591] Trial 515 finished with values: [0.9726968020778188, 0.9890291872549553] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 14, 'N': 4, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:32,663] Trial 516 finished with values: [0.632930145846963, 0.3302795379630272] and parameters: {'m': 3.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 1, 'N': 7, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:32,664] Trial 517 pruned.
# [I 2026-08-13 16:40:32,690] Trial 518 finished with values: [0.9678722947210139, 0.7670486048564286] and parameters: {'m': 3.25, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 6, 'N': 6, 'τ': 16, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:32,714] Trial 519 finished with values: [0.9670790297796191, 1.000727356993053] and parameters: {'m': 4.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 6, 'N': 6, 'τ': 15, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:40:32,717] Trial 520 pruned.
# [I 2026-08-13 16:40:32,791] Trial 521 finished with values: [0.8019344014798847, 0.3077553380636353] and parameters: {'m': 2.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 65, 'nO': 2, 'N': 4, 'τ': 7, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:32,815] Trial 522 finished with values: [0.9688723436190572, 0.9618104211015818] and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 8, 'N': 6, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:32,817] Trial 523 pruned.
# [I 2026-08-13 16:40:32,841] Trial 524 finished with values: [0.9742770245888963, 0.8336940624797109] and parameters: {'m': 4.5, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 16, 'N': 7, 'τ': 10, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:40:32,866] Trial 525 finished with values: [0.9683802342194404, 1.094129647542871] and parameters: {'m': 4.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 6, 'N': 4, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:33,265] Trial 526 finished with values: [2.9547511968735214, 0.5233164898102322] and parameters: {'m': 4.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 1, 'N': 2, 'τ': 19, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:33,405] Trial 527 finished with values: [0.9001803557893528, 6.718755211325221] and parameters: {'m': 4.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 19, 'N': 1, 'τ': 5, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:40:33,477] Trial 528 finished with values: [0.9706966554503893, 1.0116582736674766] and parameters: {'m': 3.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 6, 'N': 3, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:40:33,519] Trial 529 finished with values: [0.9641265831666842, 1.1257886266333896] and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 1, 'N': 6, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:33,521] Trial 530 pruned.
# [I 2026-08-13 16:40:33,675] Trial 531 finished with values: [0.8565560283761467, 0.8461126147391292] and parameters: {'m': 3.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 17, 'nO': 6, 'N': 2, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:33,678] Trial 532 pruned.
# [I 2026-08-13 16:40:33,835] Trial 533 finished with values: [1.7860565571561666, 0.43350819549022285] and parameters: {'m': 3.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 19, 'N': 6, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:33,861] Trial 534 finished with values: [0.9756843249422963, 0.5899455812401478] and parameters: {'m': 3.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 19, 'N': 5, 'τ': 9, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:40:33,867] Trial 535 pruned.
# [I 2026-08-13 16:40:33,868] Trial 536 pruned.
# [I 2026-08-13 16:40:34,220] Trial 537 finished with values: [2.7344664834212415, 0.19804509466366607] and parameters: {'m': 2.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 3, 'N': 6, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:34,221] Trial 538 pruned.
# [I 2026-08-13 16:40:34,245] Trial 539 finished with values: [0.9700381585627488, 1.004321268092385] and parameters: {'m': 2.75, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 8, 'N': 9, 'τ': 6, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:40:34,247] Trial 540 pruned.
# [I 2026-08-13 16:40:34,388] Trial 541 finished with values: [0.17280972690875818, 0.1580330730313672] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 8, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:40:34,814] Trial 542 finished with values: [2.010528288125771, 0.3089705278738943] and parameters: {'m': 4.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 1, 'N': 1, 'τ': 11, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:40:34,839] Trial 543 finished with values: [0.9753850788697144, 2.182430759270587] and parameters: {'m': 3.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 17, 'N': 8, 'τ': 2, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:40:34,842] Trial 544 pruned.
# [I 2026-08-13 16:40:34,866] Trial 545 finished with values: [0.9662456126629059, 1.0001521433608578] and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 5, 'N': 6, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 11}.
# [I 2026-08-13 16:40:34,950] Trial 546 finished with values: [0.6051974446753933, 0.3354485871525786] and parameters: {'m': 3.75, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 17, 'N': 4, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:40:35,501] Trial 547 finished with values: [2.2635360962566846, 0.08527510709870104] and parameters: {'m': 2.0, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 10, 'nO': 9, 'N': 8, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:40:35,534] Trial 548 finished with values: [0.9683802342194404, 1.2728787484045676] and parameters: {'m': 2.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 6, 'N': 4, 'τ': 24, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:35,573] Trial 549 finished with values: [0.9747638941136872, 1.5097663977700615] and parameters: {'m': 3.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 57, 'nO': 16, 'N': 3, 'τ': 18, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:40:35,576] Trial 550 pruned.
# [I 2026-08-13 16:40:35,609] Trial 551 finished with values: [0.9668058579208988, 3.6993489091717024] and parameters: {'m': 2.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 2, 'N': 8, 'τ': 7, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:40:35,611] Trial 552 pruned.
# [I 2026-08-13 16:40:36,033] Trial 553 finished with values: [1.774995845663757, 0.27590364793004396] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 16, 'N': 8, 'τ': 15, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:40:36,466] Trial 554 finished with values: [1.8654676496210782, 0.06347002814540341] and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 19, 'nO': 11, 'N': 1, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:36,469] Trial 555 pruned.
# [I 2026-08-13 16:40:36,520] Trial 556 finished with values: [0.9281374796919007, 0.43308193280331914] and parameters: {'m': 2.0, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 2, 'N': 5, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:36,548] Trial 557 finished with values: [0.967347784909173, 2.1515566315124115] and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 4, 'N': 4, 'τ': 22, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:40:36,576] Trial 558 finished with values: [0.9668058508814048, 0.44272804720620434] and parameters: {'m': 4.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 44, 'nO': 4, 'N': 6, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:40:37,010] Trial 559 finished with values: [1.7356266094402841, 0.7450051449170929] and parameters: {'m': 2.5, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 17, 'N': 8, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:40:37,201] Trial 560 finished with values: [0.5210726441998099, 0.2005983595104451] and parameters: {'m': 3.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 6, 'N': 5, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:37,634] Trial 561 finished with values: [2.127066265741199, 55.49943780627417] and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 11, 'N': 2, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:37,637] Trial 562 pruned.
# [I 2026-08-13 16:40:38,165] Trial 563 finished with values: [2.441106209914005, 0.2613451550402107] and parameters: {'m': 2.5, 'nI': 4, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 8, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:38,293] Trial 564 finished with values: [1.503818664026925, 61743.91530624816] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 61, 'nO': 5, 'N': 1, 'τ': 4, 'mode': 1, 'act': 0, 'mO': 4}.
# [I 2026-08-13 16:40:38,458] Trial 565 finished with values: [0.8633580712181577, 0.8311445801674398] and parameters: {'m': 3.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 17, 'N': 1, 'τ': 17, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:40:38,484] Trial 566 finished with values: [0.9744413886497195, 1.07525769459038] and parameters: {'m': 2.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 7, 'nO': 16, 'N': 8, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:40:38,487] Trial 567 pruned.
# [I 2026-08-13 16:40:38,518] Trial 568 finished with values: [0.9726968020778188, 0.7677240346447535] and parameters: {'m': 2.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 44, 'nO': 14, 'N': 6, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:40:38,521] Trial 569 pruned.
# [I 2026-08-13 16:40:38,578] Trial 570 finished with values: [0.9647586851204407, 0.8424114648276472] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 3, 'N': 3, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:40:38,906] Trial 571 finished with values: [0.6740519454964904, 0.07943346632963551] and parameters: {'m': 3.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 19, 'nO': 1, 'N': 7, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 16}.
# [I 2026-08-13 16:40:38,909] Trial 572 pruned.
# [I 2026-08-13 16:40:38,938] Trial 573 finished with values: [0.9706966201678175, 1.1927307752879892] and parameters: {'m': 2.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 11, 'N': 4, 'τ': 20, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:40:39,361] Trial 574 finished with values: [1.468392682544874, 0.24578406462895683] and parameters: {'m': 2.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 11, 'N': 8, 'τ': 4, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:40:39,363] Trial 575 pruned.
# [I 2026-08-13 16:40:39,401] Trial 576 finished with values: [0.895970158956557, 0.5113569967979011] and parameters: {'m': 4.25, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 6, 'N': 3, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:40:39,403] Trial 577 pruned.
# [I 2026-08-13 16:40:39,815] Trial 578 finished with values: [2.3742252086954134, 1.4345741610128022] and parameters: {'m': 2.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 7, 'N': 4, 'τ': 18, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:40:39,817] Trial 579 pruned.
# ...
# [I 2026-08-13 16:41:32,780] Trial 879 pruned.
# [I 2026-08-13 16:41:32,824] Trial 880 finished with values: [0.9659583710949495, 1.5018875056528085] and parameters: {'m': 2.5, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 1, 'N': 8, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:41:32,826] Trial 881 pruned.
# [I 2026-08-13 16:41:33,350] Trial 882 finished with values: [1.5858870015395272, 2.4891256869074896] and parameters: {'m': 3.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 1, 'N': 1, 'τ': 23, 'mode': 1, 'act': 1, 'mO': 5}.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_QN_R2.py:177: RuntimeWarning: overflow encountered in matmul
#   dh_next = - (self.wO.T @ eS)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_QN_R2.py:177: RuntimeWarning: invalid value encountered in matmul
#   dh_next = - (self.wO.T @ eS)
# [I 2026-08-13 16:41:33,539] Trial 883 pruned.
# [I 2026-08-13 16:41:33,633] Trial 884 finished with values: [0.6965646973467513, 0.27544716434947947] and parameters: {'m': 2.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 1, 'N': 5, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:41:33,658] Trial 885 finished with values: [0.9691127187391844, 0.8057742523489664] and parameters: {'m': 4.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 8, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:33,688] Trial 886 finished with values: [0.975078319965971, 1.6057130579823216] and parameters: {'m': 4.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 19, 'N': 5, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:33,741] Trial 887 finished with values: [0.9168913766492767, 15.251506439390733] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 19, 'N': 1, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:41:33,745] Trial 888 pruned.
# [I 2026-08-13 16:41:34,092] Trial 889 finished with values: [1.1737166130841827, 0.014267013561681847] and parameters: {'m': 2.5, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 19, 'N': 1, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:41:34,537] Trial 890 finished with values: [1.8803716066385006, 1.9540740388824391] and parameters: {'m': 3.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 6, 'N': 1, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:34,928] Trial 891 finished with values: [0.8564275987758022, 0.006562004200779391] and parameters: {'m': 3.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 17, 'N': 1, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:35,419] Trial 892 finished with values: [1.9260230872210933, 0.03208631305526157] and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 14, 'N': 1, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:41:35,421] Trial 893 pruned.
# [I 2026-08-13 16:41:35,836] Trial 894 finished with values: [1.5110854417930328, 1.2508094266583447] and parameters: {'m': 2.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 14, 'N': 1, 'τ': 4, 'mode': 1, 'act': 0, 'mO': 14}.
# [I 2026-08-13 16:41:36,175] Trial 895 finished with values: [0.6091871985891633, 0.04288000902217128] and parameters: {'m': 4.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 18, 'nO': 19, 'N': 1, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:41:36,353] Trial 896 finished with values: [0.3077875673493827, 0.1869974334336306] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 1, 'N': 8, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 8}.
# [I 2026-08-13 16:41:36,441] Trial 897 finished with values: [0.5178086252037741, 0.29592351835094816] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 32, 'nO': 11, 'N': 4, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:41:36,444] Trial 898 pruned.
# [I 2026-08-13 16:41:36,991] Trial 899 finished with values: [2.540580167373239, 0.11441049036424131] and parameters: {'m': 2.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 5, 'N': 1, 'τ': 22, 'mode': 1, 'act': 1, 'mO': 14}.
# [I 2026-08-13 16:41:37,047] Trial 900 finished with values: [0.9709097347551789, 1.4023583252399798] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 11, 'N': 3, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:37,400] Trial 901 finished with values: [1.0242287976220141, 0.1430966990303337] and parameters: {'m': 2.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 1, 'N': 5, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:37,845] Trial 902 finished with values: [0.9359254699744781, 0.12003147327127375] and parameters: {'m': 4.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 1, 'N': 1, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:37,848] Trial 903 pruned.
# [I 2026-08-13 16:41:38,334] Trial 904 finished with values: [2.94467032213381, 0.610620742495774] and parameters: {'m': 3.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 53, 'nO': 1, 'N': 1, 'τ': 20, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:38,363] Trial 905 finished with values: [0.9766768030294337, 0.5887509744884113] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 19, 'nO': 19, 'N': 7, 'τ': 5, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:41:38,829] Trial 906 finished with values: [2.381782298368682, 0.24950964134818818] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 7, 'N': 8, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 11}.
# [I 2026-08-13 16:41:38,857] Trial 907 finished with values: [0.9622478125520845, 1.8533115208837838] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 1, 'N': 5, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:41:38,901] Trial 908 finished with values: [0.962791790694031, 0.9120579279618256] and parameters: {'m': 2.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 1, 'N': 4, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:39,034] Trial 909 finished with values: [0.40813992799544285, 0.1902154794751691] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 8, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:39,179] Trial 910 finished with values: [0.2964715427081266, 0.3041608359336095] and parameters: {'m': 2.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 4, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 17}.
# [I 2026-08-13 16:41:39,181] Trial 911 pruned.
# [I 2026-08-13 16:41:39,183] Trial 912 pruned.
# [I 2026-08-13 16:41:39,186] Trial 913 pruned.
# [I 2026-08-13 16:41:39,728] Trial 914 finished with values: [2.274302598538531, 0.4108599998891423] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 5, 'N': 1, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:41:39,762] Trial 915 finished with values: [0.975078319965971, 0.9621936995756067] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 19, 'N': 8, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:39,793] Trial 916 finished with values: [0.9739418946590507, 1.4840244026262963] and parameters: {'m': 2.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 14, 'N': 8, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:41:39,824] Trial 917 finished with values: [0.9611386854222009, 1.8387350429900806] and parameters: {'m': 4.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 1, 'N': 5, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:40,291] Trial 918 finished with values: [2.4521936596117873, 1.3519402986076117] and parameters: {'m': 2.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 6, 'N': 5, 'τ': 12, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:40,295] Trial 919 pruned.
# [I 2026-08-13 16:41:40,823] Trial 920 finished with values: [2.373410275899129, 0.5858562363782279] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 14, 'nO': 7, 'N': 4, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:41,286] Trial 921 finished with values: [1.6862062487752703, 0.013861292714903292] and parameters: {'m': 4.0, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 19, 'N': 1, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:41:41,315] Trial 922 finished with values: [0.9624424257073413, 1.001346671022085] and parameters: {'m': 3.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 2, 'nO': 1, 'N': 7, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:41,582] Trial 923 finished with values: [0.3831194378248155, 0.0583007802169106] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 19, 'N': 1, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:41:41,818] Trial 924 finished with values: [0.32310483714897553, 0.141223619247823] and parameters: {'m': 3.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 1, 'N': 8, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:42,150] Trial 925 finished with values: [0.1601348996180305, 0.1432614619673347] and parameters: {'m': 3.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 7, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:42,561] Trial 926 finished with values: [0.719558934408881, 0.17119477710265535] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 14, 'N': 1, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:41:43,215] Trial 927 finished with values: [1.900323793059512, 0.16147312477975637] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 17, 'N': 1, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:43,553] Trial 928 finished with values: [0.15931794966135912, 0.14326449598025953] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 8, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:44,374] Trial 929 finished with values: [2.368428705617921, 0.9558566552098786] and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 4, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 11}.
# [I 2026-08-13 16:41:44,423] Trial 930 finished with values: [0.9739418946590507, 1.4688373464671773] and parameters: {'m': 2.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 14, 'N': 8, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 4}.
# [I 2026-08-13 16:41:44,566] Trial 931 finished with values: [0.701173161883146, 0.1855581290743158] and parameters: {'m': 4.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 18, 'nO': 7, 'N': 6, 'τ': 5, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:44,767] Trial 932 finished with values: [0.4742888084412996, 0.23886780709759875] and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 1, 'N': 8, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:45,538] Trial 933 finished with values: [1.7153611947419758, 0.24147194359303872] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 25, 'nO': 19, 'N': 1, 'τ': 3, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:41:45,801] Trial 934 finished with values: [0.25495707079264723, 0.16458691907300105] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 8, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:45,852] Trial 935 finished with values: [0.9662456126629059, 1.0228174584140135] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 5, 'N': 8, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:45,895] Trial 936 finished with values: [0.975078319965971, 0.7802954416381573] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 19, 'N': 8, 'τ': 3, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:46,533] Trial 937 finished with values: [2.391986104185527, 0.27261271006038623] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 23, 'nO': 7, 'N': 8, 'τ': 15, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:46,748] Trial 938 finished with values: [0.6006831204852328, 0.30247946230416395] and parameters: {'m': 2.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 17, 'N': 9, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:41:47,134] Trial 939 finished with values: [0.1873107905223861, 0.13949154346846263] and parameters: {'m': 4.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 6, 'N': 8, 'τ': 14, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:47,470] Trial 940 finished with values: [0.5090440317447529, 0.12350013615628547] and parameters: {'m': 4.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 1, 'N': 1, 'τ': 11, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:47,473] Trial 941 pruned.
# [I 2026-08-13 16:41:48,402] Trial 942 finished with values: [2.3685880554705223, 1.5750164991914513] and parameters: {'m': 3.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 6, 'τ': 22, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:48,744] Trial 943 finished with values: [0.5712587881466709, 0.0771669123268136] and parameters: {'m': 4.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 19, 'N': 1, 'τ': 8, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:41:48,836] Trial 944 finished with values: [0.7637443341557175, 0.3693925089978149] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 19, 'N': 8, 'τ': 15, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:41:49,338] Trial 945 finished with values: [1.183933761294081, 0.3532200112721763] and parameters: {'m': 2.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 7, 'N': 1, 'τ': 7, 'mode': 1, 'act': 0, 'mO': 5}.
# [I 2026-08-13 16:41:49,813] Trial 946 finished with values: [1.2539901625909298, 19.509971142124588] and parameters: {'m': 4.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 14, 'N': 1, 'τ': 7, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:50,187] Trial 947 finished with values: [0.20318028109604233, 0.13878257122317036] and parameters: {'m': 3.0, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 1, 'N': 4, 'τ': 10, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:41:50,681] Trial 948 finished with values: [0.61013335154892, 0.05166846568283677] and parameters: {'m': 3.25, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 28, 'nO': 14, 'N': 1, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 16}.
# [I 2026-08-13 16:41:50,742] Trial 949 finished with values: [0.9723189020241957, 1.1631104123091085] and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 14, 'N': 7, 'τ': 8, 'mode': 1, 'act': 0, 'mO': 16}.
# [I 2026-08-13 16:41:50,799] Trial 950 finished with values: [0.9717320684443034, 1.204693193203548] and parameters: {'m': 3.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 36, 'nO': 11, 'N': 6, 'τ': 17, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:41:51,682] Trial 951 finished with values: [2.368428705617921, 0.1883973958939127] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 13, 'nO': 7, 'N': 1, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:41:51,685] Trial 952 pruned.
# [I 2026-08-13 16:41:51,739] Trial 953 finished with values: [0.9758312686977445, 0.8735317495478309] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 17, 'N': 9, 'τ': 2, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:41:51,744] Trial 954 pruned.
# [I 2026-08-13 16:41:52,396] Trial 955 finished with values: [1.7405450979196884, 0.11690235852563] and parameters: {'m': 4.5, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 47, 'nO': 17, 'N': 1, 'τ': 8, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:41:53,126] Trial 956 finished with values: [0.525825454248968, 0.02339021556011092] and parameters: {'m': 3.0, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 34, 'nO': 19, 'N': 1, 'τ': 5, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:41:53,129] Trial 957 pruned.
# [I 2026-08-13 16:41:53,249] Trial 958 finished with values: [0.9446480831483319, 1.0990935793441357] and parameters: {'m': 3.0, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 19, 'N': 1, 'τ': 23, 'mode': 1, 'act': 0, 'mO': 10}.

# %%
df = dfs[1]
#df = df[(df.iloc[:,0] <= 0.07)]
params_list = df.values[:,-9:]
df
# Out:
#    MAPE_RUL   MAPE_HI     m  nI                   nR  nO  mO  N        TAU  \
# 0  1.207268  0.236227  4.25  19         [42, 60, 49]   6   9  8  10.676956
# 1  2.183819  0.126204  2.75  13  [6, 65, 34, 24, 46]  10   5  1   1.235820
# 2  0.962792  0.656823  2.50  18                 [52]   1   0  7  17.657242
# 3  2.111962  0.192931  2.50   7     [37, 70, 56, 36]  12   6  1   1.977056
# 4  2.218315  0.103551  4.50  19         [29, 41, 65]   9   9  2   2.460463
# 5  0.681176  1.385156  2.25  11         [26, 11, 19]  12   0  1  10.730664
#
#    past/ahead  activation
# 0           1           1
# 1           1           1
# 2           1           1
# 3           1           0
# 4           1           0
# 5           1           0

# %%
tedas = []
for i,params in enumerate(params_list):
    m,nI,nR,nO,mO,N1,τ,mode,act = params
    X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
    if isinstance(nR, str): nR = ast.literal_eval(nR)

    teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N1],mode=mode,act=act,
                tau=τ,rho=0.03,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
    for j,_ in enumerate(X[:]):
        teda.run(X[j])
        teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1,show=False)
        teda.Adapt(Y[j],Z[j])

    teda.c = np.append(teda.c,teda.gm)  
    tedas.append(teda)
    #PlotSeriesPLY(ySeries=[teda.wape_HI_hist,teda.wape_RUL_hist])

# %%
PlotDSI_3D_PLT(tedas[0])
