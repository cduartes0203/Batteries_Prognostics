# %%
import math
import ast
import ipynbname
import pandas as pd
import numpy as np
import optuna
from Testing.DRTLO_QN_R1 import *
from Functions.AutoCloud_V2 import *
from Functions.DataCloud_V2 import *
from Functions.Utils import *
from Functions.Graphs import *
from Functions.TedaGraphs import *
from Functions.Utils_OPT import *

FileName = ipynbname.name()
out_path = f'Optimization\\eDRTLO_QN\\multi\\Optimization.csv'
RS = pd.read_excel(r'Dataset\RS.xlsx')
HI = pd.read_csv(r'Dataset\Bearing1_1.csv')
sig = HI['PC1'].values

# %%
params =  {'nI': 3, 'nR': 3, 'nO': 3, 'N1': 0.1,
            'τ': 23, 'mode': 1, 'act': 0}

nI,nR,nO,N1,τ,mode,act= list(params.values())
X, Y, Z = PrepareData(RS, HI, nX=nI, nY=nO, mY=0, nZ=1, mode='past')

teda=AutoCloud(m=2.5,nI=nI,nR=[nR],nO=nO,ηS=[N1],mode=mode,
               tau=τ,rho=0.01,eol=0.3,ref=len(sig)-nI,wtaG=True,wtaP=True) 
for j,_ in enumerate(X[:]):
    teda.run(X[j])
    teda.RUL_Prediction(Y[j],mode='interval',lim=len(sig)-nI+1,show=False)
    teda.Adapt(Y[j],Z[j])

#teda.RUL_Granularity()
#print(teda.wape_HI,teda.wape_RUL)
#PlotDSI_3D_PLT(teda)
#teda.c = np.append(teda.c,teda.gm)   
#PlotGranulesSpace(teda,w=700,h=700)

# %%
print(xxx)

# %%
def Optimize(
        FileName=None,OptDim=None,OptSampler=None,OptSeed=None,OptPrune=False,
        n_study=None,timeout=None,n_trials=None,
        patience=None,
        mS =None,nIS=None,nLS=None,nRS=None,nOS =None,mOS=None,
        NS=None,τS =None,mdS=None,actS=None):

    '''
        OptSampler modes available: None, Auto, GP, NSGAII, Random, TPE
    
        None: sampler default, suport multivariate optimization

        GP: suport multivariate optimization

        Auto: suport multivariate optimization
        
        NSGAII: poorly suport multivariate optimization
        
        Random: poorly suport multivariate optimization

        TPE: suport multivariate optimization
    '''

    if OptDim == 1 or OptDim is None: SingleObj = True
    elif OptDim > 1: SingleObj = False    
    if n_study is None: n_study = 1
    if timeout is None: timeout = 60
    if n_trials is None and patience is None: 
        n_trials = 25
        patience = 25
    elif n_trials < 100 and patience is None:
        patience = int(0.25*n_trials)
    elif n_trials >= 1e2 and n_trials < 1e3 and patience is None:
        patience = int(0.20*n_trials)
    elif n_trials >= 1e3 and n_trials < 5e3 and patience is None:
        patience = int(0.150*n_trials)
    elif n_trials >= 5e3 and n_trials < 1e4 and patience is None:
        patience = int(0.125*n_trials)    
    elif n_trials >= 1e4 and patience is None:
        patience = int(0.03*n_trials)   

    if mS  is None: mS  = [1.75,4.25]
    if nIS is None: nIS = [2,40]
    if nLS is None: nLS = [1,5]
    if nRS is None: nRS = [1,60]
    if nOS is None: nOS = [1,40]
    if mOS is None: mOS = [0,40]
    if NS is None: NS = [1,9]
    if τS  is None: τS  = [1,25]
    if mdS is None: mdS = [0,1]
    if actS is None: actS = [0,1,2]

    if SingleObj: names = ['MAPE_RUL*MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N','TAU','past/ahead','activation']
    else: names = ['MAPE_RUL','MAPE_HI', 'm', 'nI', 'nR', 'nO', 'mO', 'N', 'TAU','past/ahead','activation']
    study_dir, out_path = df_ParamsTable(names,FileName)

    for i in range(n_study):
        print('iteration:',i+1)
        def objective(trial):
            m = trial.suggest_float('m', mS[0], mS[1],step=0.25)
            nI = trial.suggest_int('nI', nIS[0], nIS[1]) 
            n_layers = trial.suggest_int('n_layers', nLS[0], nLS[1])
            nR = [trial.suggest_int(f'nR_layer_{l}', nRS[0], nRS[1]) for l in range(n_layers)]
            nO = trial.suggest_int('nO', nOS[0], nOS[1]) 
            N = trial.suggest_int('N', NS[0], NS[1])
            τ = trial.suggest_float('τ', τS[0], τS[1])
            mode = trial.suggest_int('mode', mdS[0], mdS[1])  
            act = trial.suggest_int('act', actS[0], actS[1])  

            if mode == 'past' or mode == 0:
                mO = trial.suggest_int('mO', 0, 0) 
                if nO > nI: raise TrialPruned()

            elif mode == 'ahead' or mode == 1:
                mO = trial.suggest_int('mO', mOS[0], mOS[1]) 
                if   nI > 20 or nO > 20: raise TrialPruned()
                elif mO > nI: raise TrialPruned()
                
            X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
            
            teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N],mode=mode,act=act,
                           tau=τ,rho=0.0,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
            
            for j,_ in enumerate(X[:]):
                teda.run(X[j])
                teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1)
                teda.Adapt(Y[j],Z[j])
                #teda.WAPE_HI2(Y[j],Z[j])

                if np.isinf(teda.hiP[-1]) or np.isnan(teda.hiP[-1]): raise TrialPruned()
                if not OptPrune: continue
        
                if j >=60 and j%5==0:
                    if teda.wape_RUL > 0.6: raise TrialPruned()
                    if teda.wape_HI  > 0.3: raise TrialPruned()

                if SingleObj and j%35==0:
                    trial.report(teda.wape_RUL+teda.wape_HI, j)
                    if trial.should_prune():
                        raise optuna.TrialPruned()

            if SingleObj: return teda.wape_RUL + teda.wape_HI
            else: return teda.wape_RUL,teda.wape_HI

        pruner=optuna.pruners.HyperbandPruner()
        if SingleObj: study = optuna.create_study(direction='minimize',pruner=pruner,sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        else: study = optuna.create_study(directions=['minimize','minimize'],sampler=SelSampler(mode=OptSampler,seed=OptSeed))
        study.optimize(objective, n_trials=n_trials, timeout=timeout, callbacks=[EarlyStoppingCallback(patience=patience)])

        vec = []
        if SingleObj:
            trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
            for trial in trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]   
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
            df2 = df2.sort_values(by=df2.columns[0], ascending=False)[-5:]

        elif not SingleObj: 
            for trial in study.best_trials:
                p = trial.params
                nR_list = [p[f'nR_layer_{l}'] for l in range(p['n_layers'])]
                row = [trial.values[0],trial.values[1],p['m'],p['nI'],str(nR_list),p['nO'],p['mO'],p['N'],p['τ'],p['mode'],p['act']]
                vec.append(row)
            df2 = pd.DataFrame(vec,columns=names)
        
    if os.path.isfile(out_path) and out_path.startswith(study_dir):
        df1 = pd.read_csv(out_path)
        df_stdy = pd.concat([df1, df2], ignore_index=True)
    
    else: df_stdy = df2
    
    df_stdy.to_csv(out_path, index=False)
    opt_path = os.path.join(study_dir,f'opt_{len(os.listdir(study_dir))-1}.csv')
    
    if df2.shape[0] > 0: df2.to_csv(opt_path, index=False)

    return [df_stdy, df2 ]

# %%
dfs = Optimize(FileName=FileName[:-4],OptDim=2,OptSampler=None,OptPrune=False,
                         n_study=1,timeout=60,n_trials=0.5e3,patience=None,
                         mS=[2.0,4.5],nRS=[1,70],mdS=[1,1],actS=[0,1])

# %%
for i in range(1,6):
    dfs = Optimize(FileName=FileName[:-4],OptDim=2,OptSampler=None,OptPrune=False,
                            n_study=6,timeout=1680,n_trials=2e4,patience=2e3,
                            mS=[2.0,4.5],nLS=[i,i],nRS=[1,70],mdS=[1,1],actS=[0,1])
# Out:
# [I 2026-08-13 16:35:14,993] A new study created in memory with name: no-name-62ce87f5-07cf-40be-a6db-27b4a83b412a
# [I 2026-08-13 16:35:14,996] Trial 0 pruned.
# [I 2026-08-13 16:35:14,998] Trial 1 pruned.
# [I 2026-08-13 16:35:15,001] Trial 2 pruned.
# [I 2026-08-13 16:35:15,002] Trial 3 pruned.
# [I 2026-08-13 16:35:15,004] Trial 4 pruned.
# [I 2026-08-13 16:35:15,006] Trial 5 pruned.
# [I 2026-08-13 16:35:15,008] Trial 6 pruned.
# [I 2026-08-13 16:35:15,010] Trial 7 pruned.
# [I 2026-08-13 16:35:15,011] Trial 8 pruned.
# [I 2026-08-13 16:35:15,014] Trial 9 pruned.
# [I 2026-08-13 16:35:15,016] Trial 10 pruned.
# [I 2026-08-13 16:35:15,018] Trial 11 pruned.
# [I 2026-08-13 16:35:15,020] Trial 12 pruned.
# [I 2026-08-13 16:35:15,022] Trial 13 pruned.
# [I 2026-08-13 16:35:15,024] Trial 14 pruned.
# [I 2026-08-13 16:35:15,025] Trial 15 pruned.
# [I 2026-08-13 16:35:15,027] Trial 16 pruned.
# [I 2026-08-13 16:35:15,029] Trial 17 pruned.
# [I 2026-08-13 16:35:15,030] Trial 18 pruned.
# [I 2026-08-13 16:35:15,032] Trial 19 pruned.
# [I 2026-08-13 16:35:15,034] Trial 20 pruned.
# [I 2026-08-13 16:35:15,037] Trial 21 pruned.
# [I 2026-08-13 16:35:15,121] Trial 22 finished with values: [1.3472474136355417, 0.5414440357574367] and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 13, 'N': 7, 'τ': 4.612724350303668, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:15,123] Trial 23 pruned.
# [I 2026-08-13 16:35:15,125] Trial 24 pruned.
# [I 2026-08-13 16:35:15,127] Trial 25 pruned.
# [I 2026-08-13 16:35:15,129] Trial 26 pruned.
# [I 2026-08-13 16:35:15,132] Trial 27 pruned.
# [I 2026-08-13 16:35:15,134] Trial 28 pruned.
# [I 2026-08-13 16:35:15,135] Trial 29 pruned.
# [I 2026-08-13 16:35:15,137] Trial 30 pruned.
# [I 2026-08-13 16:35:15,139] Trial 31 pruned.
# [I 2026-08-13 16:35:15,141] Trial 32 pruned.
# [I 2026-08-13 16:35:15,143] Trial 33 pruned.
# [I 2026-08-13 16:35:15,146] Trial 34 pruned.
# [I 2026-08-13 16:35:15,148] Trial 35 pruned.
# [I 2026-08-13 16:35:15,149] Trial 36 pruned.
# [I 2026-08-13 16:35:15,151] Trial 37 pruned.
# [I 2026-08-13 16:35:15,152] Trial 38 pruned.
# [I 2026-08-13 16:35:15,154] Trial 39 pruned.
# [I 2026-08-13 16:35:15,157] Trial 40 pruned.
# [I 2026-08-13 16:35:15,159] Trial 41 pruned.
# [I 2026-08-13 16:35:15,161] Trial 42 pruned.
# [I 2026-08-13 16:35:15,164] Trial 43 pruned.
# [I 2026-08-13 16:35:15,166] Trial 44 pruned.
# [I 2026-08-13 16:35:15,168] Trial 45 pruned.
# [I 2026-08-13 16:35:15,170] Trial 46 pruned.
# iteration: 1
# [I 2026-08-13 16:35:15,172] Trial 47 pruned.
# [I 2026-08-13 16:35:15,174] Trial 48 pruned.
# [I 2026-08-13 16:35:15,176] Trial 49 pruned.
# [I 2026-08-13 16:35:15,178] Trial 50 pruned.
# [I 2026-08-13 16:35:15,180] Trial 51 pruned.
# [I 2026-08-13 16:35:15,181] Trial 52 pruned.
# [I 2026-08-13 16:35:15,183] Trial 53 pruned.
# [I 2026-08-13 16:35:15,184] Trial 54 pruned.
# [I 2026-08-13 16:35:15,186] Trial 55 pruned.
# [I 2026-08-13 16:35:15,244] Trial 56 finished with values: [0.9554965157601026, 0.5297343024630841] and parameters: {'m': 2.75, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 66, 'nO': 20, 'N': 4, 'τ': 23.941640302352173, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:15,247] Trial 57 pruned.
# [I 2026-08-13 16:35:15,249] Trial 58 pruned.
# [I 2026-08-13 16:35:15,251] Trial 59 pruned.
# [I 2026-08-13 16:35:15,253] Trial 60 pruned.
# [I 2026-08-13 16:35:15,255] Trial 61 pruned.
# [I 2026-08-13 16:35:15,258] Trial 62 pruned.
# [I 2026-08-13 16:35:15,261] Trial 63 pruned.
# [I 2026-08-13 16:35:15,264] Trial 64 pruned.
# [I 2026-08-13 16:35:15,265] Trial 65 pruned.
# [I 2026-08-13 16:35:15,267] Trial 66 pruned.
# [I 2026-08-13 16:35:15,270] Trial 67 pruned.
# [I 2026-08-13 16:35:15,272] Trial 68 pruned.
# [I 2026-08-13 16:35:15,275] Trial 69 pruned.
# [I 2026-08-13 16:35:15,925] Trial 70 finished with values: [2.3727473569270097, 0.20356533416182895] and parameters: {'m': 4.5, 'nI': 3, 'n_layers': 1, 'nR_layer_0': 5, 'nO': 8, 'N': 6, 'τ': 1.043777712155653, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:35:15,928] Trial 71 pruned.
# [I 2026-08-13 16:35:15,931] Trial 72 pruned.
# [I 2026-08-13 16:35:15,933] Trial 73 pruned.
# [I 2026-08-13 16:35:15,935] Trial 74 pruned.
# [I 2026-08-13 16:35:15,937] Trial 75 pruned.
# [I 2026-08-13 16:35:15,938] Trial 76 pruned.
# [I 2026-08-13 16:35:15,941] Trial 77 pruned.
# [I 2026-08-13 16:35:15,942] Trial 78 pruned.
# [I 2026-08-13 16:35:15,945] Trial 79 pruned.
# [I 2026-08-13 16:35:15,946] Trial 80 pruned.
# [I 2026-08-13 16:35:15,948] Trial 81 pruned.
# [I 2026-08-13 16:35:15,949] Trial 82 pruned.
# [I 2026-08-13 16:35:15,951] Trial 83 pruned.
# [I 2026-08-13 16:35:15,954] Trial 84 pruned.
# [I 2026-08-13 16:35:15,956] Trial 85 pruned.
# [I 2026-08-13 16:35:15,957] Trial 86 pruned.
# [I 2026-08-13 16:35:15,960] Trial 87 pruned.
# [I 2026-08-13 16:35:15,962] Trial 88 pruned.
# [I 2026-08-13 16:35:15,964] Trial 89 pruned.
# [I 2026-08-13 16:35:15,965] Trial 90 pruned.
# [I 2026-08-13 16:35:15,967] Trial 91 pruned.
# [I 2026-08-13 16:35:15,969] Trial 92 pruned.
# [I 2026-08-13 16:35:15,970] Trial 93 pruned.
# [I 2026-08-13 16:35:16,011] Trial 94 finished with values: [0.975976406692238, 1.3351895605787636] and parameters: {'m': 3.75, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 52, 'nO': 19, 'N': 9, 'τ': 20.100250645249577, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:16,013] Trial 95 pruned.
# [I 2026-08-13 16:35:16,015] Trial 96 pruned.
# [I 2026-08-13 16:35:16,016] Trial 97 pruned.
# [I 2026-08-13 16:35:16,017] Trial 98 pruned.
# [I 2026-08-13 16:35:16,019] Trial 99 pruned.
# [I 2026-08-13 16:35:16,021] Trial 100 pruned.
# [I 2026-08-13 16:35:16,022] Trial 101 pruned.
# [I 2026-08-13 16:35:16,446] Trial 102 finished with values: [2.9482445596540567, 0.1261219372557767] and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 1, 'N': 7, 'τ': 12.997046736411548, 'mode': 1, 'act': 1, 'mO': 17}.
# [I 2026-08-13 16:35:16,448] Trial 103 pruned.
# [I 2026-08-13 16:35:16,450] Trial 104 pruned.
# [I 2026-08-13 16:35:16,452] Trial 105 pruned.
# [I 2026-08-13 16:35:16,454] Trial 106 pruned.
# [I 2026-08-13 16:35:16,455] Trial 107 pruned.
# [I 2026-08-13 16:35:16,457] Trial 108 pruned.
# [I 2026-08-13 16:35:16,460] Trial 109 pruned.
# [I 2026-08-13 16:35:16,462] Trial 110 pruned.
# [I 2026-08-13 16:35:16,464] Trial 111 pruned.
# [I 2026-08-13 16:35:16,465] Trial 112 pruned.
# [I 2026-08-13 16:35:16,467] Trial 113 pruned.
# [I 2026-08-13 16:35:16,469] Trial 114 pruned.
# [I 2026-08-13 16:35:16,471] Trial 115 pruned.
# [I 2026-08-13 16:35:16,472] Trial 116 pruned.
# [I 2026-08-13 16:35:16,474] Trial 117 pruned.
# [I 2026-08-13 16:35:16,477] Trial 118 pruned.
# [I 2026-08-13 16:35:16,479] Trial 119 pruned.
# [I 2026-08-13 16:35:16,483] Trial 120 pruned.
# [I 2026-08-13 16:35:17,048] Trial 121 finished with values: [2.839972268866602, 1.3745787641705913] and parameters: {'m': 2.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 25, 'nO': 2, 'N': 5, 'τ': 8.599446775543047, 'mode': 1, 'act': 0, 'mO': 15}.
# [I 2026-08-13 16:35:17,049] Trial 122 pruned.
# [I 2026-08-13 16:35:17,052] Trial 123 pruned.
# [I 2026-08-13 16:35:17,054] Trial 124 pruned.
# [I 2026-08-13 16:35:17,055] Trial 125 pruned.
# [I 2026-08-13 16:35:17,058] Trial 126 pruned.
# [I 2026-08-13 16:35:17,059] Trial 127 pruned.
# [I 2026-08-13 16:35:17,061] Trial 128 pruned.
# [I 2026-08-13 16:35:17,063] Trial 129 pruned.
# [I 2026-08-13 16:35:17,065] Trial 130 pruned.
# [I 2026-08-13 16:35:17,068] Trial 131 pruned.
# [I 2026-08-13 16:35:17,070] Trial 132 pruned.
# [I 2026-08-13 16:35:17,073] Trial 133 pruned.
# [I 2026-08-13 16:35:17,075] Trial 134 pruned.
# [I 2026-08-13 16:35:17,078] Trial 135 pruned.
# [I 2026-08-13 16:35:17,081] Trial 136 pruned.
# [I 2026-08-13 16:35:17,110] Trial 137 finished with values: [0.9688723545403697, 0.7396803782147072] and parameters: {'m': 2.5, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 7, 'N': 8, 'τ': 16.246272944306234, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:17,113] Trial 138 pruned.
# [I 2026-08-13 16:35:17,115] Trial 139 pruned.
# [I 2026-08-13 16:35:17,117] Trial 140 pruned.
# [I 2026-08-13 16:35:17,120] Trial 141 pruned.
# [I 2026-08-13 16:35:17,122] Trial 142 pruned.
# [I 2026-08-13 16:35:17,124] Trial 143 pruned.
# [I 2026-08-13 16:35:17,127] Trial 144 pruned.
# [I 2026-08-13 16:35:17,130] Trial 145 pruned.
# [I 2026-08-13 16:35:17,133] Trial 146 pruned.
# [I 2026-08-13 16:35:17,134] Trial 147 pruned.
# [I 2026-08-13 16:35:17,546] Trial 148 finished with values: [1.14485167432847, 0.2656994580989707] and parameters: {'m': 2.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 2, 'N': 2, 'τ': 7.34196238037362, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:35:17,548] Trial 149 pruned.
# [I 2026-08-13 16:35:17,550] Trial 150 pruned.
# [I 2026-08-13 16:35:17,552] Trial 151 pruned.
# [I 2026-08-13 16:35:17,554] Trial 152 pruned.
# [I 2026-08-13 16:35:17,555] Trial 153 pruned.
# [I 2026-08-13 16:35:17,557] Trial 154 pruned.
# [I 2026-08-13 16:35:17,559] Trial 155 pruned.
# [I 2026-08-13 16:35:17,634] Trial 156 finished with values: [0.7260932659118259, 0.4563952802559122] and parameters: {'m': 3.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 5, 'N': 5, 'τ': 21.272291833633858, 'mode': 1, 'act': 1, 'mO': 16}.
# [I 2026-08-13 16:35:17,637] Trial 157 pruned.
# [I 2026-08-13 16:35:17,640] Trial 158 pruned.
# [I 2026-08-13 16:35:17,702] Trial 159 finished with values: [0.9709097614949594, 1.021515865891487] and parameters: {'m': 4.25, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 8, 'N': 2, 'τ': 1.117219948230015, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:17,706] Trial 160 pruned.
# [I 2026-08-13 16:35:17,708] Trial 161 pruned.
# [I 2026-08-13 16:35:17,710] Trial 162 pruned.
# [I 2026-08-13 16:35:17,743] Trial 163 finished with values: [0.9752326648488968, 2.0475390938071034] and parameters: {'m': 3.75, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 49, 'nO': 17, 'N': 9, 'τ': 3.53292063136181, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:17,746] Trial 164 pruned.
# [I 2026-08-13 16:35:17,748] Trial 165 pruned.
# [I 2026-08-13 16:35:17,751] Trial 166 pruned.
# [I 2026-08-13 16:35:17,753] Trial 167 pruned.
# [I 2026-08-13 16:35:17,756] Trial 168 pruned.
# [I 2026-08-13 16:35:17,759] Trial 169 pruned.
# [I 2026-08-13 16:35:17,761] Trial 170 pruned.
# [I 2026-08-13 16:35:17,764] Trial 171 pruned.
# [I 2026-08-13 16:35:17,768] Trial 172 pruned.
# [I 2026-08-13 16:35:17,771] Trial 173 pruned.
# [I 2026-08-13 16:35:17,774] Trial 174 pruned.
# [I 2026-08-13 16:35:17,777] Trial 175 pruned.
# [I 2026-08-13 16:35:18,199] Trial 176 finished with values: [1.9623547528029937, 0.20021285164537916] and parameters: {'m': 4.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 13, 'N': 2, 'τ': 23.11041443831531, 'mode': 1, 'act': 0, 'mO': 17}.
# [I 2026-08-13 16:35:18,201] Trial 177 pruned.
# [I 2026-08-13 16:35:18,202] Trial 178 pruned.
# [I 2026-08-13 16:35:18,205] Trial 179 pruned.
# [I 2026-08-13 16:35:18,240] Trial 180 finished with values: [0.9647586980920314, 1.7379331242524358] and parameters: {'m': 2.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 1, 'N': 8, 'τ': 10.652445415469085, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:18,243] Trial 181 pruned.
# [I 2026-08-13 16:35:18,271] Trial 182 finished with values: [0.9717320766378245, 1.811096992543447] and parameters: {'m': 3.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 10, 'N': 5, 'τ': 5.32789853805293, 'mode': 1, 'act': 0, 'mO': 7}.
# [I 2026-08-13 16:35:18,273] Trial 183 pruned.
# [I 2026-08-13 16:35:18,276] Trial 184 pruned.
# [I 2026-08-13 16:35:18,278] Trial 185 pruned.
# [I 2026-08-13 16:35:18,280] Trial 186 pruned.
# [I 2026-08-13 16:35:18,282] Trial 187 pruned.
# [I 2026-08-13 16:35:18,284] Trial 188 pruned.
# [I 2026-08-13 16:35:18,287] Trial 189 pruned.
# [I 2026-08-13 16:35:18,289] Trial 190 pruned.
# [I 2026-08-13 16:35:18,291] Trial 191 pruned.
# [I 2026-08-13 16:35:18,293] Trial 192 pruned.
# [I 2026-08-13 16:35:18,296] Trial 193 pruned.
# [I 2026-08-13 16:35:18,297] Trial 194 pruned.
# [I 2026-08-13 16:35:18,299] Trial 195 pruned.
# [I 2026-08-13 16:35:18,302] Trial 196 pruned.
# [I 2026-08-13 16:35:18,305] Trial 197 pruned.
# [I 2026-08-13 16:35:18,306] Trial 198 pruned.
# [I 2026-08-13 16:35:18,308] Trial 199 pruned.
# [I 2026-08-13 16:35:18,311] Trial 200 pruned.
# [I 2026-08-13 16:35:18,314] Trial 201 pruned.
# [I 2026-08-13 16:35:18,316] Trial 202 pruned.
# [I 2026-08-13 16:35:18,318] Trial 203 pruned.
# [I 2026-08-13 16:35:18,356] Trial 204 finished with values: [0.9713267969245962, 1.4602307630257023] and parameters: {'m': 2.75, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 70, 'nO': 11, 'N': 5, 'τ': 10.190709035612029, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:18,359] Trial 205 pruned.
# [I 2026-08-13 16:35:18,362] Trial 206 pruned.
# [I 2026-08-13 16:35:18,363] Trial 207 pruned.
# [I 2026-08-13 16:35:18,365] Trial 208 pruned.
# [I 2026-08-13 16:35:18,367] Trial 209 pruned.
# [I 2026-08-13 16:35:18,369] Trial 210 pruned.
# [I 2026-08-13 16:35:18,371] Trial 211 pruned.
# [I 2026-08-13 16:35:18,373] Trial 212 pruned.
# [I 2026-08-13 16:35:18,375] Trial 213 pruned.
# [I 2026-08-13 16:35:18,376] Trial 214 pruned.
# [I 2026-08-13 16:35:18,378] Trial 215 pruned.
# [I 2026-08-13 16:35:18,381] Trial 216 pruned.
# [I 2026-08-13 16:35:18,383] Trial 217 pruned.
# [I 2026-08-13 16:35:18,385] Trial 218 pruned.
# [I 2026-08-13 16:35:18,388] Trial 219 pruned.
# [I 2026-08-13 16:35:18,390] Trial 220 pruned.
# [I 2026-08-13 16:35:18,392] Trial 221 pruned.
# [I 2026-08-13 16:35:18,394] Trial 222 pruned.
# [I 2026-08-13 16:35:18,397] Trial 223 pruned.
# [I 2026-08-13 16:35:18,398] Trial 224 pruned.
# [I 2026-08-13 16:35:18,399] Trial 225 pruned.
# [I 2026-08-13 16:35:18,401] Trial 226 pruned.
# [I 2026-08-13 16:35:18,404] Trial 227 pruned.
# [I 2026-08-13 16:35:18,405] Trial 228 pruned.
# [I 2026-08-13 16:35:18,407] Trial 229 pruned.
# [I 2026-08-13 16:35:18,409] Trial 230 pruned.
# [I 2026-08-13 16:35:18,411] Trial 231 pruned.
# [I 2026-08-13 16:35:18,412] Trial 232 pruned.
# [I 2026-08-13 16:35:18,416] Trial 233 pruned.
# [I 2026-08-13 16:35:18,419] Trial 234 pruned.
# [I 2026-08-13 16:35:18,479] Trial 235 finished with values: [0.9721260424363982, 1.1290739713090234] and parameters: {'m': 3.75, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 11, 'N': 3, 'τ': 7.51430578542623, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:35:18,482] Trial 236 pruned.
# [I 2026-08-13 16:35:18,484] Trial 237 pruned.
# [I 2026-08-13 16:35:18,486] Trial 238 pruned.
# [I 2026-08-13 16:35:18,491] Trial 239 pruned.
# [I 2026-08-13 16:35:18,493] Trial 240 pruned.
# [I 2026-08-13 16:35:18,495] Trial 241 pruned.
# [I 2026-08-13 16:35:18,497] Trial 242 pruned.
# [I 2026-08-13 16:35:18,543] Trial 243 finished with values: [0.9650664706828846, 1.002534985822771] and parameters: {'m': 4.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 2, 'nO': 2, 'N': 2, 'τ': 17.01756434574383, 'mode': 1, 'act': 1, 'mO': 13}.
# [I 2026-08-13 16:35:18,546] Trial 244 pruned.
# [I 2026-08-13 16:35:18,549] Trial 245 pruned.
# [I 2026-08-13 16:35:18,551] Trial 246 pruned.
# [I 2026-08-13 16:35:18,554] Trial 247 pruned.
# [I 2026-08-13 16:35:18,556] Trial 248 pruned.
# [I 2026-08-13 16:35:18,559] Trial 249 pruned.
# [I 2026-08-13 16:35:18,561] Trial 250 pruned.
# [I 2026-08-13 16:35:18,565] Trial 251 pruned.
# [I 2026-08-13 16:35:18,567] Trial 252 pruned.
# [I 2026-08-13 16:35:18,570] Trial 253 pruned.
# [I 2026-08-13 16:35:18,572] Trial 254 pruned.
# [I 2026-08-13 16:35:18,575] Trial 255 pruned.
# [I 2026-08-13 16:35:18,577] Trial 256 pruned.
# [I 2026-08-13 16:35:18,581] Trial 257 pruned.
# [I 2026-08-13 16:35:18,583] Trial 258 pruned.
# [I 2026-08-13 16:35:18,586] Trial 259 pruned.
# [I 2026-08-13 16:35:18,589] Trial 260 pruned.
# [I 2026-08-13 16:35:18,593] Trial 261 pruned.
# [I 2026-08-13 16:35:18,596] Trial 262 pruned.
# [I 2026-08-13 16:35:18,599] Trial 263 pruned.
# [I 2026-08-13 16:35:19,045] Trial 264 finished with values: [2.003640943702655, 0.0767206017733131] and parameters: {'m': 2.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 12, 'N': 6, 'τ': 5.8747506713122375, 'mode': 1, 'act': 0, 'mO': 14}.
# [I 2026-08-13 16:35:19,047] Trial 265 pruned.
# [I 2026-08-13 16:35:19,049] Trial 266 pruned.
# [I 2026-08-13 16:35:19,509] Trial 267 finished with values: [2.255986438183405, 1.0333749504106062] and parameters: {'m': 3.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 10, 'N': 2, 'τ': 23.32888056910825, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:19,512] Trial 268 pruned.
# [I 2026-08-13 16:35:19,513] Trial 269 pruned.
# [I 2026-08-13 16:35:20,027] Trial 270 finished with values: [1.6337993971101603, 0.8211831132658878] and parameters: {'m': 4.0, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 19, 'N': 3, 'τ': 4.478124757611546, 'mode': 1, 'act': 0, 'mO': 12}.
# [I 2026-08-13 16:35:20,029] Trial 271 pruned.
# [I 2026-08-13 16:35:20,032] Trial 272 pruned.
# [I 2026-08-13 16:35:20,355] Trial 273 finished with values: [1.4742546163869075, 0.20827277199044558] and parameters: {'m': 2.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 57, 'nO': 2, 'N': 6, 'τ': 16.084904078151382, 'mode': 1, 'act': 1, 'mO': 8}.
# [I 2026-08-13 16:35:20,357] Trial 274 pruned.
# [I 2026-08-13 16:35:20,407] Trial 275 finished with values: [0.9698120348177116, 0.8681879153664526] and parameters: {'m': 3.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 8, 'N': 4, 'τ': 10.016774317659127, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:35:20,410] Trial 276 pruned.
# [I 2026-08-13 16:35:20,412] Trial 277 pruned.
# [I 2026-08-13 16:35:20,415] Trial 278 pruned.
# [I 2026-08-13 16:35:20,799] Trial 279 finished with values: [1.8306476583690374, 0.23588863616126662] and parameters: {'m': 3.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 17, 'N': 9, 'τ': 17.1670980638699, 'mode': 1, 'act': 1, 'mO': 13}.
# [I 2026-08-13 16:35:20,801] Trial 280 pruned.
# [I 2026-08-13 16:35:20,832] Trial 281 finished with values: [0.9732447096330745, 1.0421852098446063] and parameters: {'m': 4.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 3, 'nO': 12, 'N': 7, 'τ': 23.639876504078664, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:35:20,835] Trial 282 pruned.
# [I 2026-08-13 16:35:20,838] Trial 283 pruned.
# [I 2026-08-13 16:35:20,841] Trial 284 pruned.
# [I 2026-08-13 16:35:20,843] Trial 285 pruned.
# [I 2026-08-13 16:35:20,844] Trial 286 pruned.
# [I 2026-08-13 16:35:20,847] Trial 287 pruned.
# [I 2026-08-13 16:35:20,849] Trial 288 pruned.
# [I 2026-08-13 16:35:20,852] Trial 289 pruned.
# [I 2026-08-13 16:35:20,854] Trial 290 pruned.
# [I 2026-08-13 16:35:20,856] Trial 291 pruned.
# [I 2026-08-13 16:35:20,859] Trial 292 pruned.
# [I 2026-08-13 16:35:20,861] Trial 293 pruned.
# [I 2026-08-13 16:35:20,864] Trial 294 pruned.
# [I 2026-08-13 16:35:20,866] Trial 295 pruned.
# [I 2026-08-13 16:35:20,869] Trial 296 pruned.
# [I 2026-08-13 16:35:20,871] Trial 297 pruned.
# [I 2026-08-13 16:35:20,874] Trial 298 pruned.
# [I 2026-08-13 16:35:20,877] Trial 299 pruned.
# [I 2026-08-13 16:35:20,880] Trial 300 pruned.
# [I 2026-08-13 16:35:20,882] Trial 301 pruned.
# [I 2026-08-13 16:35:20,885] Trial 302 pruned.
# [I 2026-08-13 16:35:21,281] Trial 303 finished with values: [1.773116671439734, 0.24835731266967015] and parameters: {'m': 2.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 16, 'N': 5, 'τ': 17.198337834953627, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:21,283] Trial 304 pruned.
# [I 2026-08-13 16:35:21,285] Trial 305 pruned.
# [I 2026-08-13 16:35:21,288] Trial 306 pruned.
# [I 2026-08-13 16:35:21,291] Trial 307 pruned.
# [I 2026-08-13 16:35:21,293] Trial 308 pruned.
# [I 2026-08-13 16:35:21,295] Trial 309 pruned.
# [I 2026-08-13 16:35:21,297] Trial 310 pruned.
# [I 2026-08-13 16:35:21,299] Trial 311 pruned.
# [I 2026-08-13 16:35:21,301] Trial 312 pruned.
# [I 2026-08-13 16:35:21,303] Trial 313 pruned.
# [I 2026-08-13 16:35:21,305] Trial 314 pruned.
# [I 2026-08-13 16:35:21,307] Trial 315 pruned.
# [I 2026-08-13 16:35:21,309] Trial 316 pruned.
# [I 2026-08-13 16:35:21,311] Trial 317 pruned.
# [I 2026-08-13 16:35:21,313] Trial 318 pruned.
# [I 2026-08-13 16:35:21,315] Trial 319 pruned.
# [I 2026-08-13 16:35:21,344] Trial 320 finished with values: [0.9744413990538606, 1.4225373509435366] and parameters: {'m': 4.5, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 46, 'nO': 15, 'N': 8, 'τ': 24.357318778626976, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:35:21,346] Trial 321 pruned.
# [I 2026-08-13 16:35:21,349] Trial 322 pruned.
# [I 2026-08-13 16:35:21,350] Trial 323 pruned.
# [I 2026-08-13 16:35:21,352] Trial 324 pruned.
# [I 2026-08-13 16:35:21,354] Trial 325 pruned.
# [I 2026-08-13 16:35:21,356] Trial 326 pruned.
# [I 2026-08-13 16:35:21,358] Trial 327 pruned.
# [I 2026-08-13 16:35:21,361] Trial 328 pruned.
# [I 2026-08-13 16:35:21,363] Trial 329 pruned.
# [I 2026-08-13 16:35:21,365] Trial 330 pruned.
# [I 2026-08-13 16:35:21,366] Trial 331 pruned.
# [I 2026-08-13 16:35:21,369] Trial 332 pruned.
# [I 2026-08-13 16:35:21,370] Trial 333 pruned.
# [I 2026-08-13 16:35:21,372] Trial 334 pruned.
# [I 2026-08-13 16:35:21,374] Trial 335 pruned.
# [I 2026-08-13 16:35:21,375] Trial 336 pruned.
# [I 2026-08-13 16:35:21,377] Trial 337 pruned.
# [I 2026-08-13 16:35:21,418] Trial 338 finished with values: [0.9665280869451355, 2.126679529282222] and parameters: {'m': 4.5, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 3, 'N': 5, 'τ': 3.3107207129794203, 'mode': 1, 'act': 0, 'mO': 8}.
# [I 2026-08-13 16:35:21,421] Trial 339 pruned.
# [I 2026-08-13 16:35:21,423] Trial 340 pruned.
# [I 2026-08-13 16:35:21,426] Trial 341 pruned.
# [I 2026-08-13 16:35:21,428] Trial 342 pruned.
# [I 2026-08-13 16:35:21,429] Trial 343 pruned.
# [I 2026-08-13 16:35:21,431] Trial 344 pruned.
# [I 2026-08-13 16:35:21,433] Trial 345 pruned.
# [I 2026-08-13 16:35:21,435] Trial 346 pruned.
# [I 2026-08-13 16:35:21,437] Trial 347 pruned.
# [I 2026-08-13 16:35:21,440] Trial 348 pruned.
# [I 2026-08-13 16:35:21,443] Trial 349 pruned.
# [I 2026-08-13 16:35:21,445] Trial 350 pruned.
# [I 2026-08-13 16:35:21,448] Trial 351 pruned.
# [I 2026-08-13 16:35:21,450] Trial 352 pruned.
# [I 2026-08-13 16:35:21,453] Trial 353 pruned.
# [I 2026-08-13 16:35:21,456] Trial 354 pruned.
# [I 2026-08-13 16:35:21,459] Trial 355 pruned.
# [I 2026-08-13 16:35:21,460] Trial 356 pruned.
# [I 2026-08-13 16:35:21,462] Trial 357 pruned.
# [I 2026-08-13 16:35:21,465] Trial 358 pruned.
# [I 2026-08-13 16:35:21,761] Trial 359 finished with values: [1.6528506259789206, 1.2365463497308022] and parameters: {'m': 2.25, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 16, 'N': 2, 'τ': 13.469507215442992, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:35:21,764] Trial 360 pruned.
# [I 2026-08-13 16:35:21,767] Trial 361 pruned.
# [I 2026-08-13 16:35:21,770] Trial 362 pruned.
# [I 2026-08-13 16:35:21,772] Trial 363 pruned.
# [I 2026-08-13 16:35:21,776] Trial 364 pruned.
# [I 2026-08-13 16:35:21,779] Trial 365 pruned.
# [I 2026-08-13 16:35:21,781] Trial 366 pruned.
# [I 2026-08-13 16:35:21,784] Trial 367 pruned.
# [I 2026-08-13 16:35:21,787] Trial 368 pruned.
# [I 2026-08-13 16:35:21,790] Trial 369 pruned.
# [I 2026-08-13 16:35:21,792] Trial 370 pruned.
# [I 2026-08-13 16:35:21,794] Trial 371 pruned.
# [I 2026-08-13 16:35:21,797] Trial 372 pruned.
# [I 2026-08-13 16:35:21,799] Trial 373 pruned.
# [I 2026-08-13 16:35:21,802] Trial 374 pruned.
# [I 2026-08-13 16:35:21,804] Trial 375 pruned.
# [I 2026-08-13 16:35:21,807] Trial 376 pruned.
# [I 2026-08-13 16:35:21,810] Trial 377 pruned.
# [I 2026-08-13 16:35:21,812] Trial 378 pruned.
# [I 2026-08-13 16:35:21,815] Trial 379 pruned.
# [I 2026-08-13 16:35:21,818] Trial 380 pruned.
# [I 2026-08-13 16:35:21,821] Trial 381 pruned.
# [I 2026-08-13 16:35:21,822] Trial 382 pruned.
# [I 2026-08-13 16:35:21,824] Trial 383 pruned.
# [I 2026-08-13 16:35:21,825] Trial 384 pruned.
# [I 2026-08-13 16:35:21,827] Trial 385 pruned.
# [I 2026-08-13 16:35:21,830] Trial 386 pruned.
# [I 2026-08-13 16:35:21,832] Trial 387 pruned.
# [I 2026-08-13 16:35:21,833] Trial 388 pruned.
# [I 2026-08-13 16:35:21,835] Trial 389 pruned.
# [I 2026-08-13 16:35:21,837] Trial 390 pruned.
# [I 2026-08-13 16:35:21,839] Trial 391 pruned.
# [I 2026-08-13 16:35:21,841] Trial 392 pruned.
# [I 2026-08-13 16:35:21,885] Trial 393 finished with values: [0.9766767936433747, 1.667969260681285] and parameters: {'m': 3.0, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 37, 'nO': 20, 'N': 4, 'τ': 18.333684668640537, 'mode': 1, 'act': 1, 'mO': 11}.
# [I 2026-08-13 16:35:21,888] Trial 394 pruned.
# [I 2026-08-13 16:35:21,891] Trial 395 pruned.
# [I 2026-08-13 16:35:21,894] Trial 396 pruned.
# [I 2026-08-13 16:35:21,897] Trial 397 pruned.
# [I 2026-08-13 16:35:21,899] Trial 398 pruned.
# [I 2026-08-13 16:35:21,902] Trial 399 pruned.
# [I 2026-08-13 16:35:21,904] Trial 400 pruned.
# [I 2026-08-13 16:35:21,907] Trial 401 pruned.
# [I 2026-08-13 16:35:21,910] Trial 402 pruned.
# [I 2026-08-13 16:35:21,912] Trial 403 pruned.
# [I 2026-08-13 16:35:21,915] Trial 404 pruned.
# [I 2026-08-13 16:35:21,918] Trial 405 pruned.
# [I 2026-08-13 16:35:21,919] Trial 406 pruned.
# [I 2026-08-13 16:35:21,922] Trial 407 pruned.
# [I 2026-08-13 16:35:21,924] Trial 408 pruned.
# [I 2026-08-13 16:35:21,927] Trial 409 pruned.
# [I 2026-08-13 16:35:21,930] Trial 410 pruned.
# [I 2026-08-13 16:35:22,263] Trial 411 finished with values: [1.967564795150755, 1589.5398300429124] and parameters: {'m': 2.75, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 35, 'nO': 14, 'N': 2, 'τ': 7.478854738364916, 'mode': 1, 'act': 0, 'mO': 7}.
# [I 2026-08-13 16:35:22,266] Trial 412 pruned.
# [I 2026-08-13 16:35:22,268] Trial 413 pruned.
# [I 2026-08-13 16:35:22,302] Trial 414 finished with values: [0.9681283002461378, 2.0059932642479135] and parameters: {'m': 2.5, 'nI': 6, 'n_layers': 1, 'nR_layer_0': 53, 'nO': 3, 'N': 9, 'τ': 8.930368604137946, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:35:22,304] Trial 415 pruned.
# [I 2026-08-13 16:35:22,306] Trial 416 pruned.
# [I 2026-08-13 16:35:22,308] Trial 417 pruned.
# [I 2026-08-13 16:35:22,310] Trial 418 pruned.
# [I 2026-08-13 16:35:22,312] Trial 419 pruned.
# [I 2026-08-13 16:35:22,315] Trial 420 pruned.
# [I 2026-08-13 16:35:22,317] Trial 421 pruned.
# [I 2026-08-13 16:35:22,318] Trial 422 pruned.
# [I 2026-08-13 16:35:22,321] Trial 423 pruned.
# [I 2026-08-13 16:35:22,322] Trial 424 pruned.
# [I 2026-08-13 16:35:22,324] Trial 425 pruned.
# [I 2026-08-13 16:35:22,327] Trial 426 pruned.
# [I 2026-08-13 16:35:22,329] Trial 427 pruned.
# [I 2026-08-13 16:35:22,332] Trial 428 pruned.
# [I 2026-08-13 16:35:22,333] Trial 429 pruned.
# [I 2026-08-13 16:35:22,335] Trial 430 pruned.
# [I 2026-08-13 16:35:22,337] Trial 431 pruned.
# [I 2026-08-13 16:35:22,339] Trial 432 pruned.
# [I 2026-08-13 16:35:22,341] Trial 433 pruned.
# [I 2026-08-13 16:35:22,343] Trial 434 pruned.
# [I 2026-08-13 16:35:22,345] Trial 435 pruned.
# [I 2026-08-13 16:35:22,347] Trial 436 pruned.
# [I 2026-08-13 16:35:22,349] Trial 437 pruned.
# [I 2026-08-13 16:35:22,351] Trial 438 pruned.
# [I 2026-08-13 16:35:22,353] Trial 439 pruned.
# [I 2026-08-13 16:35:22,355] Trial 440 pruned.
# [I 2026-08-13 16:35:22,357] Trial 441 pruned.
# [I 2026-08-13 16:35:22,358] Trial 442 pruned.
# [I 2026-08-13 16:35:22,360] Trial 443 pruned.
# [I 2026-08-13 16:35:22,361] Trial 444 pruned.
# [I 2026-08-13 16:35:22,363] Trial 445 pruned.
# [I 2026-08-13 16:35:22,366] Trial 446 pruned.
# [I 2026-08-13 16:35:22,367] Trial 447 pruned.
# [I 2026-08-13 16:35:22,370] Trial 448 pruned.
# [I 2026-08-13 16:35:22,371] Trial 449 pruned.
# [I 2026-08-13 16:35:22,373] Trial 450 pruned.
# [I 2026-08-13 16:35:22,374] Trial 451 pruned.
# [I 2026-08-13 16:35:22,376] Trial 452 pruned.
# [I 2026-08-13 16:35:22,377] Trial 453 pruned.
# [I 2026-08-13 16:35:22,380] Trial 454 pruned.
# [I 2026-08-13 16:35:22,382] Trial 455 pruned.
# [I 2026-08-13 16:35:22,385] Trial 456 pruned.
# [I 2026-08-13 16:35:22,388] Trial 457 pruned.
# [I 2026-08-13 16:35:22,390] Trial 458 pruned.
# [I 2026-08-13 16:35:22,597] Trial 459 finished with values: [1.5024068003526778, 6.34175256311075] and parameters: {'m': 4.25, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 40, 'nO': 3, 'N': 1, 'τ': 15.429239061941871, 'mode': 1, 'act': 0, 'mO': 13}.
# [I 2026-08-13 16:35:22,599] Trial 460 pruned.
# [I 2026-08-13 16:35:22,603] Trial 461 pruned.
# [I 2026-08-13 16:35:22,605] Trial 462 pruned.
# [I 2026-08-13 16:35:22,606] Trial 463 pruned.
# [I 2026-08-13 16:35:22,608] Trial 464 pruned.
# [I 2026-08-13 16:35:22,610] Trial 465 pruned.
# [I 2026-08-13 16:35:22,612] Trial 466 pruned.
# [I 2026-08-13 16:35:22,614] Trial 467 pruned.
# [I 2026-08-13 16:35:22,991] Trial 468 finished with values: [1.8549853371122786, 0.28082010955721515] and parameters: {'m': 2.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 15, 'nO': 18, 'N': 8, 'τ': 14.531987344522301, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:35:22,993] Trial 469 pruned.
# [I 2026-08-13 16:35:22,996] Trial 470 pruned.
# [I 2026-08-13 16:35:22,999] Trial 471 pruned.
# [I 2026-08-13 16:35:23,001] Trial 472 pruned.
# [I 2026-08-13 16:35:23,004] Trial 473 pruned.
# [I 2026-08-13 16:35:23,006] Trial 474 pruned.
# [I 2026-08-13 16:35:23,009] Trial 475 pruned.
# [I 2026-08-13 16:35:23,011] Trial 476 pruned.
# [I 2026-08-13 16:35:23,014] Trial 477 pruned.
# [I 2026-08-13 16:35:23,017] Trial 478 pruned.
# [I 2026-08-13 16:35:23,018] Trial 479 pruned.
# [I 2026-08-13 16:35:23,020] Trial 480 pruned.
# [I 2026-08-13 16:35:23,022] Trial 481 pruned.
# [I 2026-08-13 16:35:23,024] Trial 482 pruned.
# [I 2026-08-13 16:35:23,026] Trial 483 pruned.
# [I 2026-08-13 16:35:23,029] Trial 484 pruned.
# [I 2026-08-13 16:35:23,031] Trial 485 pruned.
# [I 2026-08-13 16:35:23,034] Trial 486 pruned.
# [I 2026-08-13 16:35:23,037] Trial 487 pruned.
# [I 2026-08-13 16:35:23,039] Trial 488 pruned.
# [I 2026-08-13 16:35:23,041] Trial 489 pruned.
# [I 2026-08-13 16:35:23,114] Trial 490 finished with values: [0.7893143107899866, 0.39443156530382295] and parameters: {'m': 2.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 13, 'nO': 16, 'N': 5, 'τ': 8.481063112179209, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:35:23,117] Trial 491 pruned.
# [I 2026-08-13 16:35:23,119] Trial 492 pruned.
# [I 2026-08-13 16:35:23,387] Trial 493 finished with values: [0.5339139041858245, 0.13195068605402382] and parameters: {'m': 4.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 8, 'N': 5, 'τ': 11.741712193026494, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:23,388] Trial 494 pruned.
# [I 2026-08-13 16:35:23,443] Trial 495 finished with values: [0.9188999206734761, 0.5666734825749176] and parameters: {'m': 3.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 70, 'nO': 20, 'N': 8, 'τ': 20.780635289590403, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:35:23,446] Trial 496 pruned.
# [I 2026-08-13 16:35:23,449] Trial 497 pruned.
# [I 2026-08-13 16:35:23,451] Trial 498 pruned.
# [I 2026-08-13 16:35:23,454] Trial 499 pruned.
# [I 2026-08-13 16:35:23,457] Trial 500 pruned.
# [I 2026-08-13 16:35:23,459] Trial 501 pruned.
# [I 2026-08-13 16:35:23,461] Trial 502 pruned.
# [I 2026-08-13 16:35:23,463] Trial 503 pruned.
# [I 2026-08-13 16:35:23,465] Trial 504 pruned.
# [I 2026-08-13 16:35:23,467] Trial 505 pruned.
# [I 2026-08-13 16:35:23,468] Trial 506 pruned.
# [I 2026-08-13 16:35:23,469] Trial 507 pruned.
# [I 2026-08-13 16:35:23,471] Trial 508 pruned.
# [I 2026-08-13 16:35:23,473] Trial 509 pruned.
# [I 2026-08-13 16:35:23,476] Trial 510 pruned.
# [I 2026-08-13 16:35:23,478] Trial 511 pruned.
# [I 2026-08-13 16:35:23,480] Trial 512 pruned.
# [I 2026-08-13 16:35:23,482] Trial 513 pruned.
# [I 2026-08-13 16:35:23,485] Trial 514 pruned.
# [I 2026-08-13 16:35:23,487] Trial 515 pruned.
# [I 2026-08-13 16:35:23,489] Trial 516 pruned.
# [I 2026-08-13 16:35:23,491] Trial 517 pruned.
# [I 2026-08-13 16:35:23,492] Trial 518 pruned.
# [I 2026-08-13 16:35:23,494] Trial 519 pruned.
# [I 2026-08-13 16:35:23,496] Trial 520 pruned.
# [I 2026-08-13 16:35:23,497] Trial 521 pruned.
# [I 2026-08-13 16:35:23,499] Trial 522 pruned.
# [I 2026-08-13 16:35:23,501] Trial 523 pruned.
# [I 2026-08-13 16:35:23,503] Trial 524 pruned.
# [I 2026-08-13 16:35:23,504] Trial 525 pruned.
# [I 2026-08-13 16:35:23,507] Trial 526 pruned.
# [I 2026-08-13 16:35:23,509] Trial 527 pruned.
# [I 2026-08-13 16:35:23,512] Trial 528 pruned.
# [I 2026-08-13 16:35:23,514] Trial 529 pruned.
# [I 2026-08-13 16:35:23,516] Trial 530 pruned.
# [I 2026-08-13 16:35:23,518] Trial 531 pruned.
# [I 2026-08-13 16:35:23,521] Trial 532 pruned.
# [I 2026-08-13 16:35:23,523] Trial 533 pruned.
# [I 2026-08-13 16:35:23,525] Trial 534 pruned.
# [I 2026-08-13 16:35:23,527] Trial 535 pruned.
# [I 2026-08-13 16:35:23,529] Trial 536 pruned.
# [I 2026-08-13 16:35:23,530] Trial 537 pruned.
# [I 2026-08-13 16:35:23,533] Trial 538 pruned.
# [I 2026-08-13 16:35:23,535] Trial 539 pruned.
# [I 2026-08-13 16:35:23,537] Trial 540 pruned.
# [I 2026-08-13 16:35:23,539] Trial 541 pruned.
# [I 2026-08-13 16:35:23,542] Trial 542 pruned.
# [I 2026-08-13 16:35:23,544] Trial 543 pruned.
# [I 2026-08-13 16:35:23,546] Trial 544 pruned.
# [I 2026-08-13 16:35:23,548] Trial 545 pruned.
# [I 2026-08-13 16:35:23,551] Trial 546 pruned.
# [I 2026-08-13 16:35:23,553] Trial 547 pruned.
# [I 2026-08-13 16:35:23,593] Trial 548 finished with values: [0.967347784909173, 3.3006367396753844] and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 4, 'N': 7, 'τ': 11.780848528198085, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:35:23,596] Trial 549 pruned.
# [I 2026-08-13 16:35:23,599] Trial 550 pruned.
# [I 2026-08-13 16:35:23,635] Trial 551 finished with values: [0.9762615538103797, 0.7619863965745368] and parameters: {'m': 2.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 19, 'N': 4, 'τ': 21.633953505653597, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:35:23,637] Trial 552 pruned.
# [I 2026-08-13 16:35:23,640] Trial 553 pruned.
# [I 2026-08-13 16:35:23,642] Trial 554 pruned.
# [I 2026-08-13 16:35:23,645] Trial 555 pruned.
# [I 2026-08-13 16:35:23,647] Trial 556 pruned.
# [I 2026-08-13 16:35:23,650] Trial 557 pruned.
# [I 2026-08-13 16:35:23,652] Trial 558 pruned.
# [I 2026-08-13 16:35:23,655] Trial 559 pruned.
# [I 2026-08-13 16:35:23,657] Trial 560 pruned.
# [I 2026-08-13 16:35:23,659] Trial 561 pruned.
# [I 2026-08-13 16:35:23,662] Trial 562 pruned.
# [I 2026-08-13 16:35:23,665] Trial 563 pruned.
# [I 2026-08-13 16:35:24,073] Trial 564 finished with values: [2.9472965412201697, 0.4080930199568486] and parameters: {'m': 4.0, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 2, 'N': 2, 'τ': 19.903642437372973, 'mode': 1, 'act': 0, 'mO': 4}.
# [I 2026-08-13 16:35:24,077] Trial 565 pruned.
# [I 2026-08-13 16:35:24,128] Trial 566 finished with values: [0.9750783612730076, 1.0672965637847458] and parameters: {'m': 2.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 16, 'N': 3, 'τ': 11.647409857192407, 'mode': 1, 'act': 0, 'mO': 8}.
# [I 2026-08-13 16:35:24,131] Trial 567 pruned.
# [I 2026-08-13 16:35:24,134] Trial 568 pruned.
# [I 2026-08-13 16:35:24,136] Trial 569 pruned.
# [I 2026-08-13 16:35:24,139] Trial 570 pruned.
# [I 2026-08-13 16:35:24,141] Trial 571 pruned.
# [I 2026-08-13 16:35:24,143] Trial 572 pruned.
# [I 2026-08-13 16:35:24,145] Trial 573 pruned.
# [I 2026-08-13 16:35:24,148] Trial 574 pruned.
# [I 2026-08-13 16:35:24,150] Trial 575 pruned.
# [I 2026-08-13 16:35:24,425] Trial 576 finished with values: [1.8280762171418383, 2.5287465981507724] and parameters: {'m': 3.75, 'nI': 5, 'n_layers': 1, 'nR_layer_0': 24, 'nO': 19, 'N': 3, 'τ': 4.239884875445199, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:35:24,428] Trial 577 pruned.
# [I 2026-08-13 16:35:24,430] Trial 578 pruned.
# [I 2026-08-13 16:35:24,432] Trial 579 pruned.
# [I 2026-08-13 16:35:24,434] Trial 580 pruned.
# [I 2026-08-13 16:35:24,435] Trial 581 pruned.
# [I 2026-08-13 16:35:24,437] Trial 582 pruned.
# [I 2026-08-13 16:35:24,440] Trial 583 pruned.
# [I 2026-08-13 16:35:24,478] Trial 584 finished with values: [0.9678723024642438, 1.4110456127711368] and parameters: {'m': 4.5, 'nI': 13, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 5, 'N': 5, 'τ': 11.108629184560405, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:35:24,480] Trial 585 pruned.
# [I 2026-08-13 16:35:24,482] Trial 586 pruned.
# [I 2026-08-13 16:35:24,483] Trial 587 pruned.
# [I 2026-08-13 16:35:24,485] Trial 588 pruned.
# [I 2026-08-13 16:35:24,486] Trial 589 pruned.
# [I 2026-08-13 16:35:24,489] Trial 590 pruned.
# [I 2026-08-13 16:35:24,490] Trial 591 pruned.
# [I 2026-08-13 16:35:24,492] Trial 592 pruned.
# [I 2026-08-13 16:35:24,493] Trial 593 pruned.
# [I 2026-08-13 16:35:24,496] Trial 594 pruned.
# [I 2026-08-13 16:35:24,498] Trial 595 pruned.
# [I 2026-08-13 16:35:24,501] Trial 596 pruned.
# [I 2026-08-13 16:35:24,503] Trial 597 pruned.
# [I 2026-08-13 16:35:24,505] Trial 598 pruned.
# [I 2026-08-13 16:35:24,508] Trial 599 pruned.
# [I 2026-08-13 16:35:24,510] Trial 600 pruned.
# [I 2026-08-13 16:35:24,512] Trial 601 pruned.
# [I 2026-08-13 16:35:24,515] Trial 602 pruned.
# [I 2026-08-13 16:35:24,517] Trial 603 pruned.
# [I 2026-08-13 16:35:24,520] Trial 604 pruned.
# [I 2026-08-13 16:35:24,522] Trial 605 pruned.
# [I 2026-08-13 16:35:24,523] Trial 606 pruned.
# [I 2026-08-13 16:35:24,525] Trial 607 pruned.
# [I 2026-08-13 16:35:24,528] Trial 608 pruned.
# [I 2026-08-13 16:35:24,531] Trial 609 pruned.
# [I 2026-08-13 16:35:24,532] Trial 610 pruned.
# [I 2026-08-13 16:35:24,535] Trial 611 pruned.
# [I 2026-08-13 16:35:24,536] Trial 612 pruned.
# [I 2026-08-13 16:35:24,539] Trial 613 pruned.
# [I 2026-08-13 16:35:24,541] Trial 614 pruned.
# [I 2026-08-13 16:35:24,543] Trial 615 pruned.
# [I 2026-08-13 16:35:24,544] Trial 616 pruned.
# [I 2026-08-13 16:35:24,547] Trial 617 pruned.
# [I 2026-08-13 16:35:24,549] Trial 618 pruned.
# [I 2026-08-13 16:35:24,552] Trial 619 pruned.
# [I 2026-08-13 16:35:24,554] Trial 620 pruned.
# [I 2026-08-13 16:35:24,555] Trial 621 pruned.
# [I 2026-08-13 16:35:24,557] Trial 622 pruned.
# [I 2026-08-13 16:35:24,589] Trial 623 finished with values: [0.9758312686977445, 2.203031658850699] and parameters: {'m': 2.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 11, 'nO': 17, 'N': 8, 'τ': 7.204795937050739, 'mode': 1, 'act': 1, 'mO': 3}.
# [I 2026-08-13 16:35:24,591] Trial 624 pruned.
# [I 2026-08-13 16:35:24,593] Trial 625 pruned.
# [I 2026-08-13 16:35:24,595] Trial 626 pruned.
# [I 2026-08-13 16:35:24,598] Trial 627 pruned.
# [I 2026-08-13 16:35:24,601] Trial 628 pruned.
# [I 2026-08-13 16:35:24,603] Trial 629 pruned.
# [I 2026-08-13 16:35:24,606] Trial 630 pruned.
# [I 2026-08-13 16:35:24,609] Trial 631 pruned.
# [I 2026-08-13 16:35:24,611] Trial 632 pruned.
# [I 2026-08-13 16:35:24,613] Trial 633 pruned.
# [I 2026-08-13 16:35:24,616] Trial 634 pruned.
# [I 2026-08-13 16:35:24,618] Trial 635 pruned.
# [I 2026-08-13 16:35:24,620] Trial 636 pruned.
# [I 2026-08-13 16:35:24,622] Trial 637 pruned.
# [I 2026-08-13 16:35:24,625] Trial 638 pruned.
# [I 2026-08-13 16:35:24,627] Trial 639 pruned.
# [I 2026-08-13 16:35:24,630] Trial 640 pruned.
# [I 2026-08-13 16:35:24,658] Trial 641 finished with values: [0.9682726767907497, 1.124322253860503] and parameters: {'m': 4.5, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 9, 'N': 6, 'τ': 10.577154839575163, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:35:24,660] Trial 642 pruned.
# [I 2026-08-13 16:35:24,663] Trial 643 pruned.
# [I 2026-08-13 16:35:24,664] Trial 644 pruned.
# [I 2026-08-13 16:35:24,666] Trial 645 pruned.
# [I 2026-08-13 16:35:24,667] Trial 646 pruned.
# [I 2026-08-13 16:35:24,669] Trial 647 pruned.
# [I 2026-08-13 16:35:24,672] Trial 648 pruned.
# [I 2026-08-13 16:35:24,674] Trial 649 pruned.
# [I 2026-08-13 16:35:24,677] Trial 650 pruned.
# [I 2026-08-13 16:35:24,679] Trial 651 pruned.
# [I 2026-08-13 16:35:24,681] Trial 652 pruned.
# [I 2026-08-13 16:35:24,682] Trial 653 pruned.
# [I 2026-08-13 16:35:24,683] Trial 654 pruned.
# [I 2026-08-13 16:35:24,685] Trial 655 pruned.
# [I 2026-08-13 16:35:24,687] Trial 656 pruned.
# [I 2026-08-13 16:35:24,688] Trial 657 pruned.
# [I 2026-08-13 16:35:24,690] Trial 658 pruned.
# [I 2026-08-13 16:35:24,692] Trial 659 pruned.
# [I 2026-08-13 16:35:24,693] Trial 660 pruned.
# [I 2026-08-13 16:35:24,695] Trial 661 pruned.
# [I 2026-08-13 16:35:24,698] Trial 662 pruned.
# [I 2026-08-13 16:35:24,701] Trial 663 pruned.
# [I 2026-08-13 16:35:24,704] Trial 664 pruned.
# [I 2026-08-13 16:35:24,707] Trial 665 pruned.
# [I 2026-08-13 16:35:24,710] Trial 666 pruned.
# [I 2026-08-13 16:35:24,712] Trial 667 pruned.
# [I 2026-08-13 16:35:24,714] Trial 668 pruned.
# [I 2026-08-13 16:35:24,717] Trial 669 pruned.
# [I 2026-08-13 16:35:24,719] Trial 670 pruned.
# [I 2026-08-13 16:35:24,722] Trial 671 pruned.
# [I 2026-08-13 16:35:24,725] Trial 672 pruned.
# [I 2026-08-13 16:35:24,728] Trial 673 pruned.
# [I 2026-08-13 16:35:24,731] Trial 674 pruned.
# [I 2026-08-13 16:35:24,734] Trial 675 pruned.
# [I 2026-08-13 16:35:24,737] Trial 676 pruned.
# [I 2026-08-13 16:35:24,740] Trial 677 pruned.
# [I 2026-08-13 16:35:24,743] Trial 678 pruned.
# [I 2026-08-13 16:35:24,746] Trial 679 pruned.
# [I 2026-08-13 16:35:24,749] Trial 680 pruned.
# [I 2026-08-13 16:35:24,752] Trial 681 pruned.
# [I 2026-08-13 16:35:24,754] Trial 682 pruned.
# [I 2026-08-13 16:35:24,757] Trial 683 pruned.
# [I 2026-08-13 16:35:24,801] Trial 684 finished with values: [0.9762615415835222, 1.081074647534734] and parameters: {'m': 4.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 32, 'nO': 20, 'N': 7, 'τ': 2.9654599549274154, 'mode': 1, 'act': 0, 'mO': 7}.
# [I 2026-08-13 16:35:24,805] Trial 685 pruned.
# [I 2026-08-13 16:35:24,808] Trial 686 pruned.
# [I 2026-08-13 16:35:24,811] Trial 687 pruned.
# [I 2026-08-13 16:35:24,814] Trial 688 pruned.
# [I 2026-08-13 16:35:24,817] Trial 689 pruned.
# [I 2026-08-13 16:35:24,820] Trial 690 pruned.
# [I 2026-08-13 16:35:24,823] Trial 691 pruned.
# [I 2026-08-13 16:35:24,826] Trial 692 pruned.
# [I 2026-08-13 16:35:24,829] Trial 693 pruned.
# [I 2026-08-13 16:35:24,833] Trial 694 pruned.
# [I 2026-08-13 16:35:24,836] Trial 695 pruned.
# [I 2026-08-13 16:35:24,839] Trial 696 pruned.
# [I 2026-08-13 16:35:24,842] Trial 697 pruned.
# [I 2026-08-13 16:35:24,843] Trial 698 pruned.
# [I 2026-08-13 16:35:24,846] Trial 699 pruned.
# [I 2026-08-13 16:35:24,848] Trial 700 pruned.
# [I 2026-08-13 16:35:24,850] Trial 701 pruned.
# [I 2026-08-13 16:35:24,854] Trial 702 pruned.
# [I 2026-08-13 16:35:24,857] Trial 703 pruned.
# [I 2026-08-13 16:35:24,860] Trial 704 pruned.
# [I 2026-08-13 16:35:24,863] Trial 705 pruned.
# [I 2026-08-13 16:35:25,145] Trial 706 finished with values: [2.214643817771289, 0.3192361877711841] and parameters: {'m': 2.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 11, 'N': 7, 'τ': 12.738671433590172, 'mode': 1, 'act': 0, 'mO': 13}.
# [I 2026-08-13 16:35:25,147] Trial 707 pruned.
# [I 2026-08-13 16:35:25,149] Trial 708 pruned.
# [I 2026-08-13 16:35:25,150] Trial 709 pruned.
# [I 2026-08-13 16:35:25,152] Trial 710 pruned.
# [I 2026-08-13 16:35:25,154] Trial 711 pruned.
# [I 2026-08-13 16:35:25,155] Trial 712 pruned.
# [I 2026-08-13 16:35:25,157] Trial 713 pruned.
# [I 2026-08-13 16:35:25,759] Trial 714 finished with values: [2.1926605279020337, 0.09782548460421275] and parameters: {'m': 2.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 10, 'N': 1, 'τ': 4.662672415395017, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:25,762] Trial 715 pruned.
# [I 2026-08-13 16:35:25,765] Trial 716 pruned.
# [I 2026-08-13 16:35:25,768] Trial 717 pruned.
# [I 2026-08-13 16:35:25,821] Trial 718 finished with values: [0.9737710390699715, 1.0947253048095973] and parameters: {'m': 3.0, 'nI': 3, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 11, 'N': 3, 'τ': 22.737048955998585, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:35:25,824] Trial 719 pruned.
# [I 2026-08-13 16:35:25,828] Trial 720 pruned.
# [I 2026-08-13 16:35:25,831] Trial 721 pruned.
# [I 2026-08-13 16:35:25,834] Trial 722 pruned.
# [I 2026-08-13 16:35:25,837] Trial 723 pruned.
# [I 2026-08-13 16:35:25,840] Trial 724 pruned.
# [I 2026-08-13 16:35:25,842] Trial 725 pruned.
# [I 2026-08-13 16:35:25,845] Trial 726 pruned.
# [I 2026-08-13 16:35:25,848] Trial 727 pruned.
# [I 2026-08-13 16:35:25,850] Trial 728 pruned.
# [I 2026-08-13 16:35:25,853] Trial 729 pruned.
# [I 2026-08-13 16:35:25,856] Trial 730 pruned.
# [I 2026-08-13 16:35:25,860] Trial 731 pruned.
# [I 2026-08-13 16:35:25,863] Trial 732 pruned.
# [I 2026-08-13 16:35:25,866] Trial 733 pruned.
# [I 2026-08-13 16:35:25,869] Trial 734 pruned.
# [I 2026-08-13 16:35:25,871] Trial 735 pruned.
# [I 2026-08-13 16:35:25,873] Trial 736 pruned.
# [I 2026-08-13 16:35:25,876] Trial 737 pruned.
# [I 2026-08-13 16:35:25,879] Trial 738 pruned.
# [I 2026-08-13 16:35:25,882] Trial 739 pruned.
# [I 2026-08-13 16:35:25,885] Trial 740 pruned.
# [I 2026-08-13 16:35:25,889] Trial 741 pruned.
# [I 2026-08-13 16:35:25,892] Trial 742 pruned.
# [I 2026-08-13 16:35:25,895] Trial 743 pruned.
# [I 2026-08-13 16:35:25,898] Trial 744 pruned.
# [I 2026-08-13 16:35:25,900] Trial 745 pruned.
# [I 2026-08-13 16:35:25,904] Trial 746 pruned.
# [I 2026-08-13 16:35:25,908] Trial 747 pruned.
# [I 2026-08-13 16:35:25,911] Trial 748 pruned.
# [I 2026-08-13 16:35:25,913] Trial 749 pruned.
# [I 2026-08-13 16:35:25,916] Trial 750 pruned.
# [I 2026-08-13 16:35:25,918] Trial 751 pruned.
# [I 2026-08-13 16:35:25,920] Trial 752 pruned.
# [I 2026-08-13 16:35:25,923] Trial 753 pruned.
# [I 2026-08-13 16:35:25,926] Trial 754 pruned.
# [I 2026-08-13 16:35:25,982] Trial 755 finished with values: [0.9631347054473749, 1.224180784150733] and parameters: {'m': 3.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 2, 'N': 9, 'τ': 3.1323390497762436, 'mode': 1, 'act': 0, 'mO': 18}.
# [I 2026-08-13 16:35:25,985] Trial 756 pruned.
# [I 2026-08-13 16:35:25,988] Trial 757 pruned.
# [I 2026-08-13 16:35:25,991] Trial 758 pruned.
# [I 2026-08-13 16:35:25,994] Trial 759 pruned.
# [I 2026-08-13 16:35:25,997] Trial 760 pruned.
# [I 2026-08-13 16:35:26,000] Trial 761 pruned.
# [I 2026-08-13 16:35:26,003] Trial 762 pruned.
# [I 2026-08-13 16:35:26,006] Trial 763 pruned.
# [I 2026-08-13 16:35:26,009] Trial 764 pruned.
# [I 2026-08-13 16:35:26,012] Trial 765 pruned.
# [I 2026-08-13 16:35:26,015] Trial 766 pruned.
# [I 2026-08-13 16:35:26,018] Trial 767 pruned.
# [I 2026-08-13 16:35:26,021] Trial 768 pruned.
# [I 2026-08-13 16:35:26,057] Trial 769 finished with values: [0.9728819303587842, 1.6563993335106348] and parameters: {'m': 3.0, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 12, 'N': 6, 'τ': 9.992097868988552, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:26,107] Trial 770 finished with values: [0.9723189308536375, 1.2959103415016693] and parameters: {'m': 2.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 12, 'N': 9, 'τ': 17.1670980638699, 'mode': 1, 'act': 1, 'mO': 14}.
# [I 2026-08-13 16:35:26,156] Trial 771 finished with values: [0.9715308841724565, 1.0919795412517932] and parameters: {'m': 2.0, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 20, 'nO': 10, 'N': 5, 'τ': 13.942496860956853, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:26,335] Trial 772 finished with values: [0.23387259067808783, 0.21278462196259684] and parameters: {'m': 2.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 8, 'N': 5, 'τ': 6.574467074600598, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:26,360] Trial 773 finished with values: [0.970038149357834, 0.9272550951421127] and parameters: {'m': 4.5, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 9, 'N': 6, 'τ': 20.01061462928802, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:35:26,362] Trial 774 pruned.
# [I 2026-08-13 16:35:26,517] Trial 775 finished with values: [1.8420273062950718, 0.49928997993635255] and parameters: {'m': 3.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 17, 'N': 9, 'τ': 17.1670980638699, 'mode': 1, 'act': 0, 'mO': 13}.
# [I 2026-08-13 16:35:26,552] Trial 776 finished with values: [0.9709097558454775, 1.3790177000049273] and parameters: {'m': 3.75, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 39, 'nO': 9, 'N': 3, 'τ': 17.426387218482443, 'mode': 1, 'act': 0, 'mO': 11}.
# [I 2026-08-13 16:35:26,820] Trial 777 finished with values: [2.551278958267002, 0.2791173998146073] and parameters: {'m': 3.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 5, 'N': 5, 'τ': 9.992097868988552, 'mode': 1, 'act': 1, 'mO': 5}.
# ...
# [I 2026-08-13 16:35:34,169] Trial 833 finished with values: [0.5339139041858245, 0.13195068605402382] and parameters: {'m': 4.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 8, 'N': 5, 'τ': 11.741712193026494, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:34,348] Trial 834 finished with values: [0.8052154958592607, 1.39985669654008] and parameters: {'m': 2.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 5, 'N': 2, 'τ': 7.34196238037362, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:35:34,385] Trial 835 finished with values: [0.9695824717625579, 0.7984092695543131] and parameters: {'m': 2.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 8, 'N': 5, 'τ': 6.574467074600598, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:34,429] Trial 836 finished with values: [0.9706966499644257, 0.4924664193161271] and parameters: {'m': 4.5, 'nI': 10, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 8, 'N': 7, 'τ': 18.926017401501817, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:35:34,432] Trial 837 pruned.
# [I 2026-08-13 16:35:34,808] Trial 838 finished with values: [1.4054787193398028, 1.9468652037290635] and parameters: {'m': 3.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 10, 'N': 1, 'τ': 15.637876646448339, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:34,812] Trial 839 pruned.
# [I 2026-08-13 16:35:34,846] Trial 840 finished with values: [0.975385032293031, 0.5817796144492046] and parameters: {'m': 3.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 20, 'N': 5, 'τ': 23.941640302352173, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:35,079] Trial 841 finished with values: [0.7098544671910183, 0.2475038874621425] and parameters: {'m': 4.5, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 5, 'nO': 8, 'N': 5, 'τ': 1.043777712155653, 'mode': 1, 'act': 0, 'mO': 1}.
# [I 2026-08-13 16:35:35,082] Trial 842 pruned.
# [I 2026-08-13 16:35:35,109] Trial 843 finished with values: [0.9620864375343232, 0.9668740715270673] and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 1, 'nO': 1, 'N': 5, 'τ': 21.272291833633858, 'mode': 1, 'act': 0, 'mO': 16}.
# [I 2026-08-13 16:35:35,599] Trial 844 finished with values: [2.3171615473348597, 0.27912428512305754] and parameters: {'m': 4.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 8, 'N': 9, 'τ': 11.741712193026494, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:36,029] Trial 845 finished with values: [2.6047786149423313, 0.32524839048873944] and parameters: {'m': 2.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 5, 'N': 4, 'τ': 9.992097868988552, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:36,033] Trial 846 pruned.
# [I 2026-08-13 16:35:36,379] Trial 847 finished with values: [2.184739360952679, 0.3148187196220481] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 5, 'N': 9, 'τ': 7.34196238037362, 'mode': 1, 'act': 1, 'mO': 10}.
# [I 2026-08-13 16:35:36,769] Trial 848 finished with values: [1.7646093544824353, 0.17525868738494516] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 16, 'N': 5, 'τ': 17.198337834953627, 'mode': 1, 'act': 1, 'mO': 16}.
# [I 2026-08-13 16:35:36,772] Trial 849 pruned.
# [I 2026-08-13 16:35:37,327] Trial 850 finished with values: [2.8513720273301866, 0.4708333921673564] and parameters: {'m': 3.75, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 2, 'N': 2, 'τ': 17.1670980638699, 'mode': 1, 'act': 0, 'mO': 13}.
# [I 2026-08-13 16:35:37,728] Trial 851 finished with values: [2.2941885676578138, 0.19554398285138702] and parameters: {'m': 3.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 62, 'nO': 8, 'N': 8, 'τ': 20.780635289590403, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:35:37,761] Trial 852 finished with values: [0.9735979100661442, 1.6742860590987287] and parameters: {'m': 3.5, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 70, 'nO': 12, 'N': 6, 'τ': 10.016774317659127, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:35:37,763] Trial 853 pruned.
# [I 2026-08-13 16:35:37,796] Trial 854 finished with values: [0.964758693411654, 1.2692155662436722] and parameters: {'m': 2.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 2, 'N': 7, 'τ': 7.34196238037362, 'mode': 1, 'act': 1, 'mO': 13}.
# [I 2026-08-13 16:35:37,833] Trial 855 finished with values: [0.964758693411654, 0.9659704019164418] and parameters: {'m': 3.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 70, 'nO': 2, 'N': 8, 'τ': 16.246272944306234, 'mode': 1, 'act': 1, 'mO': 4}.
# [I 2026-08-13 16:35:38,041] Trial 856 finished with values: [0.2361138528362936, 0.21419399120028756] and parameters: {'m': 2.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 8, 'N': 6, 'τ': 6.574467074600598, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:38,045] Trial 857 pruned.
# [I 2026-08-13 16:35:38,092] Trial 858 finished with values: [0.9755356040093107, 1.0476637274460776] and parameters: {'m': 2.75, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 6, 'nO': 19, 'N': 8, 'τ': 4.612724350303668, 'mode': 1, 'act': 1, 'mO': 5}.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_QN_R2.py:268: RuntimeWarning: overflow encountered in matmul
#   yP = (self.wO @ self.hP2[-1])
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_QN_R2.py:268: RuntimeWarning: invalid value encountered in matmul
#   yP = (self.wO @ self.hP2[-1])
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_QN_R2.py:263: RuntimeWarning: overflow encountered in matmul
#   uP = (self.wR[l] @ hP) + (self.wI[l] @ curr_in)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\DRTLO_QN_R2.py:263: RuntimeWarning: invalid value encountered in matmul
#   uP = (self.wR[l] @ hP) + (self.wI[l] @ curr_in)
# [I 2026-08-13 16:35:38,349] Trial 859 pruned.
# [I 2026-08-13 16:35:38,351] Trial 860 pruned.
# [I 2026-08-13 16:35:38,782] Trial 861 finished with values: [2.835259530852025, 0.27920151459828885] and parameters: {'m': 4.0, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 2, 'N': 2, 'τ': 16.331159562251706, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:39,278] Trial 862 finished with values: [2.2941885676578138, 1.1297410363958287] and parameters: {'m': 2.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 66, 'nO': 8, 'N': 9, 'τ': 20.557923708756388, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:39,281] Trial 863 pruned.
# [I 2026-08-13 16:35:39,284] Trial 864 pruned.
# [I 2026-08-13 16:35:39,468] Trial 865 finished with values: [1.8024572518734812, 0.47628611894723033] and parameters: {'m': 2.75, 'nI': 7, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 20, 'N': 6, 'τ': 9.992097868988552, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:35:39,633] Trial 866 finished with values: [1.033464492029316, 527.4631147598367] and parameters: {'m': 2.75, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 19, 'N': 1, 'τ': 13.469507215442992, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:35:39,636] Trial 867 pruned.
# [I 2026-08-13 16:35:39,722] Trial 868 finished with values: [1.414897529072641, 0.5299791373346282] and parameters: {'m': 4.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 12, 'N': 6, 'τ': 4.612724350303668, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:39,786] Trial 869 finished with values: [0.895738352061169, 0.4579355433347961] and parameters: {'m': 3.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 66, 'nO': 20, 'N': 4, 'τ': 10.016774317659127, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:40,326] Trial 870 finished with values: [1.9623547528029937, 0.20022392481661966] and parameters: {'m': 3.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 30, 'nO': 13, 'N': 2, 'τ': 23.11041443831531, 'mode': 1, 'act': 0, 'mO': 17}.
# [I 2026-08-13 16:35:40,416] Trial 871 finished with values: [0.5427447073839342, 0.353452271121747] and parameters: {'m': 2.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 13, 'nO': 1, 'N': 7, 'τ': 8.481063112179209, 'mode': 1, 'act': 1, 'mO': 17}.
# [I 2026-08-13 16:35:40,419] Trial 872 pruned.
# [I 2026-08-13 16:35:40,449] Trial 873 finished with values: [0.9587271982372446, 0.4888281302702897] and parameters: {'m': 3.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 12, 'nO': 8, 'N': 7, 'τ': 8.481063112179209, 'mode': 1, 'act': 1, 'mO': 1}.
# [I 2026-08-13 16:35:40,859] Trial 874 finished with values: [1.6146306385804814, 0.5828223579839451] and parameters: {'m': 3.0, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 66, 'nO': 20, 'N': 5, 'τ': 17.1670980638699, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:41,439] Trial 875 finished with values: [1.7666739565925413, 0.37560964651446216] and parameters: {'m': 2.75, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 66, 'nO': 17, 'N': 4, 'τ': 23.941640302352173, 'mode': 1, 'act': 0, 'mO': 13}.
# [I 2026-08-13 16:35:41,442] Trial 876 pruned.
# [I 2026-08-13 16:35:41,477] Trial 877 finished with values: [0.965066474503263, 1.2417315984107675] and parameters: {'m': 2.25, 'nI': 11, 'n_layers': 1, 'nR_layer_0': 41, 'nO': 1, 'N': 8, 'τ': 21.633953505653597, 'mode': 1, 'act': 1, 'mO': 2}.
# [I 2026-08-13 16:35:41,480] Trial 878 pruned.
# [I 2026-08-13 16:35:41,994] Trial 879 finished with values: [2.846196890380332, 0.2519980780819265] and parameters: {'m': 3.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 2, 'N': 6, 'τ': 16.084904078151382, 'mode': 1, 'act': 1, 'mO': 8}.
# [I 2026-08-13 16:35:41,997] Trial 880 pruned.
# [I 2026-08-13 16:35:41,999] Trial 881 pruned.
# [I 2026-08-13 16:35:42,001] Trial 882 pruned.
# [I 2026-08-13 16:35:42,005] Trial 883 pruned.
# [I 2026-08-13 16:35:42,054] Trial 884 finished with values: [0.9686373206264017, 0.7392198656891648] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 70, 'nO': 20, 'N': 8, 'τ': 10.652445415469085, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:35:42,058] Trial 885 pruned.
# [I 2026-08-13 16:35:42,061] Trial 886 pruned.
# [I 2026-08-13 16:35:42,421] Trial 887 finished with values: [1.465033246836806, 0.2083782397428228] and parameters: {'m': 2.25, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 57, 'nO': 2, 'N': 7, 'τ': 16.084904078151382, 'mode': 1, 'act': 1, 'mO': 8}.
# [I 2026-08-13 16:35:42,459] Trial 888 finished with values: [0.9702609249359534, 1.2655976148544028] and parameters: {'m': 2.5, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 7, 'N': 8, 'τ': 16.246272944306234, 'mode': 1, 'act': 1, 'mO': 0}.
# [I 2026-08-13 16:35:43,009] Trial 889 finished with values: [2.552225011906248, 0.21757756235260756] and parameters: {'m': 2.25, 'nI': 17, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 5, 'N': 5, 'τ': 9.992097868988552, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:43,135] Trial 890 finished with values: [0.5517778482757186, 0.29373853736662764] and parameters: {'m': 3.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 11, 'N': 7, 'τ': 12.738671433590172, 'mode': 1, 'act': 1, 'mO': 13}.
# [I 2026-08-13 16:35:43,526] Trial 891 finished with values: [1.1969991314415163, 0.0863182603059698] and parameters: {'m': 2.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 15, 'nO': 5, 'N': 8, 'τ': 1.7607216007742394, 'mode': 1, 'act': 0, 'mO': 2}.
# [I 2026-08-13 16:35:44,153] Trial 892 finished with values: [2.86293472106944, 0.38990110933210625] and parameters: {'m': 2.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 42, 'nO': 2, 'N': 2, 'τ': 7.34196238037362, 'mode': 1, 'act': 0, 'mO': 10}.
# [I 2026-08-13 16:35:44,180] Trial 893 finished with values: [0.9732447022929724, 0.8439389457958794] and parameters: {'m': 3.25, 'nI': 12, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 13, 'N': 7, 'τ': 4.612724350303668, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:44,210] Trial 894 finished with values: [0.9704803972515734, 1.497177463947723] and parameters: {'m': 2.75, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 8, 'nO': 7, 'N': 8, 'τ': 16.246272944306234, 'mode': 1, 'act': 1, 'mO': 6}.
# [I 2026-08-13 16:35:44,239] Trial 895 finished with values: [0.9686282197509742, 0.9837260321866957] and parameters: {'m': 2.75, 'nI': 16, 'n_layers': 1, 'nR_layer_0': 36, 'nO': 7, 'N': 8, 'τ': 16.246272944306234, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:44,273] Trial 896 finished with values: [0.9753850870344822, 1.7379307740143204] and parameters: {'m': 2.25, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 13, 'nO': 16, 'N': 5, 'τ': 8.481063112179209, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:44,684] Trial 897 finished with values: [1.2847052127397225, 0.19515380425643158] and parameters: {'m': 2.75, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 68, 'nO': 7, 'N': 4, 'τ': 23.941640302352173, 'mode': 1, 'act': 0, 'mO': 6}.
# [I 2026-08-13 16:35:44,746] Trial 898 finished with values: [0.8956809573840081, 0.5073731897983301] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 70, 'nO': 19, 'N': 8, 'τ': 21.633953505653597, 'mode': 1, 'act': 1, 'mO': 7}.
# [I 2026-08-13 16:35:44,777] Trial 899 finished with values: [0.9734224833318882, 0.8243508013102343] and parameters: {'m': 2.75, 'nI': 8, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 12, 'N': 4, 'τ': 13.469507215442992, 'mode': 1, 'act': 0, 'mO': 3}.
# [I 2026-08-13 16:35:44,781] Trial 900 pruned.
# [I 2026-08-13 16:35:44,829] Trial 901 finished with values: [0.962791790694031, 1.4346624825423535] and parameters: {'m': 3.5, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 67, 'nO': 1, 'N': 7, 'τ': 12.21674388287897, 'mode': 1, 'act': 1, 'mO': 18}.
# [I 2026-08-13 16:35:44,869] Trial 902 finished with values: [0.9644454349602556, 0.5397797808456255] and parameters: {'m': 2.75, 'nI': 19, 'n_layers': 1, 'nR_layer_0': 69, 'nO': 3, 'N': 5, 'τ': 16.246272944306234, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:45,024] Trial 903 finished with values: [0.2361138528362936, 0.21419399120028756] and parameters: {'m': 2.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 8, 'N': 6, 'τ': 6.574467074600598, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:45,028] Trial 904 pruned.
# [I 2026-08-13 16:35:45,353] Trial 905 finished with values: [1.8306476583690374, 0.23588863616126662] and parameters: {'m': 3.5, 'nI': 14, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 17, 'N': 9, 'τ': 17.1670980638699, 'mode': 1, 'act': 1, 'mO': 13}.
# [I 2026-08-13 16:35:45,829] Trial 906 finished with values: [2.9482445596540567, 0.1261219372557767] and parameters: {'m': 3.75, 'nI': 18, 'n_layers': 1, 'nR_layer_0': 43, 'nO': 1, 'N': 7, 'τ': 12.997046736411548, 'mode': 1, 'act': 1, 'mO': 17}.
# [I 2026-08-13 16:35:46,280] Trial 907 finished with values: [2.292987667869713, 0.6357413475571031] and parameters: {'m': 2.75, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 66, 'nO': 8, 'N': 4, 'τ': 16.96092283193108, 'mode': 1, 'act': 0, 'mO': 0}.
# [I 2026-08-13 16:35:46,469] Trial 908 finished with values: [0.2361138528362936, 0.21419399120028756] and parameters: {'m': 2.75, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 55, 'nO': 8, 'N': 6, 'τ': 6.574467074600598, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:46,472] Trial 909 pruned.
# [I 2026-08-13 16:35:46,473] Trial 910 pruned.
# [I 2026-08-13 16:35:46,949] Trial 911 finished with values: [1.7646093544824353, 0.17567029316680594] and parameters: {'m': 2.25, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 33, 'nO': 16, 'N': 7, 'τ': 17.198337834953627, 'mode': 1, 'act': 1, 'mO': 16}.
# [I 2026-08-13 16:35:46,980] Trial 912 finished with values: [0.9721260328453389, 1.2441843524272354] and parameters: {'m': 2.0, 'nI': 15, 'n_layers': 1, 'nR_layer_0': 38, 'nO': 12, 'N': 6, 'τ': 5.8747506713122375, 'mode': 1, 'act': 1, 'mO': 14}.
# [I 2026-08-13 16:35:46,982] Trial 913 pruned.
# [I 2026-08-13 16:35:47,170] Trial 914 finished with values: [0.8672795672485862, 26.182169055264428] and parameters: {'m': 2.75, 'nI': 9, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 8, 'N': 2, 'τ': 23.941640302352173, 'mode': 1, 'act': 1, 'mO': 5}.
# [I 2026-08-13 16:35:47,173] Trial 915 pruned.
# [I 2026-08-13 16:35:47,248] Trial 916 finished with values: [0.6481467073905691, 0.368239557517909] and parameters: {'m': 2.5, 'nI': 20, 'n_layers': 1, 'nR_layer_0': 45, 'nO': 8, 'N': 5, 'τ': 21.272291833633858, 'mode': 1, 'act': 1, 'mO': 7}.

# %%
df = dfs[1]
#df = df[(df.iloc[:,0] <= 0.07)]
params_list = df.values[:,-9:]
df
# Out:
#    MAPE_RUL   MAPE_HI     m  nI                   nR  nO  mO  N        TAU  \
# 0  1.207268  0.236227  4.25  19         [42, 60, 49]   6   9  8  10.676956
# 1  2.183819  0.126204  2.75  13  [6, 65, 34, 24, 46]  10   5  1   1.235820
# 2  0.962792  0.656823  2.50  18                 [52]   1   0  7  17.657242
# 3  2.111962  0.192931  2.50   7     [37, 70, 56, 36]  12   6  1   1.977056
# 4  2.218315  0.103551  4.50  19         [29, 41, 65]   9   9  2   2.460463
# 5  0.681176  1.385156  2.25  11         [26, 11, 19]  12   0  1  10.730664
#
#    past/ahead  activation
# 0           1           1
# 1           1           1
# 2           1           1
# 3           1           0
# 4           1           0
# 5           1           0

# %%
tedas = []
for i,params in enumerate(params_list):
    m,nI,nR,nO,mO,N1,τ,mode,act = params
    X, Y, Z = PrepareData(RS, HI, nI, nO, mO, 1, mode)
    if isinstance(nR, str): nR = ast.literal_eval(nR)

    teda=AutoCloud(m=m,nI=len(Y[0]),nR=nR,nO=nO+mO,ηS=[N1],mode=mode,act=act,
                tau=τ,rho=0.03,eol=0.3,ref=len(sig)-nI+1,wtaG=True,wtaP=True) 
    for j,_ in enumerate(X[:]):
        teda.run(X[j])
        teda.RUL_Prediction(Y[j],mode='single',lim=len(sig)-nI+1,show=False)
        teda.Adapt(Y[j],Z[j])

    teda.c = np.append(teda.c,teda.gm)  
    tedas.append(teda)
    #PlotSeriesPLY(ySeries=[teda.wape_HI_hist,teda.wape_RUL_hist])

# %%
PlotDSI_3D_PLT(tedas[0])
