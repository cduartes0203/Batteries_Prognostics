# %%
import math
import pandas as pd
import numpy as np
import matplotlib.cm as cm
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from Testing.RTLO_R2 import *
from Functions.Utils import *
from Functions.Utils_RTLO import *
from Functions.Graphs import *
from Functions.TedaGraphs import *
import optuna
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_pareto_front
from optuna.importance import get_param_importances
from optuna.samplers import RandomSampler
from optuna.exceptions import TrialPruned

from sklearn.metrics import root_mean_squared_error as RMSE
from sklearn.metrics import mean_absolute_percentage_error as MAPE

df = pd.read_excel(r'Dataset\soh.xlsx')
sig = df['soh'].values


df2 = pd.read_csv(r'Dataset\replay.csv')
df2 = df2.ffill().bfill()
#df2=normalize_df(df2)

RS = pd.read_excel(r'Dataset\RS.xlsx')
#RS = exponential_moving_average_df(RS,0.25)
HI = pd.read_csv(r'Dataset\Bearing1_1.csv')
sig = HI['PC1'].values

def SelSampler(mode='auto'):
    '''mode: auto, random,  tpe'''
    if mode == 'auto':
        sampler = None
    elif mode == 'tpe':
        sampler = optuna.samplers.TPESampler(multivariate=True, constant_linker=True,group=True,n_startup_trials=2000)
    elif mode == 'random':
        sampler=RandomSampler()
    return sampler

def PrepareHI_past(HI, n, m):
    sig = HI.iloc[:,0].values
    X, Y = [], []
    V = []
    s = (m if m>n else n) +1
    for i in range(len(sig) - s - 1):
        V.append(sig[i : i + s])
    for v in V:
        X.append(v[:n])
        Y.append(v[-m:])

    df=pd.DataFrame(V)
    df = df.reset_index()
    df.columns =  ['time' if i==0 else f'{i}' for i in range(len(df.columns))]
    df['time'] = df['time'] + s-2
    return np.array(X),np.array(Y),df

def PrepareRS_past(df,i):
    df = df.reset_index()
    return df.iloc[i:,1:].values


def PrepareDataPast2(RS,HI,n,m):
    x,y,v = PrepareHI_past(HI,n,m)
    i = v.iloc[0,0]
    df = PrepareRS_past(RS,i)
    size = (len(x) if len(x)<len(df) else len(df))
    return df[:size], x[:size], y[:size]

def PrepareHI_ahead(HI, n, m):
    sig = HI.iloc[:,0].values
    X, Y = [], []
    V = []
    s = n+m
    for i in range(len(sig) - s - 1):
        V.append(sig[i : i + s])
    for v in V:
        X.append(v[:n])
        Y.append(v[-m:])

    df=pd.DataFrame(V)
    df = df.reset_index()
    df.columns =  ['time' if i==0 else f'{i}' for i in range(len(df.columns))]
    df['time'] = df['time'] + n - 1
    return np.array(X),np.array(Y),df

def PrepareRS_ahead(df,i):
    df = df.reset_index()
    return df.iloc[i:,1:].values


def PrepareDataAhead2(RS,HI,n,m):
    x,y,v = PrepareHI_ahead(HI,n,m)
    i = v.iloc[0,0]
    df = PrepareRS_ahead(RS,i)
    size = (len(x) if len(x)<len(df) else len(df))
    return df[:size], x[:size], y[:size]

# %%
def euclidian_dist(x1,x2):
    return np.linalg.norm(x1 - x2,ord=None)

class DataCloud:
	N=0
	def __init__(self,x,h,ID,rho,m,nI=1,nR=1,nO=1,ηS=[1,1,1],tau=1,mode='past',act = 'tanh'):
		self.ID = ID
		self.track = [ID]
		self.merged = False
		self.merge = None
		self.n = 1
		self.dim = len(x)
		self.rho = rho
		self.m = m
		self.mean=x
		self.center=x
		self.meant=np.array(x).dot(np.array(x))
		self.ecc = np.array([])
		self.variance=0
		self.pertinency=1
		self.tipicality=1e-12
		self.nI = nI
		self.nR = nR
		self.nO = nO
		self.N1 = ηS[0]
		self.N2 = ηS[1]
		self.N3 = ηS[2]
		self.mode = mode
		self.tau = tau
		self.act = act
		self.rnn = RTLO(self.nI, self.nR, self.nO,
					[self.N1, self.N2, self.N3], self.tau, self.mode, self.act)
		self.x = [x]
		self.rul = np.array([])
		self.rulM = []
		self.rulU = []
		self.rulL = []
		self.t = []
		self.t2 = []
		self.h = [h]
		self.vU = 0
		self.vM = 0
		self.V_ = np.array([])
		self.R_ = np.array([])
		self.R = 0
		self.V = 0
		self.Rmax = 0
		self.Recc = 0
		self.Vecc = 0
		self.Rref = 1
		self.Vref  = (math.pi ** (self.dim / 2)) / math.gamma((self.dim / 2) + 1) * (self.Rref ** self.dim)
		self.Vmax = 0
		self.Vnorm = 0
		self.Cnorm = 0
		self.xMax = x
		self.xMin = x
		self.xRef = x
		self.xIni = x
		self.sp = 0
		self.sp_sum = 0
		self.cov = 1
		self.v = 0
	
	def PrintParams(self):
		if self.ID != 'GM':
			print( f'Granule: G{self.ID} | Radius: {self.R:2.5f} | Volume {self.V:2.5f} | Coverage {self.cov:2.5f} | Specificity {self.sp:2.5f}')
		else:
			print( f'Granule: {self.ID} | Radius: {self.R:2.5f} | Volume {self.V:2.5f} | Coverage {self.cov:2.5f} | Specificity {self.sp:2.5f}')
		
		
	def addDataClaud(self,x,t,store=False):
		self.n=2
		self.mean=(self.mean+x)/2
		self.meant=((self.meant)/2) + (x.dot(x))/2
		self.variance=self.meant-self.mean.dot(self.mean)
		if store:
			self.t.append(t)
			self.x.append(x)

	def updateDataCloud(self,n,mean,meant,variance,tipicality,t,x,store=False):
		self.n=n
		self.mean=mean
		self.meant=meant
		self.variance=variance
		self.tipicality=tipicality
		self.Recc = np.sqrt(self.variance * self.m**2)
		self.Vecc = (math.pi ** (self.dim / 2)) / math.gamma((self.dim / 2) + 1) * (self.Recc ** self.dim)

		if store:
			self.t.append(t)
			self.x.append(x)
	
	def AdjustBounds2(self, x, k, density=False):
			dim = self.dim
			rho = (1+self.rho)
			self.xMin = np.minimum(self.xMin, x)
			self.xMax = np.maximum(self.xMax, x)
			R1 = np.linalg.norm(self.xMin-self.mean)
			R2 = np.linalg.norm(self.xMax-self.mean)
			self.R = max([R1/1,R1*1,R2/1,R2*1])
			self.V = (math.pi ** (dim / 2)) / math.gamma((dim / 2) + 1) * (self.R ** dim)

	def AdjustBounds(self, x, k, density=False):
			dim = self.dim
			R = np.sqrt(self.variance*(self.m**2))
			self.R = R
			self.R_ = np.append(self.R_,R)
			self.V = (math.pi ** (dim / 2)) / math.gamma((dim / 2) + 1) * (self.R ** dim)

# %%
class AutoCloud:
	def __init__(self,m,nI=1,nR=1,nO=1,ηS=[0.1,0.1,0.1],
			  tau=1,eol=0,ref=0,mode='past',act='tanh',st=0,end=0,
			  rho=0.003,wtaG=True,wtaP=True,store=True):
		
		self.rho = rho
		self.vSum = 0
		self.st = st
		self.mode = mode
		self.act = act
		self.end = end
		self.nI = nI
		self.nR = nR
		self.nO = nO
		self.N1 = ηS[0]
		self.N2 = ηS[1]
		self.N3 = ηS[2]
		self.tau = tau
		self.eol = eol
		self.store = store
		self.y = None
		self.g = 1
		self.gCreated = 0
		self.c= np.array([])
		self.alfa= np.array([0.0],dtype=float)
		self.intersection = np.zeros((1,1),dtype=int)
		self.listIntersection = np.zeros((1),dtype=int)
		self.matrixIntersection = np.zeros((1,1),dtype=int)
		self.relevanceList = np.zeros((1),dtype=int)
		self.classIndex = []
		self.k=1
		self.m = m
		self.cloud_activation = []
		self.aux = np.array([])
		self.DSIs = [np.array([]) for i in range(nI)]
		self.OffineGrnls = None

		self.eolX = 0
		self.HI = np.array([])
		self.DSI = np.array([])
		self.eolDSI = 0
		self.HIp = np.array([])
		self.cycleP=np.array([])

		self.t = np.array([])
		self.rulL = np.array([])
		self.rulP = np.array([])
		self.rulP2 = np.array([])
		self.rulU = np.array([])
		self.rulR = np.array([])
		self.ref = ref
		self.rulR2 = np.array([])
		self.rulR_Train = np.array([])
		self.lim = 160
		self.yP = np.array([])
		self.yR = np.array([])

		self.hiR = np.array([])
		self.hiP = np.array([])
		self.hiL = np.array([])
		self.hiU = np.array([])

		self.εP = []
		self.εR = []
		self.wtaG = wtaG
		self.wtaP = wtaP
		self.xR = 0
		self.xF = 0
		self.Dmax = 0

		self.sp = 0
		self.cov = 0
		self.V = 0

		self.dim = None
		self.gm = None
		self.Cnorm_gm = 1
		self.Vnorm_gm = 0
		self.mean_gm = 0
		self.meant_gm = 0
		self.var_gm = 0
		self.xMax_gm = None
		self.Rmax_gm = 0
		self.Vmax_gm = 0

	def HI_Granularity(self):
		
		for pR,pL,pU in zip(self.hiR,self.hiL,self.hiU):
			rL, rU = pR*0.75, pR*1.25
			wPred = pU-pL
			wReal = rU-rL
			sp = max(0,1-wPred/wReal)
			self.sp += sp
			if rL < pL and pU<rU:
				self.cov += 1
			#print(sp,self.cov)

		self.sp = self.sp/len(self.hiL)
		self.cov = self.cov/len(self.hiL)
		self.V = self.sp*self.cov
	
	def RUL_Granularity(self):
		
		for rulR,rulL, rulU in zip(self.rulR,self.rulL,self.rulU):
			rulRL, rulRU = 0.75*rulR, 1.25*rulR
			wPred = rulU-rulL
			wReal = rulRU-rulRL
			sp = max(0,1-wPred/wReal)
			self.sp += sp
			if rulRL < rulL and rulU<rulRU:
				self.cov += 1
			#print(sp,self.cov)

		self.sp = self.sp/len(self.rulR)
		self.cov = self.cov/len(self.rulR)
		self.V = self.sp*self.cov

	def AdjustCloudMaster2(self,t,x):
			gm = self.gm
			n = gm.n + 1
			m = ((n-1)/n)*gm.mean + (1/n)*x
			mT = ((n-1)/n) * gm.meant + (x.dot(x))/n
			v = mT-m.dot(m)

			mean_GM = m
			Rmax = 0.0
			clouds = teda.c

			for cloud in clouds:
				mean_G = cloud.mean
				R = cloud.R

				dist_to_center = np.sqrt(np.sum((mean_G-mean_GM)**2))
				dist_to_edge = dist_to_center + R
				if dist_to_edge > Rmax:
					Rmax = dist_to_edge

			radius = Rmax

			#radius = np.sqrt(gm.variance*(gm.m**2))
			
			if self.store:
							self.gm.t.append(t)
							if self.k > 1:
								self.gm.x.append(x)

			dim = self.gm.dim
			self.gm.R = radius
			self.gm.Rmax = radius
			self.gm.V = (math.pi ** (dim / 2)) / math.gamma((dim / 2) + 1) * (radius ** dim)
			gm.n, gm.mean, gm.meant, gm.variance = n,m,mT,v
			

	def AdjustCloudMaster(self,t,x):
			"""
			Calculates a single bounding sphere that contains all input spheres.
			"""
			clouds = self.c
			# 1. Extract 6 extreme points from each sphere surface along main axes
			points = []
			axes = np.eye(len(self.c[0].mean))
			for cloud in clouds:
				for axis in axes:
					points.append(cloud.mean + axis * cloud.R)
					points.append(cloud.mean - axis * cloud.R)
			points = np.array(points)
	
			# 2. Ritter's Algorithm: Find initial sphere from most distant points
			# Pick arbitrary point p0, find furthest point p1, then furthest p2 from p1
			p1 = points[np.argmax(np.linalg.norm(points - points[0], axis=1))]
			p2 = points[np.argmax(np.linalg.norm(points - p1, axis=1))]
	
			# Initial candidate sphere spanning p1 and p2
			center = (p1 + p2) / 2.0
			radius = np.linalg.norm(p1 - p2) / 2.0
	
			# 3. Expand sphere to cover any outlying points
			for p in points:
				dist = np.linalg.norm(p - center)
				if dist > radius:
					# Shift center and grow radius to contain point 'p'
					new_radius = (radius + dist) / 2.0
					center = center + (p - center) * (new_radius - radius) / dist
					radius = new_radius
	
			# 4. Final verification pass against original full sphere geometries
			for cloud in clouds:
				dist = np.linalg.norm(cloud.mean - center)
				if dist + cloud.R > radius:
					# Adjust to encompass the entire sphere 's'
					diff = dist + cloud.R - radius
					direction = (center - cloud.mean) / dist if dist > 0 else np.array([1, 0, 0])
					center = center - direction * (diff / 2.0)
					radius += diff / 2.0
		
			
			dim = self.gm.dim
			self.gm.mean = center
			self.gm.R = radius
			self.gm.Rmax = radius
			self.gm.V = (math.pi ** (dim / 2)) / math.gamma((dim / 2) + 1) * (radius ** dim)
			self.gm.n = self.k
			if self.store:
				self.gm.t.append(t)
				if self.k > 1:
					self.gm.x.append(x)
					
	def CalculateSpCov(self):
		vec = []
		for cloud in self.c:
			cloud.cov = cloud.n/self.gm.n
			cloud.sp_sum += max(0,1-cloud.V/self.gm.V)
			cloud.sp = cloud.sp_sum/self.gm.n
			vec.append(cloud.sp)
		#print(vec)
	
	def CreateCloud(self,x,t,store=False):
		self.gCreated = self.gCreated + 1
		cloud = DataCloud(x,(self.k-1),self.gCreated,self.rho,self.m,self.nI,self.nR,self.nO,
					[self.N1,self.N2,self.N3],self.tau,self.mode, self.act)
		if store:
			cloud.t.append(self.k)
		self.c = np.append(self.c,cloud)

	def CloudOtimization(self):
		vec = np.array([])
		for cloud in self.c:
			cloud.sp = cloud.sp/(self.k-1)
			cloud.cov = cloud.cov/(self.k-1)
			cloud.v = cloud.sp * cloud.cov
			vec = np.append(vec, cloud.v)
		self.vSum = np.sum(vec)

	def Adapt(self,y,z):
		n = self.c[0].rnn.n
		self.HI = np.append(self.HI,z[n])
		self.hiR = np.append(self.hiR,z[n])
		for i,cloud in enumerate(self.c):
			if self.alfa[i] > 0:
				cloud.rnn.fit(y,z)
	
	def predict(self,y,show=False):
		ws = self.alfa/np.sum(self.alfa)
		p = (np.array([w*cloud.rnn.Predict(y) for cloud,w in zip(self.c,ws)]))
		p = np.sum(p)
		return p
	
	def DefRnnParams(self, cloud):
		if len(self.c)>1:
			params = self.c[-2].rnn.ReturnParameters()
		if len(self.c)==1:
			params = self.c[-1].rnn.ReturnParameters()
		cloud.rnn.ReceiveParameters(params)

	def MergeCloudsRNN(self, c1, c2, c3):
		ps1 = c1.rnn.ReturnParameters()
		ps2 = c2.rnn.ReturnParameters()
		params = [(ps1[i]+ps2[i])/2 for i in range(len(ps2))]
		c3.rnn.ReceiveParameters(params)
		
	def RULSingle(self,X,show=False):
		rulP = 0
		cont = 0
		lim =160
		xP = X.copy()
		if show:
				for c in self.c:
					print('PS',c.rnn.hP[:3],c.rnn.hP2[:3])
		while xP[-1]>self.eol:
			pP = self.predict(xP,show)
			if show: print(rulP,pP)
			if cont ==0:
				self.HIp = np.append(self.HIp,pP)
				#print(self.HIp, pP)
				cont = False
			

			xP = np.delete(np.append(xP,pP),0)
			if rulP == lim: 
				rulP = 1
				break
			rulP=rulP+1
		self.rulR = np.append(self.rulR,self.ref - self.k)
		self.rulP = np.append(self.rulP,rulP)
		self.rulL = np.append(self.rulL,0)
		self.rulU = np.append(self.rulU,0)

		for i,cloud in enumerate(self.c):
			if self.alfa[i] > 0:
				cloud.rul = np.append(cloud.rul,rulP)
		for cloud in self.c:
			cloud.rnn.Restore()
		return
	
	def PredictTS(self,X):
		xP = X.copy()
		
		pP = self.predict(xP)
		self.HIp = np.append(self.HIp,pP)

		self.rulR = np.append(self.rulR,0)
		self.rulP = np.append(self.rulP,0)
		self.rulL = np.append(self.rulL,0)
		self.rulU = np.append(self.rulU,0)

		for cloud in self.c:
			cloud.rnn.Restore()
		return
	
	def RULInterv(self,X,lim=None,show=False):
		if lim==None:
			lim = 160
		xP,xL,xU = X.copy(),X.copy(),X.copy()
		predict = True
		Ruls = [0 for i in range(3)]
		CheckRuls = [True for i in range(3)]
		PredVals = np.zeros(3)
		cont = True

		while predict:
			if self.wtaG==False and self.wtaP==True:
				self.alfa = np.where(self.alfa<np.max(self.alfa),0,self.alfa)
			ws = self.alfa/np.sum(self.alfa)

			Pred = [w*c.rnn.PredictIntr(xP,xL,xU,self.rho,False) for w,c in zip(ws,self.c)]

			PredVals = sum(Pred)
			yL,yP,yU = PredVals

			if cont:
				self.hiP = np.append(self.hiP,yP)
				self.hiL = np.append(self.hiL,yL)
				self.hiU = np.append(self.hiU,yU)
				cont = False

			xP = np.delete(np.append(xP,yP),0)
			xL = np.delete(np.append(xL,yL),0)
			xU = np.delete(np.append(xU,yU),0)

			for j,_ in enumerate(Ruls):
				if CheckRuls[j]:
					Ruls[j] = Ruls[j] + 1

				if Ruls[j] > lim:
					CheckRuls[j] = False
					Ruls[j] = lim

			for j,_ in enumerate(CheckRuls):
				if PredVals[j] <= self.eol:
					CheckRuls[j] = False
			
			if sum(CheckRuls)==0:
				break
					
		for cloud in self.c:
			cloud.rnn.Restore()

		if Ruls[2] < Ruls[1]:
			Ruls[2] = Ruls[1] 
		self.t = np.append(self.t,self.k - 2)
		self.rulR = np.append(self.rulR,self.ref - self.k)
		self.rulP = np.append(self.rulP,Ruls[1])
		self.rulL = np.append(self.rulL,Ruls[0])
		self.rulU = np.append(self.rulU,Ruls[2])

		for i,cloud in enumerate(self.c):
			if self.alfa[i] > 0:
				cloud.t2.append(self.k-2)
				cloud.rul = np.append(cloud.rul,Ruls[1])
				cloud.rulL.append(Ruls[0])
				cloud.rulM.append(Ruls[1])
				cloud.rulU.append(Ruls[2])

	def AddRUL(self):
		for cloud in self.cloud_activation:
			cloud.rul = np.append(cloud.rul,self.rulP[-1])
		self.cloud_activation = []
	
	def mergeClouds(self,X):
		i=0
		while(i<len(self.listIntersection)-1):
			merge=False
			j=i+1
			while(j<len(self.listIntersection)):
				if(self.listIntersection[i] == 1 and self.listIntersection[j] == 1):
					self.matrixIntersection[i,j] = self.matrixIntersection[i,j] + 1
				idI = self.c[i].ID
				idJ = self.c[j].ID
				xMinI = self.c[i].xMin
				xMinJ = self.c[j].xMin
				xMaxI = self.c[i].xMax
				xMaxJ = self.c[j].xMax
				meanI = self.c[i].mean
				meanJ = self.c[j].mean
				meantI = self.c[i].meant
				meantJ = self.c[j].meant
				nI = self.c[i].n
				nJ = self.c[j].n
				tipicalityI = self.c[i].tipicality
				tipicalityJ = self.c[j].tipicality
				trackI = self.c[i].track
				trackJ = self.c[j].track
				varianceI = self.c[i].variance
				varianceJ = self.c[j].variance
				rulLI = self.c[i].rulL
				rulLJ = self.c[j].rulL
				rulUI = self.c[i].rulU
				rulUJ = self.c[j].rulU
				rulMI = self.c[i].rulM
				rulMJ = self.c[j].rulM
				nIntersc = self.matrixIntersection[i,j]
				
				if (nIntersc > (nI - nIntersc) or nIntersc > (nJ - nIntersc)):
					
					merge = True
					self.gCreated = self.gCreated + 1
					n = int(nI + nJ - nIntersc)
					mean = ((nI * meanI) + (nJ * meanJ))/(nI + nJ)
					meant = ((nI * meantI) + (nJ * meantJ))/(nI + nJ)
					variance = ((nI - 1) * varianceI + (nJ - 1) * varianceJ)/(nI + nJ - 2)
					tipicality = ((nI*tipicalityI)+(nJ*tipicalityJ))/(nI + nJ)

					newCloud = DataCloud(X,self.k-1,self.gCreated,self.rho,self.m,self.nI,self.nR,self.nO,
									[self.N1,self.N2,self.N3],self.tau,self.mode, self.act)
					for id in trackI:
						newCloud.track.append(id)
					for id in trackJ:
						newCloud.track.append(id)
						
					newCloud.updateDataCloud(n,mean,meant,variance,tipicality,self.k,X)

					x = self.c[i].x + self.c[j].x
					t = self.c[i].t + self.c[j].t
					t2 = self.c[i].t2 + self.c[j].t2

					rulM = rulMI + rulMJ
					rulL = rulLI + rulLJ
					rulU = rulUI + rulUJ
					
					mat = np.array(list(zip(t,x)), dtype=object)
					col = mat[:, 0].astype(int) 
					_, index = np.unique(col, return_index=True)
					result = mat[np.sort(index)]
					t = result[:, 0].tolist()
					x = result[:, 1].tolist()

					#mat = np.array(list(zip(t2,rulL,rulM,rulU)), dtype=object)
					#col = mat[:, 0].astype(int) 
					#_, index = np.unique(col, return_index=True)
					#result = mat[np.sort(index)]
					#t2   = result[:, 0].tolist()
					#rulL = result[:, 1].tolist()
					#rulM = result[:, 2].tolist()
					#rulU = result[:, 3].tolist()
					if np.linalg.norm(newCloud.mean - self.c[j].xIni) > np.linalg.norm(newCloud.mean - self.c[i].xIni):
						newCloud.xIni = (self.c[j].xIni)
					else: 
						newCloud.xIni = (self.c[i].xIni)

					newCloud.x = x
					newCloud.xMax = 0.5*(self.c[i].xMax + self.c[j].xMax)
					newCloud.xMin = 0.5*(self.c[i].xMin + self.c[j].xMin)
					newCloud.t = t
					#newCloud.t2 = t2
					#newCloud.rulL = rulL
					#newCloud.rulM = rulM
					#newCloud.rulU = rulU
					#xMin = np.minimum(xMinI, xMinJ)
					#xMax = np.maximum(xMaxI, xMaxJ)
					#newCloud.xMin = xMin
					#newCloud.xMax = xMax	
					newCloud.AdjustBounds(X,self.k)
						
					self.MergeCloudsRNN(self.c[i],self.c[j],newCloud)
					newCloud.merge = f'G{self.gCreated}: G{idI}+G{idJ}'

					self.cloud_activation.append(newCloud)
					self.aux = np.append(self.aux,newCloud.ID)

					self.listIntersection = np.concatenate((self.listIntersection[0 : i], np.array([1]), self.listIntersection[i + 1 : j],self.listIntersection[j + 1 : np.size(self.listIntersection)]),axis=None)
					self.c = np.concatenate((self.c[0 : i ], np.array([newCloud]), self.c[i + 1 : j],self.c[j + 1 : np.size(self.c)]),axis=None)
					M0 = self.matrixIntersection
					M1=np.concatenate((M0[0 : i , :],np.zeros((1,len(M0))),M0[i + 1 : j, :],M0[j + 1 : len(M0), :]))
					M1=np.concatenate((M1[:, 0 : i ],np.zeros((len(M1),1)),M1[:, i+1 : j],M1[:, j+1 : len(M0)]),axis=1)
					col = (M0[:, i] + M0[:, j])*(M0[: , i]*M0[:, j] != 0)
					col = np.concatenate((col[0 : j], col[j + 1 : np.size(col)]))
					lin = (M0[i, :]+M0[j, :])*(M0[i, :]*M0[j, :] != 0)
					lin = np.concatenate((lin[ 0 : j], lin[j + 1 : np.size(lin)]))
					M1[:,i]=col
					M1[i,:]=lin
					M1[i, i + 1 : j] = M0[i, i + 1 : j] + M0[i + 1 : j, j].T;   
					self.matrixIntersection = M1

				j += 1
			if(merge): 
				i = 0
			else: i += 1

	def run(self,X):
		self.alfa = np.zeros((np.size(self.c)),dtype=float)
		self.listIntersection = np.zeros((np.size(self.c)),dtype=int)
		if self.k==1:
			self.xR = X
			self.CreateCloud(X,self.k,self.store)
			self.alfa = np.ones(1)

			self.gm = DataCloud(X,(self.k-1),'GM',self.rho,self.m,self.nI,self.nR,self.nO,
					[self.N1,self.N2,self.N3],self.tau,self.mode, self.act)
			#self.gm = self.c[0]

		elif self.k==2:

			#self.gm.updateMaterCloud(self.k,X,self.store)
			#self.gm.AdjustBounds(X,self.k)
			self.c[0].Vref = self.gm.Vref
			
			self.c[0].addDataClaud(X,self.k,self.store)
			v = self.c[0].variance
			n = self.c[0].n
			self.alfa = np.ones(1)
			self.c[0].AdjustBounds(X,self.k)

			#self.gm = self.c[0]

			
		elif self.k>=3:
			i=0
			createCloud = True
			params = [[] for l in range(len(self.c))]
			#self.gm.updateMaterCloud(self.k,X,self.store)
			#self.gm.AdjustBounds(X,self.k)

			for i,cloud in enumerate(self.c):
				cloud.Vref = self.gm.Vref
				n = cloud.n +1
				m = ((n-1)/n)*cloud.mean + (1/n)*X
				mT = ((n-1)/n) * cloud.meant + (X.dot(X))/n
				v = mT-m.dot(m)
				ecc = ((1/n)+((m-X).T.dot(m-X))/(n*v))
				n_ecc = ((1/n)+((m-X).T.dot(m-X))/(n*v))/2
				n_tip = (1 - (((1/n)+((m-X).T.dot(m-X))/((n*v))-(1e-12))))/(self.k-2)
		
				if(n_ecc<=(self.m**2 +1)/(2*n)):
					
					createCloud= False
					params[i] = [n,m,mT,v,n_tip]
					self.alfa[i] = n_tip
					self.listIntersection[i] = 1
				else:
					self.alfa[i] = 0
					self.listIntersection[i] = 0
				i+=1

			if self.wtaG: 
				self.alfa = np.where(self.alfa<np.max(self.alfa),0,self.alfa)
				self.listIntersection = np.where(self.alfa>0,1,self.alfa)
			
			for i,cloud in enumerate(self.c):
				if self.alfa[i]>0:
					#print(self.k,cloud.ID)
					n,m,mT,v,n_tip = params[i]
					cloud.updateDataCloud(n,m,mT,v,n_tip,self.k,X,self.store)
					cloud.AdjustBounds(X,self.k)
					#cloud.ecc = np.append(cloud.ecc,ecc)
					#print(ecc, np.sum(cloud.ecc))
				#cloud.CalculateSpCov(self.k)

			if(createCloud):
				self.CreateCloud(X,self.store)
				self.listIntersection = np.insert(self.listIntersection,i,1)
				self.matrixIntersection = np.pad(self.matrixIntersection, ((0,1),(0,1)), 'constant', constant_values=(0)) 
				self.c[-1].t.append(self.k)
				self.c[-1].R = 0
				
				self.DefRnnParams(self.c[-1])
				self.alfa = np.append(self.alfa,1)
			
			if not self.wtaG: 
				self.mergeClouds(X)

			self.CalculateSpCov()

		#if self.k >1:
		#	self.CalculateSpCov()

		self.AdjustCloudMaster(self.k,X)
		self.cycleP = np.append(self.cycleP,self.st+self.k-1)
		self.rulR_Train = np.append(self.rulR_Train,self.end-self.k)
		self.k=self.k+1

# %%
params =  {'nI': 3, 'nR': 3, 'nO': 3, 'N1': 0.1, 'N2': 0.0001, 'N3': 0.001,
            'τ': 23, 'mode': 'Ahead', 'act': 'tanh'}

nI,nR,nO,N1,N2,N3,τ,mode,act= list(params.values())
X,Y,Z = PrepareDataPast2(RS,HI,n=nI,m=nO)
X,Y,Z = PrepareDataAhead2(RS,HI,n=nI,m=nO)

teda=AutoCloud(m=2.5,nI=nI,nR=nR,nO=nO,ηS=[N1,N2,N3],mode=mode,
               tau=τ,rho=0.01,eol=0.3,ref=len(sig)-nI,wtaG=True,wtaP=True) 
for j,_ in enumerate(X[:]):
    teda.run(X[j])
    teda.RULInterv(Y[j])
    teda.Adapt(Y[j],Z[j])

teda.RUL_Granularity()
print(teda.V)
#print(teda.vSum)  
#PlotDSI_2D_PLT(teda,ftrs=3,ncol=2,language='en')
PlotDSI_3D_PLT(teda,language='en',anchor=(0.85, -0.05),ncol=5,xi=0,xf=108,yi=0,w=18,h=6)
teda.c = np.append(teda.c,teda.gm)   
PlotGranulesSpace(teda,w=700,h=700)
# Out:
# 0.09133012264655815

# %%
rates = [1/(10**i) for i in range(1,9)][::-1]
def objective(trial):

    #w = trial.suggest_int('w', 1, 10) 
    m = trial.suggest_float('m', 1.75, 3,step=0.05)
    nI = trial.suggest_int('nI', 2, 40) 
    nR = trial.suggest_int('nR', 1, 50) 
    nO = trial.suggest_int('nO', 1, 30) 
    N1 = trial.suggest_categorical('N1', rates[:]) 
    N2 = trial.suggest_categorical('N2', rates[:-2]) 
    N3 = trial.suggest_categorical('N3', rates[:-2]) 
    τ = trial.suggest_float('τ', 5, 50,step=0.05)
    #rho = trial.suggest_float('rho', 0.0001, 0.5,step=0.0001)
    #wtaG = trial.suggest_categorical('wtaG', ['True','False'])  
    mode = trial.suggest_categorical('mode', ['past',
                                              #'ahead'
                                              ])  
    act = trial.suggest_categorical('act', ['tanh','relu','sigmoid'])  
    
    if mode == 'past':
        if nO > nI:
            raise TrialPruned()
        else:
            X,Y,Z = PrepareDataPast2(RS,HI,n=nI,m=nO)
    
    elif mode == 'ahead':
        X,Y,Z = PrepareDataAhead2(RS,HI,n=nI,m=nO)
        
    teda=AutoCloud(m=m,nI=nI,nR=nR,nO=nO,ηS=[N1,N2,N3],mode=mode,act=act,
                tau=τ,rho=0.01,eol=0.3,ref=len(sig)-nI,wtaG=True,wtaP=True) 
    for j,_ in enumerate(X[:]):
        teda.run(X[j])
        teda.RULInterv(Y[j])
        teda.Adapt(Y[j],Z[j])

        if j == 30:
            erro = MAPE(teda.rulR,teda.rulP)
            if erro > 1:
                raise TrialPruned()

    return MAPE(teda.rulR,teda.rulP)

#pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
pruner=optuna.pruners.HyperbandPruner()

study = optuna.create_study(
    direction='minimize',
    sampler=SelSampler(mode='auto'),
    #pruner=pruner,
    #storage="sqlite:///" + f'Optuna/{FileName}_Prdct.db', study_name=f'P{4}',
    load_if_exists=True)

study.optimize(objective, n_trials=1000)
best_params = study.best_params
params = list(best_params.values())
print('Erro:', study.best_value, 'parameters: ', params)
# Out:
# [I 2026-07-28 15:46:40,662] A new study created in memory with name: no-name-f95495f4-f17c-44ab-8a34-d7638484536c
# [I 2026-07-28 15:46:40,664] Trial 0 pruned.
# [I 2026-07-28 15:46:40,666] Trial 1 pruned.
# [I 2026-07-28 15:46:40,667] Trial 2 pruned.
# [I 2026-07-28 15:46:40,668] Trial 3 pruned.
# [I 2026-07-28 15:46:40,688] Trial 4 finished with value: 0.938545370889409 and parameters: {'m': 2.45, 'nI': 40, 'nR': 2, 'nO': 28, 'N1': 1e-08, 'N2': 0.001, 'N3': 0.01, 'τ': 19, 'mode': 'past', 'act': 'relu'}. Best is trial 4 with value: 0.938545370889409.
# [I 2026-07-28 15:46:41,560] Trial 5 finished with value: 8.627525900084933 and parameters: {'m': 2.15, 'nI': 38, 'nR': 15, 'nO': 8, 'N1': 1e-06, 'N2': 1e-08, 'N3': 1e-07, 'τ': 48, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 4 with value: 0.938545370889409.
# [I 2026-07-28 15:46:41,583] Trial 6 finished with value: 0.938545370889409 and parameters: {'m': 2.8, 'nI': 40, 'nR': 13, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 4 with value: 0.938545370889409.
# [I 2026-07-28 15:46:41,616] Trial 7 finished with value: 0.9449980444384198 and parameters: {'m': 2.15, 'nI': 28, 'nR': 16, 'nO': 2, 'N1': 0.0001, 'N2': 0.001, 'N3': 1e-05, 'τ': 11, 'mode': 'past', 'act': 'relu'}. Best is trial 4 with value: 0.938545370889409.
# [I 2026-07-28 15:46:42,032] Trial 8 finished with value: 0.7226060208883 and parameters: {'m': 2.45, 'nI': 21, 'nR': 18, 'nO': 14, 'N1': 0.1, 'N2': 0.001, 'N3': 0.1, 'τ': 36, 'mode': 'past', 'act': 'relu'}. Best is trial 8 with value: 0.7226060208883.
# [I 2026-07-28 15:46:42,082] Trial 9 finished with value: 0.9430173090816024 and parameters: {'m': 2.55, 'nI': 32, 'nR': 48, 'nO': 9, 'N1': 0.001, 'N2': 1e-08, 'N3': 0.01, 'τ': 28, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 8 with value: 0.7226060208883.
# [I 2026-07-28 15:46:42,089] Trial 10 pruned.
# [I 2026-07-28 15:46:42,095] Trial 11 pruned.
# [I 2026-07-28 15:46:42,127] Trial 12 finished with value: 0.9489501722616935 and parameters: {'m': 1.95, 'nI': 19, 'nR': 1, 'nO': 15, 'N1': 1e-07, 'N2': 0.001, 'N3': 0.0001, 'τ': 35, 'mode': 'past', 'act': 'relu'}. Best is trial 8 with value: 0.7226060208883.
# [I 2026-07-28 15:46:42,493] Trial 13 finished with value: 0.7206989152804747 and parameters: {'m': 2.4, 'nI': 32, 'nR': 23, 'nO': 23, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-06, 'τ': 21, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:43,342] Trial 14 finished with value: 1.93197881754561 and parameters: {'m': 2.05, 'nI': 27, 'nR': 23, 'nO': 22, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-06, 'τ': 35, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:43,377] Trial 15 finished with value: 0.9424974598104406 and parameters: {'m': 1.8, 'nI': 33, 'nR': 35, 'nO': 12, 'N1': 1e-05, 'N2': 1e-07, 'N3': 0.001, 'τ': 20, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:43,384] Trial 16 pruned.
# [I 2026-07-28 15:46:43,391] Trial 17 pruned.
# [I 2026-07-28 15:46:44,310] Trial 18 finished with value: 2.3269398760304756 and parameters: {'m': 1.55, 'nI': 34, 'nR': 19, 'nO': 18, 'N1': 0.1, 'N2': 0.0001, 'N3': 1e-06, 'τ': 31, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:44,317] Trial 19 pruned.
# [I 2026-07-28 15:46:44,352] Trial 20 finished with value: 0.9493515420662977 and parameters: {'m': 2.3, 'nI': 18, 'nR': 28, 'nO': 14, 'N1': 1e-05, 'N2': 1e-05, 'N3': 1e-08, 'τ': 14, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:44,379] Trial 21 finished with value: 0.94030984482637 and parameters: {'m': 2.45, 'nI': 37, 'nR': 6, 'nO': 27, 'N1': 1e-08, 'N2': 0.001, 'N3': 0.0001, 'τ': 21, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:44,385] Trial 22 pruned.
# [I 2026-07-28 15:46:44,412] Trial 23 finished with value: 0.9435269933016832 and parameters: {'m': 2.6500000000000004, 'nI': 31, 'nR': 6, 'nO': 22, 'N1': 0.01, 'N2': 1e-07, 'N3': 0.1, 'τ': 24, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:45,402] Trial 24 finished with value: 8.463128841014312 and parameters: {'m': 3.0, 'nI': 36, 'nR': 37, 'nO': 24, 'N1': 1e-08, 'N2': 0.01, 'N3': 1e-06, 'τ': 30, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:45,997] Trial 25 finished with value: 2.324737443749044 and parameters: {'m': 2.35, 'nI': 40, 'nR': 19, 'nO': 17, 'N1': 0.1, 'N2': 0.001, 'N3': 0.1, 'τ': 42, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:46,529] Trial 26 finished with value: 1.7284232703734366 and parameters: {'m': 2.2, 'nI': 30, 'nR': 8, 'nO': 12, 'N1': 0.1, 'N2': 0.001, 'N3': 0.01, 'τ': 16, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:46,561] Trial 27 finished with value: 0.9472726886985855 and parameters: {'m': 2.7, 'nI': 23, 'nR': 24, 'nO': 21, 'N1': 1e-08, 'N2': 1e-07, 'N3': 1e-06, 'τ': 23, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:47,618] Trial 28 finished with value: 3.002396160523628 and parameters: {'m': 2.05, 'nI': 36, 'nR': 30, 'nO': 28, 'N1': 0.1, 'N2': 0.001, 'N3': 1e-08, 'τ': 32, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:47,628] Trial 29 pruned.
# [I 2026-07-28 15:46:47,639] Trial 30 pruned.
# [I 2026-07-28 15:46:47,669] Trial 31 finished with value: 0.9391460965864747 and parameters: {'m': 2.8, 'nI': 39, 'nR': 14, 'nO': 5, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 47, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:47,718] Trial 32 finished with value: 0.938545370889409 and parameters: {'m': 2.6, 'nI': 40, 'nR': 11, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:47,752] Trial 33 finished with value: 0.9414259808436742 and parameters: {'m': 2.75, 'nI': 35, 'nR': 13, 'nO': 5, 'N1': 0.0001, 'N2': 1e-05, 'N3': 0.01, 'τ': 42, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:48,090] Trial 34 finished with value: 0.925659173192908 and parameters: {'m': 2.95, 'nI': 22, 'nR': 17, 'nO': 11, 'N1': 0.001, 'N2': 0.1, 'N3': 1e-05, 'τ': 38, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:48,123] Trial 35 finished with value: 0.9477032573975797 and parameters: {'m': 3.0, 'nI': 22, 'nR': 17, 'nO': 12, 'N1': 1e-06, 'N2': 0.1, 'N3': 1e-05, 'τ': 39, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:48,157] Trial 36 finished with value: 0.9497460908482046 and parameters: {'m': 2.9000000000000004, 'nI': 17, 'nR': 26, 'nO': 13, 'N1': 0.001, 'N2': 0.1, 'N3': 1e-05, 'τ': 26, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: overflow encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: overflow encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: overflow encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: overflow encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: overflow encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: overflow encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in add
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in add
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in add
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:63: RuntimeWarning: overflow encountered in matmul
#   yP = self.wO @ hP
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:70: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# [I 2026-07-28 15:46:49,007] Trial 37 finished with value: 7.61021853140668 and parameters: {'m': 2.5, 'nI': 26, 'nR': 21, 'nO': 9, 'N1': 0.01, 'N2': 0.1, 'N3': 1e-05, 'τ': 8, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:50,043] Trial 38 finished with value: 7.95890949450214 and parameters: {'m': 2.1, 'nI': 30, 'nR': 27, 'nO': 10, 'N1': 1e-08, 'N2': 0.0001, 'N3': 1e-07, 'τ': 38, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:50,052] Trial 39 pruned.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: overflow encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: overflow encountered in add
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: overflow encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: overflow encountered in add
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: overflow encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: overflow encountered in add
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: invalid value encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: invalid value encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: invalid value encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: overflow encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: overflow encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: overflow encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:63: RuntimeWarning: overflow encountered in matmul
#   yP = self.wO @ hP
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:70: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# [I 2026-07-28 15:46:51,175] Trial 40 finished with value: 7.333708509763312 and parameters: {'m': 1.95, 'nI': 21, 'nR': 42, 'nO': 16, 'N1': 0.001, 'N2': 0.1, 'N3': 0.1, 'τ': 11, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:51,207] Trial 41 finished with value: 0.9397341171966246 and parameters: {'m': 2.9000000000000004, 'nI': 38, 'nR': 13, 'nO': 3, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 45, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:51,244] Trial 42 finished with value: 0.9445170741407074 and parameters: {'m': 2.8, 'nI': 29, 'nR': 9, 'nO': 7, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 33, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:51,273] Trial 43 finished with value: 0.9424974598104406 and parameters: {'m': 2.55, 'nI': 33, 'nR': 16, 'nO': 10, 'N1': 0.001, 'N2': 0.001, 'N3': 0.001, 'τ': 46, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:52,205] Trial 44 finished with value: 8.627525900084933 and parameters: {'m': 2.95, 'nI': 38, 'nR': 22, 'nO': 30, 'N1': 1e-05, 'N2': 1e-08, 'N3': 1e-05, 'τ': 36, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:52,213] Trial 45 pruned.
# [I 2026-07-28 15:46:52,263] Trial 46 finished with value: 0.88973283333228 and parameters: {'m': 2.7, 'nI': 27, 'nR': 18, 'nO': 4, 'N1': 0.001, 'N2': 0.001, 'N3': 0.1, 'τ': 40, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:53,048] Trial 47 finished with value: 2.807538548826005 and parameters: {'m': 2.7, 'nI': 27, 'nR': 25, 'nO': 3, 'N1': 0.1, 'N2': 0.001, 'N3': 0.1, 'τ': 37, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: overflow encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: overflow encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: overflow encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: invalid value encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: invalid value encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: invalid value encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: overflow encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: overflow encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: overflow encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:63: RuntimeWarning: overflow encountered in matmul
#   yP = self.wO @ hP
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:70: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# [I 2026-07-28 15:46:53,470] Trial 48 finished with value: 6.887564501733289 and parameters: {'m': 2.6, 'nI': 23, 'nR': 18, 'nO': 7, 'N1': 1e-06, 'N2': 0.001, 'N3': 0.1, 'τ': 33, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:53,508] Trial 49 finished with value: 0.9475545627744733 and parameters: {'m': 2.45, 'nI': 16, 'nR': 15, 'nO': 11, 'N1': 0.001, 'N2': 0.001, 'N3': 0.1, 'τ': 40, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:53,539] Trial 50 finished with value: 0.9463878838796309 and parameters: {'m': 2.6, 'nI': 25, 'nR': 29, 'nO': 14, 'N1': 1e-08, 'N2': 0.0001, 'N3': 1e-07, 'τ': 22, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:54,172] Trial 51 finished with value: 2.716481392719389 and parameters: {'m': 2.8, 'nI': 20, 'nR': 11, 'nO': 1, 'N1': 0.001, 'N2': 0.001, 'N3': 0.1, 'τ': 44, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:54,204] Trial 52 finished with value: 0.9449980444384198 and parameters: {'m': 2.75, 'nI': 28, 'nR': 21, 'nO': 4, 'N1': 0.001, 'N2': 1e-07, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:54,234] Trial 53 finished with value: 0.9468343048875675 and parameters: {'m': 2.4, 'nI': 24, 'nR': 13, 'nO': 6, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 18, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:55,075] Trial 54 finished with value: 3.077337565973247 and parameters: {'m': 2.9000000000000004, 'nI': 33, 'nR': 20, 'nO': 3, 'N1': 0.1, 'N2': 0.001, 'N3': 1e-08, 'τ': 48, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:55,105] Trial 55 finished with value: 0.9414259808436742 and parameters: {'m': 2.5, 'nI': 35, 'nR': 7, 'nO': 28, 'N1': 0.01, 'N2': 1e-06, 'N3': 0.0001, 'τ': 20, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:55,137] Trial 56 finished with value: 0.9489501722616935 and parameters: {'m': 2.7, 'nI': 19, 'nR': 24, 'nO': 14, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.1, 'τ': 35, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:55,168] Trial 57 finished with value: 0.9435269933016832 and parameters: {'m': 2.3, 'nI': 31, 'nR': 18, 'nO': 26, 'N1': 0.0001, 'N2': 1e-07, 'N3': 0.001, 'τ': 40, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: overflow encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: overflow encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: overflow encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: invalid value encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: invalid value encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: invalid value encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: overflow encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: overflow encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: overflow encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:63: RuntimeWarning: overflow encountered in matmul
#   yP = self.wO @ hP
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:70: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# [I 2026-07-28 15:46:56,151] Trial 58 finished with value: 7.552097737786646 and parameters: {'m': 2.55, 'nI': 26, 'nR': 32, 'nO': 16, 'N1': 1e-07, 'N2': 0.1, 'N3': 1e-06, 'τ': 38, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:56,978] Trial 59 finished with value: 2.820538416586092 and parameters: {'m': 2.95, 'nI': 40, 'nR': 23, 'nO': 22, 'N1': 0.1, 'N2': 0.001, 'N3': 0.01, 'τ': 13, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,012] Trial 60 finished with value: 0.954953487781344 and parameters: {'m': 2.6500000000000004, 'nI': 2, 'nR': 3, 'nO': 2, 'N1': 1e-08, 'N2': 1e-08, 'N3': 1e-05, 'τ': 44, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,041] Trial 61 finished with value: 0.938545370889409 and parameters: {'m': 2.4, 'nI': 40, 'nR': 11, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,071] Trial 62 finished with value: 0.94030984482637 and parameters: {'m': 2.6, 'nI': 37, 'nR': 15, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,100] Trial 63 finished with value: 0.9391460965864747 and parameters: {'m': 2.85, 'nI': 39, 'nR': 12, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 25, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,129] Trial 64 finished with value: 0.9408736736415613 and parameters: {'m': 2.75, 'nI': 36, 'nR': 5, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 46, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,420] Trial 65 finished with value: 7.070542814940405 and parameters: {'m': 2.55, 'nI': 34, 'nR': 1, 'nO': 5, 'N1': 0.1, 'N2': 0.001, 'N3': 0.1, 'τ': 49, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,449] Trial 66 finished with value: 0.9397341171966246 and parameters: {'m': 2.6500000000000004, 'nI': 38, 'nR': 8, 'nO': 8, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-08, 'τ': 16, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,484] Trial 67 finished with value: 0.9430173090816024 and parameters: {'m': 2.5, 'nI': 32, 'nR': 50, 'nO': 24, 'N1': 1e-06, 'N2': 1e-07, 'N3': 1e-06, 'τ': 43, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,518] Trial 68 finished with value: 0.9477032573975797 and parameters: {'m': 2.2, 'nI': 22, 'nR': 20, 'nO': 18, 'N1': 1e-08, 'N2': 0.0001, 'N3': 0.01, 'τ': 34, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: overflow encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: overflow encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: overflow encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: invalid value encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: invalid value encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: invalid value encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in add
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in add
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in add
#   uU = (wRU @ hU) + (wIU @ xU)
# [I 2026-07-28 15:46:57,573] Trial 69 finished with value: 2.1944306494320034 and parameters: {'m': 2.6, 'nI': 39, 'nR': 16, 'nO': 4, 'N1': 1e-07, 'N2': 0.1, 'N3': 1e-07, 'τ': 37, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,936] Trial 70 finished with value: 0.990432877826043 and parameters: {'m': 2.3, 'nI': 35, 'nR': 10, 'nO': 6, 'N1': 0.1, 'N2': 0.001, 'N3': 0.0001, 'τ': 21, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:57,967] Trial 71 finished with value: 0.938545370889409 and parameters: {'m': 2.4, 'nI': 40, 'nR': 11, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:58,364] Trial 72 finished with value: 7.210695566131208 and parameters: {'m': 2.4, 'nI': 37, 'nR': 14, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 42, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:59,280] Trial 73 finished with value: 8.455155608775293 and parameters: {'m': 1.5, 'nI': 40, 'nR': 18, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 39, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:59,311] Trial 74 finished with value: 0.9391460965864747 and parameters: {'m': 2.35, 'nI': 39, 'nR': 9, 'nO': 29, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 40, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:59,374] Trial 75 finished with value: 0.94030984482637 and parameters: {'m': 2.45, 'nI': 37, 'nR': 15, 'nO': 3, 'N1': 0.01, 'N2': 1e-05, 'N3': 1e-05, 'τ': 31, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:46:59,408] Trial 76 finished with value: 0.9493515420662977 and parameters: {'m': 2.3, 'nI': 18, 'nR': 12, 'nO': 13, 'N1': 0.001, 'N2': 1e-06, 'N3': 0.1, 'τ': 45, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:00,408] Trial 77 finished with value: 7.8937887252440415 and parameters: {'m': 2.85, 'nI': 29, 'nR': 17, 'nO': 1, 'N1': 1e-05, 'N2': 0.01, 'N3': 0.01, 'τ': 19, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:00,437] Trial 78 finished with value: 0.9397341171966246 and parameters: {'m': 2.45, 'nI': 38, 'nR': 6, 'nO': 23, 'N1': 0.0001, 'N2': 0.1, 'N3': 0.001, 'τ': 37, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:00,446] Trial 79 pruned.
# [I 2026-07-28 15:47:01,808] Trial 80 finished with value: 6.447213239016557 and parameters: {'m': 2.95, 'nI': 36, 'nR': 21, 'nO': 15, 'N1': 0.001, 'N2': 1e-07, 'N3': 1e-05, 'τ': 47, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:01,870] Trial 81 finished with value: 0.938545370889409 and parameters: {'m': 2.4, 'nI': 40, 'nR': 11, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:01,931] Trial 82 finished with value: 0.938545370889409 and parameters: {'m': 2.35, 'nI': 40, 'nR': 10, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:01,992] Trial 83 finished with value: 0.9391460965864747 and parameters: {'m': 2.4, 'nI': 39, 'nR': 12, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:02,056] Trial 84 finished with value: 0.9419671275825564 and parameters: {'m': 2.2, 'nI': 34, 'nR': 14, 'nO': 5, 'N1': 1e-08, 'N2': 1e-05, 'N3': 0.01, 'τ': 38, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:02,121] Trial 85 finished with value: 0.9397341171966246 and parameters: {'m': 2.25, 'nI': 38, 'nR': 16, 'nO': 3, 'N1': 0.001, 'N2': 0.001, 'N3': 0.1, 'τ': 36, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:03,801] Trial 86 finished with value: 8.455155608775293 and parameters: {'m': 2.7, 'nI': 40, 'nR': 22, 'nO': 1, 'N1': 0.001, 'N2': 1e-08, 'N3': 0.01, 'τ': 44, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:05,023] Trial 87 finished with value: 3.060752614808076 and parameters: {'m': 2.45, 'nI': 24, 'nR': 3, 'nO': 7, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.01, 'τ': 40, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:05,090] Trial 88 finished with value: 0.9454699982436243 and parameters: {'m': 2.55, 'nI': 27, 'nR': 7, 'nO': 11, 'N1': 0.001, 'N2': 0.1, 'N3': 0.1, 'τ': 42, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:05,172] Trial 89 finished with value: 0.94030984482637 and parameters: {'m': 2.75, 'nI': 37, 'nR': 9, 'nO': 27, 'N1': 1e-06, 'N2': 0.001, 'N3': 1e-07, 'τ': 27, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:07,397] Trial 90 finished with value: 7.4610923174081 and parameters: {'m': 3.0, 'nI': 23, 'nR': 13, 'nO': 17, 'N1': 1e-08, 'N2': 0.0001, 'N3': 1e-08, 'τ': 39, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:07,462] Trial 91 finished with value: 0.938545370889409 and parameters: {'m': 2.4, 'nI': 40, 'nR': 11, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:07,528] Trial 92 finished with value: 0.9391460965864747 and parameters: {'m': 2.5, 'nI': 39, 'nR': 14, 'nO': 3, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:07,610] Trial 93 finished with value: 0.9536827015808509 and parameters: {'m': 2.35, 'nI': 6, 'nR': 25, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 46, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:07,674] Trial 94 finished with value: 0.9408736736415613 and parameters: {'m': 2.4, 'nI': 36, 'nR': 11, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 45, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:08,867] Trial 95 finished with value: 1.4199947388315932 and parameters: {'m': 2.8, 'nI': 40, 'nR': 19, 'nO': 1, 'N1': 0.001, 'N2': 1e-06, 'N3': 1e-06, 'τ': 36, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:10,845] Trial 96 finished with value: 3.35687663636338 and parameters: {'m': 2.6500000000000004, 'nI': 38, 'nR': 17, 'nO': 5, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-05, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:10,904] Trial 97 finished with value: 0.9391460965864747 and parameters: {'m': 2.6, 'nI': 39, 'nR': 8, 'nO': 21, 'N1': 1e-07, 'N2': 1e-05, 'N3': 0.0001, 'τ': 38, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:12,460] Trial 98 finished with value: 7.363146934150309 and parameters: {'m': 2.3, 'nI': 25, 'nR': 5, 'nO': 3, 'N1': 0.01, 'N2': 0.001, 'N3': 0.01, 'τ': 34, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: overflow encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: overflow encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: overflow encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:137: RuntimeWarning: invalid value encountered in matmul
#   yP = ( wO @ hP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:138: RuntimeWarning: invalid value encountered in matmul
#   yL = (wOL @ hL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:139: RuntimeWarning: invalid value encountered in matmul
#   yU = (wOU @ hU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: overflow encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: overflow encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: overflow encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:121: RuntimeWarning: invalid value encountered in matmul
#   uP = ( wR @ hP) + ( wI @ xP)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:122: RuntimeWarning: invalid value encountered in matmul
#   uL = (wRL @ hL) + (wIL @ xL)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:123: RuntimeWarning: invalid value encountered in matmul
#   uU = (wRU @ hU) + (wIU @ xU)
# C:\Users\Claudio\AppData\Roaming\Python\Python312\site-packages\numpy\core\numeric.py:925: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:70: RuntimeWarning: overflow encountered in multiply
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:61: RuntimeWarning: overflow encountered in matmul
#   uP = self.wR @ self.hP + self.wI @ xP
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:70: RuntimeWarning: invalid value encountered in matmul
#   δRS = η2*np.outer((self.BS@eS),np.ones(self.nR))*self.pS
# c:\Users\Claudio\Desktop\Python\Batteries_Prognostics\Testing\RTLO_R2.py:75: RuntimeWarning: invalid value encountered in add
#   self.wO = self.wO + δOS
# C:\Users\Claudio\AppData\Roaming\Python\Python312\site-packages\numpy\core\numeric.py:925: RuntimeWarning: invalid value encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# [I 2026-07-28 15:47:13,219] Trial 99 finished with value: 5.861867009338154 and parameters: {'m': 2.45, 'nI': 14, 'nR': 35, 'nO': 6, 'N1': 0.001, 'N2': 0.01, 'N3': 0.1, 'τ': 17, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:14,529] Trial 100 finished with value: 6.44256831946301 and parameters: {'m': 1.7, 'nI': 22, 'nR': 27, 'nO': 9, 'N1': 1e-05, 'N2': 1e-05, 'N3': 0.01, 'τ': 42, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:14,591] Trial 101 finished with value: 0.938545370889409 and parameters: {'m': 2.35, 'nI': 40, 'nR': 11, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:14,663] Trial 102 finished with value: 0.938545370889409 and parameters: {'m': 2.25, 'nI': 40, 'nR': 10, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 2, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:14,727] Trial 103 finished with value: 0.9397341171966246 and parameters: {'m': 2.35, 'nI': 38, 'nR': 13, 'nO': 13, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 44, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:14,798] Trial 104 finished with value: 0.9489501722616935 and parameters: {'m': 2.5, 'nI': 19, 'nR': 12, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 40, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:14,860] Trial 105 finished with value: 0.94030984482637 and parameters: {'m': 2.3, 'nI': 37, 'nR': 10, 'nO': 1, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.001, 'τ': 39, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:14,925] Trial 106 finished with value: 0.9414259808436742 and parameters: {'m': 2.4, 'nI': 35, 'nR': 15, 'nO': 3, 'N1': 0.001, 'N2': 0.1, 'N3': 0.01, 'τ': 48, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:16,736] Trial 107 finished with value: 3.4021433529442704 and parameters: {'m': 2.2, 'nI': 39, 'nR': 9, 'nO': 6, 'N1': 0.1, 'N2': 1e-07, 'N3': 1e-06, 'τ': 45, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:16,801] Trial 108 finished with value: 0.9430173090816024 and parameters: {'m': 2.55, 'nI': 32, 'nR': 7, 'nO': 5, 'N1': 1e-08, 'N2': 1e-05, 'N3': 0.1, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:18,656] Trial 109 finished with value: 8.631780673000982 and parameters: {'m': 2.4, 'nI': 40, 'nR': 18, 'nO': 25, 'N1': 0.001, 'N2': 0.001, 'N3': 1e-05, 'τ': 42, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:18,717] Trial 110 finished with value: 0.9397341171966246 and parameters: {'m': 2.7, 'nI': 38, 'nR': 14, 'nO': 3, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 14, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:18,779] Trial 111 finished with value: 0.938545370889409 and parameters: {'m': 2.4, 'nI': 40, 'nR': 11, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:20,868] Trial 112 finished with value: 8.692395309959997 and parameters: {'m': 2.45, 'nI': 39, 'nR': 16, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:20,932] Trial 113 finished with value: 0.94030984482637 and parameters: {'m': 2.35, 'nI': 37, 'nR': 11, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 39, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:21,002] Trial 114 finished with value: 0.948541796953083 and parameters: {'m': 2.85, 'nI': 20, 'nR': 12, 'nO': 19, 'N1': 0.001, 'N2': 1e-08, 'N3': 0.01, 'τ': 20, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:21,065] Trial 115 finished with value: 0.938545370889409 and parameters: {'m': 2.45, 'nI': 40, 'nR': 9, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 47, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:22,863] Trial 116 finished with value: 2.5113239299646883 and parameters: {'m': 2.5, 'nI': 39, 'nR': 13, 'nO': 14, 'N1': 0.1, 'N2': 1e-05, 'N3': 0.1, 'τ': 37, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:22,926] Trial 117 finished with value: 0.944026817430357 and parameters: {'m': 2.35, 'nI': 30, 'nR': 7, 'nO': 2, 'N1': 0.001, 'N2': 0.1, 'N3': 1e-08, 'τ': 40, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:22,989] Trial 118 finished with value: 0.9408736736415613 and parameters: {'m': 2.15, 'nI': 36, 'nR': 5, 'nO': 8, 'N1': 1e-06, 'N2': 0.0001, 'N3': 1e-07, 'τ': 22, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:23,046] Trial 119 finished with value: 0.9397341171966246 and parameters: {'m': 2.55, 'nI': 38, 'nR': 2, 'nO': 18, 'N1': 1e-08, 'N2': 0.001, 'N3': 0.01, 'τ': 44, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:23,108] Trial 120 finished with value: 0.938545370889409 and parameters: {'m': 2.25, 'nI': 40, 'nR': 22, 'nO': 16, 'N1': 0.001, 'N2': 1e-07, 'N3': 1e-06, 'τ': 41, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:23,168] Trial 121 finished with value: 0.938545370889409 and parameters: {'m': 2.4, 'nI': 40, 'nR': 10, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:24,826] Trial 122 finished with value: 8.506367785838384 and parameters: {'m': 2.3, 'nI': 39, 'nR': 11, 'nO': 3, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 43, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:26,666] Trial 123 finished with value: 8.661124657508365 and parameters: {'m': 2.35, 'nI': 40, 'nR': 15, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 42, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:27,198] Trial 124 finished with value: 0.94030984482637 and parameters: {'m': 2.4, 'nI': 37, 'nR': 45, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 38, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:27,260] Trial 125 finished with value: 0.9397341171966246 and parameters: {'m': 2.45, 'nI': 38, 'nR': 10, 'nO': 2, 'N1': 1e-07, 'N2': 1e-05, 'N3': 0.0001, 'τ': 45, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:29,105] Trial 126 finished with value: 3.562411371134594 and parameters: {'m': 2.25, 'nI': 39, 'nR': 12, 'nO': 30, 'N1': 0.1, 'N2': 1e-06, 'N3': 1e-05, 'τ': 39, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:29,169] Trial 127 finished with value: 0.9408736736415613 and parameters: {'m': 2.9000000000000004, 'nI': 36, 'nR': 8, 'nO': 5, 'N1': 0.001, 'N2': 0.001, 'N3': 0.01, 'τ': 46, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:30,283] Trial 128 finished with value: 1.0561306855155712 and parameters: {'m': 2.3, 'nI': 39, 'nR': 16, 'nO': 11, 'N1': 0.01, 'N2': 1e-05, 'N3': 0.01, 'τ': 5, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:32,566] Trial 129 finished with value: 7.819488223605961 and parameters: {'m': 2.35, 'nI': 28, 'nR': 13, 'nO': 1, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.1, 'τ': 18, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:32,581] Trial 130 pruned.
# [I 2026-07-28 15:47:32,642] Trial 131 finished with value: 0.938545370889409 and parameters: {'m': 2.1, 'nI': 40, 'nR': 11, 'nO': 2, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 2, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:34,676] Trial 132 finished with value: 8.803801390489072 and parameters: {'m': 2.35, 'nI': 40, 'nR': 9, 'nO': 3, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 30, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:37,000] Trial 133 finished with value: 8.643267043285324 and parameters: {'m': 2.25, 'nI': 38, 'nR': 10, 'nO': 3, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 9, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:39,245] Trial 134 finished with value: 8.822377898354144 and parameters: {'m': 2.5, 'nI': 40, 'nR': 17, 'nO': 2, 'N1': 0.001, 'N2': 0.01, 'N3': 0.01, 'τ': 25, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:39,310] Trial 135 finished with value: 0.9391460965864747 and parameters: {'m': 2.4, 'nI': 39, 'nR': 19, 'nO': 15, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.001, 'τ': 40, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:41,519] Trial 136 finished with value: 8.550270292108182 and parameters: {'m': 2.8, 'nI': 37, 'nR': 6, 'nO': 2, 'N1': 0.0001, 'N2': 0.001, 'N3': 0.01, 'τ': 44, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:43,821] Trial 137 finished with value: 8.64370783082573 and parameters: {'m': 2.6, 'nI': 38, 'nR': 8, 'nO': 4, 'N1': 0.001, 'N2': 1e-05, 'N3': 1e-06, 'τ': 5, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:45,449] Trial 138 finished with value: 1.938088408854976 and parameters: {'m': 2.3, 'nI': 23, 'nR': 12, 'nO': 3, 'N1': 0.1, 'N2': 1e-07, 'N3': 0.01, 'τ': 42, 'mode': 'past', 'act': 'relu'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:47,760] Trial 139 finished with value: 7.67194993022616 and parameters: {'m': 2.6500000000000004, 'nI': 26, 'nR': 20, 'nO': 1, 'N1': 1e-08, 'N2': 1e-05, 'N3': 0.1, 'τ': 50, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:47,820] Trial 140 finished with value: 0.938545370889409 and parameters: {'m': 2.45, 'nI': 40, 'nR': 10, 'nO': 5, 'N1': 0.001, 'N2': 1e-08, 'N3': 1e-05, 'τ': 28, 'mode': 'past', 'act': 'tanh'}. Best is trial 13 with value: 0.7206989152804747.
# [I 2026-07-28 15:47:47,884] Trial 141 finished with value: 0.938545370889409 and parameters: {'m': 2.4, 'nI': 40, 'nR': 11, 'nO': 29, 'N1': 0.001, 'N2': 1e-05, 'N3': 0.01, 'τ': 41, 'mode': 'past', 'act': 'sigmoid'}. Best is trial 13 with value: 0.7206989152804747.
# ...
# [I 2026-07-28 15:56:48,963] Trial 940 finished with value: 1.7689749726589696 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 15, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:49,944] Trial 941 finished with value: 0.5546180906509693 and parameters: {'m': 2.5, 'nI': 29, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:50,899] Trial 942 finished with value: 0.553153386907772 and parameters: {'m': 2.5, 'nI': 29, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:52,895] Trial 943 finished with value: 2.3242607002028643 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:53,869] Trial 944 finished with value: 0.5511600049477388 and parameters: {'m': 2.5, 'nI': 29, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:54,272] Trial 945 finished with value: 0.540759421172826 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:54,658] Trial 946 finished with value: 0.540759421172826 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:55,002] Trial 947 finished with value: 0.5527513180879042 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:56,929] Trial 948 finished with value: 2.229864213797651 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:58,542] Trial 949 finished with value: 1.7796826273126525 and parameters: {'m': 2.5, 'nI': 30, 'nR': 27, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:56:58,964] Trial 950 finished with value: 0.47603467933194293 and parameters: {'m': 2.5, 'nI': 29, 'nR': 28, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:01,007] Trial 951 finished with value: 2.76166854192673 and parameters: {'m': 2.5, 'nI': 31, 'nR': 28, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:02,876] Trial 952 finished with value: 2.3017092370135095 and parameters: {'m': 2.5, 'nI': 29, 'nR': 27, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 9, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:03,180] Trial 953 finished with value: 0.5614225798278553 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:03,555] Trial 954 finished with value: 0.5614225798278553 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:05,723] Trial 955 finished with value: 2.76166854192673 and parameters: {'m': 2.5, 'nI': 31, 'nR': 28, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:07,579] Trial 956 finished with value: 2.071246154453679 and parameters: {'m': 2.45, 'nI': 30, 'nR': 29, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:08,493] Trial 957 finished with value: 0.5543298626320551 and parameters: {'m': 2.5, 'nI': 29, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:08,865] Trial 958 finished with value: 0.5527513180879042 and parameters: {'m': 2.5, 'nI': 30, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:09,231] Trial 959 finished with value: 0.5527513180879042 and parameters: {'m': 2.45, 'nI': 30, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:11,243] Trial 960 finished with value: 2.3242607002028643 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:13,200] Trial 961 finished with value: 2.229864213797651 and parameters: {'m': 2.45, 'nI': 30, 'nR': 29, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:15,086] Trial 962 finished with value: 2.0650156256995102 and parameters: {'m': 2.45, 'nI': 31, 'nR': 27, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:16,284] Trial 963 finished with value: 0.9965602968766567 and parameters: {'m': 2.5, 'nI': 31, 'nR': 29, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 9, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:17,714] Trial 964 finished with value: 1.2180819695601885 and parameters: {'m': 2.5, 'nI': 29, 'nR': 30, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:18,302] Trial 965 finished with value: 0.381824094462243 and parameters: {'m': 2.5, 'nI': 30, 'nR': 27, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:18,895] Trial 966 finished with value: 0.381824094462243 and parameters: {'m': 2.45, 'nI': 30, 'nR': 27, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:19,483] Trial 967 finished with value: 0.381824094462243 and parameters: {'m': 2.45, 'nI': 30, 'nR': 27, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:19,804] Trial 968 finished with value: 0.6060156584143428 and parameters: {'m': 2.45, 'nI': 31, 'nR': 27, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:20,396] Trial 969 finished with value: 0.4019810358655743 and parameters: {'m': 2.45, 'nI': 30, 'nR': 27, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:22,382] Trial 970 finished with value: 2.4446402926948023 and parameters: {'m': 2.45, 'nI': 32, 'nR': 27, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:24,114] Trial 971 finished with value: 1.6957284710107174 and parameters: {'m': 2.45, 'nI': 30, 'nR': 26, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:25,714] Trial 972 finished with value: 2.0233829105943393 and parameters: {'m': 2.45, 'nI': 30, 'nR': 28, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:27,554] Trial 973 finished with value: 1.8883804514179388 and parameters: {'m': 2.5, 'nI': 31, 'nR': 27, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 8, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:28,129] Trial 974 finished with value: 0.3795029122412841 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:30,167] Trial 975 finished with value: 2.530135449851469 and parameters: {'m': 2.5, 'nI': 31, 'nR': 28, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:32,225] Trial 976 finished with value: 2.166148231980234 and parameters: {'m': 2.5, 'nI': 30, 'nR': 26, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:34,281] Trial 977 finished with value: 2.421107456656925 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:36,551] Trial 978 finished with value: 2.841209866319236 and parameters: {'m': 2.5, 'nI': 29, 'nR': 29, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:37,658] Trial 979 finished with value: 0.7988986742352888 and parameters: {'m': 2.5, 'nI': 32, 'nR': 27, 'nO': 21, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 8, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:37,978] Trial 980 finished with value: 0.6076099900888237 and parameters: {'m': 2.45, 'nI': 31, 'nR': 27, 'nO': 22, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:38,483] Trial 981 finished with value: 0.3723881625267416 and parameters: {'m': 2.45, 'nI': 30, 'nR': 28, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:39,003] Trial 982 finished with value: 0.375511053973908 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:39,533] Trial 983 finished with value: 0.375511053973908 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:41,591] Trial 984 finished with value: 2.166148231980234 and parameters: {'m': 2.5, 'nI': 30, 'nR': 26, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 12, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:42,092] Trial 985 finished with value: 0.4188046931754992 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:44,184] Trial 986 finished with value: 2.530227760485949 and parameters: {'m': 2.5, 'nI': 31, 'nR': 28, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:45,943] Trial 987 finished with value: 2.1451219969388844 and parameters: {'m': 2.5, 'nI': 32, 'nR': 27, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 13, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:46,406] Trial 988 finished with value: 0.4251604625067457 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 9, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:46,884] Trial 989 finished with value: 0.4128280479262062 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:47,361] Trial 990 finished with value: 0.4251604625067457 and parameters: {'m': 2.5, 'nI': 30, 'nR': 28, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 9, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:49,222] Trial 991 finished with value: 2.0815176812673957 and parameters: {'m': 2.5, 'nI': 31, 'nR': 27, 'nO': 20, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 9, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:50,595] Trial 992 finished with value: 1.1724740694354212 and parameters: {'m': 2.5, 'nI': 30, 'nR': 26, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 9, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:52,742] Trial 993 finished with value: 2.641122164759286 and parameters: {'m': 2.5, 'nI': 31, 'nR': 28, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 7, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:54,906] Trial 994 finished with value: 2.781587414432773 and parameters: {'m': 2.5, 'nI': 32, 'nR': 28, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:55,457] Trial 995 finished with value: 0.47500689550847724 and parameters: {'m': 2.5, 'nI': 30, 'nR': 26, 'nO': 18, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:57,447] Trial 996 finished with value: 2.7825237440207884 and parameters: {'m': 2.5, 'nI': 32, 'nR': 26, 'nO': 18, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:57,768] Trial 997 finished with value: 0.6299094490023381 and parameters: {'m': 2.5, 'nI': 30, 'nR': 27, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 10, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:59,015] Trial 998 finished with value: 1.319736518638742 and parameters: {'m': 2.45, 'nI': 30, 'nR': 26, 'nO': 19, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 11, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# [I 2026-07-28 15:57:59,514] Trial 999 finished with value: 0.4452776167163482 and parameters: {'m': 2.5, 'nI': 29, 'nR': 28, 'nO': 18, 'N1': 0.1, 'N2': 1e-08, 'N3': 0.001, 'τ': 9, 'mode': 'past', 'act': 'tanh'}. Best is trial 908 with value: 0.3361430461793889.
# Erro: 0.3361430461793889 parameters:  [2.5, 26, 31, 22, 0.1, 1e-08, 1e-06, 17, 'past', 'tanh']

# %% [markdown]
# Erro: 0.14040920446630023 parameters:  [2.35, 21, 44, 29, 1e-08, 1e-07, 1e-05, 12, 'ahead', 'tanh']\
# Erro: 0.3361430461793889 parameters:  [2.5, 26, 31, 22, 0.1, 1e-08, 1e-06, 17, 'past', 'tanh']

# %%
best_params = {'m': 1.55, 'nI': 34, 'nR': 19, 'nO': 18, 'N1': 0.1, 'N2': 0.0001, 'N3': 1e-06, 'τ': 31, 'mode': 'past', 'act': 'tanh'}
params = list(best_params.values())

# %%
m,nI,nR,nO,N1,N2,N3,τ,mode,act= params
if mode == 'past':
    X,Y,Z = PrepareDataPast2(RS,HI,n=nI,m=nO)
else:
    X,Y,Z = PrepareDataAhead2(RS,HI,n=nI,m=nO)

teda=AutoCloud(m=2,nI=nI,nR=nR,nO=nO,ηS=[N1,N2,N3],mode=mode,act=act,
               tau=τ,rho=0.1,eol=0.3,ref=len(sig)-nI,wtaG=True,wtaP=True) 
for j,_ in enumerate(X[:]):
    teda.run(X[j])
    teda.RULInterv(Y[j])
    teda.Adapt(Y[j],Z[j])

teda.RUL_Granularity()
print(teda.V)
#print(teda.vSum)  
#PlotDSI_2D_PLT(teda,ftrs=3,ncol=2,language='en')
PlotDSI_3D_PLT(teda,language='en',anchor=(0.85, -0.05),ncol=5,xi=0,xf=108,yi=0,w=18,h=6)
teda.c = np.append(teda.c,teda.gm)   
#PlotGranulesSpace(teda,w=700,h=700)
# Out:
# 0.010097728609862794

# %%
e=30
yR = teda.rulR[:e]
yP = teda.rulP[:e]

MAPE(yR,yP)
# Out:
# 1.2545537484362386
